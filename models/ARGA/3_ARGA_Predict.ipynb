# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
from openpom.feat.graph_featurizer import GraphFeaturizer, GraphConvConstants
from openpom.utils.data_utils import get_class_imbalance_ratio, IterativeStratifiedSplitter
from openpom.models.mpnn_pom import MPNNPOMModel
from datetime import datetime
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import gaussian_kde
from collections import Counter
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# WARNING:tensorflow:From c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\deepchem\models\torch_models\__init__.py)

# %%
# Odor Labels
TASKS = [
    'alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
    'anisic', 'apple', 'apricot', 'aromatic', 'balsamic', 'banana', 'beefy',
    'bergamot', 'berry', 'bitter', 'black currant', 'brandy', 'burnt',
    'buttery', 'cabbage', 'camphoreous', 'caramellic', 'cedar', 'celery',
    'chamomile', 'cheesy', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clean',
    'clove', 'cocoa', 'coconut', 'coffee', 'cognac', 'cooked', 'cooling',
    'cortex', 'coumarinic', 'creamy', 'cucumber', 'dairy', 'dry', 'earthy',
    'ethereal', 'fatty', 'fermented', 'fishy', 'floral', 'fresh', 'fruit skin',
    'fruity', 'garlic', 'gassy', 'geranium', 'grape', 'grapefruit', 'grassy',
    'green', 'hawthorn', 'hay', 'hazelnut', 'herbal', 'honey', 'hyacinth',
    'jasmin', 'juicy', 'ketonic', 'lactonic', 'lavender', 'leafy', 'leathery',
    'lemon', 'lily', 'malty', 'meaty', 'medicinal', 'melon', 'metallic',
    'milky', 'mint', 'muguet', 'mushroom', 'musk', 'musty', 'natural', 'nutty',
    'odorless', 'oily', 'onion', 'orange', 'orangeflower', 'orris', 'ozone',
    'peach', 'pear', 'phenolic', 'pine', 'pineapple', 'plum', 'popcorn',
    'potato', 'powdery', 'pungent', 'radish', 'raspberry', 'ripe', 'roasted',
    'rose', 'rummy', 'sandalwood', 'savory', 'sharp', 'smoky', 'soapy',
    'solvent', 'sour', 'spicy', 'strawberry', 'sulfurous', 'sweaty', 'sweet',
    'tea', 'terpenic', 'tobacco', 'tomato', 'tropical', 'vanilla', 'vegetable',
    'vetiver', 'violet', 'warm', 'waxy', 'weedy', 'winey', 'woody'
]
len(TASKS)
# Out:
# 138

# %%
input_file = '../../data/curated dataset/curated_GS_LF_merged_4983.csv'
featurizer = GraphFeaturizer()
smiles_field = 'nonStereoSMILES' # column that contains SMILES

# %%
loader = dc.data.CSVLoader(tasks=TASKS,
feature_field=smiles_field,
featurizer=featurizer)

# %%
dataset = loader.create_dataset(inputs=[input_file])
n_tasks = len(dataset.tasks)
randomstratifiedsplitter = dc.splits.RandomStratifiedSplitter()
train_dataset, test_dataset, valid_dataset = randomstratifiedsplitter.train_valid_test_split(dataset, frac_train = 0.8, frac_valid = 0.1, frac_test = 0.1, seed = 1)
train_ratios = get_class_imbalance_ratio(train_dataset)

# %%
assert len(train_ratios) == n_tasks

# %%
learning_rate = dc.models.optimizers.ExponentialDecay(initial_rate=0.001, decay_rate=0.5, decay_steps=32*20, staircase=True)

# %%
model = MPNNPOMModel(n_tasks = n_tasks,
                     batch_size = 128,
                     learning_rate = learning_rate,
                     class_imbalance_ratio = train_ratios,
                     loss_aggr_type = 'sum',
                     node_out_feats = 100,
                     edge_hidden_feats = 75,
                     edge_out_feats = 100,
                     num_step_message_passing = 5,
                     mpnn_residual = True,
                     message_aggregator_type = 'sum',
                     mode = 'classification',
                     number_atom_features = GraphConvConstants.ATOM_FDIM,
                     number_bond_features = GraphConvConstants.BOND_FDIM,
                     n_classes = 1,
                     readout_type = 'set2set',
                     num_step_set2set = 3,
                     num_layer_set2set = 2,
                     ffn_hidden_list = [392, 392],
                     ffn_embeddings = 256,
                     ffn_activation = 'relu',
                     ffn_dropout_p = 0.12,
                     ffn_dropout_at_input_no_act = False,
                     weight_decay = 1e-5,
                     self_loop = False,
                     optimizer_name = 'adam',
                     log_frequency = 32,
                     model_dir = './experiments',
                     device_name ='cpu')

# %%
# Load the saved model state
import torch
checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
if 'model_state_dict' in checkpoint:
    model.model.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    model.model.load_state_dict(checkpoint, strict=False)
model.model.eval()
# Out:
# C:\Users\sarab\AppData\Local\Temp\ipykernel_18452\1392124263.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
# MPNNPOM(
#   (mpnn): CustomMPNNGNN(
#     (project_node_feats): Sequential(
#       (0): Linear(in_features=134, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (gnn_layer): NNConv(
#       (edge_func): Sequential(
#         (0): Linear(in_features=6, out_features=75, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=75, out_features=10000, bias=True)
#       )
#       (res_fc): Identity()
#     )
#     (gru): GRU(100, 100)
#   )
#   (project_edge_feats): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#   )
#   (readout_set2set): Set2Set(
#     n_iters=3
#     (lstm): LSTM(400, 200, num_layers=2)
#   )
#   (ffn): CustomPositionwiseFeedForward(
#     (activation): ReLU()
#     (linears): ModuleList(
#       (0): Linear(in_features=400, out_features=392, bias=True)
#       (1): Linear(in_features=392, out_features=392, bias=True)
#       (2): Linear(in_features=392, out_features=256, bias=True)
#       (3): Linear(in_features=256, out_features=138, bias=True)
#     )
#     (dropout_p): ModuleList(
#       (0-3): 4 x Dropout(p=0.12, inplace=False)
#     )
#     (batchnorms): ModuleList(
#       (0-1): 2 x BatchNorm1d(392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
csv_file_path = '../../data/ARGA/logistic equation/novel_odorrous_set_log_eq.csv'
df = pd.read_csv(csv_file_path)

# %%
smiles_list = df['SMILE'].tolist()
print(smiles_list)


featurizer = GraphFeaturizer()
featurized_data = featurizer.featurize(smiles_list)


all_top_odors = []
problematic_smiles = []

for i, featurized_mol in enumerate(featurized_data):
    try:
        
        single_mol_dataset = dc.data.NumpyDataset([featurized_mol])

        
        prediction = model.predict(single_mol_dataset)

        
        odor_probs = prediction.squeeze()
        high_prob_indices = np.where(odor_probs > 0.5)[0]
        
        
        sorted_indices = high_prob_indices[np.argsort(odor_probs[high_prob_indices])[::-1]]
        
        
        top_odors = [TASKS[i] for i in sorted_indices]
        all_top_odors.extend(top_odors)

        
        print(f"\nTop odors for {smiles_list[i]} (probability > 0.5):")
        for odor, score in zip(top_odors, odor_probs[sorted_indices]):
            print(f"{odor}: {score:.4f}")

    except KeyError as e:
        print(f"\nError processing SMILES: {smiles_list[i]}")
        print(f"Error message: {str(e)}")
        problematic_smiles.append(smiles_list[i])
        continue
# Out:
# ['CCCCC(O)O', 'CC1C=CCC=C1', 'CC1=CC(C(C)(C)C)=CCC1', 'CC1CC1', 'CCOc1ccsc1', 'CCCSCS', 'C=CCNCCCCCCCC', 'CCCC(C)C', 'C=C(C)O', 'CCC1=CC=CC1', 'C1=CC=S2SC=CC=C2C=1', 'C1COSC1', 'c1csc2cccc-2c1', 'CC(C)CC(C)S', 'CC1CCOC1', 'COCC(O)S', 'CCCC(C)SCS', 'CCCCC(C)S', 'SS', 'CCSC1C=CCCC1', 'SC1CCCSC1', 'C1CCSCC1', 'CCCCC(S)OC', 'CCCCc1ccccc1', 'CC(S)CSC1CCCS1', 'SOSCCC1C=CCS1', 'CCSO', 'CC(O)CC1C=CC=CC1', 'CCc1coc(C)c1', 'C1CC1', 'CC1CCC(C(C)C)C1', 'CCCCC(C)OC', 'c1ccccc1', 'CCSCCCSS', 'Cc1cnc2c(c1)=CCCC=2', 'CCCCCCC(CC)Cc1ccccc1', 'CC1C=CCS1', 'CCCCOC', 'C=CCCCCCCCCSSC', 'SN1CCCCCC1', 'SC1=CC2C=CCC2=CC1', 'CCC(C)C', 'CCSSO', 'CCC', 'CSCCS(C)(C)S', 'CC1C=C(S)CS1', 'CCCCCSCC', 'CCCCOCC', 'C=C=C', 'CCCCCOC', 'CC1CCCCC1', 'C1CCCC1', 'CCCc1ccccc1', 'CCCCCCSC', 'CC(C)C', 'CCCCSC1=C=S=C=CS1', 'CC(C)(O)S', 'C=CCCCCSC', 'CCCCC', 'CSSC(C)C', 'CCCC(CCC)C1=CC=CC1', 'CCCC(C)CC', 'C1=CCSC1', 'CC1=CSCC1C', 'CC1CC(C(C)C)CS1', 'C1=CC1', 'CC(C)(C)C', 'CCCC(C)c1ccccc1', 'C=C1C=C(CS)CC1', 'OCCCSCS', 'CCCCSS', 'CC(C)SS', 'CC1CCCC1', 'CCCC', 'C1=CCC=C1', 'CCCCCC', 'CCC(C)CC(C)C', 'CCCC(C)SC', 'CCOC', 'C=C(C)C(C)C', 'CS1=NC=CS1', 'C=CC', 'CCCC(C)CSC', 'C=CCOCCC1=CCCSC1', 'Sc1cc2c(s1)=COSC=2', 'C=C(C)C', 'CC1(S)C=CCCC1', 'CC=CCCC', 'C=S=S=CCCCC', 'C=CSCC', 'C=CC(C)(C)S', 'C=S(CCC)C(S)(CCCS)SS', 'C=[SH](=C=CC)CC', 'CSCCC=S', 'CC(C)CCCC(C)S', 'CCCC(C)C1=CC=CSC1', 'CSO', 'CCCSSSCO', 'C=CCC', 'CCCCCCC(C)CC(C)S', 'CC1CCC(CO)C1', 'OS', 'COS', 'CCC1=S(O)C=C(C)C1', 'CCSCC(C)O', 'S=S1C=CCSO1', 'CC1CCSC1', 'CCCC(C)C(CC)CC', 'CS1=CC=C(S2=CC=CC=C2)C=C1', 'CCCCC(C)C(C)CCS', 'CSNCS', 'CCCC(CCC)CCSC', 'CCSCO', 'CC1=CCC=C1', 'CC1SC=CSS1', 'CCCCCCSCC', 'CCCSCCCS', 'CC1CCCC(C)C1', 'CSc1cccs1', 'CC(O)CCCCCCCCS', 'CCC(C)C(C)C', 'CCCCCc1ccccc1', 'CC', 'SCCCC1=CCC=C1', 'COCC1CSCCS1', 'CCCC=S(=S)=CSS', 'CCCCC(C)CCO', 'OC(CS)C1C=CC=CC1', 'COC1C=CSC(C)C1', 'CC=S(C)CSC', 'CCCSCO', 'CCCSC=S', 'C=C(CCCO)CCCOCC', 'CC(C)C1CCCOC1(C)C', 'CCCCSCSCCCC(C)C', 'CCCCCCCSS', 'CCCCOC1CCCC1', 'C=S1CCCCC1', 'CC1CCCC1S(C)=O', 'CC1CS1']
#
# Top odors for CCCCC(O)O (probability > 0.5):
# fruity: 0.7785
# oily: 0.5157
# sweet: 0.5092
#
# Top odors for CC1C=CCC=C1 (probability > 0.5):
# citrus: 0.5315
#
# Top odors for CC1=CC(C(C)(C)C)=CCC1 (probability > 0.5):
# woody: 0.8535
# sweet: 0.5835
# herbal: 0.5647
# floral: 0.5346
# fresh: 0.5284
# citrus: 0.5213
# pine: 0.5121
# terpenic: 0.5111
#
# Top odors for CC1CC1 (probability > 0.5):
# woody: 0.6998
# amber: 0.5660
# musk: 0.5548
#
# Top odors for CCOc1ccsc1 (probability > 0.5):
# sweet: 0.6825
# spicy: 0.6066
# floral: 0.5227
#
# Top odors for CCCSCS (probability > 0.5):
# sulfurous: 0.8483
# onion: 0.6586
# meaty: 0.6269
# garlic: 0.6168
# alliaceous: 0.5626
# vegetable: 0.5530
# savory: 0.5459
#
# Top odors for C=CCNCCCCCCCC (probability > 0.5):
# fishy: 0.5462
#
# Top odors for CCCC(C)C (probability > 0.5):
# green: 0.6614
# herbal: 0.5785
# musty: 0.5105
#
# Top odors for C=C(C)O (probability > 0.5):
# pungent: 0.5576
# sharp: 0.5349
#
# Top odors for CCC1=CC=CC1 (probability > 0.5):
# citrus: 0.6220
# woody: 0.5356
#
# Top odors for C1=CC=S2SC=CC=C2C=1 (probability > 0.5):
# sulfurous: 0.6953
#
# Top odors for C1COSC1 (probability > 0.5):
# sulfurous: 0.6932
# meaty: 0.5220
#
# Top odors for c1csc2cccc-2c1 (probability > 0.5):
# sulfurous: 0.7955
# burnt: 0.5587
# pungent: 0.5463
# garlic: 0.5082
# alliaceous: 0.5057
#
# Top odors for CC(C)CC(C)S (probability > 0.5):
# sulfurous: 0.8513
# meaty: 0.6166
# grapefruit: 0.6084
# fruity: 0.6021
# tropical: 0.5940
# black currant: 0.5206
#
# Top odors for CC1CCOC1 (probability > 0.5):
# solvent: 0.6844
# ethereal: 0.6445
# mint: 0.5113
# sweet: 0.5051
#
# Top odors for COCC(O)S (probability > 0.5):
#
# Top odors for CCCC(C)SCS (probability > 0.5):
# sulfurous: 0.8243
# onion: 0.5893
# meaty: 0.5823
# green: 0.5611
# fruity: 0.5199
# tropical: 0.5127
# vegetable: 0.5026
#
# Top odors for CCCCC(C)S (probability > 0.5):
# sulfurous: 0.8587
# meaty: 0.6802
# fruity: 0.5550
# tropical: 0.5307
# roasted: 0.5218
# grapefruit: 0.5138
# savory: 0.5039
#
# Top odors for SS (probability > 0.5):
# sulfurous: 0.8812
# meaty: 0.6595
# garlic: 0.5543
# savory: 0.5041
#
# Top odors for CCSC1C=CCCC1 (probability > 0.5):
# sulfurous: 0.7689
# meaty: 0.5851
# onion: 0.5052
#
# Top odors for SC1CCCSC1 (probability > 0.5):
# sulfurous: 0.8283
# meaty: 0.7021
#
# Top odors for C1CCSCC1 (probability > 0.5):
# sulfurous: 0.8706
# meaty: 0.6183
# garlic: 0.5146
#
# Top odors for CCCCC(S)OC (probability > 0.5):
# cheesy: 0.6502
# sulfurous: 0.6423
# green: 0.6114
# fruity: 0.5974
# vegetable: 0.5156
# tropical: 0.5132
#
# Top odors for CCCCc1ccccc1 (probability > 0.5):
# sweet: 0.6127
# green: 0.5182
# fatty: 0.5173
#
# Top odors for CC(S)CSC1CCCS1 (probability > 0.5):
# sulfurous: 0.7682
# meaty: 0.7297
# roasted: 0.5900
# onion: 0.5127
#
# Top odors for SOSCCC1C=CCS1 (probability > 0.5):
# sulfurous: 0.7298
# meaty: 0.6271
# roasted: 0.5436
# onion: 0.5269
#
# Top odors for CCSO (probability > 0.5):
# sulfurous: 0.7705
# meaty: 0.5994
# cheesy: 0.5210
#
# Top odors for CC(O)CC1C=CC=CC1 (probability > 0.5):
# fruity: 0.7705
# green: 0.7425
# floral: 0.6810
# herbal: 0.5147
#
# Top odors for CCc1coc(C)c1 (probability > 0.5):
# nutty: 0.6913
# sweet: 0.6509
# musty: 0.6405
# green: 0.5298
# earthy: 0.5252
# roasted: 0.5211
# burnt: 0.5158
# ethereal: 0.5142
#
# Top odors for C1CC1 (probability > 0.5):
# musk: 0.7450
# animal: 0.6078
# amber: 0.5811
# sweet: 0.5811
# woody: 0.5327
# dry: 0.5011
#
# Top odors for CC1CCC(C(C)C)C1 (probability > 0.5):
# woody: 0.7125
# green: 0.7102
# herbal: 0.6624
# floral: 0.6425
# fresh: 0.5878
# citrus: 0.5293
#
# Top odors for CCCCC(C)OC (probability > 0.5):
# green: 0.8709
# fruity: 0.7556
# herbal: 0.6156
# apple: 0.5353
# cognac: 0.5251
#
# Top odors for c1ccccc1 (probability > 0.5):
# sweet: 0.7312
# balsamic: 0.5270
# floral: 0.5239
#
# Top odors for CCSCCCSS (probability > 0.5):
# sulfurous: 0.8488
# onion: 0.6669
# meaty: 0.6235
# garlic: 0.5786
# alliaceous: 0.5554
# savory: 0.5437
#
# Top odors for Cc1cnc2c(c1)=CCCC=2 (probability > 0.5):
# sweet: 0.5503
# green: 0.5295
# animal: 0.5291
# herbal: 0.5063
#
# Top odors for CCCCCCC(CC)Cc1ccccc1 (probability > 0.5):
# waxy: 0.5551
# fatty: 0.5072
#
# Top odors for CC1C=CCS1 (probability > 0.5):
# sulfurous: 0.7972
# meaty: 0.6102
#
# Top odors for CCCCOC (probability > 0.5):
# ethereal: 0.8438
# alcoholic: 0.7664
# fruity: 0.6744
# fermented: 0.6428
# green: 0.5994
# cognac: 0.5426
# sweet: 0.5377
# winey: 0.5259
# solvent: 0.5214
# cocoa: 0.5134
#
# Top odors for C=CCCCCCCCCSSC (probability > 0.5):
# sulfurous: 0.6861
# fatty: 0.6188
# green: 0.6130
# meaty: 0.5799
# vegetable: 0.5492
#
# Top odors for SN1CCCCCC1 (probability > 0.5):
# fishy: 0.6911
# meaty: 0.6098
#
# Top odors for SC1=CC2C=CCC2=CC1 (probability > 0.5):
# fruity: 0.5256
# sulfurous: 0.5113
#
# Top odors for CCC(C)C (probability > 0.5):
# ethereal: 0.6290
# musty: 0.5625
# fermented: 0.5411
#
# Top odors for CCSSO (probability > 0.5):
# sulfurous: 0.8447
# onion: 0.6836
# garlic: 0.6280
# savory: 0.5408
# alliaceous: 0.5399
# meaty: 0.5256
# cooked: 0.5206
#
# Top odors for CCC (probability > 0.5):
# ethereal: 0.7056
# sweet: 0.5995
#
# Top odors for CSCCS(C)(C)S (probability > 0.5):
# sulfurous: 0.8822
# onion: 0.6190
# meaty: 0.6030
# alliaceous: 0.5944
# green: 0.5791
# savory: 0.5278
# vegetable: 0.5033
# garlic: 0.5020
#
# Top odors for CC1C=C(S)CS1 (probability > 0.5):
# sulfurous: 0.7806
# meaty: 0.7654
# roasted: 0.6114
#
# Top odors for CCCCCSCC (probability > 0.5):
# sulfurous: 0.8190
# vegetable: 0.6903
# green: 0.6154
# meaty: 0.5910
# onion: 0.5608
# alliaceous: 0.5340
# fatty: 0.5331
# savory: 0.5271
#
# Top odors for CCCCOCC (probability > 0.5):
# ethereal: 0.7952
# alcoholic: 0.7737
# fruity: 0.6849
# fermented: 0.6107
# sweet: 0.5641
# solvent: 0.5585
# pungent: 0.5005
#
# Top odors for C=C=C (probability > 0.5):
# pungent: 0.6350
# ethereal: 0.5449
# green: 0.5218
# sharp: 0.5195
#
# Top odors for CCCCCOC (probability > 0.5):
# green: 0.7648
# fruity: 0.7315
# ethereal: 0.7296
# alcoholic: 0.7118
# fermented: 0.6413
# cognac: 0.6396
# winey: 0.5434
# sweet: 0.5383
# pungent: 0.5261
# cocoa: 0.5040
#
# Top odors for CC1CCCCC1 (probability > 0.5):
# musk: 0.6843
# woody: 0.6497
# amber: 0.6054
# sweet: 0.5288
# dry: 0.5106
# animal: 0.5003
#
# Top odors for C1CCCC1 (probability > 0.5):
# musk: 0.7450
# animal: 0.6078
# amber: 0.5811
# sweet: 0.5811
# woody: 0.5327
# dry: 0.5011
#
# Top odors for CCCc1ccccc1 (probability > 0.5):
# sweet: 0.6520
# green: 0.5467
#
# Top odors for CCCCCCSC (probability > 0.5):
# sulfurous: 0.7736
# vegetable: 0.7208
# green: 0.7003
# fatty: 0.5947
# meaty: 0.5630
# onion: 0.5406
# alliaceous: 0.5282
#
# Top odors for CC(C)C (probability > 0.5):
# ethereal: 0.7854
# fermented: 0.5977
# alcoholic: 0.5499
# solvent: 0.5422
# musty: 0.5044
#
# Top odors for CCCCSC1=C=S=C=CS1 (probability > 0.5):
# sulfurous: 0.6584
# onion: 0.5295
# roasted: 0.5219
# meaty: 0.5211
# pungent: 0.5062
#
# Top odors for CC(C)(O)S (probability > 0.5):
# sulfurous: 0.8556
# meaty: 0.6672
# tropical: 0.5740
# fruity: 0.5577
# onion: 0.5291
#
# Top odors for C=CCCCCSC (probability > 0.5):
# vegetable: 0.6695
# fatty: 0.6655
# sulfurous: 0.6614
# green: 0.6325
# meaty: 0.5589
# onion: 0.5199
#
# Top odors for CCCCC (probability > 0.5):
# sweet: 0.6926
# musty: 0.5120
#
# Top odors for CSSC(C)C (probability > 0.5):
# sulfurous: 0.8666
# onion: 0.7356
# garlic: 0.6448
# alliaceous: 0.6435
# vegetable: 0.5785
# green: 0.5772
# savory: 0.5373
# meaty: 0.5177
#
# Top odors for CCCC(CCC)C1=CC=CC1 (probability > 0.5):
# woody: 0.6273
# waxy: 0.5461
# floral: 0.5083
#
# Top odors for CCCC(C)CC (probability > 0.5):
# green: 0.6141
# herbal: 0.5269
# sweet: 0.5156
#
# Top odors for C1=CCSC1 (probability > 0.5):
# sulfurous: 0.8469
# meaty: 0.6068
# garlic: 0.5405
#
# Top odors for CC1=CSCC1C (probability > 0.5):
# sulfurous: 0.6923
#
# Top odors for CC1CC(C(C)C)CS1 (probability > 0.5):
# sulfurous: 0.7359
# green: 0.7071
# tropical: 0.6989
# fruity: 0.5705
# herbal: 0.5390
#
# Top odors for C1=CC1 (probability > 0.5):
#
# Top odors for CC(C)(C)C (probability > 0.5):
# ethereal: 0.6560
# fresh: 0.6150
# camphoreous: 0.5831
# green: 0.5190
#
# Top odors for CCCC(C)c1ccccc1 (probability > 0.5):
# green: 0.6962
# fresh: 0.5791
# floral: 0.5736
# herbal: 0.5302
#
# Top odors for C=C1C=C(CS)CC1 (probability > 0.5):
# fruity: 0.7045
# sulfurous: 0.5489
# tropical: 0.5375
#
# Top odors for OCCCSCS (probability > 0.5):
# sulfurous: 0.7978
# meaty: 0.6728
#
# Top odors for CCCCSS (probability > 0.5):
# sulfurous: 0.8439
# onion: 0.6866
# garlic: 0.6473
# alliaceous: 0.5904
# meaty: 0.5633
# vegetable: 0.5517
# savory: 0.5323
#
# Top odors for CC(C)SS (probability > 0.5):
# sulfurous: 0.8815
# onion: 0.6902
# meaty: 0.6329
# garlic: 0.5711
# alliaceous: 0.5557
# savory: 0.5480
#
# Top odors for CC1CCCC1 (probability > 0.5):
# woody: 0.6672
# musk: 0.6640
# amber: 0.6049
# sweet: 0.5169
# dry: 0.5091
#
# Top odors for CCCC (probability > 0.5):
# sweet: 0.6530
# ethereal: 0.5686
# musty: 0.5133
#
# Top odors for C1=CCC=C1 (probability > 0.5):
#
# Top odors for CCCCCC (probability > 0.5):
# sweet: 0.6706
#
# Top odors for CCC(C)CC(C)C (probability > 0.5):
# green: 0.7226
# herbal: 0.6439
# floral: 0.6187
# citrus: 0.5586
# fresh: 0.5371
# woody: 0.5309
#
# Top odors for CCCC(C)SC (probability > 0.5):
# sulfurous: 0.8123
# vegetable: 0.6884
# green: 0.6742
# meaty: 0.5523
# onion: 0.5503
# tropical: 0.5149
#
# Top odors for CCOC (probability > 0.5):
# ethereal: 0.8860
# alcoholic: 0.6447
# fruity: 0.5927
# sweet: 0.5812
#
# Top odors for C=C(C)C(C)C (probability > 0.5):
# herbal: 0.7053
# mint: 0.6704
# fresh: 0.6006
# green: 0.5663
# camphoreous: 0.5660
# citrus: 0.5614
# fruity: 0.5281
#
# Top odors for CS1=NC=CS1 (probability > 0.5):
# sulfurous: 0.6449
# meaty: 0.5561
# roasted: 0.5176
#
# Top odors for C=CC (probability > 0.5):
# gassy: 0.5847
# green: 0.5182
#
# Top odors for CCCC(C)CSC (probability > 0.5):
# sulfurous: 0.8052
# green: 0.6954
# vegetable: 0.6810
# alliaceous: 0.5607
# onion: 0.5602
# meaty: 0.5542
#
# Top odors for C=CCOCCC1=CCCSC1 (probability > 0.5):
# sulfurous: 0.5515
#
# Top odors for Sc1cc2c(s1)=COSC=2 (probability > 0.5):
# sulfurous: 0.7666
# meaty: 0.7570
# roasted: 0.6204
#
# Top odors for C=C(C)C (probability > 0.5):
# gassy: 0.5311
# fresh: 0.5271
# green: 0.5016
#
# Top odors for CC1(S)C=CCCC1 (probability > 0.5):
# sulfurous: 0.7344
# tropical: 0.6441
# fruity: 0.5885
# meaty: 0.5224
#
# Top odors for CC=CCCC (probability > 0.5):
# green: 0.6731
# gassy: 0.5436
#
# Top odors for C=S=S=CCCCC (probability > 0.5):
# pungent: 0.8568
# radish: 0.7306
# onion: 0.6303
# garlic: 0.5369
# sulfurous: 0.5173
#
# Top odors for C=CSCC (probability > 0.5):
# sulfurous: 0.8064
# onion: 0.7633
# garlic: 0.7593
# pungent: 0.5977
# alliaceous: 0.5769
#
# Top odors for C=CC(C)(C)S (probability > 0.5):
# sulfurous: 0.7923
# tropical: 0.6729
# fruity: 0.6201
# meaty: 0.5488
# grapefruit: 0.5271
# onion: 0.5216
#
# Top odors for C=S(CCC)C(S)(CCCS)SS (probability > 0.5):
# sulfurous: 0.7359
# onion: 0.5737
# meaty: 0.5402
#
# Top odors for C=[SH](=C=CC)CC (probability > 0.5):
# pungent: 0.8867
# onion: 0.7026
# radish: 0.6881
# sulfurous: 0.6223
# garlic: 0.6216
#
# Top odors for CSCCC=S (probability > 0.5):
# sulfurous: 0.7930
# onion: 0.7294
# garlic: 0.7052
# pungent: 0.5762
# alliaceous: 0.5588
# cabbage: 0.5201
#
# Top odors for CC(C)CCCC(C)S (probability > 0.5):
# sulfurous: 0.8260
# grapefruit: 0.6597
# meaty: 0.6279
# fruity: 0.6265
# tropical: 0.5827
# black currant: 0.5181
# roasted: 0.5153
#
# Top odors for CCCC(C)C1=CC=CSC1 (probability > 0.5):
# sulfurous: 0.5160
#
# Top odors for CSO (probability > 0.5):
# sulfurous: 0.7593
# meaty: 0.5300
#
# Top odors for CCCSSSCO (probability > 0.5):
# sulfurous: 0.8158
# onion: 0.7097
# garlic: 0.6544
# alliaceous: 0.5653
# savory: 0.5425
# cooked: 0.5123
#
# Top odors for C=CCC (probability > 0.5):
# green: 0.6033
# gassy: 0.5553
# fruity: 0.5241
#
# Top odors for CCCCCCC(C)CC(C)S (probability > 0.5):
# sulfurous: 0.7594
# meaty: 0.6396
# fruity: 0.6270
# roasted: 0.5108
# grapefruit: 0.5062
#
# Top odors for CC1CCC(CO)C1 (probability > 0.5):
# fruity: 0.5596
#
# Top odors for OS (probability > 0.5):
# sulfurous: 0.5473
# odorless: 0.5050
#
# Top odors for COS (probability > 0.5):
# sulfurous: 0.7219
# meaty: 0.5161
#
# Top odors for CCC1=S(O)C=C(C)C1 (probability > 0.5):
#
# Top odors for CCSCC(C)O (probability > 0.5):
# sulfurous: 0.7934
# meaty: 0.6900
# onion: 0.5564
# savory: 0.5070
# roasted: 0.5058
#
# Top odors for S=S1C=CCSO1 (probability > 0.5):
# sulfurous: 0.7077
# meaty: 0.6538
# roasted: 0.5260
#
# Top odors for CC1CCSC1 (probability > 0.5):
# sulfurous: 0.8590
# meaty: 0.6012
# alliaceous: 0.5507
# vegetable: 0.5213
# garlic: 0.5179
# onion: 0.5097
#
# Top odors for CCCC(C)C(CC)CC (probability > 0.5):
# floral: 0.7467
# green: 0.6138
# citrus: 0.5560
# fresh: 0.5334
# woody: 0.5328
# waxy: 0.5020
#
# Top odors for CS1=CC=C(S2=CC=CC=C2)C=C1 (probability > 0.5):
# sulfurous: 0.6488
#
# Top odors for CCCCC(C)C(C)CCS (probability > 0.5):
# sulfurous: 0.7499
# fruity: 0.6290
# meaty: 0.5716
# grapefruit: 0.5476
# green: 0.5299
# tropical: 0.5148
#
# Top odors for CSNCS (probability > 0.5):
# meaty: 0.7145
# sulfurous: 0.6955
#
# Top odors for CCCC(CCC)CCSC (probability > 0.5):
# sulfurous: 0.7360
# green: 0.6290
# meaty: 0.6044
# fatty: 0.5852
# vegetable: 0.5815
# fruity: 0.5632
#
# Top odors for CCSCO (probability > 0.5):
# sulfurous: 0.8300
# meaty: 0.5915
# onion: 0.5804
# vegetable: 0.5397
# cabbage: 0.5248
# savory: 0.5126
#
# Top odors for CC1=CCC=C1 (probability > 0.5):
# citrus: 0.6384
# woody: 0.5559
# herbal: 0.5126
#
# Top odors for CC1SC=CSS1 (probability > 0.5):
# sulfurous: 0.8074
# meaty: 0.6646
#
# Top odors for CCCCCCSCC (probability > 0.5):
# sulfurous: 0.8034
# vegetable: 0.6761
# meaty: 0.6235
# fatty: 0.6168
# green: 0.5994
# onion: 0.5214
# savory: 0.5197
#
# Top odors for CCCSCCCS (probability > 0.5):
# sulfurous: 0.8533
# meaty: 0.6511
# onion: 0.6282
# savory: 0.5718
# garlic: 0.5642
# vegetable: 0.5529
# alliaceous: 0.5458
#
# Top odors for CC1CCCC(C)C1 (probability > 0.5):
# woody: 0.7289
# amber: 0.5920
# musk: 0.5633
#
# Top odors for CSc1cccs1 (probability > 0.5):
# sulfurous: 0.8321
# meaty: 0.7244
# roasted: 0.7104
# coffee: 0.6091
# burnt: 0.5336
#
# Top odors for CC(O)CCCCCCCCS (probability > 0.5):
# meaty: 0.7222
# sulfurous: 0.7089
# grapefruit: 0.6345
# roasted: 0.5726
# fatty: 0.5495
#
# Top odors for CCC(C)C(C)C (probability > 0.5):
# green: 0.7548
# herbal: 0.7013
# woody: 0.5219
# mint: 0.5015
#
# Top odors for CCCCCc1ccccc1 (probability > 0.5):
# sweet: 0.5666
# fatty: 0.5434
#
# Top odors for CC (probability > 0.5):
# ethereal: 0.6569
# sweet: 0.5423
#
# Top odors for SCCCC1=CCC=C1 (probability > 0.5):
# sulfurous: 0.7130
# meaty: 0.5933
# fruity: 0.5822
#
# Top odors for COCC1CSCCS1 (probability > 0.5):
# sulfurous: 0.7687
# meaty: 0.5819
# garlic: 0.5220
# onion: 0.5103
#
# Top odors for CCCC=S(=S)=CSS (probability > 0.5):
# pungent: 0.7558
# onion: 0.7425
# sulfurous: 0.7291
# garlic: 0.6807
# radish: 0.5431
# alliaceous: 0.5122
#
# Top odors for CCCCC(C)CCO (probability > 0.5):
# green: 0.7273
# floral: 0.7101
# fruity: 0.6484
# herbal: 0.6048
# oily: 0.5803
# sweet: 0.5783
# fresh: 0.5623
# citrus: 0.5550
# waxy: 0.5444
# rose: 0.5294
# fatty: 0.5261
#
# Top odors for OC(CS)C1C=CC=CC1 (probability > 0.5):
#
# Top odors for COC1C=CSC(C)C1 (probability > 0.5):
# meaty: 0.5461
#
# Top odors for CC=S(C)CSC (probability > 0.5):
# onion: 0.7361
# garlic: 0.7005
# sulfurous: 0.6795
# pungent: 0.5556
# alliaceous: 0.5186
#
# Top odors for CCCSCO (probability > 0.5):
# sulfurous: 0.8010
# vegetable: 0.6192
# onion: 0.6110
# meaty: 0.5432
# garlic: 0.5390
# cabbage: 0.5325
# savory: 0.5082
#
# Top odors for CCCSC=S (probability > 0.5):
# sulfurous: 0.7970
# onion: 0.7352
# garlic: 0.7040
# pungent: 0.5808
# alliaceous: 0.5587
# cabbage: 0.5181
#
# Top odors for C=C(CCCO)CCCOCC (probability > 0.5):
#
# Top odors for CC(C)C1CCCOC1(C)C (probability > 0.5):
# herbal: 0.7651
# woody: 0.6930
# green: 0.6864
# floral: 0.6571
# fresh: 0.6062
# mint: 0.5863
# camphoreous: 0.5741
# pine: 0.5197
#
# Top odors for CCCCSCSCCCC(C)C (probability > 0.5):
# sulfurous: 0.7839
# green: 0.6506
# vegetable: 0.5745
# onion: 0.5654
# meaty: 0.5191
#
# Top odors for CCCCCCCSS (probability > 0.5):
# sulfurous: 0.7783
# meaty: 0.6049
# vegetable: 0.5942
# green: 0.5868
# onion: 0.5649
# fatty: 0.5612
# savory: 0.5236
# roasted: 0.5044
#
# Top odors for CCCCOC1CCCC1 (probability > 0.5):
# fruity: 0.7252
# alcoholic: 0.6599
# green: 0.6502
# ethereal: 0.6364
# fermented: 0.5616
#
# Top odors for C=S1CCCCC1 (probability > 0.5):
# sulfurous: 0.7413
# meaty: 0.5216
#
# Top odors for CC1CCCC1S(C)=O (probability > 0.5):
# floral: 0.5835
# herbal: 0.5662
# fruity: 0.5623
# green: 0.5623
#
# Top odors for CC1CS1 (probability > 0.5):
# sulfurous: 0.8382
# meaty: 0.5789
# alliaceous: 0.5777
# garlic: 0.5699
# onion: 0.5147

# %%
import os 

odor_counts = Counter(all_top_odors)


plt.figure(figsize=(12, 6))
odors, counts = zip(*odor_counts.most_common(20))  
plt.bar(odors, counts)
plt.title("Top Predicted Odors Across All Molecules")
plt.xlabel("Odor Labels")
plt.ylabel("Count in Top 10 Predictions")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_folder = '../../figures/ARGVA/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300, 600, 1200]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_ten_{dpi}dpi.png", dpi=dpi, bbox_inches='tight')
plt.show()


print("\nCounts of odors in top 10 predictions across all molecules:")
for odor, count in odor_counts.most_common():
    print(f"{odor}: {count}")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Counts of odors in top 10 predictions across all molecules:
# sulfurous: 77
# meaty: 60
# green: 42
# onion: 38
# fruity: 28
# sweet: 25
# garlic: 24
# alliaceous: 20
# vegetable: 20
# savory: 17
# herbal: 16
# woody: 15
# roasted: 15
# ethereal: 14
# pungent: 13
# floral: 12
# tropical: 12
# fatty: 12
# fresh: 10
# citrus: 9
# grapefruit: 7
# amber: 6
# musk: 6
# musty: 6
# alcoholic: 6
# fermented: 6
# solvent: 4
# mint: 4
# animal: 4
# dry: 4
# waxy: 4
# gassy: 4
# cabbage: 4
# burnt: 3
# cognac: 3
# camphoreous: 3
# radish: 3
# oily: 2
# pine: 2
# fishy: 2
# sharp: 2
# black currant: 2
# cheesy: 2
# winey: 2
# cocoa: 2
# cooked: 2
# terpenic: 1
# spicy: 1
# nutty: 1
# earthy: 1
# apple: 1
# balsamic: 1
# odorless: 1
# coffee: 1
# rose: 1
#
# Problematic SMILES that caused errors:

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt


odor_counts = Counter(all_top_odors)
total_predictions = sum(odor_counts.values())  


percentages = [(count / total_predictions) * 100 for count in odor_counts.values()]


sorted_odors_percentages = sorted(zip(odor_counts.keys(), percentages), key=lambda x: x[1], reverse=True)


top_20_odors_percentages = sorted_odors_percentages[:20]
top_20_odors, top_20_percentages = zip(*top_20_odors_percentages)


plt.figure(figsize=(15, 8))  


bars = plt.bar(top_20_odors, top_20_percentages, edgecolor='black')
ax = plt.gca()  
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(2)  

plt.title("Most Common Odor Predictions (ARGA)", fontsize=33, fontweight='bold', pad=20)
plt.xlabel("Odor Labels", fontsize=33, fontweight='bold', labelpad=15)
plt.ylabel("(%) of Predictions", fontsize=29, fontweight='bold', labelpad=10)


plt.xticks(rotation=45, ha='right', fontsize=28, fontweight='bold')
plt.yticks(fontsize=26, fontweight='bold')

plt.tight_layout()


output_folder = '../../figures/ARGA/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_odor_per.png", dpi=dpi, bbox_inches='tight')


plt.show()


print("\nPercentages of top 20 odors in top 10 predictions across all molecules:")
for odor, percentage in zip(top_20_odors, top_20_percentages):
    print(f"{odor}: {percentage:.2f}%")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Percentages of top 20 odors in top 10 predictions across all molecules:
# sulfurous: 13.21%
# meaty: 10.29%
# green: 7.20%
# onion: 6.52%
# fruity: 4.80%
# sweet: 4.29%
# garlic: 4.12%
# alliaceous: 3.43%
# vegetable: 3.43%
# savory: 2.92%
# herbal: 2.74%
# woody: 2.57%
# roasted: 2.57%
# ethereal: 2.40%
# pungent: 2.23%
# floral: 2.06%
# tropical: 2.06%
# fatty: 2.06%
# fresh: 1.72%
# citrus: 1.54%
#
# Problematic SMILES that caused errors:
