# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
from openpom.feat.graph_featurizer import GraphFeaturizer, GraphConvConstants
from openpom.utils.data_utils import get_class_imbalance_ratio, IterativeStratifiedSplitter
from openpom.models.mpnn_pom import MPNNPOMModel
from datetime import datetime
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import gaussian_kde
from collections import Counter
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# WARNING:tensorflow:From c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\deepchem\models\torch_models\__init__.py)

# %%
# Odor Labels
TASKS = [
    'alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
    'anisic', 'apple', 'apricot', 'aromatic', 'balsamic', 'banana', 'beefy',
    'bergamot', 'berry', 'bitter', 'black currant', 'brandy', 'burnt',
    'buttery', 'cabbage', 'camphoreous', 'caramellic', 'cedar', 'celery',
    'chamomile', 'cheesy', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clean',
    'clove', 'cocoa', 'coconut', 'coffee', 'cognac', 'cooked', 'cooling',
    'cortex', 'coumarinic', 'creamy', 'cucumber', 'dairy', 'dry', 'earthy',
    'ethereal', 'fatty', 'fermented', 'fishy', 'floral', 'fresh', 'fruit skin',
    'fruity', 'garlic', 'gassy', 'geranium', 'grape', 'grapefruit', 'grassy',
    'green', 'hawthorn', 'hay', 'hazelnut', 'herbal', 'honey', 'hyacinth',
    'jasmin', 'juicy', 'ketonic', 'lactonic', 'lavender', 'leafy', 'leathery',
    'lemon', 'lily', 'malty', 'meaty', 'medicinal', 'melon', 'metallic',
    'milky', 'mint', 'muguet', 'mushroom', 'musk', 'musty', 'natural', 'nutty',
    'odorless', 'oily', 'onion', 'orange', 'orangeflower', 'orris', 'ozone',
    'peach', 'pear', 'phenolic', 'pine', 'pineapple', 'plum', 'popcorn',
    'potato', 'powdery', 'pungent', 'radish', 'raspberry', 'ripe', 'roasted',
    'rose', 'rummy', 'sandalwood', 'savory', 'sharp', 'smoky', 'soapy',
    'solvent', 'sour', 'spicy', 'strawberry', 'sulfurous', 'sweaty', 'sweet',
    'tea', 'terpenic', 'tobacco', 'tomato', 'tropical', 'vanilla', 'vegetable',
    'vetiver', 'violet', 'warm', 'waxy', 'weedy', 'winey', 'woody'
]
len(TASKS)
# Out:
# 138

# %%
input_file = '../../data/curated dataset/curated_GS_LF_merged_4983.csv'
featurizer = GraphFeaturizer()
smiles_field = 'nonStereoSMILES' # column that contains SMILES

# %%
loader = dc.data.CSVLoader(tasks=TASKS,
feature_field=smiles_field,
featurizer=featurizer)

# %%
dataset = loader.create_dataset(inputs=[input_file])
n_tasks = len(dataset.tasks)
randomstratifiedsplitter = dc.splits.RandomStratifiedSplitter()
train_dataset, test_dataset, valid_dataset = randomstratifiedsplitter.train_valid_test_split(dataset, frac_train = 0.8, frac_valid = 0.1, frac_test = 0.1, seed = 1)
train_ratios = get_class_imbalance_ratio(train_dataset)

# %%
assert len(train_ratios) == n_tasks

# %%
learning_rate = dc.models.optimizers.ExponentialDecay(initial_rate=0.001, decay_rate=0.5, decay_steps=32*20, staircase=True)

# %%
model = MPNNPOMModel(n_tasks = n_tasks,
                     batch_size = 128,
                     learning_rate = learning_rate,
                     class_imbalance_ratio = train_ratios,
                     loss_aggr_type = 'sum',
                     node_out_feats = 100,
                     edge_hidden_feats = 75,
                     edge_out_feats = 100,
                     num_step_message_passing = 5,
                     mpnn_residual = True,
                     message_aggregator_type = 'sum',
                     mode = 'classification',
                     number_atom_features = GraphConvConstants.ATOM_FDIM,
                     number_bond_features = GraphConvConstants.BOND_FDIM,
                     n_classes = 1,
                     readout_type = 'set2set',
                     num_step_set2set = 3,
                     num_layer_set2set = 2,
                     ffn_hidden_list = [392, 392],
                     ffn_embeddings = 256,
                     ffn_activation = 'relu',
                     ffn_dropout_p = 0.12,
                     ffn_dropout_at_input_no_act = False,
                     weight_decay = 1e-5,
                     self_loop = False,
                     optimizer_name = 'adam',
                     log_frequency = 32,
                     model_dir = './experiments',
                     device_name ='cpu')

# %%
import torch
checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
if 'model_state_dict' in checkpoint:
    model.model.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    model.model.load_state_dict(checkpoint, strict=False)
model.model.eval()
# Out:
# C:\Users\sarab\AppData\Local\Temp\ipykernel_10236\2995347586.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
# MPNNPOM(
#   (mpnn): CustomMPNNGNN(
#     (project_node_feats): Sequential(
#       (0): Linear(in_features=134, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (gnn_layer): NNConv(
#       (edge_func): Sequential(
#         (0): Linear(in_features=6, out_features=75, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=75, out_features=10000, bias=True)
#       )
#       (res_fc): Identity()
#     )
#     (gru): GRU(100, 100)
#   )
#   (project_edge_feats): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#   )
#   (readout_set2set): Set2Set(
#     n_iters=3
#     (lstm): LSTM(400, 200, num_layers=2)
#   )
#   (ffn): CustomPositionwiseFeedForward(
#     (activation): ReLU()
#     (linears): ModuleList(
#       (0): Linear(in_features=400, out_features=392, bias=True)
#       (1): Linear(in_features=392, out_features=392, bias=True)
#       (2): Linear(in_features=392, out_features=256, bias=True)
#       (3): Linear(in_features=256, out_features=138, bias=True)
#     )
#     (dropout_p): ModuleList(
#       (0-3): 4 x Dropout(p=0.12, inplace=False)
#     )
#     (batchnorms): ModuleList(
#       (0-1): 2 x BatchNorm1d(392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
csv_file_path = '../../data/GAE/logistic equation/novel_odorrous_set_log_eq.csv'
df = pd.read_csv(csv_file_path)

# %%
smiles_list = df['SMILE'].tolist()
print(smiles_list)


featurizer = GraphFeaturizer()
featurized_data = featurizer.featurize(smiles_list)

# Processing each featurized data point and collect top 10 odors
all_top_odors = []
problematic_smiles = []

for i, featurized_mol in enumerate(featurized_data):
    try:
        
        single_mol_dataset = dc.data.NumpyDataset([featurized_mol])

        
        prediction = model.predict(single_mol_dataset)

        
        odor_probs = prediction.squeeze()
        high_prob_indices = np.where(odor_probs > 0.5)[0]
        
        
        sorted_indices = high_prob_indices[np.argsort(odor_probs[high_prob_indices])[::-1]]
        
        
        top_odors = [TASKS[i] for i in sorted_indices]
        all_top_odors.extend(top_odors)

        # Printing top odors for each molecule
        print(f"\nTop odors for {smiles_list[i]} (probability > 0.5):")
        for odor, score in zip(top_odors, odor_probs[sorted_indices]):
            print(f"{odor}: {score:.4f}")

    except KeyError as e:
        print(f"\nError processing SMILES: {smiles_list[i]}")
        print(f"Error message: {str(e)}")
        problematic_smiles.append(smiles_list[i])
        continue
# Out:
# ['CCCOCC', 'COCCO', 'CSS1=C(C)COC1', 'NCS', 'C=CC(S)CNCCCC', 'CCCCCCCC=CSO', 'CCCOOC(C)OC', 'CCSSCO', 'CCOCCOC', 'COCCCO', 'CCCOC[NH-]', 'CCCC(C)=S', 'CCS1=CCC(O)C=C1', 'CCC(=O)C=O', 'C=CCC=CCC', 'CC1C=CN=CC1', 'C=C(CCCSCCCCC)OC(C)CCC', 'Cc1occc1CS', 'NCCCCO', 'C=C1CCCC(CO)O1', 'C=C(C)C(C)C(C)=O', 'CSC=C(C)C', 'C1CC1', 'C=C(SC)C1C=COCC1', 'CC(C)OC=N', 'C=CC(C)CC', 'OCS1=CCC=CO1', 'CCCCCSC(=O)CC', 'CC1CCCC1=S', 'CC', 'CC=CC(C)S', 'C=C(C)C(C)OC', 'CCOCC(=O)O', 'CCCCCSC', 'C=C(C)C', 'C1CSCCN1', 'CC(CCO)CCCSO', 'CCOC(=S)CC(O)CC', 'C=C(O)CCC', 'CCCCCCC(C)SCC', 'COC(C)(C)O', 'CCC(=O)C1=CCC(OC)=CC1', 'CC1CCOC1', 'CC=NSCS', 'CCC=C(C)C(=O)SC', 'C=CCOCC=CC', 'CC(=O)CCC(O)SCCO', 'C=C(O)CCOCC', 'CC(=O)OCC1C=CC2=C(C1)OCC2', 'CCCCC', 'CCOCC(C)O', 'C=C(CCC)C(O)CC', 'OCC=CCO', 'O=C(O)O', 'OSCS', 'C=CCCCC=O', 'CC1=CC=CC1', 'CC(O)S', 'NCCCC(=O)S', 'CCC(CC)CCCS', 'C=C1CC2CCC1C2(C)S', 'CCC(O)CC1=CCC=CS1', 'CCCCCC1OCCC1O', 'CCC=CC(C)OCS', 'CCC(O)SC', 'CSCSCSS', 'CCCC=CCC(=N)O', 'OS1=NC(OS)C(S)C=C1', 'C1CO1', 'CCCCc1cncs1', 'CN(C)N', 'C=C(C)c1cnc(C)o1', 'C=CCN', 'CCCCCC1=CC(C)=CC1', 'COCCSO', 'CC1=CC=CC(C)S1', 'CC1=CC=C(CO)OC1', 'CC1CC(C)(C)CCO1', 'C=C1C(S)OC(C)C1NC', 'CC(O)CCO', 'CSCN', 'CCOC', 'CCOCCCCS', 'CC(C)C1=CN2C(=CS1)C(C)(C)C(C)S2(C)C', 'CCCCC(CC)NO', 'CCC1=CC=CC1', 'CCC(C)CCC(C)(C)CC', 'CC1CCCCO1', 'CC=CC(=O)SCCC(C)N', 'CCCCCSO', 'CNCCC=CCCCCCCCCCC=O', 'CC1CCC(N)CS1', 'CC(=O)CSC(N)=O', 'C=CNCCCCCCCSC(C)C', 'CC1=CCC=C1', 'OCCCS', 'CCC(=O)C(N)CC', 'CNC(=O)CC(C)C', 'CC1OCCO1', 'CCCCC1C=NOO1', 'CCC=CCC', 'CSC(C)C(C)(C)O', 'CCCCCC=CCS', 'CSCCSCCCCCCCCS', 'CCC1=CN=C(C)SO1', 'C=CCCC', 'CC1=CCS2(O)CC1C2(C)S', 'CNC(=O)C1CC2CC1C(C)(C)C2', 'CC1CCSCC1', 'CCC=CCCCSCC(=S)CC', 'NC1CCOC1', 'CC1CCSCC1=S', 'CCC(C)OC(=O)C=C(C)C', 'CC1=CSC(CCO)=CS1', 'CSOO', 'CCCCCC', 'CNCCCCCO', 'CC=CC(N)=O', 'CCC(O)CCCCO', 'C=CC=CC', 'C=CC(=C)CCCC(C)(S)CC', 'CC1(C)C2CCC(C2)C1O', 'CC=COC', 'CCCCC1=C(C)SC(C)S1', 'CC1(C)C2=CC1C(OCC=O)=CC2', 'CC(=O)OCO', 'CC(N)CO', 'CCCCCCC(C)C', 'O=S(CO)c1ncco1', 'CC1CCSC1', 'CC(S)c1ccc(O)cn1', 'CC(=S)CC(C)S', 'CCCCC(C)C', 'C=C(SC)C(S)CCCCCCCC', 'CCC(=O)SC(C)C', 'CCNCCCC(O)C=O', 'COCCOC(C)O', 'C=CC(=C)NCC', 'CC1=CSCCN1', 'CSC(=O)CCCS', 'C=CCOOC', 'CC1CCCC1', 'C=C(O)C=CC(CCC(=C)O)C(C)C', 'CC(O)CCC(O)SCCN', 'OCCCc1cccnc1', 'C=CCOCCCCCCCC', 'C1=COCC1', 'CCC(O)S', 'CC=CC=CC(=O)CSCC', 'CC=COCC', 'CCC(CC)CS', 'C=CCCSC', '[NH-]CCCS', 'OCCC(O)S', 'CC(C)=CC=N', 'CC(C)OC(C)C', 'CCC(C)C=S', 'O=CCCC=O', 'CCCCCC=COC1CCCC1C', 'COC1=C=C=C(CCCS)N=C1', 'OOCC(O)O', 'C1COSSC1', 'C=CCCCOCCCC', 'C=CC1=COSC=C1C', 'CC1=CC(C)CC1', 'C=C1OCC(C)=C1CCCCC', 'Cn1cccn1', 'CSCO', 'CC(C=O)CCCCO', 'CSCCC(C)O', 'C=CCC(C)C(=C)OCC', 'CCC', 'CCCS(=O)N1OC=CS1', 'CCCCOC', 'CSC(C)CO', 'CC1CC(C)SC(O)N1', 'C=CCC=CCCC(=O)NCC', 'CCCOSC', 'C=C(CCCC)OCC', 'C1ONSCSO1', 'CCCCNSCCC', 'COC(C)C(C)O', 'CNCCCC1OC(C)C(C)O1', 'S=C1CCCCCC1', 'CC1=C(C)SC2=C(CCC2)N1', 'CCCCCCCC(C)CC', 'C=CC(C)(C)S(=O)CC(C)C', 'OO', 'CCCOCCC', 'CC(S)CCCC(C)S', 'CC1CCC(S)S1', 'O=C(CCO)C1=NC=CC1', 'CSC(=O)O', 'CCc1cc(C)cnc1N', 'CC(C)COC1=CC=S2C=CC=CC2=C1', 'CCCCS(C)=O', 'CCC(C)(O)SO', 'CC1C=CC(C)O1', 'COSC', 'C=C(O)c1ccccc1', 'CSCC=CNC(C)=O', 'C[SH](=O)=Cc1ccccc1', 'CCCSC(=O)O', 'CC1C=CC(CC(C)C=O)C=C1', 'CCC(C)CNC=O', 'C=CCCC(=C)S', 'CCCCOCSSS', 'C=CC1C=CN(C)C=C1S', 'CC(C=S)c1ccccc1', 'C=CC=C', 'Cc1cc(CC(C)C)ccc1CCCO', 'CCCCCOC(=O)OCCS', 'CC1CCC(=S)C1=S', 'CCCOC', 'SC1CCSC1', 'CCSC(=O)CC1CCCCC1', 'C1=CCCC1', 'CSCS(C)=O', 'COCCN=CCCCC=O', 'CCC(C)CCC(C)C', 'CC(C)=COC(C)C', 'C=C(CCC)OCCCCOCCCC', 'Cc1cc(N)cc(S)n1', 'CCOCC1=C(N)C=CCC1', 'COc1ccc(C)c(C)n1', 'C=CC(C)(O)CNC=S(C)C', 'CC(C)C', 'C=C(CC)CO', 'CC1=CCC(C)C(C)C1O', 'CC1=CC(O)OC1C', 'CCS(=O)CCC(=O)NC', 'CSCCC[O-]', 'CCCCSCCC', 'CCNC(N)=O', 'COC(OC)OCCCCN', 'CCSC(C)S(O)(O)CC', 'CNN1CC=CC1C(C)=O', 'CC(CC(=O)O)CS(C)(C)C', 'CCOC(=O)C1=CC=CCC1', 'C=NCCC', 'CCCC', 'Cc1csc(C)c1', 'CCCSCCCCC1CCCC1=S', 'CCC(C)C(N)=O', 'Cc1ccccc1C(=O)O', 'C1CNCOC1', 'O=C(OO)c1ccco1', 'CC1CCC(C)C1', 'CC(C)C(C)C', 'CCCCCCCCCSSC', 'CCCOCCCCC(=O)CC(C)C', 'O=S(C=CCO)OCCOO', 'CCOOc1cnccn1', 'OCCCCCCO' ...
#
# Top odors for CCCOCC (probability > 0.5):
# ethereal: 0.8540
# alcoholic: 0.7516
# fruity: 0.7050
# sweet: 0.5767
# fermented: 0.5585
# solvent: 0.5269
#
# Top odors for COCCO (probability > 0.5):
# alcoholic: 0.5667
# odorless: 0.5570
#
# Top odors for CSS1=C(C)COC1 (probability > 0.5):
# sulfurous: 0.6996
# meaty: 0.6847
# roasted: 0.6041
# onion: 0.5014
#
# Top odors for NCS (probability > 0.5):
# meaty: 0.7087
# sulfurous: 0.6654
#
# Top odors for C=CC(S)CNCCCC (probability > 0.5):
# meaty: 0.6903
#
# Top odors for CCCCCCCC=CSO (probability > 0.5):
# green: 0.6142
# fatty: 0.5985
# citrus: 0.5644
#
# Top odors for CCCOOC(C)OC (probability > 0.5):
# fruity: 0.7416
#
# Top odors for CCSSCO (probability > 0.5):
# sulfurous: 0.8472
# onion: 0.6949
# garlic: 0.6231
# alliaceous: 0.5593
# savory: 0.5420
# meaty: 0.5331
# cooked: 0.5063
#
# Top odors for CCOCCOC (probability > 0.5):
# fruity: 0.7090
# ethereal: 0.6499
# alcoholic: 0.6166
#
# Top odors for COCCCO (probability > 0.5):
# fruity: 0.6361
# alcoholic: 0.5702
# ethereal: 0.5468
#
# Top odors for CCCOC[NH-] (probability > 0.5):
# fruity: 0.6370
# alcoholic: 0.5953
# ethereal: 0.5134
#
# Top odors for CCCC(C)=S (probability > 0.5):
# sulfurous: 0.7538
# cheesy: 0.5697
# meaty: 0.5172
# onion: 0.5064
#
# Top odors for CCS1=CCC(O)C=C1 (probability > 0.5):
# meaty: 0.6571
# roasted: 0.5939
#
# Top odors for CCC(=O)C=O (probability > 0.5):
# caramellic: 0.8018
# buttery: 0.6639
# sweet: 0.5830
# creamy: 0.5649
# fatty: 0.5164
#
# Top odors for C=CCC=CCC (probability > 0.5):
# green: 0.6303
# gassy: 0.5511
#
# Top odors for CC1C=CN=CC1 (probability > 0.5):
# roasted: 0.5408
# nutty: 0.5383
#
# Top odors for C=C(CCCSCCCCC)OC(C)CCC (probability > 0.5):
# sulfurous: 0.6627
# grapefruit: 0.5972
# fruity: 0.5463
# tropical: 0.5372
# green: 0.5372
#
# Top odors for Cc1occc1CS (probability > 0.5):
# roasted: 0.7528
# meaty: 0.7369
# sulfurous: 0.7340
# coffee: 0.6228
# burnt: 0.5292
#
# Top odors for NCCCCO (probability > 0.5):
# fishy: 0.7868
#
# Top odors for C=C1CCCC(CO)O1 (probability > 0.5):
# fruity: 0.6119
# green: 0.5011
#
# Top odors for C=C(C)C(C)C(C)=O (probability > 0.5):
# fruity: 0.8227
# apple: 0.5252
# mint: 0.5165
# herbal: 0.5021
#
# Top odors for CSC=C(C)C (probability > 0.5):
# onion: 0.7125
# garlic: 0.6671
# sulfurous: 0.6443
# pungent: 0.6176
# alliaceous: 0.5377
#
# Top odors for C1CC1 (probability > 0.5):
# musk: 0.7450
# animal: 0.6078
# amber: 0.5811
# sweet: 0.5811
# woody: 0.5327
# dry: 0.5011
#
# Top odors for C=C(SC)C1C=COCC1 (probability > 0.5):
# sulfurous: 0.6790
# meaty: 0.6517
# roasted: 0.5682
# onion: 0.5647
#
# Top odors for CC(C)OC=N (probability > 0.5):
# fruity: 0.7821
# ethereal: 0.7093
# green: 0.6915
# pungent: 0.5986
# sharp: 0.5471
#
# Top odors for C=CC(C)CC (probability > 0.5):
# green: 0.6759
# fruity: 0.5774
# fresh: 0.5510
# herbal: 0.5434
# citrus: 0.5401
#
# Top odors for OCS1=CCC=CO1 (probability > 0.5):
# meaty: 0.5679
# sulfurous: 0.5170
#
# Top odors for CCCCCSC(=O)CC (probability > 0.5):
# sulfurous: 0.7440
# fruity: 0.6796
# cheesy: 0.6455
# tropical: 0.6284
# vegetable: 0.5523
# green: 0.5405
#
# Top odors for CC1CCCC1=S (probability > 0.5):
# sulfurous: 0.6438
# meaty: 0.5872
#
# Top odors for CC (probability > 0.5):
# ethereal: 0.6569
# sweet: 0.5423
#
# Top odors for CC=CC(C)S (probability > 0.5):
# sulfurous: 0.8143
# meaty: 0.6661
# onion: 0.6622
# garlic: 0.5498
# roasted: 0.5133
#
# Top odors for C=C(C)C(C)OC (probability > 0.5):
# fruity: 0.7601
# green: 0.5824
# herbal: 0.5613
#
# Top odors for CCOCC(=O)O (probability > 0.5):
# fruity: 0.5913
#
# Top odors for CCCCCSC (probability > 0.5):
# sulfurous: 0.7860
# vegetable: 0.7349
# green: 0.7099
# onion: 0.5911
# alliaceous: 0.5670
# meaty: 0.5331
# garlic: 0.5226
#
# Top odors for C=C(C)C (probability > 0.5):
# gassy: 0.5311
# fresh: 0.5271
# green: 0.5016
#
# Top odors for C1CSCCN1 (probability > 0.5):
# meaty: 0.6586
# nutty: 0.6012
# roasted: 0.5980
# popcorn: 0.5514
# fishy: 0.5483
#
# Top odors for CC(CCO)CCCSO (probability > 0.5):
#
# Top odors for CCOC(=S)CC(O)CC (probability > 0.5):
# fruity: 0.8393
# tropical: 0.6433
# sulfurous: 0.6016
# cheesy: 0.5697
#
# Top odors for C=C(O)CCC (probability > 0.5):
# cheesy: 0.6238
#
# Top odors for CCCCCCC(C)SCC (probability > 0.5):
# sulfurous: 0.7966
# meaty: 0.6275
# vegetable: 0.5893
# green: 0.5790
# fruity: 0.5750
# fatty: 0.5664
# tropical: 0.5465
# roasted: 0.5317
#
# Top odors for COC(C)(C)O (probability > 0.5):
# fruity: 0.7864
# ethereal: 0.7612
# fresh: 0.6301
# green: 0.5849
# sweet: 0.5572
# sharp: 0.5445
#
# Top odors for CCC(=O)C1=CCC(OC)=CC1 (probability > 0.5):
# fruity: 0.7418
# floral: 0.6605
# sweet: 0.6119
#
# Top odors for CC1CCOC1 (probability > 0.5):
# solvent: 0.6844
# ethereal: 0.6445
# mint: 0.5113
# sweet: 0.5051
#
# Top odors for CC=NSCS (probability > 0.5):
# sulfurous: 0.7482
# pungent: 0.6721
# onion: 0.6549
# garlic: 0.5998
#
# Top odors for CCC=C(C)C(=O)SC (probability > 0.5):
# fruity: 0.6917
# sulfurous: 0.6125
# cheesy: 0.5839
# tropical: 0.5072
#
# Top odors for C=CCOCC=CC (probability > 0.5):
# fruity: 0.7636
# green: 0.7344
# pungent: 0.6585
# sharp: 0.5867
# ethereal: 0.5133
# fresh: 0.5026
#
# Top odors for CC(=O)CCC(O)SCCO (probability > 0.5):
# sulfurous: 0.6176
# fruity: 0.5292
# tropical: 0.5111
#
# Top odors for C=C(O)CCOCC (probability > 0.5):
# fruity: 0.5642
#
# Top odors for CC(=O)OCC1C=CC2=C(C1)OCC2 (probability > 0.5):
# fruity: 0.7881
# floral: 0.7476
# sweet: 0.6266
# green: 0.5980
# herbal: 0.5495
# woody: 0.5210
#
# Top odors for CCCCC (probability > 0.5):
# sweet: 0.6926
# musty: 0.5120
#
# Top odors for CCOCC(C)O (probability > 0.5):
# fruity: 0.5996
#
# Top odors for C=C(CCC)C(O)CC (probability > 0.5):
# fruity: 0.5527
#
# Top odors for OCC=CCO (probability > 0.5):
#
# Top odors for O=C(O)O (probability > 0.5):
# odorless: 0.8655
#
# Top odors for OSCS (probability > 0.5):
# sulfurous: 0.8084
# meaty: 0.6394
#
# Top odors for C=CCCCC=O (probability > 0.5):
# green: 0.8412
# fruity: 0.7170
# fatty: 0.6754
# fresh: 0.5507
# aldehydic: 0.5119
# vegetable: 0.5080
#
# Top odors for CC1=CC=CC1 (probability > 0.5):
# citrus: 0.6228
# woody: 0.5567
#
# Top odors for CC(O)S (probability > 0.5):
# sulfurous: 0.8016
# meaty: 0.6361
# cheesy: 0.5511
#
# Top odors for NCCCC(=O)S (probability > 0.5):
# meaty: 0.6643
# sulfurous: 0.5337
#
# Top odors for CCC(CC)CCCS (probability > 0.5):
# sulfurous: 0.8135
# meaty: 0.7314
# roasted: 0.5965
# fatty: 0.5743
# grapefruit: 0.5631
# savory: 0.5080
#
# Top odors for C=C1CC2CCC1C2(C)S (probability > 0.5):
# fruity: 0.7294
# tropical: 0.6046
# green: 0.5103
#
# Top odors for CCC(O)CC1=CCC=CS1 (probability > 0.5):
# meaty: 0.6143
# sulfurous: 0.5366
# roasted: 0.5053
#
# Top odors for CCCCCC1OCCC1O (probability > 0.5):
# floral: 0.5120
#
# Top odors for CCC=CC(C)OCS (probability > 0.5):
# green: 0.6971
# fruity: 0.5079
#
# Top odors for CCC(O)SC (probability > 0.5):
# sulfurous: 0.7835
# cheesy: 0.5979
# onion: 0.5650
# vegetable: 0.5619
# meaty: 0.5366
# cabbage: 0.5081
#
# Top odors for CSCSCSS (probability > 0.5):
# sulfurous: 0.8436
# onion: 0.6768
# garlic: 0.6159
# meaty: 0.5663
# savory: 0.5466
# alliaceous: 0.5359
#
# Top odors for CCCC=CCC(=N)O (probability > 0.5):
# green: 0.6365
#
# Top odors for OS1=NC(OS)C(S)C=C1 (probability > 0.5):
# odorless: 0.6084
# meaty: 0.5473
#
# Top odors for C1CO1 (probability > 0.5):
# ethereal: 0.7791
# fruity: 0.6434
# solvent: 0.6134
# alcoholic: 0.6066
# sweet: 0.5733
#
# Top odors for CCCCc1cncs1 (probability > 0.5):
# green: 0.8549
# vegetable: 0.7477
# nutty: 0.7064
#
# Top odors for CN(C)N (probability > 0.5):
# fishy: 0.7991
#
# Top odors for C=C(C)c1cnc(C)o1 (probability > 0.5):
# nutty: 0.7439
# green: 0.5832
# roasted: 0.5795
#
# Top odors for C=CCN (probability > 0.5):
# fishy: 0.6171
# meaty: 0.5945
#
# Top odors for CCCCCC1=CC(C)=CC1 (probability > 0.5):
# woody: 0.6783
# waxy: 0.5297
#
# Top odors for COCCSO (probability > 0.5):
#
# Top odors for CC1=CC=CC(C)S1 (probability > 0.5):
# sulfurous: 0.6758
# meaty: 0.5292
#
# Top odors for CC1=CC=C(CO)OC1 (probability > 0.5):
# sweet: 0.5804
#
# Top odors for CC1CC(C)(C)CCO1 (probability > 0.5):
# herbal: 0.7491
# woody: 0.6671
# mint: 0.5843
# green: 0.5725
# fresh: 0.5687
# floral: 0.5240
# camphoreous: 0.5136
#
# Top odors for C=C1C(S)OC(C)C1NC (probability > 0.5):
# meaty: 0.5920
#
# Top odors for CC(O)CCO (probability > 0.5):
# fruity: 0.5016
#
# Top odors for CSCN (probability > 0.5):
# sulfurous: 0.7932
# meaty: 0.6992
# savory: 0.5050
#
# Top odors for CCOC (probability > 0.5):
# ethereal: 0.8860
# alcoholic: 0.6447
# fruity: 0.5927
# sweet: 0.5812
#
# Top odors for CCOCCCCS (probability > 0.5):
# sulfurous: 0.7947
# meaty: 0.6592
# cheesy: 0.5160
# onion: 0.5120
#
# Top odors for CC(C)C1=CN2C(=CS1)C(C)(C)C(C)S2(C)C (probability > 0.5):
# nutty: 0.7242
# roasted: 0.6853
# meaty: 0.6816
#
# Top odors for CCCCC(CC)NO (probability > 0.5):
#
# Top odors for CCC1=CC=CC1 (probability > 0.5):
# citrus: 0.6220
# woody: 0.5356
#
# Top odors for CCC(C)CCC(C)(C)CC (probability > 0.5):
# woody: 0.6580
# green: 0.6009
# floral: 0.5927
# herbal: 0.5037
#
# Top odors for CC1CCCCO1 (probability > 0.5):
# fruity: 0.5707
# solvent: 0.5615
# ethereal: 0.5471
# sweet: 0.5320
#
# Top odors for CC=CC(=O)SCCC(C)N (probability > 0.5):
# meaty: 0.6335
# sulfurous: 0.5788
#
# Top odors for CCCCCSO (probability > 0.5):
# green: 0.6376
# sulfurous: 0.5599
# cheesy: 0.5587
# vegetable: 0.5389
#
# Top odors for CNCCC=CCCCCCCCCCC=O (probability > 0.5):
# fatty: 0.6504
# citrus: 0.6239
#
# Top odors for CC1CCC(N)CS1 (probability > 0.5):
# meaty: 0.7671
# roasted: 0.6675
# nutty: 0.5409
# fishy: 0.5205
#
# Top odors for CC(=O)CSC(N)=O (probability > 0.5):
# sulfurous: 0.6772
# meaty: 0.6008
#
# Top odors for C=CNCCCCCCCSC(C)C (probability > 0.5):
# meaty: 0.6330
# grapefruit: 0.5312
#
# Top odors for CC1=CCC=C1 (probability > 0.5):
# citrus: 0.6384
# woody: 0.5559
# herbal: 0.5126
#
# Top odors for OCCCS (probability > 0.5):
# sulfurous: 0.7456
# meaty: 0.7201
# cheesy: 0.5645
# savory: 0.5002
#
# Top odors for CCC(=O)C(N)CC (probability > 0.5):
#
# Top odors for CNC(=O)CC(C)C (probability > 0.5):
#
# Top odors for CC1OCCO1 (probability > 0.5):
# fruity: 0.8486
# ethereal: 0.7089
# green: 0.6172
# sweet: 0.6055
#
# Top odors for CCCCC1C=NOO1 (probability > 0.5):
# nutty: 0.7078
# roasted: 0.5793
# green: 0.5373
#
# Top odors for CCC=CCC (probability > 0.5):
# green: 0.6856
# gassy: 0.5417
#
# Top odors for CSC(C)C(C)(C)O (probability > 0.5):
# floral: 0.6274
# sulfurous: 0.5991
# tropical: 0.5632
# grapefruit: 0.5571
#
# Top odors for CCCCCC=CCS (probability > 0.5):
# fatty: 0.6749
# sulfurous: 0.6360
# meaty: 0.6108
# vegetable: 0.5113
# green: 0.5018
#
# Top odors for CSCCSCCCCCCCCS (probability > 0.5):
# sulfurous: 0.8279
# meaty: 0.6751
# savory: 0.5577
# onion: 0.5534
# fatty: 0.5513
# roasted: 0.5471
# vegetable: 0.5337
# alliaceous: 0.5120
#
# Top odors for CCC1=CN=C(C)SO1 (probability > 0.5):
# nutty: 0.6476
# roasted: 0.6423
# meaty: 0.6286
#
# Top odors for C=CCCC (probability > 0.5):
# green: 0.6016
# gassy: 0.5733
#
# Top odors for CC1=CCS2(O)CC1C2(C)S (probability > 0.5):
#
# Top odors for CNC(=O)C1CC2CC1C(C)(C)C2 (probability > 0.5):
# cooling: 0.6804
# mint: 0.5597
# odorless: 0.5337
#
# Top odors for CC1CCSCC1 (probability > 0.5):
# sulfurous: 0.8007
# meaty: 0.5332
#
# Top odors for CCC=CCCCSCC(=S)CC (probability > 0.5):
# sulfurous: 0.5989
# meaty: 0.5277
# green: 0.5218
#
# Top odors for NC1CCOC1 (probability > 0.5):
# fishy: 0.6105
#
# Top odors for CC1CCSCC1=S (probability > 0.5):
# sulfurous: 0.7540
# meaty: 0.6833
# roasted: 0.5326
# onion: 0.5167
# garlic: 0.5052
#
# Top odors for CCC(C)OC(=O)C=C(C)C (probability > 0.5):
# fruity: 0.8604
# sweet: 0.6223
# green: 0.5842
# apple: 0.5795
#
# Top odors for CC1=CSC(CCO)=CS1 (probability > 0.5):
# sulfurous: 0.7377
# meaty: 0.6588
# roasted: 0.5762
#
# Top odors for CSOO (probability > 0.5):
# sulfurous: 0.5745
#
# Top odors for CCCCCC (probability > 0.5):
# sweet: 0.6706
#
# Top odors for CNCCCCCO (probability > 0.5):
# fishy: 0.7794
#
# Top odors for CC=CC(N)=O (probability > 0.5):
#
# Top odors for CCC(O)CCCCO (probability > 0.5):
#
# Top odors for C=CC=CC (probability > 0.5):
# green: 0.7266
#
# Top odors for C=CC(=C)CCCC(C)(S)CC (probability > 0.5):
# fruity: 0.7614
# sulfurous: 0.5706
# grapefruit: 0.5689
# floral: 0.5316
# tropical: 0.5206
#
# Top odors for CC1(C)C2CCC(C2)C1O (probability > 0.5):
# camphoreous: 0.7232
# woody: 0.6851
# mint: 0.6618
# herbal: 0.6228
# pine: 0.6120
# cooling: 0.5865
# earthy: 0.5549
# green: 0.5097
#
# Top odors for CC=COC (probability > 0.5):
# ethereal: 0.8715
# fruity: 0.8321
# green: 0.7573
# sharp: 0.6836
# fresh: 0.5615
# pungent: 0.5005
#
# Top odors for CCCCC1=C(C)SC(C)S1 (probability > 0.5):
# sulfurous: 0.6990
# meaty: 0.6388
# roasted: 0.5402
#
# Top odors for CC1(C)C2=CC1C(OCC=O)=CC2 (probability > 0.5):
# woody: 0.7013
# herbal: 0.5882
# fruity: 0.5309
# sweet: 0.5146
#
# Top odors for CC(=O)OCO (probability > 0.5):
# ethereal: 0.6545
# fruity: 0.6222
# winey: 0.5481
# green: 0.5129
# fresh: 0.5031
#
# Top odors for CC(N)CO (probability > 0.5):
# fishy: 0.5714
#
# Top odors for CCCCCCC(C)C (probability > 0.5):
#
# Top odors for O=S(CO)c1ncco1 (probability > 0.5):
# odorless: 0.6981
#
# Top odors for CC1CCSC1 (probability > 0.5):
# sulfurous: 0.8590
# meaty: 0.6012
# alliaceous: 0.5507
# vegetable: 0.5213
# garlic: 0.5179
# onion: 0.5097
#
# Top odors for CC(S)c1ccc(O)cn1 (probability > 0.5):
# meaty: 0.8237
# roasted: 0.7385
# sulfurous: 0.6281
# burnt: 0.5082
#
# Top odors for CC(=S)CC(C)S (probability > 0.5):
# sulfurous: 0.8354
# meaty: 0.6649
# onion: 0.5773
# roasted: 0.5205
# fruity: 0.5174
#
# Top odors for CCCCC(C)C (probability > 0.5):
# green: 0.6399
# herbal: 0.5495
#
# Top odors for C=C(SC)C(S)CCCCCCCC (probability > 0.5):
# sulfurous: 0.7077
# fruity: 0.6660
# grapefruit: 0.6228
# green: 0.5564
# meaty: 0.5284
#
# Top odors for CCC(=O)SC(C)C (probability > 0.5):
# sulfurous: 0.7797
# fruity: 0.6678
# cheesy: 0.6460
# tropical: 0.6019
# vegetable: 0.5557
#
# Top odors for CCNCCCC(O)C=O (probability > 0.5):
# fishy: 0.6721
#
# Top odors for COCCOC(C)O (probability > 0.5):
# fruity: 0.6979
#
# Top odors for C=CC(=C)NCC (probability > 0.5):
# meaty: 0.6418
#
# Top odors for CC1=CSCCN1 (probability > 0.5):
# meaty: 0.7254
# roasted: 0.6510
# nutty: 0.5714
# sulfurous: 0.5195
#
# Top odors for CSC(=O)CCCS (probability > 0.5):
# sulfurous: 0.8683
# meaty: 0.6598
# onion: 0.5258
# savory: 0.5180
# roasted: 0.5077
# fruity: 0.5018
#
# Top odors for C=CCOOC (probability > 0.5):
# fruity: 0.6064
#
# Top odors for CC1CCCC1 (probability > 0.5):
# woody: 0.6672
# musk: 0.6640
# amber: 0.6049
# sweet: 0.5169
# dry: 0.5091
#
# Top odors for C=C(O)C=CC(CCC(=C)O)C(C)C (probability > 0.5):
#
# Top odors for CC(O)CCC(O)SCCN (probability > 0.5):
# meaty: 0.5072
#
# Top odors for OCCCc1cccnc1 (probability > 0.5):
#
# Top odors for C=CCOCCCCCCCC (probability > 0.5):
# green: 0.7678
# fatty: 0.6710
# fresh: 0.6264
# fruity: 0.6091
# waxy: 0.6058
# floral: 0.5873
# herbal: 0.5863
# sweet: 0.5756
# citrus: 0.5556
# oily: 0.5518
# earthy: 0.5264
# orange: 0.5231
# mushroom: 0.5231
# aldehydic: 0.5019
#
# Top odors for C1=COCC1 (probability > 0.5):
# ethereal: 0.7473
# fruity: 0.7383
# sweet: 0.5734
# sharp: 0.5661
# green: 0.5189
#
# Top odors for CCC(O)S (probability > 0.5):
# sulfurous: 0.7889
# meaty: 0.6454
# cheesy: 0.6368
#
# Top odors for CC=CC=CC(=O)CSCC (probability > 0.5):
# meaty: 0.5254
# onion: 0.5240
#
# Top odors for CC=COCC (probability > 0.5):
# ethereal: 0.8565
# fruity: 0.8209
# green: 0.7234
# sharp: 0.6695
# fresh: 0.5554
#
# Top odors for CCC(CC)CS (probability > 0.5):
# sulfurous: 0.8307
# meaty: 0.6648
# savory: 0.5233
# vegetable: 0.5201
# roasted: 0.5050
#
# Top odors for C=CCCSC (probability > 0.5):
# sulfurous: 0.7456
# onion: 0.7165
# garlic: 0.7014
# alliaceous: 0.5775
# vegetable: 0.5755
#
# Top odors for [NH-]CCCS (probability > 0.5):
# meaty: 0.7769
# sulfurous: 0.6597
#
# Top odors for OCCC(O)S (probability > 0.5):
# sulfurous: 0.5965
# meaty: 0.5201
# cheesy: 0.5132
#
# Top odors for CC(C)=CC=N (probability > 0.5):
# green: 0.7594
# pungent: 0.6459
#
# Top odors for CC(C)OC(C)C (probability > 0.5):
# ethereal: 0.8404
# fruity: 0.7762
# alcoholic: 0.7590
# green: 0.7222
# fermented: 0.6777
# cognac: 0.5642
# cocoa: 0.5247
#
# Top odors for CCC(C)C=S (probability > 0.5):
# sulfurous: 0.6083
# onion: 0.5582
# pungent: 0.5521
# vegetable: 0.5271
# garlic: 0.5044
#
# Top odors for O=CCCC=O (probability > 0.5):
# pungent: 0.6984
# fruity: 0.5868
# sharp: 0.5789
#
# Top odors for CCCCCC=COC1CCCC1C (probability > 0.5):
# green: 0.8472
# fruity: 0.6215
# fresh: 0.5500
# herbal: 0.5243
# floral: 0.5185
#
# Top odors for COC1=C=C=C(CCCS)N=C1 (probability > 0.5):
# roasted: 0.6484
# meaty: 0.6213
# nutty: 0.5145
#
# Top odors for OOCC(O)O (probability > 0.5):
# odorless: 0.6736
#
# Top odors for C1COSSC1 (probability > 0.5):
# sulfurous: 0.7823
# meaty: 0.6252
#
# Top odors for C=CCCCOCCCC (probability > 0.5):
# green: 0.8704
# fruity: 0.7903
# fresh: 0.5539
# apple: 0.5392
#
# Top odors for C=CC1=COSC=C1C (probability > 0.5):
# sulfurous: 0.5823
# meaty: 0.5600
#
# Top odors for CC1=CC(C)CC1 (probability > 0.5):
# woody: 0.7593
# citrus: 0.6429
# herbal: 0.5151
#
# Top odors for C=C1OCC(C)=C1CCCCC (probability > 0.5):
# fruity: 0.8135
# floral: 0.7948
# jasmin: 0.5731
# woody: 0.5662
#
# Top odors for Cn1cccn1 (probability > 0.5):
# nutty: 0.8388
# roasted: 0.7496
# hazelnut: 0.6781
# cocoa: 0.6483
# musty: 0.6181
# earthy: 0.6046
# burnt: 0.6005
# coffee: 0.5757
# chocolate: 0.5635
# almond: 0.5252
# potato: 0.5189
#
# Top odors for CSCO (probability > 0.5):
# sulfurous: 0.8263
# onion: 0.6112
# garlic: 0.5764
# cabbage: 0.5610
# vegetable: 0.5294
# meaty: 0.5289
# savory: 0.5202
#
# Top odors for CC(C=O)CCCCO (probability > 0.5):
# fruity: 0.6730
# green: 0.5049
#
# Top odors for CSCCC(C)O (probability > 0.5):
# sulfurous: 0.8003
# meaty: 0.6094
# onion: 0.5557
# cheesy: 0.5551
# vegetable: 0.5412
# savory: 0.5011
#
# Top odors for C=CCC(C)C(=C)OCC (probability > 0.5):
# fruity: 0.7945
# green: 0.6682
# herbal: 0.5553
# fresh: 0.5016
#
# Top odors for CCC (probability > 0.5):
# ethereal: 0.7056
# sweet: 0.5995
#
# Top odors for CCCS(=O)N1OC=CS1 (probability > 0.5):
# odorless: 0.7067
#
# Top odors for CCCCOC (probability > 0.5):
# ethereal: 0.8438
# alcoholic: 0.7664
# fruity: 0.6744
# fermented: 0.6428
# green: 0.5994
# cognac: 0.5426
# sweet: 0.5377
# winey: 0.5259
# solvent: 0.5214
# cocoa: 0.5134
#
# Top odors for CSC(C)CO (probability > 0.5):
# sulfurous: 0.7900
# meaty: 0.6158
# onion: 0.5480
# vegetable: 0.5313
# savory: 0.5095
# cheesy: 0.5000
#
# Top odors for CC1CC(C)SC(O)N1 (probability > 0.5):
# meaty: 0.6526
# roasted: 0.6322
# nutty: 0.5876
#
# Top odors for C=CCC=CCCC(=O)NCC (probability > 0.5):
# meaty: 0.5273
#
# Top odors for CCCOSC (probability > 0.5):
# sulfurous: 0.6502
#
# Top odors for C=C(CCCC)OCC (probability > 0.5):
# fruity: 0.9110
# green: 0.6536
# herbal: 0.5820
# ethereal: 0.5225
# banana: 0.5219
#
# Top odors for C1ONSCSO1 (probability > 0.5):
# meaty: 0.6966
# sulfurous: 0.5568
# roasted: 0.5171
#
# Top odors for CCCCNSCCC (probability > 0.5):
# meaty: 0.6523
# fishy: 0.5482
# cheesy: 0.5213
#
# Top odors for COC(C)C(C)O (probability > 0.5):
# fruity: 0.7067
#
# Top odors for CNCCCC1OC(C)C(C)O1 (probability > 0.5):
#
# Top odors for S=C1CCCCCC1 (probability > 0.5):
# sulfurous: 0.5977
# meaty: 0.5502
#
# Top odors for CC1=C(C)SC2=C(CCC2)N1 (probability > 0.5):
# roasted: 0.7210
# meaty: 0.7044
# nutty: 0.6914
# popcorn: 0.5658
#
# Top odors for CCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.6171
#
# Top odors for C=CC(C)(C)S(=O)CC(C)C (probability > 0.5):
# floral: 0.5942
# citrus: 0.5927
# grapefruit: 0.5692
# herbal: 0.5369
#
# Top odors for OO (probability > 0.5):
# odorless: 0.7138
#
# Top odors for CCCOCCC (probability > 0.5):
# ethereal: 0.8744
# alcoholic: 0.7966
# fruity: 0.7831
# green: 0.6526
# fermented: 0.6209
# cognac: 0.6028
# pungent: 0.5025
#
# Top odors for CC(S)CCCC(C)S (probability > 0.5):
# sulfurous: 0.8592
# meaty: 0.7408
# roasted: 0.5661
# grapefruit: 0.5402
# onion: 0.5118
# fruity: 0.5055
#
# Top odors for CC1CCC(S)S1 (probability > 0.5):
# sulfurous: 0.7526
# meaty: 0.7343
# roasted: 0.5653
#
# Top odors for O=C(CCO)C1=NC=CC1 (probability > 0.5):
# roasted: 0.5231
#
# Top odors for CSC(=O)O (probability > 0.5):
# sulfurous: 0.8122
# meaty: 0.5414
#
# Top odors for CCc1cc(C)cnc1N (probability > 0.5):
# animal: 0.5347
# earthy: 0.5036
#
# Top odors for CC(C)COC1=CC=S2C=CC=CC2=C1 (probability > 0.5):
# fruity: 0.5146
#
# Top odors for CCCCS(C)=O (probability > 0.5):
# cheesy: 0.5941
# sulfurous: 0.5543
# fruity: 0.5383
#
# Top odors for CCC(C)(O)SO (probability > 0.5):
# sulfurous: 0.6726
# fruity: 0.5306
# meaty: 0.5074
#
# Top odors for CC1C=CC(C)O1 (probability > 0.5):
# fruity: 0.5362
# green: 0.5308
#
# Top odors for COSC (probability > 0.5):
# sulfurous: 0.7866
# onion: 0.5890
# vegetable: 0.5425
# garlic: 0.5242
# meaty: 0.5133
#
# Top odors for C=C(O)c1ccccc1 (probability > 0.5):
# sweet: 0.7286
# phenolic: 0.6206
# balsamic: 0.5912
# floral: 0.5590
# vanilla: 0.5281
# almond: 0.5116
#
# Top odors for CSCC=CNC(C)=O (probability > 0.5):
# meaty: 0.6129
# roasted: 0.5158
# sulfurous: 0.5090
#
# Top odors for C[SH](=O)=Cc1ccccc1 (probability > 0.5):
# pungent: 0.6136
# sulfurous: 0.5087
#
# Top odors for CCCSC(=O)O (probability > 0.5):
# sulfurous: 0.8281
# cheesy: 0.6441
# fruity: 0.6063
# meaty: 0.5307
# tropical: 0.5084
# vegetable: 0.5016
#
# Top odors for CC1C=CC(CC(C)C=O)C=C1 (probability > 0.5):
# green: 0.6947
# floral: 0.6560
# fruity: 0.5533
# herbal: 0.5115
#
# Top odors for CCC(C)CNC=O (probability > 0.5):
#
# Top odors for C=CCCC(=C)S (probability > 0.5):
# sulfurous: 0.7571
# onion: 0.6060
# meaty: 0.5987
#
# Top odors for CCCCOCSSS (probability > 0.5):
# sulfurous: 0.6920
# onion: 0.5548
#
# Top odors for C=CC1C=CN(C)C=C1S (probability > 0.5):
# meaty: 0.6987
# roasted: 0.6494
#
# Top odors for CC(C=S)c1ccccc1 (probability > 0.5):
# sulfurous: 0.6607
# green: 0.5161
# onion: 0.5063
#
# Top odors for C=CC=C (probability > 0.5):
# green: 0.6591
# gassy: 0.5238
# pungent: 0.5046
#
# Top odors for Cc1cc(CC(C)C)ccc1CCCO (probability > 0.5):
# floral: 0.8562
# rose: 0.6581
# sweet: 0.5853
# green: 0.5777
# fresh: 0.5030
#
# Top odors for CCCCCOC(=O)OCCS (probability > 0.5):
# fruity: 0.7943
# sulfurous: 0.6180
# tropical: 0.5712
#
# Top odors for CC1CCC(=S)C1=S (probability > 0.5):
# meaty: 0.7324
# roasted: 0.6901
# sulfurous: 0.6017
#
# Top odors for CCCOC (probability > 0.5):
# ethereal: 0.8919
# fruity: 0.7730
# alcoholic: 0.7009
# sweet: 0.5959
# fermented: 0.5625
# green: 0.5370
# winey: 0.5023
#
# Top odors for SC1CCSC1 (probability > 0.5):
# sulfurous: 0.8131
# meaty: 0.7261
#
# Top odors for CCSC(=O)CC1CCCCC1 (probability > 0.5):
# sulfurous: 0.7586
# tropical: 0.6656
# fruity: 0.6507
#
# Top odors for C1=CCCC1 (probability > 0.5):
# musk: 0.5594
#
# Top odors for CSCS(C)=O (probability > 0.5):
# sulfurous: 0.7175
# onion: 0.6792
# garlic: 0.5531
#
# Top odors for COCCN=CCCCC=O (probability > 0.5):
# green: 0.7224
# pungent: 0.5683
# fruity: 0.5381
#
# Top odors for CCC(C)CCC(C)C (probability > 0.5):
# floral: 0.6619
# green: 0.6526
# herbal: 0.5738
# citrus: 0.5657
# fresh: 0.5441
# woody: 0.5214
#
# Top odors for CC(C)=COC(C)C (probability > 0.5):
# fruity: 0.8700
# ethereal: 0.8434
# green: 0.6462
# fresh: 0.5265
#
# Top odors for C=C(CCC)OCCCCOCCCC (probability > 0.5):
# fruity: 0.7827
# green: 0.5132
# ethereal: 0.5074
#
# Top odors for Cc1cc(N)cc(S)n1 (probability > 0.5):
# meaty: 0.6713
# roasted: 0.5706
# burnt: 0.5285
#
# Top odors for CCOCC1=C(N)C=CCC1 (probability > 0.5):
# floral: 0.5333
#
# Top odors for COc1ccc(C)c(C)n1 (probability > 0.5):
# green: 0.7238
# earthy: 0.6010
#
# Top odors for C=CC(C)(O)CNC=S(C)C (probability > 0.5):
#
# Top odors for CC(C)C (probability > 0.5):
# ethereal: 0.7854
# fermented: 0.5977
# alcoholic: 0.5499
# solvent: 0.5422
# musty: 0.5044
#
# Top odors for C=C(CC)CO (probability > 0.5):
# fruity: 0.7190
# sweet: 0.6319
# ethereal: 0.6096
# pungent: 0.5638
# caramellic: 0.5186
#
# Top odors for CC1=CCC(C)C(C)C1O (probability > 0.5):
# mint: 0.6658
# herbal: 0.5708
# woody: 0.5255
# camphoreous: 0.5075
#
# Top odors for CC1=CC(O)OC1C (probability > 0.5):
# sweet: 0.6290
# vanilla: 0.5648
# caramellic: 0.5455
#
# Top odors for CCS(=O)CCC(=O)NC (probability > 0.5):
# meaty: 0.5099
#
# Top odors for CSCCC[O-] (probability > 0.5):
# sulfurous: 0.6630
# cheesy: 0.6310
# meaty: 0.5615
#
# Top odors for CCCCSCCC (probability > 0.5):
# sulfurous: 0.8139
# vegetable: 0.7200
# green: 0.6629
# onion: 0.6235
# alliaceous: 0.5895
# garlic: 0.5736
# meaty: 0.5410
# savory: 0.5259
#
# Top odors for CCNC(N)=O (probability > 0.5):
# odorless: 0.5966
#
# Top odors for COC(OC)OCCCCN (probability > 0.5):
#
# Top odors for CCSC(C)S(O)(O)CC (probability > 0.5):
# sulfurous: 0.6759
# meaty: 0.5615
# grapefruit: 0.5079
#
# Top odors for CNN1CC=CC1C(C)=O (probability > 0.5):
# fishy: 0.5258
#
# Top odors for CC(CC(=O)O)CS(C)(C)C (probability > 0.5):
# fruity: 0.6946
# tropical: 0.6308
# sulfurous: 0.5616
#
# Top odors for CCOC(=O)C1=CC=CCC1 (probability > 0.5):
# fruity: 0.8235
# floral: 0.6911
# sweet: 0.6732
# green: 0.5810
#
# Top odors for C=NCCC (probability > 0.5):
# green: 0.8227
# pungent: 0.6713
# vegetable: 0.5563
# fruity: 0.5127
# radish: 0.5018
#
# Top odors for CCCC (probability > 0.5):
# sweet: 0.6530
# ethereal: 0.5686
# musty: 0.5133
#
# Top odors for Cc1csc(C)c1 (probability > 0.5):
# sulfurous: 0.6252
# green: 0.5518
# onion: 0.5404
# alliaceous: 0.5288
# vegetable: 0.5283
# roasted: 0.5162
#
# Top odors for CCCSCCCCC1CCCC1=S (probability > 0.5):
# meaty: 0.7246
# sulfurous: 0.6654
# roasted: 0.6481
#
# Top odors for CCC(C)C(N)=O (probability > 0.5):
# cheesy: 0.5002
#
# Top odors for Cc1ccccc1C(=O)O (probability > 0.5):
# phenolic: 0.6225
# floral: 0.6015
# sweet: 0.5718
# balsamic: 0.5447
#
# Top odors for C1CNCOC1 (probability > 0.5):
# fishy: 0.6722
#
# Top odors for O=C(OO)c1ccco1 (probability > 0.5):
# caramellic: 0.6358
# fruity: 0.5292
# sweet: 0.5207
#
# Top odors for CC1CCC(C)C1 (probability > 0.5):
# woody: 0.7317
# amber: 0.5685
# musk: 0.5135
#
# Top odors for CC(C)C(C)C (probability > 0.5):
# green: 0.6377
# mint: 0.5962
# ethereal: 0.5871
# camphoreous: 0.5728
# herbal: 0.5459
# fermented: 0.5069
#
# Top odors for CCCCCCCCCSSC (probability > 0.5):
# sulfurous: 0.7799
# green: 0.6775
# vegetable: 0.6386
# fatty: 0.5813
# onion: 0.5783
# meaty: 0.5693
# alliaceous: 0.5111
#
# Top odors for CCCOCCCCC(=O)CC(C)C (probability > 0.5):
# fruity: 0.7068
#
# Top odors for O=S(C=CCO)OCCOO (probability > 0.5):
# sweet: 0.5036
#
# Top odors for CCOOc1cnccn1 (probability > 0.5):
# nutty: 0.6300
# almond: 0.5214
# roasted: 0.5117
#
# Top odors for OCCCCCCO (probability > 0.5):
#
# Top odors for COCC(=O)CCCCCN (probability > 0.5):
# fishy: 0.6111
#
# Top odors for C=C(C)C(C)C(C)O (probability > 0.5):
# floral: 0.6704
# fruity: 0.6301
# citrus: 0.5447
# woody: 0.5155
# rose: 0.5030
#
# Top odors for CCCC(O)CCO (probability > 0.5):
# fruity: 0.5749
#
# Top odors for C=CCOC(=O)[N-]CC (probability > 0.5):
# fruity: 0.8187
#
# Top odors for C=CCSOOSC=C (probability > 0.5):
# sulfurous: 0.7215
# onion: 0.6483
# pungent: 0.5980
# garlic: 0.5135
#
# Top odors for O=C(O)C1CCCCS1 (probability > 0.5):
# sulfurous: 0.8121
# meaty: 0.6773
# roasted: 0.5517
#
# Top odors for CS(C)([O-])O (probability > 0.5):
#
# Top odors for O=C1NCCCCS1 (probability > 0.5):
# meaty: 0.6424
# roasted: 0.5702
#
# Top odors for CCC(N)C(O)=S (probability > 0.5):
# meaty: 0.6077
# sulfurous: 0.5582
#
# Top odors for SCC1CC=CSS1 (probability > 0.5):
# sulfurous: 0.8163
# meaty: 0.6957
# roasted: 0.5180
#
# Top odors for CCS(=O)COC(C)O (probability > 0.5):
#
# Top odors for CCCC=CC(O)SC (probability > 0.5):
# green: 0.5618
# sulfurous: 0.5387
#
# Top odors for CS1=CC=S(C)O1 (probability > 0.5):
# sulfurous: 0.7557
# garlic: 0.5936
# onion: 0.5917
# meaty: 0.5507
# roasted: 0.5001
#
# Top odors for C=C(OSCCCCC)SC (probability > 0.5):
# sulfurous: 0.7429
# onion: 0.6388
#
# Top odors for CNCCS (probability > 0.5):
# meaty: 0.7744
# sulfurous: 0.5767
# fishy: 0.5704
#
# Top odors for S=C1C=CCO1 (probability > 0.5):
# meaty: 0.6523
# roasted: 0.5949
# sulfurous: 0.5888
#
# Top odors for OCOC1CC=C(S)C1(O)S (probability > 0.5):
# odorless: 0.5281
#
# Top odors for CCC(C)C (probability > 0.5):
# ethereal: 0.6290
# musty: 0.5625
# fermented: 0.5411
#
# Top odors for CCOC(=O)OCO (probability > 0.5):
# ethereal: 0.6520
# fresh: 0.5132
# winey: 0.5129
# green: 0.5082
# fruity: 0.5039
#
# Top odors for CSC1CSON(CO)S1 (probability > 0.5):
# meaty: 0.6992
# roasted: 0.5327
# sulfurous: 0.5015
#
# Top odors for CCOC(=O)C(C)(O)C(C)CC (probability > 0.5):
# fruity: 0.7596
#
# Top odors for CC(C)CC(C)C(=O)O (probability > 0.5):
# fruity: 0.8220
#
# Top odors for C=S1C=CC(O)C1 (probability > 0.5):
# meaty: 0.5659
#
# Top odors for NCO (probability > 0.5):
# odorless: 0.7267
# fishy: 0.5953
#
# Top odors for C=C1CCCCCN1 (probability > 0.5):
# animal: 0.5408
# roasted: 0.5387
# fishy: 0.5073
#
# Top odors for C=CC(O)C(O)CS (probability > 0.5):
# sulfurous: 0.5792
# meaty: 0.5374
#
# Top odors for CCCCC=CCCCCS (probability > 0.5):
# fatty: 0.7207
# meaty: 0.6644
# sulfurous: 0.6638

# %%
import os 

odor_counts = Counter(all_top_odors)


plt.figure(figsize=(12, 6))
odors, counts = zip(*odor_counts.most_common(20)) 
plt.bar(odors, counts)
plt.title("Top Predicted Odors Across All Molecules")
plt.xlabel("Odor Labels")
plt.ylabel("Count in Top 10 Predictions")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_folder = '../../figures/GAE/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300, 600, 1200]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_ten_{dpi}dpi.png", dpi=dpi, bbox_inches='tight')
plt.show()

# Print the counts for all odors
print("\nCounts of odors in top 10 predictions across all molecules:")
for odor, count in odor_counts.most_common():
    print(f"{odor}: {count}")

# Print the list of problematic SMILES
print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Counts of odors in top 10 predictions across all molecules:
# sulfurous: 99
# meaty: 95
# fruity: 82
# green: 67
# roasted: 46
# onion: 34
# sweet: 32
# ethereal: 31
# vegetable: 23
# cheesy: 20
# herbal: 20
# floral: 19
# woody: 17
# fresh: 17
# garlic: 16
# fishy: 16
# pungent: 15
# nutty: 14
# tropical: 14
# alcoholic: 12
# savory: 12
# odorless: 11
# fatty: 11
# citrus: 11
# alliaceous: 10
# grapefruit: 9
# fermented: 8
# mint: 7
# sharp: 7
# solvent: 6
# gassy: 5
# musty: 5
# earthy: 5
# caramellic: 4
# burnt: 4
# musk: 4
# camphoreous: 4
# winey: 4
# apple: 3
# animal: 3
# amber: 3
# waxy: 3
# cognac: 3
# cocoa: 3
# almond: 3
# coffee: 2
# dry: 2
# popcorn: 2
# aldehydic: 2
# cabbage: 2
# cooling: 2
# phenolic: 2
# balsamic: 2
# vanilla: 2
# rose: 2
# cooked: 1
# buttery: 1
# creamy: 1
# pine: 1
# oily: 1
# orange: 1
# mushroom: 1
# jasmin: 1
# hazelnut: 1
# chocolate: 1
# potato: 1
# banana: 1
# radish: 1
#
# Problematic SMILES that caused errors:

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt


odor_counts = Counter(all_top_odors)
total_predictions = sum(odor_counts.values())  


percentages = [(count / total_predictions) * 100 for count in odor_counts.values()]


sorted_odors_percentages = sorted(zip(odor_counts.keys(), percentages), key=lambda x: x[1], reverse=True)


top_20_odors_percentages = sorted_odors_percentages[:20]
top_20_odors, top_20_percentages = zip(*top_20_odors_percentages)


plt.figure(figsize=(15, 8))  


bars = plt.bar(top_20_odors, top_20_percentages, edgecolor='black')
ax = plt.gca()  
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(2)  

plt.title("Most Common Odor Predictions (GAE)", fontsize=33, fontweight='bold', pad=20)
plt.xlabel("Odor Labels", fontsize=33, fontweight='bold', labelpad=15)
plt.ylabel("(%) of Predictions", fontsize=29, fontweight='bold', labelpad=10)


plt.xticks(rotation=45, ha='right', fontsize=28, fontweight='bold')
plt.yticks(fontsize=26, fontweight='bold')


plt.tight_layout()


output_folder = '../../figures/GAE/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_odor_per.png", dpi=dpi, bbox_inches='tight')

#Show the plot
plt.show()

# Printing the percentages for the top 20 odors in descending order
print("\nPercentages of top 20 odors in top 10 predictions across all molecules:")
for odor, percentage in zip(top_20_odors, top_20_percentages):
    print(f"{odor}: {percentage:.2f}%")

# Printing the list of problematic SMILES
print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Percentages of top 20 odors in top 10 predictions across all molecules:
# sulfurous: 11.38%
# meaty: 10.92%
# fruity: 9.43%
# green: 7.70%
# roasted: 5.29%
# onion: 3.91%
# sweet: 3.68%
# ethereal: 3.56%
# vegetable: 2.64%
# cheesy: 2.30%
# herbal: 2.30%
# floral: 2.18%
# woody: 1.95%
# fresh: 1.95%
# garlic: 1.84%
# fishy: 1.84%
# pungent: 1.72%
# nutty: 1.61%
# tropical: 1.61%
# alcoholic: 1.38%
#
# Problematic SMILES that caused errors:
