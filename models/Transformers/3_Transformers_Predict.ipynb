# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
from openpom.feat.graph_featurizer import GraphFeaturizer, GraphConvConstants
from openpom.utils.data_utils import get_class_imbalance_ratio, IterativeStratifiedSplitter
from openpom.models.mpnn_pom import MPNNPOMModel
from datetime import datetime
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import gaussian_kde
from collections import Counter
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# WARNING:tensorflow:From c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\deepchem\models\torch_models\__init__.py)

# %%
# Odor Labels
TASKS = [
    'alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
    'anisic', 'apple', 'apricot', 'aromatic', 'balsamic', 'banana', 'beefy',
    'bergamot', 'berry', 'bitter', 'black currant', 'brandy', 'burnt',
    'buttery', 'cabbage', 'camphoreous', 'caramellic', 'cedar', 'celery',
    'chamomile', 'cheesy', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clean',
    'clove', 'cocoa', 'coconut', 'coffee', 'cognac', 'cooked', 'cooling',
    'cortex', 'coumarinic', 'creamy', 'cucumber', 'dairy', 'dry', 'earthy',
    'ethereal', 'fatty', 'fermented', 'fishy', 'floral', 'fresh', 'fruit skin',
    'fruity', 'garlic', 'gassy', 'geranium', 'grape', 'grapefruit', 'grassy',
    'green', 'hawthorn', 'hay', 'hazelnut', 'herbal', 'honey', 'hyacinth',
    'jasmin', 'juicy', 'ketonic', 'lactonic', 'lavender', 'leafy', 'leathery',
    'lemon', 'lily', 'malty', 'meaty', 'medicinal', 'melon', 'metallic',
    'milky', 'mint', 'muguet', 'mushroom', 'musk', 'musty', 'natural', 'nutty',
    'odorless', 'oily', 'onion', 'orange', 'orangeflower', 'orris', 'ozone',
    'peach', 'pear', 'phenolic', 'pine', 'pineapple', 'plum', 'popcorn',
    'potato', 'powdery', 'pungent', 'radish', 'raspberry', 'ripe', 'roasted',
    'rose', 'rummy', 'sandalwood', 'savory', 'sharp', 'smoky', 'soapy',
    'solvent', 'sour', 'spicy', 'strawberry', 'sulfurous', 'sweaty', 'sweet',
    'tea', 'terpenic', 'tobacco', 'tomato', 'tropical', 'vanilla', 'vegetable',
    'vetiver', 'violet', 'warm', 'waxy', 'weedy', 'winey', 'woody'
]
len(TASKS)
# Out:
# 138

# %%
input_file = '../../data/curated dataset/curated_GS_LF_merged_4983.csv'
featurizer = GraphFeaturizer()
smiles_field = 'nonStereoSMILES'

# %%
loader = dc.data.CSVLoader(tasks=TASKS,
feature_field=smiles_field,
featurizer=featurizer)

# %%
dataset = loader.create_dataset(inputs=[input_file])
n_tasks = len(dataset.tasks)
randomstratifiedsplitter = dc.splits.RandomStratifiedSplitter()
train_dataset, test_dataset, valid_dataset = randomstratifiedsplitter.train_valid_test_split(dataset, frac_train = 0.8, frac_valid = 0.1, frac_test = 0.1, seed = 1)
train_ratios = get_class_imbalance_ratio(train_dataset)

# %%
assert len(train_ratios) == n_tasks

# %%
learning_rate = dc.models.optimizers.ExponentialDecay(initial_rate=0.001, decay_rate=0.5, decay_steps=32*20, staircase=True)

# %%
model = MPNNPOMModel(n_tasks = n_tasks,
                     batch_size = 128,
                     learning_rate = learning_rate,
                     class_imbalance_ratio = train_ratios,
                     loss_aggr_type = 'sum',
                     node_out_feats = 100,
                     edge_hidden_feats = 75,
                     edge_out_feats = 100,
                     num_step_message_passing = 5,
                     mpnn_residual = True,
                     message_aggregator_type = 'sum',
                     mode = 'classification',
                     number_atom_features = GraphConvConstants.ATOM_FDIM,
                     number_bond_features = GraphConvConstants.BOND_FDIM,
                     n_classes = 1,
                     readout_type = 'set2set',
                     num_step_set2set = 3,
                     num_layer_set2set = 2,
                     ffn_hidden_list = [392, 392],
                     ffn_embeddings = 256,
                     ffn_activation = 'relu',
                     ffn_dropout_p = 0.12,
                     ffn_dropout_at_input_no_act = False,
                     weight_decay = 1e-5,
                     self_loop = False,
                     optimizer_name = 'adam',
                     log_frequency = 32,
                     model_dir = './experiments',
                     device_name ='cpu')

# %%
import torch
checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
if 'model_state_dict' in checkpoint:
    model.model.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    model.model.load_state_dict(checkpoint, strict=False)
model.model.eval()
# Out:
# C:\Users\sarab\AppData\Local\Temp\ipykernel_10172\2995347586.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
# MPNNPOM(
#   (mpnn): CustomMPNNGNN(
#     (project_node_feats): Sequential(
#       (0): Linear(in_features=134, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (gnn_layer): NNConv(
#       (edge_func): Sequential(
#         (0): Linear(in_features=6, out_features=75, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=75, out_features=10000, bias=True)
#       )
#       (res_fc): Identity()
#     )
#     (gru): GRU(100, 100)
#   )
#   (project_edge_feats): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#   )
#   (readout_set2set): Set2Set(
#     n_iters=3
#     (lstm): LSTM(400, 200, num_layers=2)
#   )
#   (ffn): CustomPositionwiseFeedForward(
#     (activation): ReLU()
#     (linears): ModuleList(
#       (0): Linear(in_features=400, out_features=392, bias=True)
#       (1): Linear(in_features=392, out_features=392, bias=True)
#       (2): Linear(in_features=392, out_features=256, bias=True)
#       (3): Linear(in_features=256, out_features=138, bias=True)
#     )
#     (dropout_p): ModuleList(
#       (0-3): 4 x Dropout(p=0.12, inplace=False)
#     )
#     (batchnorms): ModuleList(
#       (0-1): 2 x BatchNorm1d(392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
csv_file_path = '../../data/Transformer/logistic equation/novel_odorrous_set_log_eq.csv'
df = pd.read_csv(csv_file_path)

# %%
smiles_list = df['SMILE'].tolist()
print(smiles_list)


featurizer = GraphFeaturizer()
featurized_data = featurizer.featurize(smiles_list)


all_top_odors = []
problematic_smiles = []

for i, featurized_mol in enumerate(featurized_data):
    try:
        
        single_mol_dataset = dc.data.NumpyDataset([featurized_mol])

        
        prediction = model.predict(single_mol_dataset)

        
        odor_probs = prediction.squeeze()
        high_prob_indices = np.where(odor_probs > 0.5)[0]
        
        
        sorted_indices = high_prob_indices[np.argsort(odor_probs[high_prob_indices])[::-1]]
        

        top_odors = [TASKS[i] for i in sorted_indices]
        all_top_odors.extend(top_odors)

        
        print(f"\nTop odors for {smiles_list[i]} (probability > 0.5):")
        for odor, score in zip(top_odors, odor_probs[sorted_indices]):
            print(f"{odor}: {score:.4f}")

    except KeyError as e:
        print(f"\nError processing SMILES: {smiles_list[i]}")
        print(f"Error message: {str(e)}")
        problematic_smiles.append(smiles_list[i])
        continue
# Out:
# ['CCCCC=CS(C)=S', 'CCCCCOC(=O)O', 'CC[NH2+]N', 'CSCCC(C)O', 'CCC(=O)S(C)(C)C', 'CCC[SH+]CC', 'CCC(C)CCC(C)N', 'C=CCOCC(C)C(=O)O', 'CC1=CCC(O)(C(C)C)C[NH2+]1', 'COC(=S)C(C)O', 'CCCCC(C)(CC)C(=O)NCC', 'CCC(O)CC1=CC=CCC1', 'CC1=NC2C=CC=CC2C1', 'OC1CCCCC1S', 'CCC(CC)CC', 'CCC(O)C[NH2+]C', 'CCCCCC', 'C=S(C)C', 'CCC=CCOCS', 'CC(C)CC1=CC2=CC=CNC2=CN1', 'C[NH2+]CC[NH2+]C(CO)C(C)=O', 'c1c[nH+]ccn1', 'CSOSO', 'CC(N)CCOOC(=O)CC(C)O', 'C=[NH+]C1=C(O)C=C(C)NN1', 'C[NH2+]CCCCCCCC(=O)CCCCCCS', 'C=CCNC(=O)COC1=CC=CCN1', 'C=CCCCN', 'C=C(C)S1=CC=C(Cl)C=C1', 'CCCOC(=N)OCC(C)CC', 'C=C(CC)C1=[NH+]CCC1', 'CNCCCCN=CCS', 'CSCCCC1CC=CO1', 'C=CCOC(=O)ONCCC', 'CC1CCOC(CO)O1', 'CCCCCOC(C)CC', 'C=C(CC)COC(C)=O', 'CC([NH3+])CN', 'CCN1C=NN(C)S1', 'COCCC=[NH2+]', 'CC(=O)OCC[NH2+]c1ccccc1', 'C=CC1SC=NC1C', 'CC(=S)SC(=O)O', 'CC(S)=CCOC(C)=CCCC=O', 'CCCNSC', '[NH3+]c1cccc(C=O)c1', 'CCCC1=CCC=N1', 'CC1CNC(=O)C1', 'CCCCONO', 'CC[n+]1cc[nH+]nc1SC', 'CC=CCCC[NH2+]C=N', 'CCC(C)C(C)C(=O)O', 'CCC(C)[NH2+]C=O', 'OCCCCc1ccc2ccccc2c1', 'CCCC(CC)SC', 'CCC(O)C(C)C=O', 'C=[N+](C)c1ccc(C)o1', 'CCOC(OOC)C(C)S', 'CCC[SH2+]', 'O=CNCCCC1CCCCC1', 'C=C(NCC(C)C)C(C)=CC', 'CC=CCN', 'CCCC=CCCCCC(C)=O', 'CNS(=O)CCc1ccccc1', 'CCC(=O)CC(C)N', 'CCCCCC(O)C(C)=N', 'CNC(C)C(C)O', 'CCN=S', 'Cc1cc([SH2+])c(C)o1', 'CCCC=CCNC(=O)C(C)CC', 'CCCC', 'CC(C)=CCCC(C)(C)N1CO1', 'CCC1(C)C2(C)CCC(O2)C1(C)C', 'CC(C)[NH2+][O-]', 'C=C(C=CSCCC)OCC', 'c1csc(OCCc2c[nH+]cs2)c1', 'CC1=CC(S)C(C)C(C(=O)S)C1', 'CCC=C[NH2+]O', 'C=C(NC)OCC(C)C', 'CCCCCn1nccn1', 'CCCC(=O)CSOC(=O)O', 'C=S(C)(=O)O', 'CCOC(=O)C(C)(S)S', 'CC[n+]1ccccc1', 'CC(C)CC(=S)OON', 'C=COOCOCOC[NH2+]CCCCC', 'CCOC(C=C(C)NNC=C(C)S)OCC', 'O=C(O)OC1CCCCC1', 'CCSOCC=CC(=O)O', 'CC(S)C(C)CS', 'C=C(C)c1occc1C', 'CCOCC1=CNC=CS1', 'Cc1cnc(C=O)o1', 'COC(=O)CCO', 'C1CCSCC1', 'C1=CC2=CNO[NH2+]C2=C1', 'O=C1CCCOCC1', 'C=CCC(C)C1CC=C(C)CC1', 'C=[N+](C)c1occc1O', 'C=C1CCC(CCCCC)O1', 'CSS1=CN=C(C)NN1', 'CCCC[NH2+]CCC1CC=CC(=S)C1', 'CC(C)CSC(C)C', 'CC(C)C[N+](=O)OCCC1CCCC[NH2+]1', 'CC(=S)C(=N)O', 'CCCCCCCC1CCCC1=S', 'CC[N+]1=NCCC(OC)=C1', 'CC(C)CC(=N)C(O)C(C)C', 'COS1=NC=C(C)N=S1C', 'CCCC(O)C(C)N', 'CCCC1=N[NH2+]C=C1', 'CC1NC(=S)CO1', 'C[N+](=O)CCC=S(C)C', 'C=CCC[NH+]([O-])c1ccccc1', 'CCCOCCC', 'CCC=CCC[NH2+]S(=O)CCC', 'CCC1=COC(C)S1', 'CC(=O)SCC=CCCO', 'CCCCOC[SH+]CC(=O)O[NH2+]C(C)C', 'C=C(C)C(=C)OCCCC', 'OCC1=CCC2=C(C1)OCO2', 'C=C(CN)C(C)(C)C', 'Cc1c(=O)[nH]c(=O)n2c1ncn2C', 'O=C1C=CCC1', 'C=C(CC)CO', 'CC(=S)c1ccccc1N', 'C=C(CCC)CCCN(C)C', 'O=C(O)CCCS', 'CC1=C(S)CCC1=O', 'CCCCNCS', 'CCCCNCC(C)=O', 'CCCSC[NH2+]SCN[NH2+]C', 'C=C[NH2+]CCCCCCCOC(=N)CC', 'CC(C)[NH2+]C1NCC(O)CO1', 'CS1=C(CCO)C=CS1', 'COC1=CC=CNC1', 'CC1(N)CCC=C2CC(C=O)CCN21', 'C1NSCSSO1', 'C=CC=CCC', 'C=C[NH2+]SC', 'NC(=O)c1ccccc1S', 'CSC(C)S1=CC=CO1', 'CCC(N)S', 'CC(C)C1C=CC(O)CC1', 'CC(C)c1ccc(C(C)O)cc1', 'C=CNCCCCCCC=O', 'CCCCC(O)C(=S)CC', 'COCCO', 'CCOS(=O)CC(C)C', 'CC1=C(CC(C)C)[NH+]=CN(C)N1', 'C=C(C)OCc1ccc(C)cc1', 'C=CC(NCC)NCC', 'CC=CC(C)OCC(C)C', 'OCc1cncc[nH+]1', 'CCC(C=O)C[NH3+]', 'CCNC(=O)C(C)CC', 'CCC(O)SCCS', 'CC(=O)NC(C)C(C)=O', 'CSC(S)c1ccco1', 'CCCCCCNCCCOC(=O)S', 'CC1CCCSS1', 'CCCCCCC(=N)CCC=O', 'COONc1ccccc1', 'CCCCO[SH+](=O)C(C)SCC', 'CCCCCC(=O)OCCCSCC', 'CNO', 'CCC[NH2+]C[SH+]COCCO', 'NCOc1ccccc1C=O', 'CC(CO)CC(N)c1ccccc1', 'CC(C)COC(=O)C=CCCS', 'c1ccnnc1', 'C=COCC(C)S', 'Cc1ccc(ONCO)cc1', '[SH2+]c1ccncc1', 'O=C(S)[NH2+]c1ccccc1', 'CCCCC(C)(C)NO', 'CCOC(=O)CCS1=NC=CS1', 'CC', 'CC(=N)c1nccs1', 'O=C(O)CSS', 'CCCC=CCOC(=O)CNCC', 'CCOS(=O)OC1CCCC[NH+]1C(C)(C)O', 'CC(O)CCS', 'CC(C)C1C=CC(C)(C)CC1', 'CC1C2CC2(C(C)C)CS1=N', 'CON', 'CCCOC(=O)C(C)=N', 'CCOC(C)NCC(C)CC', 'O[NH2+]OCC1C=CCC=C1', 'CC1=CSC=S1C', 'O=C(O)CC=CO', 'CC=C[SH+]C', 'CC(=N)N', 'SCC1CC=CN1', 'CC1CCCC1', 'CC(S)NC(=O)C1C=CC=CN1', 'CSNc1ccccc1', 'CC(=N)C(C)N', 'C=C(OC(C)CC)C(C)O', 'C=S(S)NCS1=CC=CO1', 'CCCC(=O)C(C)(C)OC', 'CC(O)C1=CCS2=NC=CC=C2O1', 'CCc1ccccc1C', 'C=S(C)C1CCC(C=O)CC1', 'OCC1NCC2C3CC(OC3NO)C12', 'CCCCC(O)O', 'CCCC(C)C=S', 'C=NOCC', 'CC(C)=[NH+]CC(=O)S1=COC=C1', 'CC(C)(C)[O-]', 'N=CSOCCC1=CC=CON1', 'C=CC(O)CC[NH2+ ...
#
# Top odors for CCCCC=CS(C)=S (probability > 0.5):
# onion: 0.6936
# sulfurous: 0.5991
# pungent: 0.5577
# garlic: 0.5494
#
# Top odors for CCCCCOC(=O)O (probability > 0.5):
# fruity: 0.8027
# winey: 0.5680
#
# Top odors for CC[NH2+]N (probability > 0.5):
# fishy: 0.8925
# cheesy: 0.5563
#
# Top odors for CSCCC(C)O (probability > 0.5):
# sulfurous: 0.8003
# meaty: 0.6094
# onion: 0.5557
# cheesy: 0.5551
# vegetable: 0.5412
# savory: 0.5011
#
# Top odors for CCC(=O)S(C)(C)C (probability > 0.5):
# fruity: 0.7729
# tropical: 0.6374
# sulfurous: 0.6185
# green: 0.5232
#
# Top odors for CCC[SH+]CC (probability > 0.5):
# sulfurous: 0.8749
# meaty: 0.8394
# savory: 0.6335
# roasted: 0.6163
# burnt: 0.5265
# onion: 0.5005
#
# Top odors for CCC(C)CCC(C)N (probability > 0.5):
#
# Top odors for C=CCOCC(C)C(=O)O (probability > 0.5):
# fruity: 0.8093
#
# Top odors for CC1=CCC(O)(C(C)C)C[NH2+]1 (probability > 0.5):
# mint: 0.5201
# woody: 0.5053
#
# Top odors for COC(=S)C(C)O (probability > 0.5):
# sulfurous: 0.7326
# fruity: 0.6609
# meaty: 0.5321
# tropical: 0.5241
#
# Top odors for CCCCC(C)(CC)C(=O)NCC (probability > 0.5):
# mint: 0.5692
# cooling: 0.5526
#
# Top odors for CCC(O)CC1=CC=CCC1 (probability > 0.5):
# green: 0.7437
# floral: 0.7148
# fruity: 0.7130
# herbal: 0.5851
#
# Top odors for CC1=NC2C=CC=CC2C1 (probability > 0.5):
# nutty: 0.6215
# roasted: 0.5570
#
# Top odors for OC1CCCCC1S (probability > 0.5):
# meaty: 0.6996
# sulfurous: 0.5206
#
# Top odors for CCC(CC)CC (probability > 0.5):
# green: 0.6220
# fruity: 0.5940
# sweet: 0.5929
# herbal: 0.5566
#
# Top odors for CCC(O)C[NH2+]C (probability > 0.5):
# fishy: 0.5020
#
# Top odors for CCCCCC (probability > 0.5):
# sweet: 0.6706
#
# Top odors for C=S(C)C (probability > 0.5):
# pungent: 0.6659
# onion: 0.6647
# garlic: 0.6326
# sulfurous: 0.5609
# alliaceous: 0.5579
#
# Top odors for CCC=CCOCS (probability > 0.5):
# green: 0.6918
# fruity: 0.5949
#
# Top odors for CC(C)CC1=CC2=CC=CNC2=CN1 (probability > 0.5):
# nutty: 0.6669
# roasted: 0.6419
# meaty: 0.5116
# popcorn: 0.5112
#
# Top odors for C[NH2+]CC[NH2+]C(CO)C(C)=O (probability > 0.5):
# fishy: 0.5590
#
# Top odors for c1c[nH+]ccn1 (probability > 0.5):
# nutty: 0.7902
# burnt: 0.7160
# musty: 0.6777
# roasted: 0.6702
# cocoa: 0.6574
# sweet: 0.5916
# ethereal: 0.5838
# coffee: 0.5783
# hazelnut: 0.5603
# fishy: 0.5043
#
# Top odors for CSOSO (probability > 0.5):
# sulfurous: 0.7349
# meaty: 0.5037
#
# Top odors for CC(N)CCOOC(=O)CC(C)O (probability > 0.5):
#
# Top odors for C=[NH+]C1=C(O)C=C(C)NN1 (probability > 0.5):
# odorless: 0.8093
#
# Top odors for C[NH2+]CCCCCCCC(=O)CCCCCCS (probability > 0.5):
# meaty: 0.6607
# grapefruit: 0.5865
# fatty: 0.5488
#
# Top odors for C=CCNC(=O)COC1=CC=CCN1 (probability > 0.5):
# odorless: 0.5931
#
# Top odors for C=CCCCN (probability > 0.5):
# cheesy: 0.6096
# fishy: 0.5456
# meaty: 0.5256
#
# Top odors for C=C(C)S1=CC=C(Cl)C=C1 (probability > 0.5):
#
# Top odors for CCCOC(=N)OCC(C)CC (probability > 0.5):
# fruity: 0.8573
# green: 0.6586
# apple: 0.6350
#
# Top odors for C=C(CC)C1=[NH+]CCC1 (probability > 0.5):
#
# Top odors for CNCCCCN=CCS (probability > 0.5):
# meaty: 0.6126
# fishy: 0.5928
#
# Top odors for CSCCCC1CC=CO1 (probability > 0.5):
# sulfurous: 0.6691
# meaty: 0.5915
# vegetable: 0.5598
# onion: 0.5339
#
# Top odors for C=CCOC(=O)ONCCC (probability > 0.5):
# fruity: 0.7843
#
# Top odors for CC1CCOC(CO)O1 (probability > 0.5):
# fruity: 0.7843
# ethereal: 0.5054
#
# Top odors for CCCCCOC(C)CC (probability > 0.5):
# green: 0.8520
# fruity: 0.7566
# alcoholic: 0.7160
# ethereal: 0.7012
# cognac: 0.6571
# fermented: 0.6504
# apple: 0.5479
# cocoa: 0.5099
#
# Top odors for C=C(CC)COC(C)=O (probability > 0.5):
# fruity: 0.8691
# sweet: 0.6170
# ethereal: 0.6113
# apple: 0.5804
# green: 0.5023
#
# Top odors for CC([NH3+])CN (probability > 0.5):
# fishy: 0.8282
# cheesy: 0.6860
#
# Top odors for CCN1C=NN(C)S1 (probability > 0.5):
# nutty: 0.8127
# meaty: 0.7440
# roasted: 0.7277
# popcorn: 0.6487
#
# Top odors for COCCC=[NH2+] (probability > 0.5):
# fruity: 0.8267
# green: 0.7760
# ethereal: 0.6783
# pungent: 0.6635
# sharp: 0.6038
# fresh: 0.5378
#
# Top odors for CC(=O)OCC[NH2+]c1ccccc1 (probability > 0.5):
# floral: 0.8410
# sweet: 0.7393
# rose: 0.7317
# honey: 0.6607
# fruity: 0.5397
# balsamic: 0.5306
#
# Top odors for C=CC1SC=NC1C (probability > 0.5):
# meaty: 0.6884
# roasted: 0.6431
# nutty: 0.6164
#
# Top odors for CC(=S)SC(=O)O (probability > 0.5):
# sulfurous: 0.8634
# meaty: 0.5525
#
# Top odors for CC(S)=CCOC(C)=CCCC=O (probability > 0.5):
# sulfurous: 0.6940
# fruity: 0.5548
# tropical: 0.5348
# onion: 0.5212
#
# Top odors for CCCNSC (probability > 0.5):
# meaty: 0.7147
# fishy: 0.5670
# sulfurous: 0.5343
# cheesy: 0.5093
#
# Top odors for [NH3+]c1cccc(C=O)c1 (probability > 0.5):
# sweet: 0.8021
# cherry: 0.6868
# almond: 0.6673
# floral: 0.6503
# fruity: 0.6131
# bitter: 0.5513
#
# Top odors for CCCC1=CCC=N1 (probability > 0.5):
# nutty: 0.6920
# roasted: 0.6027
# meaty: 0.5245
#
# Top odors for CC1CNC(=O)C1 (probability > 0.5):
# odorless: 0.5749
#
# Top odors for CCCCONO (probability > 0.5):
#
# Top odors for CC[n+]1cc[nH+]nc1SC (probability > 0.5):
# nutty: 0.7719
# roasted: 0.6943
# earthy: 0.6076
# green: 0.5713
# meaty: 0.5463
# hazelnut: 0.5368
# vegetable: 0.5085
# burnt: 0.5049
#
# Top odors for CC=CCCC[NH2+]C=N (probability > 0.5):
# green: 0.5970
# fatty: 0.5315
#
# Top odors for CCC(C)C(C)C(=O)O (probability > 0.5):
# fruity: 0.8331
# cheesy: 0.5099
#
# Top odors for CCC(C)[NH2+]C=O (probability > 0.5):
# fruity: 0.7159
# cheesy: 0.7153
#
# Top odors for OCCCCc1ccc2ccccc2c1 (probability > 0.5):
# floral: 0.8909
# rose: 0.8209
# sweet: 0.7178
# honey: 0.6166
# balsamic: 0.5809
# green: 0.5159
#
# Top odors for CCCC(CC)SC (probability > 0.5):
# sulfurous: 0.8082
# green: 0.7150
# vegetable: 0.6943
# tropical: 0.5357
# meaty: 0.5292
# onion: 0.5254
# fruity: 0.5052
#
# Top odors for CCC(O)C(C)C=O (probability > 0.5):
# fruity: 0.7570
#
# Top odors for C=[N+](C)c1ccc(C)o1 (probability > 0.5):
# herbal: 0.5946
# spicy: 0.5705
# nutty: 0.5241
# green: 0.5100
#
# Top odors for CCOC(OOC)C(C)S (probability > 0.5):
# fruity: 0.5375
#
# Top odors for CCC[SH2+] (probability > 0.5):
# sulfurous: 0.8030
# meaty: 0.7299
# cheesy: 0.6539
# savory: 0.5688
# fishy: 0.5301
# vegetable: 0.5038
#
# Top odors for O=CNCCCC1CCCCC1 (probability > 0.5):
# odorless: 0.5198
#
# Top odors for C=C(NCC(C)C)C(C)=CC (probability > 0.5):
#
# Top odors for CC=CCN (probability > 0.5):
# meaty: 0.5481
#
# Top odors for CCCC=CCCCCC(C)=O (probability > 0.5):
# fruity: 0.7596
# fatty: 0.7457
# waxy: 0.5888
# green: 0.5668
# floral: 0.5356
#
# Top odors for CNS(=O)CCc1ccccc1 (probability > 0.5):
#
# Top odors for CCC(=O)CC(C)N (probability > 0.5):
#
# Top odors for CCCCCC(O)C(C)=N (probability > 0.5):
#
# Top odors for CNC(C)C(C)O (probability > 0.5):
#
# Top odors for CCN=S (probability > 0.5):
# pungent: 0.7533
# radish: 0.5978
# sulfurous: 0.5908
#
# Top odors for Cc1cc([SH2+])c(C)o1 (probability > 0.5):
# meaty: 0.7376
# roasted: 0.6849
# sulfurous: 0.6638
# burnt: 0.5754
#
# Top odors for CCCC=CCNC(=O)C(C)CC (probability > 0.5):
#
# Top odors for CCCC (probability > 0.5):
# sweet: 0.6530
# ethereal: 0.5686
# musty: 0.5133
#
# Top odors for CC(C)=CCCC(C)(C)N1CO1 (probability > 0.5):
# woody: 0.5485
#
# Top odors for CCC1(C)C2(C)CCC(O2)C1(C)C (probability > 0.5):
# woody: 0.7244
# green: 0.6612
# herbal: 0.6449
# camphoreous: 0.6362
# earthy: 0.6208
# pine: 0.5445
# mint: 0.5167
#
# Top odors for CC(C)[NH2+][O-] (probability > 0.5):
# odorless: 0.5522
#
# Top odors for C=C(C=CSCCC)OCC (probability > 0.5):
# sulfurous: 0.7126
# onion: 0.6368
# garlic: 0.5022
#
# Top odors for c1csc(OCCc2c[nH+]cs2)c1 (probability > 0.5):
# sulfurous: 0.6584
# roasted: 0.6454
# meaty: 0.6197
# coffee: 0.5831
# nutty: 0.5300
#
# Top odors for CC1=CC(S)C(C)C(C(=O)S)C1 (probability > 0.5):
# meaty: 0.7174
# sulfurous: 0.6221
# roasted: 0.6212
#
# Top odors for CCC=C[NH2+]O (probability > 0.5):
# fruity: 0.5787
# cheesy: 0.5512
# pungent: 0.5512
# green: 0.5273
#
# Top odors for C=C(NC)OCC(C)C (probability > 0.5):
#
# Top odors for CCCCCn1nccn1 (probability > 0.5):
# nutty: 0.7617
# roasted: 0.6456
# green: 0.5765
# earthy: 0.5499
# cocoa: 0.5433
# meaty: 0.5188
#
# Top odors for CCCC(=O)CSOC(=O)O (probability > 0.5):
# sulfurous: 0.7291
# fruity: 0.6865
# tropical: 0.6199
#
# Top odors for C=S(C)(=O)O (probability > 0.5):
# odorless: 0.8753
#
# Top odors for CCOC(=O)C(C)(S)S (probability > 0.5):
# sulfurous: 0.8294
# fruity: 0.7365
# tropical: 0.6998
# meaty: 0.5682
# green: 0.5224
#
# Top odors for CC[n+]1ccccc1 (probability > 0.5):
# sweet: 0.6285
# green: 0.6038
# floral: 0.5053
#
# Top odors for CC(C)CC(=S)OON (probability > 0.5):
# fruity: 0.6913
#
# Top odors for C=COOCOCOC[NH2+]CCCCC (probability > 0.5):
# fruity: 0.5327
# odorless: 0.5190
#
# Top odors for CCOC(C=C(C)NNC=C(C)S)OCC (probability > 0.5):
#
# Top odors for O=C(O)OC1CCCCC1 (probability > 0.5):
# fruity: 0.6248
#
# Top odors for CCSOCC=CC(=O)O (probability > 0.5):
# sulfurous: 0.7124
# meaty: 0.5473
#
# Top odors for CC(S)C(C)CS (probability > 0.5):
# sulfurous: 0.8705
# meaty: 0.7301
# roasted: 0.5654
# onion: 0.5537
# savory: 0.5109
#
# Top odors for C=C(C)c1occc1C (probability > 0.5):
# nutty: 0.6586
# roasted: 0.5411
# herbal: 0.5237
# sweet: 0.5107
# musty: 0.5075
#
# Top odors for CCOCC1=CNC=CS1 (probability > 0.5):
# meaty: 0.6284
# roasted: 0.5970
#
# Top odors for Cc1cnc(C=O)o1 (probability > 0.5):
# nutty: 0.6721
#
# Top odors for COC(=O)CCO (probability > 0.5):
# fruity: 0.7658
# ethereal: 0.6652
# green: 0.6021
# winey: 0.5996
# apple: 0.5448
#
# Top odors for C1CCSCC1 (probability > 0.5):
# sulfurous: 0.8706
# meaty: 0.6183
# garlic: 0.5146
#
# Top odors for C1=CC2=CNO[NH2+]C2=C1 (probability > 0.5):
# nutty: 0.5323
# roasted: 0.5269
#
# Top odors for O=C1CCCOCC1 (probability > 0.5):
# sweet: 0.5637
# caramellic: 0.5547
# fruity: 0.5185
#
# Top odors for C=CCC(C)C1CC=C(C)CC1 (probability > 0.5):
# woody: 0.6496
# citrus: 0.6098
# floral: 0.5506
# herbal: 0.5422
# fresh: 0.5192
#
# Top odors for C=[N+](C)c1occc1O (probability > 0.5):
# fruity: 0.7245
# caramellic: 0.5415
#
# Top odors for C=C1CCC(CCCCC)O1 (probability > 0.5):
# fruity: 0.7018
# floral: 0.6815
# green: 0.6603
# jasmin: 0.5843
# herbal: 0.5590
# fatty: 0.5010
#
# Top odors for CSS1=CN=C(C)NN1 (probability > 0.5):
# meaty: 0.6616
# roasted: 0.6055
# nutty: 0.5902
#
# Top odors for CCCC[NH2+]CCC1CC=CC(=S)C1 (probability > 0.5):
# meaty: 0.6270
# roasted: 0.5723
#
# Top odors for CC(C)CSC(C)C (probability > 0.5):
# sulfurous: 0.8501
# vegetable: 0.6318
# meaty: 0.6209
# green: 0.5876
# tropical: 0.5518
# onion: 0.5339
# alliaceous: 0.5178
#
# Top odors for CC(C)C[N+](=O)OCCC1CCCC[NH2+]1 (probability > 0.5):
# fruity: 0.6607
#
# Top odors for CC(=S)C(=N)O (probability > 0.5):
# sulfurous: 0.5491
#
# Top odors for CCCCCCCC1CCCC1=S (probability > 0.5):
# meaty: 0.5582
# fruity: 0.5203
#
# Top odors for CC[N+]1=NCCC(OC)=C1 (probability > 0.5):
# nutty: 0.6860
# roasted: 0.6445
#
# Top odors for CC(C)CC(=N)C(O)C(C)C (probability > 0.5):
# mint: 0.6014
#
# Top odors for COS1=NC=C(C)N=S1C (probability > 0.5):
# nutty: 0.6861
# roasted: 0.6151
# meaty: 0.6044
#
# Top odors for CCCC(O)C(C)N (probability > 0.5):
#
# Top odors for CCCC1=N[NH2+]C=C1 (probability > 0.5):
# nutty: 0.7084
# roasted: 0.6595
# popcorn: 0.5746
# meaty: 0.5229
#
# Top odors for CC1NC(=S)CO1 (probability > 0.5):
# odorless: 0.6628
# meaty: 0.5245
#
# Top odors for C[N+](=O)CCC=S(C)C (probability > 0.5):
# fruity: 0.5154
# sulfurous: 0.5046
#
# Top odors for C=CCC[NH+]([O-])c1ccccc1 (probability > 0.5):
# sweet: 0.5638
#
# Top odors for CCCOCCC (probability > 0.5):
# ethereal: 0.8744
# alcoholic: 0.7966
# fruity: 0.7831
# green: 0.6526
# fermented: 0.6209
# cognac: 0.6028
# pungent: 0.5025
#
# Top odors for CCC=CCC[NH2+]S(=O)CCC (probability > 0.5):
#
# Top odors for CCC1=COC(C)S1 (probability > 0.5):
# sulfurous: 0.6659
# meaty: 0.6007
# roasted: 0.5284
#
# Top odors for CC(=O)SCC=CCCO (probability > 0.5):
# sulfurous: 0.7749
# fruity: 0.5760
# onion: 0.5704
# tropical: 0.5682
# meaty: 0.5289
#
# Top odors for CCCCOC[SH+]CC(=O)O[NH2+]C(C)C (probability > 0.5):
# fruity: 0.5420
#
# Top odors for C=C(C)C(=C)OCCCC (probability > 0.5):
# fruity: 0.7921
# herbal: 0.6060
# mint: 0.5865
#
# Top odors for OCC1=CCC2=C(C1)OCO2 (probability > 0.5):
# caramellic: 0.6506
# fruity: 0.6368
# sweet: 0.6182
#
# Top odors for C=C(CN)C(C)(C)C (probability > 0.5):
# woody: 0.5342
# mint: 0.5126
#
# Top odors for Cc1c(=O)[nH]c(=O)n2c1ncn2C (probability > 0.5):
# odorless: 0.8338
#
# Top odors for O=C1C=CCC1 (probability > 0.5):
# caramellic: 0.5544
# sweet: 0.5290
#
# Top odors for C=C(CC)CO (probability > 0.5):
# fruity: 0.7190
# sweet: 0.6319
# ethereal: 0.6096
# pungent: 0.5638
# caramellic: 0.5186
#
# Top odors for CC(=S)c1ccccc1N (probability > 0.5):
# meaty: 0.6063
# sulfurous: 0.6034
# roasted: 0.5140
#
# Top odors for C=C(CCC)CCCN(C)C (probability > 0.5):
# woody: 0.5043
#
# Top odors for O=C(O)CCCS (probability > 0.5):
# sulfurous: 0.8659
# meaty: 0.7667
# roasted: 0.5498
# savory: 0.5003
#
# Top odors for CC1=C(S)CCC1=O (probability > 0.5):
# sulfurous: 0.6514
# meaty: 0.5780
# roasted: 0.5446
# fruity: 0.5140
#
# Top odors for CCCCNCS (probability > 0.5):
# fishy: 0.6640
# meaty: 0.6337
# cheesy: 0.6106
#
# Top odors for CCCCNCC(C)=O (probability > 0.5):
# fishy: 0.6761
#
# Top odors for CCCSC[NH2+]SCN[NH2+]C (probability > 0.5):
# meaty: 0.6514
#
# Top odors for C=C[NH2+]CCCCCCCOC(=N)CC (probability > 0.5):
#
# Top odors for CC(C)[NH2+]C1NCC(O)CO1 (probability > 0.5):
# odorless: 0.6738
#
# Top odors for CS1=C(CCO)C=CS1 (probability > 0.5):
# meaty: 0.6857
# sulfurous: 0.6794
# roasted: 0.6077
#
# Top odors for COC1=CC=CNC1 (probability > 0.5):
# nutty: 0.5922
# roasted: 0.5854
#
# Top odors for CC1(N)CCC=C2CC(C=O)CCN21 (probability > 0.5):
# odorless: 0.5183
#
# Top odors for C1NSCSSO1 (probability > 0.5):
# meaty: 0.7123
# sulfurous: 0.6779
# roasted: 0.5355
#
# Top odors for C=CC=CCC (probability > 0.5):
# green: 0.7007
# gassy: 0.5170
#
# Top odors for C=C[NH2+]SC (probability > 0.5):
# sulfurous: 0.8053
# meaty: 0.6983
# onion: 0.6169
# roasted: 0.5745
# garlic: 0.5358
#
# Top odors for NC(=O)c1ccccc1S (probability > 0.5):
# meaty: 0.5702
#
# Top odors for CSC(C)S1=CC=CO1 (probability > 0.5):
# sulfurous: 0.7120
# meaty: 0.6787
# roasted: 0.6329
# onion: 0.5278
#
# Top odors for CCC(N)S (probability > 0.5):
# meaty: 0.7831
# sulfurous: 0.6600
# savory: 0.5041
#
# Top odors for CC(C)C1C=CC(O)CC1 (probability > 0.5):
# mint: 0.6971
# herbal: 0.6875
# floral: 0.5948
# woody: 0.5804
# spicy: 0.5138
# green: 0.5055
#
# Top odors for CC(C)c1ccc(C(C)O)cc1 (probability > 0.5):
# floral: 0.7359
# green: 0.6569
# herbal: 0.6000
# sweet: 0.5609
#
# Top odors for C=CNCCCCCCC=O (probability > 0.5):
#
# Top odors for CCCCC(O)C(=S)CC (probability > 0.5):
#
# Top odors for COCCO (probability > 0.5):
# alcoholic: 0.5667
# odorless: 0.5570
#
# Top odors for CCOS(=O)CC(C)C (probability > 0.5):
# fruity: 0.7979
# tropical: 0.6048
# sulfurous: 0.5368
#
# Top odors for CC1=C(CC(C)C)[NH+]=CN(C)N1 (probability > 0.5):
# roasted: 0.5086
#
# Top odors for C=C(C)OCc1ccc(C)cc1 (probability > 0.5):
# floral: 0.8328
# sweet: 0.7872
# fruity: 0.7346
# anisic: 0.5666
# cherry: 0.5644
# balsamic: 0.5391
#
# Top odors for C=CC(NCC)NCC (probability > 0.5):
# fishy: 0.5461
#
# Top odors for CC=CC(C)OCC(C)C (probability > 0.5):
# green: 0.7654
# fruity: 0.7176
#
# Top odors for OCc1cncc[nH+]1 (probability > 0.5):
# nutty: 0.6582
# roasted: 0.6025
# almond: 0.5342
#
# Top odors for CCC(C=O)C[NH3+] (probability > 0.5):
# fruity: 0.7122
# green: 0.6476
# cheesy: 0.5685
# pungent: 0.5574
#
# Top odors for CCNC(=O)C(C)CC (probability > 0.5):
# fishy: 0.5081
#
# Top odors for CCC(O)SCCS (probability > 0.5):
# sulfurous: 0.8249
# meaty: 0.6196
# onion: 0.5905
# savory: 0.5170
#
# Top odors for CC(=O)NC(C)C(C)=O (probability > 0.5):
#
# Top odors for CSC(S)c1ccco1 (probability > 0.5):
# meaty: 0.7960
# sulfurous: 0.7940
# roasted: 0.7738
# coffee: 0.6269
# burnt: 0.5402
# beefy: 0.5026
#
# Top odors for CCCCCCNCCCOC(=O)S (probability > 0.5):
#
# Top odors for CC1CCCSS1 (probability > 0.5):
# sulfurous: 0.8532
# garlic: 0.5953
# meaty: 0.5776
# alliaceous: 0.5744
#
# Top odors for CCCCCCC(=N)CCC=O (probability > 0.5):
# citrus: 0.6245
# fresh: 0.5001
#
# Top odors for COONc1ccccc1 (probability > 0.5):
# rose: 0.6364
# sweet: 0.6154
# floral: 0.5818
# honey: 0.5013
#
# Top odors for CCCCO[SH+](=O)C(C)SCC (probability > 0.5):
# sulfurous: 0.7093
# tropical: 0.5075
# fruity: 0.5045
#
# Top odors for CCCCCC(=O)OCCCSCC (probability > 0.5):
# fruity: 0.7804
# sulfurous: 0.7703
# tropical: 0.6922
# cheesy: 0.5455
#
# Top odors for CNO (probability > 0.5):
# odorless: 0.5658
#
# Top odors for CCC[NH2+]C[SH+]COCCO (probability > 0.5):
# fishy: 0.5641
#
# Top odors for NCOc1ccccc1C=O (probability > 0.5):
# sweet: 0.6974
# vanilla: 0.6048
#
# Top odors for CC(CO)CC(N)c1ccccc1 (probability > 0.5):
# sweet: 0.5371
#
# Top odors for CC(C)COC(=O)C=CCCS (probability > 0.5):
# fruity: 0.7684
# sulfurous: 0.7527
# tropical: 0.6925
#
# Top odors for c1ccnnc1 (probability > 0.5):
# nutty: 0.8243
# roasted: 0.6955
# burnt: 0.6783
# cocoa: 0.6759
# musty: 0.6645
# coffee: 0.6054
# hazelnut: 0.5993
# ethereal: 0.5598
# sweet: 0.5574
#
# Top odors for C=COCC(C)S (probability > 0.5):
# sulfurous: 0.7749
# onion: 0.5648
# fruity: 0.5552
# meaty: 0.5536
# tropical: 0.5395
#
# Top odors for Cc1ccc(ONCO)cc1 (probability > 0.5):
# sweet: 0.6271
# balsamic: 0.5026
#
# Top odors for [SH2+]c1ccncc1 (probability > 0.5):
# burnt: 0.6503
# sulfurous: 0.6148
# roasted: 0.5977
# nutty: 0.5812
# coffee: 0.5553
# meaty: 0.5201
#
# Top odors for O=C(S)[NH2+]c1ccccc1 (probability > 0.5):
# sulfurous: 0.5485
#
# Top odors for CCCCC(C)(C)NO (probability > 0.5):
#
# Top odors for CCOC(=O)CCS1=NC=CS1 (probability > 0.5):
# meaty: 0.6244
# sulfurous: 0.5905
# roasted: 0.5861
#
# Top odors for CC (probability > 0.5):
# ethereal: 0.6569
# sweet: 0.5423
#
# Top odors for CC(=N)c1nccs1 (probability > 0.5):
# nutty: 0.7339
# roasted: 0.5709
#
# Top odors for O=C(O)CSS (probability > 0.5):
# sulfurous: 0.8254
# meaty: 0.6556
#
# Top odors for CCCC=CCOC(=O)CNCC (probability > 0.5):
# green: 0.6310
# fruity: 0.5624
#
# Top odors for CCOS(=O)OC1CCCC[NH+]1C(C)(C)O (probability > 0.5):
# odorless: 0.5488
# cooling: 0.5217
# mint: 0.5118
#
# Top odors for CC(O)CCS (probability > 0.5):
# sulfurous: 0.8136
# meaty: 0.7151
# onion: 0.5213
#
# Top odors for CC(C)C1C=CC(C)(C)CC1 (probability > 0.5):
# woody: 0.8068
# herbal: 0.6888
# green: 0.6344
# citrus: 0.6218
# fresh: 0.6185
# floral: 0.5567
# terpenic: 0.5309
# pine: 0.5292
# spicy: 0.5035
#
# Top odors for CC1C2CC2(C(C)C)CS1=N (probability > 0.5):
# green: 0.5074
#
# Top odors for CON (probability > 0.5):
# odorless: 0.7115
#
# Top odors for CCCOC(=O)C(C)=N (probability > 0.5):
# fruity: 0.8510
# caramellic: 0.5443
# apple: 0.5053
#
# Top odors for CCOC(C)NCC(C)CC (probability > 0.5):
#
# Top odors for O[NH2+]OCC1C=CCC=C1 (probability > 0.5):
# fruity: 0.7147
# green: 0.6289
# floral: 0.5928
#
# Top odors for CC1=CSC=S1C (probability > 0.5):
# sulfurous: 0.7384
# garlic: 0.5284
# meaty: 0.5200
# onion: 0.5159
#
# Top odors for O=C(O)CC=CO (probability > 0.5):
# sour: 0.5110
# odorless: 0.5005
#
# Top odors for CC=C[SH+]C (probability > 0.5):
# sulfurous: 0.8086
# onion: 0.7374
# garlic: 0.7210
# pungent: 0.6120
# alliaceous: 0.5303
#
# Top odors for CC(=N)N (probability > 0.5):
# odorless: 0.6912
#
# Top odors for SCC1CC=CN1 (probability > 0.5):
# meaty: 0.7820
# roasted: 0.7231
# nutty: 0.6773
# popcorn: 0.5358
#
# Top odors for CC1CCCC1 (probability > 0.5):
# woody: 0.6672
# musk: 0.6640
# amber: 0.6049
# sweet: 0.5169
# dry: 0.5091
#
# Top odors for CC(S)NC(=O)C1C=CC=CN1 (probability > 0.5):
# odorless: 0.5810
# meaty: 0.5587
#
# Top odors for CSNc1ccccc1 (probability > 0.5):
# sulfurous: 0.7661
# meaty: 0.6724
# roasted: 0.5605
#
# Top odors for CC(=N)C(C)N (probability > 0.5):
# fishy: 0.5027
#
# Top odors for C=C(OC(C)CC)C(C)O (probability > 0.5):
# fruity: 0.6410
# sweet: 0.5459
#
# Top odors for C=S(S)NCS1=CC=CO1 (probability > 0.5):
# sulfurous: 0.5288
# meaty: 0.5106
#
# Top odors for CCCC(=O)C(C)(C)OC (probability > 0.5):
# fruity: 0.8606
#
# Top odors for CC(O)C1=CCS2=NC=CC=C2O1 (probability > 0.5):
# roasted: 0.6698
# meaty: 0.6315
# nutty: 0.5853
#
# Top odors for CCc1ccccc1C (probability > 0.5):
# sweet: 0.6470
# floral: 0.5340
#
# Top odors for C=S(C)C1CCC(C=O)CC1 (probability > 0.5):
#
# Top odors for OCC1NCC2C3CC(OC3NO)C12 (probability > 0.5):
# odorless: 0.7305
#
# Top odors for CCCCC(O)O (probability > 0.5):
# fruity: 0.7785
# oily: 0.5157
# sweet: 0.5092
#
# Top odors for CCCC(C)C=S (probability > 0.5):
# sulfurous: 0.5705
# green: 0.5649
# vegetable: 0.5531
# onion: 0.5145
#
# Top odors for C=NOCC (probability > 0.5):
# fruity: 0.6706
# pungent: 0.5994
# ethereal: 0.5985
# sharp: 0.5339
# green: 0.5059
#
# Top odors for CC(C)=[NH+]CC(=O)S1=COC=C1 (probability > 0.5):
# meaty: 0.5116
#
# Top odors for CC(C)(C)[O-] (probability > 0.5):
# fruity: 0.7726
# ethereal: 0.6409
# green: 0.6194
# fresh: 0.5191
#
# Top odors for N=CSOCCC1=CC=CON1 (probability > 0.5):
# odorless: 0.5912
#
# Top odors for C=CC(O)CC[NH2+]CCC (probability > 0.5):
#
# Top odors for CC(N)C(N)C(=O)O (probability > 0.5):
#
# Top odors for COCCCCCN=C=S (probability > 0.5):
# pungent: 0.7498
# radish: 0.5898
# green: 0.5349
#
# Top odors for Cc1ccc(C(O)O)cc1 (probability > 0.5):
# floral: 0.7347
# sweet: 0.6986
# balsamic: 0.5872
# green: 0.5719
# fruity: 0.5444
# rose: 0.5422
#
# Top odors for C=CSCC(=O)[NH2+]CC (probability > 0.5):
# meaty: 0.5786
#
# Top odors for CCC1C=CC(=O)S1 (probability > 0.5):
# meaty: 0.6857
# roasted: 0.6833
# sulfurous: 0.6106
#
# Top odors for CCOS(=O)SC(C)CO (probability > 0.5):
# sulfurous: 0.7327
# onion: 0.5040
#
# Top odors for C=C(C)N1N=CC=C(C(C)=O)N1 (probability > 0.5):
# odorless: 0.5190
#
# Top odors for CS(C)=N (probability > 0.5):
# pungent: 0.8328
# radish: 0.7001
# onion: 0.6751
# garlic: 0.5874
# sulfurous: 0.5418
#
# Top odors for CC1=C(S)C(=[SH+])CC1 (probability > 0.5):
# meaty: 0.6645
# sulfurous: 0.6307
# roasted: 0.5704
#
# Top odors for c1nc2c(o1)CCCCCCCCSC2 (probability > 0.5):
# green: 0.6030
# vegetable: 0.5737
# nutty: 0.5451
#
# Top odors for CCCS(=O)OCn1cccc1 (probability > 0.5):
#
# Top odors for CCC=CCC(=O)O[NH3+] (probability > 0.5):
# fruity: 0.9015
# green: 0.8370
# apple: 0.6419
# tropical: 0.5911
# pineapple: 0.5738
# pear: 0.5080
#
# Top odors for CC(C)C (probability > 0.5):
# ethereal: 0.7854
# fermented: 0.5977
# alcoholic: 0.5499
# solvent: 0.5422
# musty: 0.5044
#
# Top odors for C=CS(=C)C (probability > 0.5):
# onion: 0.7780
# pungent: 0.7605
# garlic: 0.7054
# sulfurous: 0.6092
# radish: 0.5726
# alliaceous: 0.5192
#
# Top odors for CCC(C=O)CN (probability > 0.5):
# cheesy: 0.5164
#
# Top odors for CCCCCCCCOSC(=O)c1ccccc1 (probability > 0.5):
# green: 0.6835
# floral: 0.5765
#
# Top odors for C1CO1 (probability > 0.5):
# ethereal: 0.7791
# fruity: 0.6434
# solvent: 0.6134
# alcoholic: 0.6066
# sweet: 0.5733
#
# Top odors for CCCCCC=CC(=S)OCCCC (probability > 0.5):
# fruity: 0.7797
# green: 0.6015
# tropical: 0.6007
# cheesy: 0.5576
#
# Top odors for CCOC (probability > 0.5):
# ethereal: 0.8860
# alcoholic: 0.6447
# fruity: 0.5927
# sweet: 0.5812
#
# Top odors for CCCCCC(=O)SCCc1scnc1C (probability > 0.5):
# meaty: 0.7410
# roasted: 0.7125
# nutty: 0.6271
# sulfurous: 0.5847
#
# Top odors for OCS (probability > 0.5):
# sulfurous: 0.6728
# meaty: 0.5220
#
# Top odors for CCCC(O)CCCC(C)=O (probability > 0.5):
# fruity: 0.5927
#
# Top odors for CCNc1nccnc1C (probability > 0.5):
# nutty: 0.5939
# roasted: 0.5584
# meaty: 0.5114
#
# Top odors for CCC1=COC=CC1 (probability > 0.5):
# ethereal: 0.6313
# fruity: 0.6265
# green: 0.5893
#
# Top odors for CCC=CCC(OC)SC (probability > 0.5):
# green: 0.7357
# vegetable: 0.5328
#
# Top odors for CNC(CC(C)OCC=C(C)C)OC (probability > 0.5):
# fruity: 0.5408
#
# Top odors for C=C(C)CCOC (probability > 0.5):
# green: 0.8652
# fruity: 0.8436
# fresh: 0.5638
# apple: 0.5325
# herbal: 0.5141
#
# Top odors for CCCCCONCC(=O)OOCCC (probability > 0.5):
# fruity: 0.5863
#
# Top odors for C=C(NCCC=CCC)C(C)CC (probability > 0.5):
# spicy: 0.5361
# herbal: 0.5295
# citrus: 0.5259
#
# Top odors for COCCCO (probability > 0.5):
# fruity: 0.6361
# alcoholic: 0.5702
# ethereal: 0.5468
#
# Top odors for CC1=CC2C(=CC1)N(C)CCC2C(C)C (probability > 0.5):
# woody: 0.5420
# nutty: 0.5395
#
# Top odors for CCC1CSS(C)(C)C1 (probability > 0.5):
# sulfurous: 0.7877
# meaty: 0.6441
# green: 0.6381
# tropical: 0.6134
# vegetable: 0.6054
# roasted: 0.5156
#
# Top odors for CC1NNCS1 (probability > 0.5):
# nutty: 0.6576
# meaty: 0.6439
# roasted: 0.5970
# popcorn: 0.5580
#
# Top odors for CC1CC1 (probability > 0.5):
# woody: 0.6998
# amber: 0.5660
# musk: 0.5548
#
# Top odors for CC(=S)Cc1ccco1 (probability > 0.5):
# roasted: 0.7172
# sulfurous: 0.7105
# meaty: 0.6753
# coffee: 0.6502
# nutty: 0.5028
#
# Top odors for CC1(O)C[SH+]C(C)(O)CS1 (probability > 0.5):
# meaty: 0.7733
# roasted: 0.6428
#
# Top odors for CC(S)OCCC(=O)O (probability > 0.5):
# sulfurous: 0.7024
# fruity: 0.5564
# meaty: 0.5423
#
# Top odors for CC(=O)C1=[NH+]CCS1 (probability > 0.5):
# roasted: 0.7531
# meaty: 0.7415
# nutty: 0.6651
# sulfurous: 0.5579
# popcorn: 0.5091
#
# Top odors for CC(=N)S[NH2+]CCCCCCS (probability > 0.5):
# meaty: 0.7283
# sulfurous: 0.6102
# roasted: 0.5261
#
# Top odors for CC(C)OC(=S)C1=C(N)SCC=C1 (probability > 0.5):
# meaty: 0.6577
# sulfurous: 0.6277
# roasted: 0.5426
#
# Top odors for CCCC(=O)C(O)SSC (probability > 0.5):
# sulfurous: 0.6909
# fruity: 0.5150
#
# Top odors for CCS(=O)C1=NCCC1 (probability > 0.5):
# nutty: 0.6768
# roasted: 0.6507
# popcorn: 0.5680
# meaty: 0.5613
#
# Top odors for C=CCSCC[NH3+] (probability > 0.5):
# sulfurous: 0.7971
# meaty: 0.6583
# onion: 0.6537
# garlic: 0.6252
# savory: 0.5110
# alliaceous: 0.5092
#
# Top odors for CCC1=NCC(=O)O1 (probability > 0.5):
# odorless: 0.6053
#
# Top odors for C=CNCC (probability > 0.5):
# fishy: 0.5517
#
# Top odors for Nc1ccc(C(=O)O)cc1O (probability > 0.5):
# odorless: 0.5947
# phenolic: 0.5273
#
# Top odors for CC([NH3+])C(C)S (probability > 0.5):
# sulfurous: 0.8351
# meaty: 0.7090
# grapefruit: 0.5876
# roasted: 0.5847
#
# Top odors for COC1=C(C(C)C)N=C[NH2+]S1 (probability > 0.5):
# nutty: 0.6661
# roasted: 0.6630
# meaty: 0.5801
#
# Top odors for CCCCCCCC[NH+]=CC=CC=N (probability > 0.5):
# green: 0.6666
# fatty: 0.6497
# citrus: 0.5272
#
# Top odors for CC(=CC=O)CCC=C(S)CCC=[N+](C)N (probability > 0.5):
# meaty: 0.5311
#
# Top odors for CCC(=O)C1=COCO1 (probability > 0.5):
# caramellic: 0.8351
# fruity: 0.7668
# sweet: 0.5534
# burnt: 0.5483
#
# Top odors for C=C(C)CC (probability > 0.5):
# gassy: 0.5552
# fruity: 0.5164
# green: 0.5050
# fresh: 0.5034
#
# Top odors for SCC1CC=C[NH2+]1 (probability > 0.5):
# meaty: 0.7800
# roasted: 0.7243
# nutty: 0.5991
#
# Top odors for C=CCCC (probability > 0.5):
# green: 0.6016
# gassy: 0.5733
#
# Top odors for CSc1[nH+]c[nH+]cc1O (probability > 0.5):
# meaty: 0.6894
# roasted: 0.6177
# sulfurous: 0.5260
#
# Top odors for CCC(OC(C)=O)C(=[NH2+])NC (probability > 0.5):
#
# Top odors for CCC(C)COC=S (probability > 0.5):
# fruity: 0.8088
# green: 0.6194
#
# Top odors for CC(C)=CC(=N)[NH3+] (probability > 0.5):
# spicy: 0.5658
#
# Top odors for C=C(O)CO (probability > 0.5):
# sweet: 0.5241
#
# Top odors for CCC(=O)NCC(C)O (probability > 0.5):
#
# Top odors for CC(CO)[NH2+]S (probability > 0.5):
# meaty: 0.6998
# sulfurous: 0.6417
#
# Top odors for CCC(S)C(=O)OCSCNSC (probability > 0.5):
# sulfurous: 0.7349
# meaty: 0.5890
#
# Top odors for CCCCCc1ccc(C)[nH]1 (probability > 0.5):
# green: 0.7558
# nutty: 0.5826
# earthy: 0.5071
#
# Top odors for CCCC=[NH+]SCN (probability > 0.5):
# pungent: 0.5283
# meaty: 0.5225
#
# Top odors for CC(CCO)[NH+]=S (probability > 0.5):
# meaty: 0.5596
# sulfurous: 0.5002
#
# Top odors for CC(=S)ON(C)c1ccccc1 (probability > 0.5):
# fruity: 0.5659
# grape: 0.5115
#
# Top odors for CCCC(N)NC=N (probability > 0.5):
# odorless: 0.6086
#
# Top odors for C[NH2+]SS(C)=N (probability > 0.5):
# sulfurous: 0.7065
# onion: 0.5837
# pungent: 0.5520
# garlic: 0.5150
#
# Top odors for CCCC1=COC=CC1 (probability > 0.5):
# green: 0.7356
# fruity: 0.6550
#
# Top odors for C=C(CCCCCCCC[NH2+]O)OC (probability > 0.5):
# floral: 0.5115
#
# Top odors for CCC(C)C(=N)N (probability > 0.5):
#
# Top odors for OC1C=CC=CC1 (probability > 0.5):
#
# Top odors for CC(=O)C1=NCOO1 (probability > 0.5):
# caramellic: 0.5828
#
# Top odors for CC(O)C1CCCCC=[NH+]C1 (probability > 0.5):
# green: 0.5071
#
# Top odors for CC[NH2+]C(=O)OCC (probability > 0.5):
# fruity: 0.8204
# winey: 0.5186
#
# Top odors for C=CCC(C)(C)Cc1ccccc1 (probability > 0.5):
# floral: 0.7834
# green: 0.5946
# sweet: 0.5513
# woody: 0.5410
# fresh: 0.5149
# herbal: 0.5098
#
# Top odors for CCCCCCCCNCC=O (probability > 0.5):
# fishy: 0.5275
#
# Top odors for CSCc1cccnc1 (probability > 0.5):
# sulfurous: 0.6828
# roasted: 0.6341
# coffee: 0.6192
# nutty: 0.5936
# meaty: 0.5548
# onion: 0.5134
#
# Top odors for COC(CC(C)=O)SC (probability > 0.5):
# sulfurous: 0.7197
# fruity: 0.7118
# tropical: 0.6080
# cheesy: 0.5538
#
# Top odors for C=C(C)NC(C)=O (probability > 0.5):
# meaty: 0.5207
#
# Top odors for c1ccc2c(c1)CCNN2 (probability > 0.5):
# animal: 0.5305
#
# Top odors for CCCC(C)(N)S (probability > 0.5):
# meaty: 0.7443
# savory: 0.5186
#
# Top odors for C=CC(C)C (probability > 0.5):
# green: 0.8070
# fruity: 0.6385
# fresh: 0.5259
#
# Top odors for CC(CC=O)S[NH3+] (probability > 0.5):
# sulfurous: 0.6544
# meaty: 0.5486
# onion: 0.5387
# vegetable: 0.5292
# cheesy: 0.5281
#
# Top odors for C[NH2+]C(=O)C(C)O (probability > 0.5):
# sweet: 0.5772
# caramellic: 0.5270
#
# Top odors for CC1=CCC(C)C(C)=N1 (probability > 0.5):
# nutty: 0.6806
# roasted: 0.6135
#
# Top odors for CCC[NH3+] (probability > 0.5):
# sweet: 0.6917
#
# Top odors for CC(S)NCN (probability > 0.5):
# meaty: 0.6481
#
# Top odors for CCCCOC(C)CCCC(C)S (probability > 0.5):
# sulfurous: 0.7093
# grapefruit: 0.6423
# tropical: 0.5674
# fruity: 0.5532
# green: 0.5253
#
# Top odors for C=CCCCCCNOCO (probability > 0.5):
#
# Top odors for CSOC=O (probability > 0.5):
# sulfurous: 0.7767
# fruity: 0.5441
# meaty: 0.5258
# cheesy: 0.5140
# onion: 0.5058
#
# Top odors for CCCCC[N+](=O)CC(C)CO (probability > 0.5):
#
# Top odors for C=S(CC)N(C)C (probability > 0.5):
# meaty: 0.5781
#
# Top odors for CCCOC(=S)COC(C)O (probability > 0.5):
# fruity: 0.7444
#
# Top odors for COS(=O)CCCOc1ccco1 (probability > 0.5):
# fruity: 0.7244
#
# Top odors for OCCc1cccc(O)c1 (probability > 0.5):
# floral: 0.7209
# sweet: 0.7197
# balsamic: 0.5407
# rose: 0.5082
#
# Top odors for CS1=CC=C(C=S)C(O)=C1 (probability > 0.5):
# sulfurous: 0.6206
# meaty: 0.5890
# roasted: 0.5384
#
# Top odors for CC1CC=CSO1 (probability > 0.5):
# sulfurous: 0.7123
# meaty: 0.6221
#
# Top odors for CC(S)C1=CNC=CS1 (probability > 0.5):
# meaty: 0.7824
# roasted: 0.6872
# sulfurous: 0.6389
#
# Top odors for CC1ONCC1S (probability > 0.5):
# meaty: 0.7477
# roasted: 0.6475
# nutty: 0.5474
#
# Top odors for SC1CCCO1 (probability > 0.5):
# meaty: 0.7423
# sulfurous: 0.7010
# roasted: 0.5333
#
# Top odors for CCC=CCCCSO (probability > 0.5):
# green: 0.7359
# fatty: 0.6686
# vegetable: 0.5045
#
# Top odors for COCSC (probability > 0.5):
# sulfurous: 0.7779
# onion: 0.6598
# garlic: 0.6219
# vegetable: 0.6028
# alliaceous: 0.5600
# cabbage: 0.5425
#
# Top odors for CC(N)SC(N)[NH3+] (probability > 0.5):
# meaty: 0.6411
#
# Top odors for C=C1C=[NH+]C(CC)O1 (probability > 0.5):
# nutty: 0.6974
# roasted: 0.6785
# meaty: 0.5252
# popcorn: 0.5175
#
# Top odors for CS[NH+]1N=CCS1 (probability > 0.5):
# meaty: 0.7380
# roasted: 0.6747
# nutty: 0.6503
#
# Top odors for CCSSN[NH3+] (probability > 0.5):
# sulfurous: 0.7406
# meaty: 0.5898
# onion: 0.5454
# savory: 0.5220
#
# Top odors for CSc1nc(C)co1 (probability > 0.5):
# nutty: 0.6719
# sulfurous: 0.6444
# meaty: 0.5897
# vegetable: 0.5769
# roasted: 0.5743
# green: 0.5084
#
# Top odors for CCCCCS1=CC=CC=C1 (probability > 0.5):
# sulfurous: 0.5841
#
# Top odors for CCC(=O)C(C)(C)O (probability > 0.5):
# fruity: 0.6319
# sweet: 0.5975
# creamy: 0.5214
#
# Top odors for CCC(=O)C(C)CC (probability > 0.5):
# fruity: 0.9325
# sweet: 0.5446
# ethereal: 0.5334
# green: 0.5174
# herbal: 0.5066
# cheesy: 0.5014
#
# Top odors for C=C(CC)C(C)S (probability > 0.5):
# sulfurous: 0.7511
# meaty: 0.5909
# fruity: 0.5639
# grapefruit: 0.5519
#
# Top odors for CCCCCC(OCC)OCCO (probability > 0.5):
# green: 0.6961
# fruity: 0.6624
#
# Top odors for C=C(C)C1=CCC(C)C=C1 (probability > 0.5):
# woody: 0.7502
# herbal: 0.6167
# citrus: 0.6130
# terpenic: 0.5425
# sweet: 0.5400
# fresh: 0.5326
# fruity: 0.5269
#
# Top odors for CC1=C(C)SN(C)C1 (probability > 0.5):
# roasted: 0.7315
# nutty: 0.7059
# meaty: 0.6488
# popcorn: 0.6281
# burnt: 0.5246
#
# Top odors for CNCc1ccsc1 (probability > 0.5):
# meaty: 0.7282
# roasted: 0.6058
# sulfurous: 0.5485
#
# Top odors for CC=CCCC (probability > 0.5):
# green: 0.6731
# gassy: 0.5436
#
# Top odors for CC(=N)CC(=O)OC1CCCCC1 (probability > 0.5):
# fruity: 0.8069
#
# Top odors for C=S(C)CC (probability > 0.5):
# onion: 0.7171
# garlic: 0.7163
# sulfurous: 0.6673
# alliaceous: 0.5734
# pungent: 0.5682
#
# Top odors for C=CCSNNC (probability > 0.5):
# meaty: 0.6493
#
# Top odors for CCCC(C)C(C)=N (probability > 0.5):
# green: 0.6924
# citrus: 0.5734
# floral: 0.5580
# fresh: 0.5138
#
# Top odors for CC=CS[NH2+]CO (probability > 0.5):
# sulfurous: 0.6458
# meaty: 0.5763
#
# Top odors for CC=C(C=O)CCC (probability > 0.5):
# fruity: 0.7071
# green: 0.6198
# pungent: 0.6063
# nutty: 0.5148
# ethereal: 0.5061
#
# Top odors for CN=C(N)S(C)=O (probability > 0.5):
#
# Top odors for CC(=O)OC(C)(S)C1CCC(C)CC1 (probability > 0.5):
# fruity: 0.7451
# tropical: 0.5913
#
# Top odors for CCCS(=O)SC (probability > 0.5):
# sulfurous: 0.7767
# onion: 0.6772
# garlic: 0.5667
# alliaceous: 0.5257
#
# Top odors for CCCO[NH2+]c1nsc(C)n1 (probability > 0.5):
# nutty: 0.6437
# roasted: 0.5842
#
# Top odors for O=C1COc2ccccc2C1 (probability > 0.5):
# sweet: 0.6702
# floral: 0.6472
# coumarinic: 0.5711
# green: 0.5229
#
# Top odors for CC(C)CC(=O)CC1CCCCC1 (probability > 0.5):
# fruity: 0.7564
# herbal: 0.6638
# floral: 0.5810
# green: 0.5626
#
# Top odors for CCCCC1CCCN1 (probability > 0.5):
# nutty: 0.5311
# roasted: 0.5193
#
# Top odors for O=CC=Cc1cnco1 (probability > 0.5):
# nutty: 0.6531
# spicy: 0.6347
# almond: 0.5127
#
# Top odors for CC(C)CC(N)=O (probability > 0.5):
#
# Top odors for CC(C)C(=N)OCCCCCO (probability > 0.5):
# fruity: 0.7432
#
# Top odors for C=COCCCCCCCC=O (probability > 0.5):
# green: 0.8105
# fruity: 0.6815
# fresh: 0.5946
# fatty: 0.5477
#
# Top odors for CNC(CCSC)OC(C)=O (probability > 0.5):
# sulfurous: 0.6106
# fruity: 0.5543
# meaty: 0.5322
# tropical: 0.5229
# cheesy: 0.5136
#
# Top odors for C[NH2+]C=O (probability > 0.5):
# odorless: 0.6721
# pungent: 0.5736
#
# Top odors for O=C(O)COC1C=CC=CC1 (probability > 0.5):
#
# Top odors for OCCc1ccco1 (probability > 0.5):
# fruity: 0.6501
# sweet: 0.6307
# spicy: 0.5755
#
# Top odors for CNCC[NH2+]C (probability > 0.5):
# fishy: 0.8864
# cheesy: 0.5300
#
# Top odors for CCCC[SH+]CC (probability > 0.5):
# sulfurous: 0.8470
# meaty: 0.8343
# roasted: 0.6370
# savory: 0.6243
# fatty: 0.5407
#
# Top odors for CC=CCC=CC (probability > 0.5):
# green: 0.6887
# gassy: 0.5146
#
# Top odors for CC(O)=CSCC(C)CCNC=N (probability > 0.5):
# meaty: 0.5113
#
# Top odors for COS1=CC=CC(C)=C1 (probability > 0.5):
#
# Top odors for CCc1ccccc1 (probability > 0.5):
# sweet: 0.6694
# green: 0.5178
# floral: 0.5155
#
# Top odors for Cc1n[nH+]cnc1CC(C)C (probability > 0.5):
# nutty: 0.7411
# earthy: 0.6850
# roasted: 0.6331
# green: 0.6128
# cocoa: 0.5208
# hazelnut: 0.5141
#
# Top odors for CC[SH2+]=CCCOC=O (probability > 0.5):
# sulfurous: 0.6437
# cheesy: 0.5351
# fruity: 0.5249
# pungent: 0.5213
#
# Top odors for CCCCNCC (probability > 0.5):
# fishy: 0.8489
# cheesy: 0.7046
#
# Top odors for CC(C)=[NH+]CCC(C)CCCC(C)C=O (probability > 0.5):
# floral: 0.7711
# citrus: 0.6247
# fruity: 0.5770
# waxy: 0.5543
# rose: 0.5448
# fresh: 0.5416
# sweet: 0.5225
# green: 0.5004
#
# Top odors for CC(S)N1C=NC=CO1 (probability > 0.5):
# meaty: 0.7124
# roasted: 0.6748
# nutty: 0.6217
#
# Top odors for N=C(O)CC[SH+]CO (probability > 0.5):
# meaty: 0.5793
#
# Top odors for CCCS(=O)c1ccco1 (probability > 0.5):
# roasted: 0.6334
# meaty: 0.5653
# sulfurous: 0.5481
# nutty: 0.5201
#
# Top odors for CCCOCC (probability > 0.5):
# ethereal: 0.8540
# alcoholic: 0.7516
# fruity: 0.7050
# sweet: 0.5767
# fermented: 0.5585
# solvent: 0.5269
#
# Top odors for C=CCOC(=S)NC (probability > 0.5):
# sulfurous: 0.6662
# meaty: 0.5317
#
# Top odors for C1=CSSN=C1 (probability > 0.5):
# sulfurous: 0.6800
# meaty: 0.5010
#
# Top odors for CC1CC(C)(C)SO1 (probability > 0.5):
# sulfurous: 0.6773
# meaty: 0.5759
# green: 0.5228
# vegetable: 0.5082
# roasted: 0.5015
#
# Top odors for COS1=C(C)C=CS(C(=O)O)=C1 (probability > 0.5):
# meaty: 0.5863
# roasted: 0.5376
# sulfurous: 0.5121
#
# Top odors for CCC(=O)S(=O)O (probability > 0.5):
# sour: 0.5133
#
# Top odors for CC(C)(O)CN (probability > 0.5):
# fishy: 0.6045
#
# Top odors for CCCC=CCO[NH+]([O-])CC (probability > 0.5):
# green: 0.6832
# fruity: 0.5659
#
# Top odors for O=C(O)CCC(O)O (probability > 0.5):
# odorless: 0.5285
#
# Top odors for C=CS(=O)CC (probability > 0.5):
# sulfurous: 0.6191
# onion: 0.6172
# pungent: 0.5396
#
# Top odors for CC(=O)C(O)CS (probability > 0.5):
# sulfurous: 0.5801
# meaty: 0.5728
#
# Top odors for CCCCCCOCCCNO (probability > 0.5):
#
# Top odors for CC=C[NH+]([O-])CCCCC (probability > 0.5):
#
# Top odors for CCC1C=CC(O)=CC1 (probability > 0.5):
#
# Top odors for CCCCCOC(C)SCCC(C)C (probability > 0.5):
# green: 0.7601
# sulfurous: 0.5602
#
# Top odors for CCCc1ccc([NH3+])cc1 (probability > 0.5):
# sweet: 0.6442
# green: 0.5821
# floral: 0.5532
#
# Top odors for CNC(C)CCCC(C)(C)O (probability > 0.5):
#
# Top odors for Cc1ccc[sH+]1 (probability > 0.5):
# green: 0.6673
# nutty: 0.6167
# vegetable: 0.5707
# burnt: 0.5578
# roasted: 0.5463
# sulfurous: 0.5335
#
# Top odors for C=C(CC)[NH2+]CC (probability > 0.5):
#
# Top odors for CN1CCSC1 (probability > 0.5):
# nutty: 0.7070
# meaty: 0.6794
# roasted: 0.6781
# popcorn: 0.5976
# fishy: 0.5314
#
# Top odors for CCC1=C[NH2+]C(CC)=C(C)O1 (probability > 0.5):
# fruity: 0.7469
# floral: 0.5644
#
# Top odors for CCc1cc(C)sc1CC (probability > 0.5):
# green: 0.5941
# fruity: 0.5571
# roasted: 0.5277
#
# Top odors for CCC=[NH+]CC=CCCS (probability > 0.5):
# meaty: 0.5711
# sulfurous: 0.5489
#
# Top odors for CCSC1C=C(COC)NC=C1O (probability > 0.5):
# meaty: 0.6299
# roasted: 0.5281
#
# Top odors for CC(=O)C1=[NH+]NCCS1 (probability > 0.5):
# roasted: 0.7320
# nutty: 0.7245
# meaty: 0.6874
# popcorn: 0.6355
#
# Top odors for CC(=O)CCNCCS (probability > 0.5):
# meaty: 0.6901
# fishy: 0.5126
#
# Top odors for CCNC(=O)C(O)C(C)C(=O)OCC (probability > 0.5):
# fruity: 0.5767
#
# Top odors for CCC(=O)C1=NNCS1 (probability > 0.5):
# nutty: 0.7413
# roasted: 0.6768
# meaty: 0.6142
# popcorn: 0.5954
#
# Top odors for CC1C=CC(C(C)C)CO1 (probability > 0.5):
# herbal: 0.6923
# green: 0.6562
# woody: 0.5901
# fresh: 0.5700
# floral: 0.5658
# mint: 0.5517
# spicy: 0.5057
#
# Top odors for C=C[NH2+]CC=O (probability > 0.5):
#
# Top odors for C=C(C)SCC=[NH2+] (probability > 0.5):
# sulfurous: 0.8046
# onion: 0.7103
# garlic: 0.6125
# meaty: 0.5704
#
# Top odors for CCCCCCCSCCOC (probability > 0.5):
# sulfurous: 0.6622
# fatty: 0.6327
# green: 0.6173
# vegetable: 0.5606
# meaty: 0.5559
# fruity: 0.5129
#
# Top odors for CCOC(=S)NS (probability > 0.5):
# sulfurous: 0.6233
# meaty: 0.5436
#
# Top odors for NC(O)C(O)CO (probability > 0.5):
# odorless: 0.5589
#
# Top odors for CCCC(C)[N+](=O)NC (probability > 0.5):
#
# Top odors for CCC(=O)NCCc1scnc1C (probability > 0.5):
# meaty: 0.6236
# odorless: 0.5170
#
# Top odors for CCC1=C[NH+](C=CC=O)CC(SC)=C1O (probability > 0.5):
# meaty: 0.5532
#
# Top odors for c1ccc(CC2CCCC2)cc1 (probability > 0.5):
# sweet: 0.5859
# woody: 0.5253
#
# Top odors for CC(C)(C)c1ccc([NH2+]C[NH2+][O-])cc1 (probability > 0.5):
# floral: 0.6840
# sweet: 0.6064
# rose: 0.5637
#
# Top odors for CC(C)On1cccc1 (probability > 0.5):
# sweet: 0.5042
#
# Top odors for CCNCCCCC(=N)O (probability > 0.5):
# fishy: 0.6446
#
# Top odors for CCCCC(C)CCC(N)=O (probability > 0.5):
#
# Top odors for NOCCCC=CN=[NH+]C(=O)CCCC[SH2+] (probability > 0.5):
#
# Top odors for SCCC1NCCS1 (probability > 0.5):
# meaty: 0.8173
# roasted: 0.7340
# nutty: 0.6770
# sulfurous: 0.5005
#
# Top odors for C=CCCCCN=C=[SH+] (probability > 0.5):
# green: 0.7441
# pungent: 0.7424
# radish: 0.6602
#
# Top odors for CCC[N+](=O)OCCCCO (probability > 0.5):
# fruity: 0.7674
#
# Top odors for CCCNNSC (probability > 0.5):
# fishy: 0.6542
#
# Top odors for C=CC(C)(C)C(C)C=C(C)C (probability > 0.5):
# floral: 0.7719
# woody: 0.6582
# herbal: 0.6375
# citrus: 0.6365
# green: 0.5556
# sweet: 0.5490
# fresh: 0.5435
#
# Top odors for CC(C)(O)c1ccc(C=O)cc1 (probability > 0.5):
# sweet: 0.7999
# floral: 0.7559
# fruity: 0.6405
# cherry: 0.5708
# vanilla: 0.5662
# balsamic: 0.5604
# anisic: 0.5142
#
# Top odors for CC(C)N=C=N (probability > 0.5):
# pungent: 0.8341
# radish: 0.7057
# green: 0.5890
#
# Top odors for C=C(C)C(C)OC(=S)CCC (probability > 0.5):
# fruity: 0.8395
# tropical: 0.6098
# sulfurous: 0.5854
#
# Top odors for CCCCCC(N)CC (probability > 0.5):
# cheesy: 0.5489
# fishy: 0.5139
#
# Top odors for CCCN=C(C)C(=O)O (probability > 0.5):
#
# Top odors for CCC(C=O)[NH2+]C (probability > 0.5):
# cheesy: 0.6256
#
# Top odors for CC1=C(N)C(=O)CC(C)(C)C1 (probability > 0.5):
# fruity: 0.6612
# sweet: 0.5069
#
# Top odors for c1cn[nH]c1 (probability > 0.5):
# nutty: 0.8367
# roasted: 0.6916
# burnt: 0.6709
# cocoa: 0.6615
# musty: 0.6412
# coffee: 0.6047
# hazelnut: 0.6007
# sweet: 0.5626
#
# Top odors for CNCC1=CNC=C[NH2+]1 (probability > 0.5):
# odorless: 0.6738
#
# Top odors for C=CC1OC1CCCC (probability > 0.5):
# meaty: 0.5579
# roasted: 0.5344
#
# Top odors for CC1=CCC2(S)CC1C2(C)C (probability > 0.5):
# fruity: 0.7685
# tropical: 0.6638
# green: 0.5686
# sulfurous: 0.5247
#
# Top odors for CC(C)C1=C2C=CC=CN2N=CS1 (probability > 0.5):
# nutty: 0.7819
# roasted: 0.7086
# meaty: 0.6682
# popcorn: 0.5600
#
# Top odors for CC(C)CC(=N)O (probability > 0.5):
# fruity: 0.6300
# cheesy: 0.5687
# pungent: 0.5201
#
# Top odors for NC1CCNS1 (probability > 0.5):
# meaty: 0.6424
# odorless: 0.5870
#
# Top odors for C=CC=CC(C)N (probability > 0.5):
# meaty: 0.5938
#
# Top odors for O=[N+](OSCCc1ccccc1)c1ccccc1 (probability > 0.5):
# floral: 0.6895
# sweet: 0.6520
# rose: 0.5565
# honey: 0.5547
# balsamic: 0.5526
# green: 0.5250
#
# Top odors for CCCCC(N)NC (probability > 0.5):
# fishy: 0.6719
#
# Top odors for CCC(CC)(CC)C(=O)[NH2+]C(C)(C)CO (probability > 0.5):
# mint: 0.5911
# cooling: 0.5552
#
# Top odors for CNC(=O)c1ccccc1C (probability > 0.5):
#
# Top odors for CC(O)SN (probability > 0.5):
# sulfurous: 0.5904
# meaty: 0.5386
#
# Top odors for CC1=CCC(C)([N+](C)=O)SC1 (probability > 0.5):
# floral: 0.5145
#
# Top odors for C=CCC(C)C (probability > 0.5):
# green: 0.7279
# fruity: 0.6389
# fresh: 0.5426
#
# Top odors for C=S(=C)(C)NC (probability > 0.5):
# odorless: 0.6056
#
# Top odors for CCCCC(=O)C(C)S (probability > 0.5):
# grapefruit: 0.6582
# sulfurous: 0.5731
# meaty: 0.5357
# fruity: 0.5028
#
# Top odors for COC1C=CNC=[N+]1O (probability > 0.5):
# odorless: 0.7147
#
# Top odors for CC(C)C(=O)S(=O)O (probability > 0.5):
# fruity: 0.6371
#
# Top odors for C=C(C)CCCCNOC(C)=O (probability > 0.5):
#
# Top odors for CCC[NH2+]CCCC(C)C=O (probability > 0.5):
# cheesy: 0.6139
#
# Top odors for CCC(=S)CC(C)C (probability > 0.5):
# fruity: 0.6368
# sulfurous: 0.6300
# green: 0.5083
#
# Top odors for C=CC(C)CS (probability > 0.5):
# sulfurous: 0.7904
# onion: 0.6477
# meaty: 0.6314
# garlic: 0.5485
# roasted: 0.5017
#
# Top odors for CCCCCCOCCC(=N)O (probability > 0.5):
# fruity: 0.5439
#
# Top odors for C=CCNC=S (probability > 0.5):
# pungent: 0.5023
#
# Top odors for COC1=CC=S(C)C=C1C (probability > 0.5):
# woody: 0.5678
# sweet: 0.5354
#
# Top odors for CC(S)CCSSNC(O)S (probability > 0.5):
# sulfurous: 0.6982
# meaty: 0.5982
# savory: 0.5201
#
# Top odors for CC1=CCN(C)N1 (probability > 0.5):
# odorless: 0.6173
# fishy: 0.5126
#
# Top odors for CCC(C)CC (probability > 0.5):
# green: 0.5985
# sweet: 0.5600
# herbal: 0.5347
# musty: 0.5156
# fruity: 0.5152
#
# Top odors for CCCCC1=CCC(O)C=C1 (probability > 0.5):
# floral: 0.8064
# fruity: 0.7000
# green: 0.5549
# jasmin: 0.5505
#
# Top odors for CCCCC(CC)OC (probability > 0.5):
# green: 0.8681
# fruity: 0.7054
# herbal: 0.6056
# cognac: 0.5967
# oily: 0.5828
# alcoholic: 0.5613
# fermented: 0.5551
# apple: 0.5257
#
# Top odors for NCCCS (probability > 0.5):
# meaty: 0.8005
# sulfurous: 0.6209
# fishy: 0.5396
# savory: 0.5064
#
# Top odors for CC(=O)CCCC(C)[NH3+] (probability > 0.5):
# fruity: 0.7765
# floral: 0.6822
# herbal: 0.6219
# green: 0.6078
#
# Top odors for CCC=C(C)C(=O)CC (probability > 0.5):
# fruity: 0.8317
# herbal: 0.5593
# ketonic: 0.5426
# green: 0.5090
#
# Top odors for CCCN1NCON(C)S1 (probability > 0.5):
# odorless: 0.7198
#
# Top odors for C1CCC2(CCOC2)CCSC1 (probability > 0.5):
# sulfurous: 0.6848
#
# Top odors for CCCC1=NSC=CO1 (probability > 0.5):
# meaty: 0.5284
# roasted: 0.5009
#
# Top odors for CCCNC(C)CC[NH2+]C (probability > 0.5):
# fishy: 0.7122
#
# Top odors for COC(=O)NNSC (probability > 0.5):
# odorless: 0.6244
#
# Top odors for CCCSOSCO (probability > 0.5):
# sulfurous: 0.6901
#
# Top odors for CCCCC(C)C(=O)COCCC (probability > 0.5):
# fruity: 0.5407
# floral: 0.5236
#
# Top odors for CCCC(CS)C[NH2+]C (probability > 0.5):
# meaty: 0.7109
# grapefruit: 0.6270
# sulfurous: 0.5968
# roasted: 0.5422
# savory: 0.5061
#
# Top odors for CCOCSCC=CC(=O)OCC (probability > 0.5):
# fruity: 0.7325
# sulfurous: 0.7135
# tropical: 0.6528
# sweet: 0.5272
#
# Top odors for CC[N+]1(CC)CNCS1 (probability > 0.5):
# nutty: 0.8218
# roasted: 0.7524
# meaty: 0.7086
# popcorn: 0.6775
#
# Top odors for COC(=O)CN (probability > 0.5):
# fruity: 0.5189
#
# Top odors for CC1CCC(=O)C1 (probability > 0.5):
# mint: 0.6438
# herbal: 0.6142
# camphoreous: 0.5178
#
# Top odors for CC(C)C(C)CS (probability > 0.5):
# sulfurous: 0.8489
# meaty: 0.5979
# tropical: 0.5720
# grapefruit: 0.5528
# green: 0.5493
# fruity: 0.5183
# onion: 0.5058
# vegetable: 0.5023
#
# Top odors for CCc1ccc(CC)nc1 (probability > 0.5):
# green: 0.7979
# earthy: 0.6739
# nutty: 0.6027
#
# Top odors for CCC(C)CCCCNS (probability > 0.5):
# meaty: 0.5824
#
# Top odors for CNC(=N)[NH+]1C=CN([NH3+])C(C)=C1C (probability > 0.5):
# odorless: 0.6286
#
# Top odors for CC(=O)CC1=CC=CC1 (probability > 0.5):
# fruity: 0.7907
# floral: 0.7619
# green: 0.5925
# woody: 0.5397
# sweet: 0.5373
# jasmin: 0.5183
# berry: 0.5058
#
# Top odors for CCCCC(=O)OCNCC (probability > 0.5):
# fruity: 0.5839
# cheesy: 0.5833
#
# Top odors for NCO (probability > 0.5):
# odorless: 0.7267
# fishy: 0.5953
#
# Top odors for CCC(C)C(=N)OCCO (probability > 0.5):
# fruity: 0.6568
#
# Top odors for C1=CCC=C1 (probability > 0.5):
#
# Top odors for CC(C)C(N)S (probability > 0.5):
# meaty: 0.7433
# sulfurous: 0.6550
# savory: 0.5529
# roasted: 0.5293
#
# Top odors for CCCCOS(=O)CCC (probability > 0.5):
# fruity: 0.7927
# tropical: 0.5263
# ...
#
# Top odors for COC(=O)C(C)=N (probability > 0.5):
# fruity: 0.8159
# caramellic: 0.5653
# green: 0.5574
# winey: 0.5183
# ethereal: 0.5156
# apple: 0.5087
#
# Top odors for CCCCCC(=O)OCC(CC)SCCC (probability > 0.5):
# fruity: 0.7859
# sulfurous: 0.7634
# tropical: 0.7045
# cheesy: 0.5352
#
# Top odors for CCC(O)C[NH2+]C(C)C (probability > 0.5):
#
# Top odors for CCN=CC=S (probability > 0.5):
# pungent: 0.8431
# radish: 0.6819
# onion: 0.5271
#
# Top odors for CCC(S)CCC(C)C (probability > 0.5):
# sulfurous: 0.8331
# grapefruit: 0.6579
# fruity: 0.6063
# meaty: 0.6047
# tropical: 0.5893
# green: 0.5425
# black currant: 0.5234
#
# Top odors for CC1=N[NH+](C)CC1N (probability > 0.5):
# odorless: 0.6491
#
# Top odors for CCC=CCCC=[NH2+] (probability > 0.5):
# green: 0.6230
# fatty: 0.5631
# citrus: 0.5479
#
# Top odors for CC(S)CO (probability > 0.5):
# sulfurous: 0.8093
# meaty: 0.7080
#
# Top odors for CC1=NC(CO)OC1C (probability > 0.5):
# nutty: 0.6862
# roasted: 0.6615
# popcorn: 0.5146
# meaty: 0.5042
#
# Top odors for S=C1CCCO1 (probability > 0.5):
# meaty: 0.5768
# sulfurous: 0.5750
# roasted: 0.5532
#
# Top odors for [SH2+]c1ccc[nH+]c1 (probability > 0.5):
# burnt: 0.5722
# sulfurous: 0.5606
#
# Top odors for C=C(O)CC(C)O (probability > 0.5):
#
# Top odors for CC(C)=C[SH+](C)=O (probability > 0.5):
# onion: 0.6274
# sulfurous: 0.5494
# roasted: 0.5065
#
# Top odors for CNC(=O)CCO (probability > 0.5):
# odorless: 0.5242
#
# Top odors for CC(=O)C1CC=[N+](C)C1(C)C (probability > 0.5):
# fruity: 0.7612
# floral: 0.7142
# woody: 0.6846
# herbal: 0.5474
#
# Top odors for CC(=O)C(N)S (probability > 0.5):
# meaty: 0.7130
# sulfurous: 0.6555
#
# Top odors for CC(O)CN(C)C (probability > 0.5):
#
# Top odors for C=C([NH3+])CCCC(C)CO (probability > 0.5):
# floral: 0.7095
# citrus: 0.5384
# woody: 0.5266
#
# Top odors for ON1CCSC[SH+]1 (probability > 0.5):
# meaty: 0.6002
# odorless: 0.5527
#
# Top odors for CNN1C=CC=CC1O (probability > 0.5):
# odorless: 0.6297
#
# Top odors for CCCCCCNNNC (probability > 0.5):
# fishy: 0.7507
#
# Top odors for CCSCOC (probability > 0.5):
# sulfurous: 0.8066
# onion: 0.6478
# vegetable: 0.6080
# garlic: 0.5838
# cabbage: 0.5307
# alliaceous: 0.5306
# meaty: 0.5268
# savory: 0.5170
#
# Top odors for CON1CC=C(C)C=C1S (probability > 0.5):
#
# Top odors for CC(C)(S)[NH2+]CN (probability > 0.5):
# meaty: 0.7100
# fishy: 0.5830
# savory: 0.5014
#
# Top odors for CS[NH2+]NC(=O)S (probability > 0.5):
# meaty: 0.5853
#
# Top odors for c1c[nH]cn1 (probability > 0.5):
# nutty: 0.7795
# burnt: 0.6928
# sweet: 0.6304
# musty: 0.6162
# roasted: 0.6019
# cocoa: 0.5716
# coffee: 0.5196
# hazelnut: 0.5056
#
# Top odors for C=C(C)CCC (probability > 0.5):
# citrus: 0.6039
# fruity: 0.5682
# herbal: 0.5375
# sweet: 0.5192
# green: 0.5097
# fresh: 0.5037
#
# Top odors for CCCCCC(C)=S (probability > 0.5):
# sulfurous: 0.6414
# fruity: 0.5817
# meaty: 0.5489
# grapefruit: 0.5054
#
# Top odors for NC1C=CC=CN1S (probability > 0.5):
# meaty: 0.6428
# roasted: 0.5177
# odorless: 0.5113
#
# Top odors for CCOS(=O)C(C)CSC (probability > 0.5):
# sulfurous: 0.7798
# tropical: 0.5935
# onion: 0.5751
# fruity: 0.5641
#
# Top odors for O=C1CC=C(O)O1 (probability > 0.5):
# odorless: 0.6726
#
# Top odors for CC(C)NC(C)OC(C)C (probability > 0.5):
# odorless: 0.5046
#
# Top odors for C=[N+]([O-])S1=C(C)C(C)=C(C)S([N+](=O)[O-])=C1C(C)(C)C (probability > 0.5):
#
# Top odors for CC(C)=CSC=C(C)CC=O (probability > 0.5):
# onion: 0.6635
# pungent: 0.6540
# garlic: 0.5498
# sulfurous: 0.5223
#
# Top odors for C=C(C)C=CN1C=CCC=C1 (probability > 0.5):
# nutty: 0.5548
# roasted: 0.5285
#
# Top odors for CCc1csc(C)c1 (probability > 0.5):
# green: 0.6416
# vegetable: 0.5651
# sulfurous: 0.5503
# onion: 0.5206
# roasted: 0.5054
#
# Top odors for Cc1ccc(O)o1 (probability > 0.5):
# sweet: 0.5915
# phenolic: 0.5106
#
# Top odors for CCC (probability > 0.5):
# ethereal: 0.7056
# sweet: 0.5995
#
# Top odors for CC1=CCCC(C)=C1C (probability > 0.5):
# woody: 0.8362
# sweet: 0.6123
# floral: 0.5195
#
# Top odors for CC1CCCC(=S)C1 (probability > 0.5):
# sulfurous: 0.5592
#
# Top odors for CNCCCCCC(=O)O (probability > 0.5):
# cheesy: 0.5676
# fishy: 0.5159
#
# Top odors for CC[NH2+]C(=[NH2+])C(C)[SH+]SC (probability > 0.5):
# meaty: 0.6672
#
# Top odors for CCNC(=O)CC (probability > 0.5):
# fishy: 0.5768
# cheesy: 0.5182
#
# Top odors for CCSCSCCNC (probability > 0.5):
# meaty: 0.7108
# sulfurous: 0.7004
# savory: 0.5242
# roasted: 0.5024
#
# Top odors for COC(=O)CCCC=CCO (probability > 0.5):
# fruity: 0.8778
# green: 0.6421
# tropical: 0.5210
# sweet: 0.5194
# pineapple: 0.5034
#
# Top odors for CCOSC (probability > 0.5):
# sulfurous: 0.7726
# onion: 0.5867
# vegetable: 0.5308
# garlic: 0.5075
#
# Top odors for CC(C)(C=O)OC(N)=S (probability > 0.5):
# fruity: 0.6208
# sulfurous: 0.6015
#
# Top odors for CCOC(=O)CC[SH2+] (probability > 0.5):
# fruity: 0.7574
# sulfurous: 0.6715
# tropical: 0.5428
#
# Top odors for COc1cccc(OS)c1O (probability > 0.5):
#
# Top odors for CCCC=CC(=O)SCC(C)C (probability > 0.5):
# sulfurous: 0.7004
# fruity: 0.6703
# tropical: 0.6303
# cheesy: 0.5390
# green: 0.5057
#
# Top odors for NS[NH+]([O-])c1ccco1 (probability > 0.5):
# odorless: 0.6210
#
# Top odors for CC(=S)c1ccc(C)o1 (probability > 0.5):
# meaty: 0.7129
# roasted: 0.7078
# sulfurous: 0.6575
# coffee: 0.5383
#
# Top odors for C=CCCCC (probability > 0.5):
# gassy: 0.5686
#
# Top odors for C=C(C)C1CCC(S)CC1 (probability > 0.5):
# fruity: 0.6223
# tropical: 0.5867
# sulfurous: 0.5722
#
# Top odors for CCC(=O)C(C)SC (probability > 0.5):
# sulfurous: 0.6549
# meaty: 0.5467
#
# Top odors for CSC=CCO (probability > 0.5):
# sulfurous: 0.7807
# onion: 0.6842
# garlic: 0.6358
# pungent: 0.5925
# alliaceous: 0.5098
# cabbage: 0.5096
#
# Top odors for C=C(N)CCCC (probability > 0.5):
# cheesy: 0.5162
#
# Top odors for CC1(O)CCC(S(C)(C)N)CC1 (probability > 0.5):
#
# Top odors for CCCOC(=O)S (probability > 0.5):
# fruity: 0.7520
# sulfurous: 0.5520
# cheesy: 0.5130
#
# Top odors for CCc1ccc[sH+]1 (probability > 0.5):
# green: 0.8000
# vegetable: 0.6858
# nutty: 0.6408
# roasted: 0.5169
#
# Top odors for CC(C)C1CCC(N)C[N+](=O)C1 (probability > 0.5):
#
# Top odors for C=C1OC(C)C(C)=C1O (probability > 0.5):
# caramellic: 0.7864
# sweet: 0.6440
# burnt: 0.6309
# fruity: 0.5490
#
# Top odors for CC(=O)CC[NH+](N)c1ccccc1 (probability > 0.5):
# sweet: 0.5344
#
# Top odors for C=CCOSC (probability > 0.5):
# sulfurous: 0.6673
# onion: 0.5555
#
# Top odors for NC1SCCC1=O (probability > 0.5):
# meaty: 0.6594
# roasted: 0.5907
#
# Top odors for CSOC(=O)C(C)OC([NH3+])=O (probability > 0.5):
# fruity: 0.6784
# sulfurous: 0.5592
# tropical: 0.5102
#
# Top odors for CC1=C(S)C(C)C(C)C1=O (probability > 0.5):
# fruity: 0.5770
# sulfurous: 0.5600
# roasted: 0.5134
#
# Top odors for CC(C)C=N (probability > 0.5):
# green: 0.8460
# ethereal: 0.6399
# pungent: 0.6258
# fruity: 0.5253
#
# Top odors for CCCC(C)OC (probability > 0.5):
# green: 0.8440
# fruity: 0.7871
# ethereal: 0.7300
# alcoholic: 0.6514
# cognac: 0.6092
# fermented: 0.5816
# apple: 0.5181
# cocoa: 0.5178
#
# Top odors for C=C(CCCC(CCC)NC(C)=O)OCO (probability > 0.5):
# cooling: 0.5372
# mint: 0.5152
#
# Top odors for CCCSCCCC(C)=O (probability > 0.5):
# sulfurous: 0.7863
# meaty: 0.5978
# vegetable: 0.5348
#
# Top odors for OCCCCS (probability > 0.5):
# sulfurous: 0.7681
# meaty: 0.7391
# savory: 0.5175
# cheesy: 0.5042
#
# Top odors for Cc1csc(CO)c1 (probability > 0.5):
# sweet: 0.5494
#
# Top odors for CCCCCSC(=O)CCC (probability > 0.5):
# sulfurous: 0.7619
# fruity: 0.7165
# tropical: 0.6704
# cheesy: 0.6462
# green: 0.5174
#
# Top odors for CCc1ccc[nH+]c1 (probability > 0.5):
# sweet: 0.6461
# green: 0.6029
# earthy: 0.5304
# musty: 0.5267
#
# Top odors for CCSS (probability > 0.5):
# sulfurous: 0.8995
# onion: 0.6845
# meaty: 0.6763
# garlic: 0.6470
# alliaceous: 0.5967
# savory: 0.5466
#
# Top odors for CC1COOC1=O (probability > 0.5):
# caramellic: 0.7753
# fruity: 0.6011
# sweet: 0.5791
#
# Top odors for C=CCCC(=O)SC (probability > 0.5):
# sulfurous: 0.6807
# fruity: 0.6722
# cheesy: 0.6510
# tropical: 0.5279
#
# Top odors for CSCCCCOCCCC=CCS (probability > 0.5):
# sulfurous: 0.7450
# meaty: 0.6238
# onion: 0.6133
# garlic: 0.5004
#
# Top odors for C=C(O)C1CCCCO1 (probability > 0.5):
#
# Top odors for C=C(C=CC)CC (probability > 0.5):
# herbal: 0.6247
# citrus: 0.5991
# green: 0.5594
# sweet: 0.5516
# floral: 0.5430
# fruity: 0.5228
# fresh: 0.5013
#
# Top odors for CCC(C)=N (probability > 0.5):
# green: 0.8421
# fruity: 0.7559
# pungent: 0.5569
# vegetable: 0.5352
# ethereal: 0.5293
#
# Top odors for C[NH2+]CCC=CCCO (probability > 0.5):
# green: 0.6167
# cheesy: 0.5905
# earthy: 0.5036
#
# Top odors for CCCSCC(=N)OCC=[NH2+] (probability > 0.5):
# sulfurous: 0.6514
# onion: 0.5656
#
# Top odors for CO[NH3+] (probability > 0.5):
# ethereal: 0.8593
# alcoholic: 0.6534
# fruity: 0.6175
# sweet: 0.5536
#
# Top odors for CC1CCS2(CC1)COC(=O)O2 (probability > 0.5):
#
# Top odors for CCN(CC)CO (probability > 0.5):
# fishy: 0.7434
#
# Top odors for C=C(OCC=C[NH2+]CC)C(C)O (probability > 0.5):
#
# Top odors for CCCS(=S)O[NH3+] (probability > 0.5):
# sulfurous: 0.6897
# onion: 0.5390
#
# Top odors for CC1CC(c2ccc3c(c2)OCO3)SC1C (probability > 0.5):
#
# Top odors for CCOC(=S)C(C)SC (probability > 0.5):
# sulfurous: 0.8077
# fruity: 0.7334
# tropical: 0.6940
# onion: 0.5526
# green: 0.5003
#
# Top odors for CCC(C=O)c1ccc([NH3+])s1 (probability > 0.5):
# roasted: 0.6079
# meaty: 0.5209
#
# Top odors for COC1=[NH+]CN(C[SH+]C)C=C1 (probability > 0.5):
# meaty: 0.6017
# roasted: 0.5640
#
# Top odors for CC1=NN(C)C=CC1 (probability > 0.5):
# nutty: 0.7860
# roasted: 0.7263
# popcorn: 0.6962
# meaty: 0.5949
#
# Top odors for CC(C)(C)C(C)(C)C (probability > 0.5):
# camphoreous: 0.6833
# fresh: 0.5773
# earthy: 0.5533
# woody: 0.5482
#
# Top odors for CCC(N)CS (probability > 0.5):
# meaty: 0.7753
# sulfurous: 0.5988
# savory: 0.5085
#
# Top odors for CCCSCOC (probability > 0.5):
# sulfurous: 0.7710
# vegetable: 0.6593
# onion: 0.6367
# garlic: 0.5722
# green: 0.5513
# alliaceous: 0.5343
# cabbage: 0.5200
#
# Top odors for CCC1=CCC(CC(C)(C)N=O)C=C1 (probability > 0.5):
# floral: 0.6376
# green: 0.6052
# fresh: 0.5595
#
# Top odors for CCCCC(S)CNOC (probability > 0.5):
#
# Top odors for CC=CCC (probability > 0.5):
# green: 0.7571
# fruity: 0.5446
# gassy: 0.5087
# vegetable: 0.5058
#
# Top odors for CC1=S(CC2OC2(C)C)OC=C1 (probability > 0.5):
# meaty: 0.6856
# roasted: 0.6609
# sulfurous: 0.5043
#
# Top odors for CCCCCCCNCC(C)N (probability > 0.5):
# fishy: 0.7022
#
# Top odors for CCCOC(=O)C=CCCOCC (probability > 0.5):
# fruity: 0.8587
# green: 0.6008
# sweet: 0.5720
# apple: 0.5215
#
# Top odors for CCCNC(CN)CC(C)CCC (probability > 0.5):
# fishy: 0.6055
#
# Top odors for C=C1NOC(C)=C1O (probability > 0.5):
# odorless: 0.7115
#
# Top odors for CCCC[NH+](C)NC(=O)CSC (probability > 0.5):
#
# Top odors for C=CCC(O)C=NCCC (probability > 0.5):
# green: 0.6285
#
# Top odors for Cc1ccc2ccnnc2c1 (probability > 0.5):
# nutty: 0.6208
# sweet: 0.6107
# burnt: 0.5585
# musty: 0.5541
# earthy: 0.5386
# green: 0.5332
# animal: 0.5155
# roasted: 0.5026
#
# Top odors for CCSC(C)S (probability > 0.5):
# sulfurous: 0.8764
# meaty: 0.7037
# onion: 0.6174
# roasted: 0.5367
# savory: 0.5324
#
# Top odors for CSCC=CNC=O (probability > 0.5):
# pungent: 0.6267
# sulfurous: 0.5634
# onion: 0.5283
#
# Top odors for CC1CCC2=C(C1)[NH+](C)C=C2 (probability > 0.5):
# nutty: 0.5079
#
# Top odors for CCSC(=O)C(C)C (probability > 0.5):
# sulfurous: 0.7978
# fruity: 0.7297
# tropical: 0.6512
# cheesy: 0.6307
# vegetable: 0.5318
#
# Top odors for CCC1=NS(C)=CN=C1 (probability > 0.5):
# nutty: 0.7916
# roasted: 0.6347
# meaty: 0.6292
#
# Top odors for CSC(=O)O (probability > 0.5):
# sulfurous: 0.8122
# meaty: 0.5414
#
# Top odors for CC1CCOO1 (probability > 0.5):
# fruity: 0.8485
# ethereal: 0.8020
# alcoholic: 0.5725
# green: 0.5583
# fermented: 0.5506
# sweet: 0.5119
#
# Top odors for CCCCC(=N)OCCC1CCCCC1 (probability > 0.5):
# fruity: 0.6317
# green: 0.5052
#
# Top odors for CC1=NCN(C)N1 (probability > 0.5):
# odorless: 0.7722
#
# Top odors for CC1(C)C2CCS(C)(S)C1C2 (probability > 0.5):
# sulfurous: 0.7852
# tropical: 0.7771
# green: 0.7000
# fruity: 0.6482
#
# Top odors for CCC(=O)C(C)(C)C (probability > 0.5):
# fruity: 0.9089
# herbal: 0.6169
# apple: 0.5945
#
# Top odors for CCC(C)C(=O)[NH+]([O-])OC (probability > 0.5):
# fruity: 0.5471
# odorless: 0.5349
#
# Top odors for CNOCc1ccc(O)c([NH2+]C)c1 (probability > 0.5):
# sweet: 0.5977
# vanilla: 0.5348
#
# Top odors for O=COCOc1ccccc1 (probability > 0.5):
# floral: 0.7094
# sweet: 0.6700
# fruity: 0.6402
# green: 0.6142
# balsamic: 0.5350
#
# Top odors for CC([NH3+])(S)CCO (probability > 0.5):
# meaty: 0.6844
# sulfurous: 0.6469
# grapefruit: 0.6025
#
# Top odors for CCCSS[NH2+]C (probability > 0.5):
# sulfurous: 0.8203
# onion: 0.6919
# garlic: 0.6304
# alliaceous: 0.5799
# meaty: 0.5691
# savory: 0.5350
# cooked: 0.5094
#
# Top odors for C=CCCSCC=C (probability > 0.5):
# sulfurous: 0.7547
# onion: 0.7198
# garlic: 0.6782
# meaty: 0.5304
# alliaceous: 0.5068
#
# Top odors for O=COCC[SH2+] (probability > 0.5):
# sulfurous: 0.6309
# fruity: 0.6293
# cheesy: 0.5105
#
# Top odors for CCC1=C(O)C(=N)CC1C (probability > 0.5):
# mint: 0.5106
#
# Top odors for CC1=CC(=O)C(S)O1 (probability > 0.5):
# meaty: 0.6735
# sulfurous: 0.6384
# roasted: 0.6082
# burnt: 0.5314
#
# Top odors for C=C(C)C(CC)CC=C(C)C (probability > 0.5):
# floral: 0.7834
# citrus: 0.6793
# sweet: 0.6348
# woody: 0.5996
# fruity: 0.5828
# rose: 0.5549
# fresh: 0.5535
# herbal: 0.5413
#
# Top odors for N=C1CCCCC1=O (probability > 0.5):
# caramellic: 0.5181
#
# Top odors for C=C(CC(C)C)C(C)C (probability > 0.5):
# herbal: 0.6910
# citrus: 0.6419
# woody: 0.6188
# floral: 0.6030
# fresh: 0.5599
# green: 0.5436
# lavender: 0.5092
#
# Top odors for CC(S)C(=N)O (probability > 0.5):
# sulfurous: 0.6995
# meaty: 0.6086
#
# Top odors for CCCCNN (probability > 0.5):
# fishy: 0.8438
# cheesy: 0.5821
#
# Top odors for CC(O)C(C)(C)S (probability > 0.5):
# sulfurous: 0.6308
# meaty: 0.5794
# grapefruit: 0.5573
#
# Top odors for CC(C)c1cc[nH+]cc1 (probability > 0.5):
# green: 0.7422
# earthy: 0.6219
# herbal: 0.5974
# woody: 0.5092
#
# Top odors for CC(C)CC(C)C(=O)S (probability > 0.5):
# fruity: 0.7909
# sulfurous: 0.7034
# tropical: 0.6831
# cheesy: 0.5633
#
# Top odors for COc1ccc(C(=O)CN)cc1 (probability > 0.5):
# sweet: 0.7443
# vanilla: 0.5554
#
# Top odors for O=C(S)CCc1ccccc1 (probability > 0.5):
# floral: 0.6185
# sulfurous: 0.5584
#
# Top odors for CS1(C)C2CCC(CCO)C1C2 (probability > 0.5):
# woody: 0.5377
# tropical: 0.5268
# green: 0.5219
# fruity: 0.5107
#
# Top odors for CCCC[NH+]=CCCCCO (probability > 0.5):
# fatty: 0.6177
# citrus: 0.5735
# green: 0.5602
# cheesy: 0.5176
#
# Top odors for CCOC(C)CCC1=CNCC=C1 (probability > 0.5):
# roasted: 0.5174
#
# Top odors for CCC=CC=CCC=CCC (probability > 0.5):
# green: 0.5511
# herbal: 0.5339
# gassy: 0.5048
# citrus: 0.5047
#
# Top odors for CCC=CCC(C)=O (probability > 0.5):
# fruity: 0.8459
# green: 0.7195
# earthy: 0.5365
# fatty: 0.5289
# herbal: 0.5044
#
# Top odors for CC=Cc1ccc(NC([NH3+])=S)c(CC)c1 (probability > 0.5):
# meaty: 0.5429
#
# Top odors for CCCCCSC1CCCCC(=O)O1 (probability > 0.5):
# sulfurous: 0.6453
# fruity: 0.5114
#
# Top odors for CCCCC(OCC)OOC (probability > 0.5):
# fruity: 0.7489
#
# Top odors for C=CCNC(=O)C(C)=O (probability > 0.5):
#
# Top odors for CCNSC (probability > 0.5):
# meaty: 0.7136
# sulfurous: 0.6051
#
# Top odors for CCCC(=N)CC(C)CC (probability > 0.5):
# citrus: 0.6257
# green: 0.5662
# floral: 0.5629
# fresh: 0.5165
#
# Top odors for c1csc(SSn2cccn2)c1 (probability > 0.5):
# sulfurous: 0.6786
# meaty: 0.6447
# roasted: 0.5839
#
# Top odors for O=S1CCCCCCCCONCCCCCC1 (probability > 0.5):
#
# Top odors for CCOc1ccc(C=O)cc1OO (probability > 0.5):
# vanilla: 0.8039
# sweet: 0.7777
# floral: 0.6168
# balsamic: 0.6089
# powdery: 0.5025
# creamy: 0.5014
#
# Top odors for CCCC(C)C(=N)OC (probability > 0.5):
# fruity: 0.7241
# green: 0.7236
# tropical: 0.5200
#
# Top odors for COc1ccc(C2OC(C)[NH+](C)O2)cc1 (probability > 0.5):
# vanilla: 0.6351
# sweet: 0.5644
#
# Top odors for CC(C)[NH2+]CN (probability > 0.5):
# fishy: 0.7294
# cheesy: 0.5990
#
# Top odors for CCC=CCNOC (probability > 0.5):
# green: 0.5324
#
# Top odors for CCCCOCC(=S)OCCCC (probability > 0.5):
# fruity: 0.8018
#
# Top odors for CCCCCCCCOC(=N)CCCCCC (probability > 0.5):
# fruity: 0.5962
# green: 0.5614
# waxy: 0.5005
#
# Top odors for SCC1=CCC=C1 (probability > 0.5):
# sulfurous: 0.7260
# meaty: 0.5799
#
# Top odors for Cc1coc(C)n1 (probability > 0.5):
# nutty: 0.7560
# green: 0.7402
# vegetable: 0.6551
# roasted: 0.5784
# cocoa: 0.5386
# burnt: 0.5280
#
# Top odors for C1CN=NC1 (probability > 0.5):
# nutty: 0.7018
# roasted: 0.6002
# meaty: 0.5579
# popcorn: 0.5469
#
# Top odors for CC(C)C(=O)OSC(C)c1ccccc1 (probability > 0.5):
# fruity: 0.7266
# sweet: 0.6065
# tropical: 0.5648
# sulfurous: 0.5447
#
# Top odors for CCC(S)CC(S)CC (probability > 0.5):
# sulfurous: 0.8422
# meaty: 0.6822
# fruity: 0.6058
# grapefruit: 0.5854
# roasted: 0.5413
# onion: 0.5108
# tropical: 0.5032
#
# Top odors for C=S(N)C(N)CCOC (probability > 0.5):
# odorless: 0.5153
#
# Top odors for C=C1CCC(C(N)(O)CN)CC1 (probability > 0.5):
# cooling: 0.5184

# %%
import os 

odor_counts = Counter(all_top_odors)

# Create a bar graph
plt.figure(figsize=(12, 6))
odors, counts = zip(*odor_counts.most_common(20))  #
plt.bar(odors, counts)
plt.title("Top Predicted Odors Across All Molecules")
plt.xlabel("Odor Labels")
plt.ylabel("Count in Top 10 Predictions")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_folder = '../../figures/Transformer/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300, 600, 1200]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_ten_{dpi}dpi.png", dpi=dpi, bbox_inches='tight')
plt.show()


print("\nCounts of odors in top 10 predictions across all molecules:")
for odor, count in odor_counts.most_common():
    print(f"{odor}: {count}")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Counts of odors in top 10 predictions across all molecules:
# meaty: 208
# sulfurous: 203
# fruity: 189
# green: 142
# roasted: 134
# sweet: 86
# nutty: 79
# onion: 61
# odorless: 58
# floral: 54
# tropical: 47
# cheesy: 46
# fishy: 43
# herbal: 42
# pungent: 36
# ethereal: 33
# vegetable: 30
# savory: 28
# woody: 28
# garlic: 27
# fresh: 24
# popcorn: 22
# citrus: 19
# burnt: 17
# mint: 17
# alliaceous: 16
# fatty: 13
# balsamic: 13
# earthy: 13
# caramellic: 13
# grapefruit: 12
# apple: 12
# alcoholic: 12
# musty: 11
# cocoa: 10
# coffee: 10
# rose: 10
# spicy: 10
# fermented: 8
# gassy: 8
# cooling: 7
# radish: 7
# hazelnut: 6
# vanilla: 6
# winey: 5
# cognac: 4
# sharp: 4
# honey: 4
# cherry: 4
# camphoreous: 4
# solvent: 4
# cabbage: 4
# almond: 3
# waxy: 3
# jasmin: 3
# pine: 2
# anisic: 2
# terpenic: 2
# sour: 2
# musk: 2
# amber: 2
# oily: 2
# pineapple: 2
# phenolic: 2
# animal: 2
# creamy: 2
# cinnamon: 2
# bitter: 1
# beefy: 1
# dry: 1
# pear: 1
# grape: 1
# coumarinic: 1
# ketonic: 1
# berry: 1
# black currant: 1
# cooked: 1
# lavender: 1
# powdery: 1
#
# Problematic SMILES that caused errors:

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt


odor_counts = Counter(all_top_odors)
total_predictions = sum(odor_counts.values())


percentages = [(count / total_predictions) * 100 for count in odor_counts.values()]


sorted_odors_percentages = sorted(zip(odor_counts.keys(), percentages), key=lambda x: x[1], reverse=True)


sorted_odors_percentages = [(odor, pct) for odor, pct in sorted_odors_percentages if odor != 'odorless']


top_20_odors_percentages = sorted_odors_percentages[:20]
top_20_odors, top_20_percentages = zip(*top_20_odors_percentages)

plt.figure(figsize=(15, 8))  


bars = plt.bar(top_20_odors, top_20_percentages, edgecolor='black')
ax = plt.gca()  
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(2)  


plt.title("Most Common Odor Predictions (Transformer)", fontsize=33, fontweight='bold', pad=20)
plt.xlabel("Odor Labels", fontsize=33, fontweight='bold', labelpad=15)
plt.ylabel("(%) of Predictions", fontsize=29, fontweight='bold', labelpad=10)


plt.xticks(rotation=45, ha='right', fontsize=28, fontweight='bold')
plt.yticks(fontsize=26, fontweight='bold')


plt.tight_layout()


output_folder = '../../figures/Transformer/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True) 
dpi_values = [300]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_odor_per.png", dpi=dpi, bbox_inches='tight')


plt.show()


print("\nPercentages of top 20 odors in top 10 predictions across all molecules:")
for odor, percentage in zip(top_20_odors, top_20_percentages):
    print(f"{odor}: {percentage:.2f}%")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Percentages of top 20 odors in top 10 predictions across all molecules:
# meaty: 10.68%
# sulfurous: 10.42%
# fruity: 9.70%
# green: 7.29%
# roasted: 6.88%
# sweet: 4.41%
# nutty: 4.06%
# onion: 3.13%
# floral: 2.77%
# tropical: 2.41%
# cheesy: 2.36%
# fishy: 2.21%
# herbal: 2.16%
# pungent: 1.85%
# ethereal: 1.69%
# vegetable: 1.54%
# savory: 1.44%
# woody: 1.44%
# garlic: 1.39%
# fresh: 1.23%
#
# Problematic SMILES that caused errors:
