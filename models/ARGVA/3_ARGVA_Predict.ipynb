# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
from openpom.feat.graph_featurizer import GraphFeaturizer, GraphConvConstants
from openpom.utils.data_utils import get_class_imbalance_ratio, IterativeStratifiedSplitter
from openpom.models.mpnn_pom import MPNNPOMModel
from datetime import datetime
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import gaussian_kde
from collections import Counter
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# WARNING:tensorflow:From c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\deepchem\models\torch_models\__init__.py)

# %%
# Odor Labels
TASKS = [
    'alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
    'anisic', 'apple', 'apricot', 'aromatic', 'balsamic', 'banana', 'beefy',
    'bergamot', 'berry', 'bitter', 'black currant', 'brandy', 'burnt',
    'buttery', 'cabbage', 'camphoreous', 'caramellic', 'cedar', 'celery',
    'chamomile', 'cheesy', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clean',
    'clove', 'cocoa', 'coconut', 'coffee', 'cognac', 'cooked', 'cooling',
    'cortex', 'coumarinic', 'creamy', 'cucumber', 'dairy', 'dry', 'earthy',
    'ethereal', 'fatty', 'fermented', 'fishy', 'floral', 'fresh', 'fruit skin',
    'fruity', 'garlic', 'gassy', 'geranium', 'grape', 'grapefruit', 'grassy',
    'green', 'hawthorn', 'hay', 'hazelnut', 'herbal', 'honey', 'hyacinth',
    'jasmin', 'juicy', 'ketonic', 'lactonic', 'lavender', 'leafy', 'leathery',
    'lemon', 'lily', 'malty', 'meaty', 'medicinal', 'melon', 'metallic',
    'milky', 'mint', 'muguet', 'mushroom', 'musk', 'musty', 'natural', 'nutty',
    'odorless', 'oily', 'onion', 'orange', 'orangeflower', 'orris', 'ozone',
    'peach', 'pear', 'phenolic', 'pine', 'pineapple', 'plum', 'popcorn',
    'potato', 'powdery', 'pungent', 'radish', 'raspberry', 'ripe', 'roasted',
    'rose', 'rummy', 'sandalwood', 'savory', 'sharp', 'smoky', 'soapy',
    'solvent', 'sour', 'spicy', 'strawberry', 'sulfurous', 'sweaty', 'sweet',
    'tea', 'terpenic', 'tobacco', 'tomato', 'tropical', 'vanilla', 'vegetable',
    'vetiver', 'violet', 'warm', 'waxy', 'weedy', 'winey', 'woody'
]
len(TASKS)
# Out:
# 138

# %%
input_file = '../../data/curated dataset/curated_GS_LF_merged_4983.csv'
featurizer = GraphFeaturizer()
smiles_field = 'nonStereoSMILES'

# %%
loader = dc.data.CSVLoader(tasks=TASKS,
feature_field=smiles_field,
featurizer=featurizer)

# %%
dataset = loader.create_dataset(inputs=[input_file])
n_tasks = len(dataset.tasks)
randomstratifiedsplitter = dc.splits.RandomStratifiedSplitter()
train_dataset, test_dataset, valid_dataset = randomstratifiedsplitter.train_valid_test_split(dataset, frac_train = 0.8, frac_valid = 0.1, frac_test = 0.1, seed = 1)
train_ratios = get_class_imbalance_ratio(train_dataset)

# %%
assert len(train_ratios) == n_tasks

# %%
learning_rate = dc.models.optimizers.ExponentialDecay(initial_rate=0.001, decay_rate=0.5, decay_steps=32*20, staircase=True)

# %%
model = MPNNPOMModel(n_tasks = n_tasks,
                     batch_size = 128,
                     learning_rate = learning_rate,
                     class_imbalance_ratio = train_ratios,
                     loss_aggr_type = 'sum',
                     node_out_feats = 100,
                     edge_hidden_feats = 75,
                     edge_out_feats = 100,
                     num_step_message_passing = 5,
                     mpnn_residual = True,
                     message_aggregator_type = 'sum',
                     mode = 'classification',
                     number_atom_features = GraphConvConstants.ATOM_FDIM,
                     number_bond_features = GraphConvConstants.BOND_FDIM,
                     n_classes = 1,
                     readout_type = 'set2set',
                     num_step_set2set = 3,
                     num_layer_set2set = 2,
                     ffn_hidden_list = [392, 392],
                     ffn_embeddings = 256,
                     ffn_activation = 'relu',
                     ffn_dropout_p = 0.12,
                     ffn_dropout_at_input_no_act = False,
                     weight_decay = 1e-5,
                     self_loop = False,
                     optimizer_name = 'adam',
                     log_frequency = 32,
                     model_dir = './experiments',
                     device_name ='cpu')

# %%
# Load the saved model state
import torch
checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
if 'model_state_dict' in checkpoint:
    model.model.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    model.model.load_state_dict(checkpoint, strict=False)
model.model.eval()
# Out:
# C:\Users\sarab\AppData\Local\Temp\ipykernel_1872\1392124263.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
# MPNNPOM(
#   (mpnn): CustomMPNNGNN(
#     (project_node_feats): Sequential(
#       (0): Linear(in_features=134, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (gnn_layer): NNConv(
#       (edge_func): Sequential(
#         (0): Linear(in_features=6, out_features=75, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=75, out_features=10000, bias=True)
#       )
#       (res_fc): Identity()
#     )
#     (gru): GRU(100, 100)
#   )
#   (project_edge_feats): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#   )
#   (readout_set2set): Set2Set(
#     n_iters=3
#     (lstm): LSTM(400, 200, num_layers=2)
#   )
#   (ffn): CustomPositionwiseFeedForward(
#     (activation): ReLU()
#     (linears): ModuleList(
#       (0): Linear(in_features=400, out_features=392, bias=True)
#       (1): Linear(in_features=392, out_features=392, bias=True)
#       (2): Linear(in_features=392, out_features=256, bias=True)
#       (3): Linear(in_features=256, out_features=138, bias=True)
#     )
#     (dropout_p): ModuleList(
#       (0-3): 4 x Dropout(p=0.12, inplace=False)
#     )
#     (batchnorms): ModuleList(
#       (0-1): 2 x BatchNorm1d(392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
csv_file_path = '../../data/ARGVA/logistic equation/novel_odorrous_set_log_eq.csv'
df = pd.read_csv(csv_file_path)

# %%
smiles_list = df['SMILE'].tolist()
print(smiles_list)

# Featurize all SMILES at once
featurizer = GraphFeaturizer()
featurized_data = featurizer.featurize(smiles_list)


all_top_odors = []
problematic_smiles = []

for i, featurized_mol in enumerate(featurized_data):
    try:
        
        single_mol_dataset = dc.data.NumpyDataset([featurized_mol])

        
        prediction = model.predict(single_mol_dataset)

        
        odor_probs = prediction.squeeze()
        high_prob_indices = np.where(odor_probs > 0.5)[0]
        
        
        sorted_indices = high_prob_indices[np.argsort(odor_probs[high_prob_indices])[::-1]]
        
        
        top_odors = [TASKS[i] for i in sorted_indices]
        all_top_odors.extend(top_odors)

        
        print(f"\nTop odors for {smiles_list[i]} (probability > 0.5):")
        for odor, score in zip(top_odors, odor_probs[sorted_indices]):
            print(f"{odor}: {score:.4f}")

    except KeyError as e:
        print(f"\nError processing SMILES: {smiles_list[i]}")
        print(f"Error message: {str(e)}")
        problematic_smiles.append(smiles_list[i])
        continue
# Out:
# ['CCCC(C)C1CCCCC1C', 'CCCCCCC1CCCC1C', 'CCC(C)CCCC(C)CCCC(C)C', 'CCCC(CCC)C1CCC2CCCC2C1', 'CC1CCCC2(C)CCCCC12C', 'CCC(CC)C1CCC(C)C1', 'CCCCCCCCC1CCCC(C)C1', 'CCCC(C)C(C)CCCC(C)CCCC(C)C', 'CCC(C)CC1CCCCCCCCCCC1', 'CCCC(C)CC1(C)CCC(C)C1', 'CCCCC(CC)CCCC', 'CCCC1(C)CCC2C(C)C1CCC2(C)C', 'CCCCC(C)C1CCC(C)CC1', 'CCC1(C)CCC(C(C)C)CC1C(C)C', 'CC(C)CCCC(C)CCCC(C)C(C)C(C)C', 'CC(C)CC1CCCC(C(C)(C)C)C1', 'CCCCC(C)CCC1CCCCC1', 'CCCC(C)CC(CC(C)C)C(C)C', 'CCC(C)C1CC1(C)CCC1C(C)CCCC1(C)C', 'CCCCCCCCCCCCCCCCCCC', 'CC(C)CC1C(C)C2CC1C1CCC(C)C21', 'CCC12CCC(C1)C(C1(C)CCCCC1)C2', 'CC(C)C1CCCCC1C(C)C', 'CCC1CCC(C)CC1CC', 'CCCCC(C)CCCCCC1CCCCC1', 'CCCCCCCCCCC(C)CCCCC', 'CCCCC1CCC(CC(C)C)CC1C', 'CCC(C)CC1CCCCC1C(C)CC', 'CC(C)CCCC(C)CCCC(C)C(C)C', 'CCCCCC(C)C(C)C(C)C', 'CCCCCC(C)CCCCC1CCCCC1', 'CC(C)C1CCC(C(C)(C)C)CC1', 'CCC1CC(C)CC(C)C1', 'CCCCCC(C)CC(C)CC(C)C', 'CCCCCC(CCC)CC(C)C', 'CCCCCC(C)CCCC(C)CCCC(C)C', 'OOOOO', 'CCC(C)CCC(C)CC(C)C1CCCC(C)(C)C1', 'CC1CCC(C(C)C)C(C(C)CCCC2CCCCC2)C1', 'CC1CCCC1C', 'CC(C)C(C)CCC(C)C1CCCCC1', 'CC1CCCC(C)(C)C1C', 'CCCCCCCCCCC(C)CCCC', 'CCCCC1CC2CC1C1CCCC21', 'CCCCCC1CCC(CC(C)C)CC1', 'CC1CCC(C2CCC3CCCC3C2)C1', 'CC(C)CCCC1CCCC1C', 'CC(C)C(C)CCC1CCC(C)C1(C)C', 'CCCCCCCCCC1CCCC(C)C1', 'CCCCCC(CC)CC(C)C(C)CC', 'CCC(C)CCC(CCC(C)CC)CC(C)CC', 'CCCCC(C)C(C)CC', 'CC1CCC2(CC1)CCC(C)CC2', 'CC(C)CC1CC(C)C2CC(C(C)C)CC2C(C)C1', 'C1CCC(CCCC2CCCC2)CC1', 'CCCCC1CCCCC1', 'CCC(C)C1CCCCC1CCCC(C)CCCC(C)(C)C', 'CCCCCCCC(C)CC(C)C', 'CCCCC1CCC(CC)CC1', 'CCC(C)C1CCCCC1', 'CC(C)CCCCC(C)C1CCCCC1C', 'CCCCCC(CCC)CCC', 'CCCCC(C)CC1CCC(C)CC1', 'CC1CCCCCCCCCCCCCCCC1', 'CC(C1CCCCC1)C1CCCC1', 'CCCC(C)CCC1CCCC1', 'CC(C)C(C)CCC1CCCCC1', 'CCCC(C)C1CC1C1CCCCC1', 'CCCCCCCC(C)CCCCCC', 'CC1CC2CCCCC2C1', 'CCC1(C)CCC(C(C)(C)CC(C)C)C1', 'CCCC1CC(C)C2CCCCC12', 'CC(C)C(C)CCCC1CCCC1C', 'CCCCCCC(C)C(C)C', 'CCCCCCCCCC(C)CCCCC1CCCCC1', 'CCC(C)C(C)C(C)CC(C)C', 'CC1CCCCCC1', 'CCC1CC2CC1C1CCCCC21', 'CCC(C)C(C)CC1(C)CC2CCC1C2', 'CCCC1C2(C)CCC(C2)C1(C)C', 'CC1CCC2CCCC2C1', 'CCC(CC)CC(C)CCCC(C)(C)C', 'CC(C)CC(C)CCC1CCC(C)CC1', 'CCCC1C2CCC(C2)C1CC', 'CC1CCC2(C1)C(C)(C)CCCC2(C)C', 'CCCC(C)C1C(CC(C)C)C1(C)C', 'CC1CCC2(C)CCCC(C)(C)C23CC13', 'CC(C)CCC1C(C)CC(C)CC1(C)C', 'CCCC(C)CCCCCCCCCCC(C)CCC', 'C=C=C', 'CC(C)CCCCCC(C)C', 'CCC1CCC(C)C(CC(C)C)C1', 'CCCCCCCCCCCCCCCCCC(C)CCCCCCC', 'CCCC(C)C1CC1(C)C1CCC(C)CC1', 'CC(C)CCC1C(C)C(C)CCC1(C)C', 'CCCCCC(CCC1CCCCC1)CC(C)C', 'CC(C)CCCC(C)CCCCCC(C)CCCC(C)C', 'CC1CCCCCCCCCCCC1', 'CCC(C)C1CC1C1CCC(C)CC1', 'CC1CCCCC1C(C)CCC1CCCCC1', 'CC1CCCC(C)C1', 'CCC1CC(C)CCC1C', 'CC(C)CCC(C)C(C)C', 'CCCCCCC(C)CCCC(C)CCCC(C)C', 'CCCCCCC(C)C1CCCCC1C', 'CC(C)CCCC(C)(C)C1CC1', 'CCCCC(C)C1C(C)CCCC1(C)C', 'CCCC1CCCC(CC)C1C', 'CC(C)CC(C)C1CCCCC1', 'CCC1CCCCC1CCC(C)C', 'CCCCCCC1CCC(C)CC1', 'CCCC1CCCCC1C', 'CC(C)C(C)CC1CC2CC1C1CCCC21', 'CCCCCCC(C)CC(C)CCC', 'CCCCC1CCCCC(C)C1', 'CCCCC(C(C)C)C(C)CC(C)C', 'CCCC1CC(CC)C(C)C(C)C1C', 'CC(C)C(C)CC(C)C(C)C', 'CC(CCCCC1CCCCC1)CCC1CCCCC1', 'CCC1CCC(CC(C)C)CC1C', 'CCC(C)C(C)CCCC1CCCCC1', 'CCC(C)CCC1CCCCC1', 'CCCC1C(C)CCCC1(C)C', 'C1CCC(CCC2CCCCC2)CC1', 'CCC(C)(CCC1CC1(C)C)CC(C)C', 'CCCCCCCCC(CC(C)C)C(C)CC', 'CC(C)CCCC1CCCC1', 'CCC1C(C)CC2C(C1CC)C(C)(C)CCC2(C)C', 'CCC1CCC(C)CC1', 'CCC(C)(C)CC', 'CCCCCC(C)C(C)CCCC', 'CCCCCC(C)CCC(CC)CCCC', 'CCCCCCC(C)CCCCC', 'CCCCCCCCCCCCCCCC(C)C', 'CC1CCC2CCC(C)CC2C1', 'CC(C)C1CCC2(C)C3CCC(C)C3C12', 'CCCC(C)CC(C)C1CCCCC1', 'CCC(C)C1CC(C(C)C)CCC1C', 'CCCCCCCCCC(C)CC(CCCC)CCCCC(C)C', 'CC(C)C(C)C', 'CCCCCCCC(CCC(C)C)CC(C)C', 'CCCCCC1CC(C)CC1C', 'CCC(C)CC(C)CC', 'CC1CCC(C(C)C)C(CC(C)CC2CCCCC2)C1', 'CCCCC(CCCC)CCCC', 'CCCCC(CC)CC', 'CC(C)C1CCC2(C)CC2C1', 'CCCCCCC1CC1CCCC', 'CCCC1CC(C2CC(C)CC(C)(C)C2)CCC1C', 'CCC1CCC(C(C)CCC2CCCCC2)C(C)C1', 'CC1CC(C)C2(CC(C)(C)CC(C)(C)C2)C1(C)C', 'CCCC(C)CC(C)(CC(C)CCC)C(C)C', 'CC(C)C1CCC(C)(C(C)C2CCCC2C)C1C', 'CC(C)C(C)CC1CCC2CCCCC2C1', 'CCCCC(CC)C(C)CCC', 'CC(C)CCC1C(C)CCCC1(C)C', 'CCC1(C)CCC(C)C1', 'CC(C)CCC1CCC(C)CC1', 'CC1CCCCCCCCCCCCCC(C)C1', 'CCCCC(C)C1CCCC(C)(C)C1', 'CCCCCCCCCCCCCC(C)CC', 'CC1CCC(CC2C3CCC(C3)C2(C)C)CC1C', 'CCCCCCCCCC(C)CCC', 'CCCC(C)CCC ...
#
# Top odors for CCCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6590
# green: 0.5812
# floral: 0.5024
#
# Top odors for CCCCCCC1CCCC1C (probability > 0.5):
# waxy: 0.6019
#
# Top odors for CCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6021
# waxy: 0.5522
# green: 0.5408
# woody: 0.5373
#
# Top odors for CCCC(CCC)C1CCC2CCCC2C1 (probability > 0.5):
# woody: 0.6004
# waxy: 0.5443
#
# Top odors for CC1CCCC2(C)CCCCC12C (probability > 0.5):
# woody: 0.7988
# amber: 0.5504
# dry: 0.5370
#
# Top odors for CCC(CC)C1CCC(C)C1 (probability > 0.5):
# woody: 0.6435
# floral: 0.5720
# green: 0.5694
#
# Top odors for CCCCCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.6688
#
# Top odors for CCCC(C)C(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6809
# woody: 0.6024
# green: 0.5903
# waxy: 0.5258
#
# Top odors for CCC(C)CC1CCCCCCCCCCC1 (probability > 0.5):
# woody: 0.5563
#
# Top odors for CCCC(C)CC1(C)CCC(C)C1 (probability > 0.5):
# woody: 0.7074
# green: 0.5363
#
# Top odors for CCCCC(CC)CCCC (probability > 0.5):
# waxy: 0.6381
#
# Top odors for CCCC1(C)CCC2C(C)C1CCC2(C)C (probability > 0.5):
# woody: 0.8698
# amber: 0.5170
# pine: 0.5078
# green: 0.5052
#
# Top odors for CCCCC(C)C1CCC(C)CC1 (probability > 0.5):
# woody: 0.5907
#
# Top odors for CCC1(C)CCC(C(C)C)CC1C(C)C (probability > 0.5):
# woody: 0.7948
# green: 0.6651
# herbal: 0.5783
# floral: 0.5694
# fresh: 0.5137
#
# Top odors for CC(C)CCCC(C)CCCC(C)C(C)C(C)C (probability > 0.5):
# floral: 0.7565
# green: 0.6544
# woody: 0.6162
#
# Top odors for CC(C)CC1CCCC(C(C)(C)C)C1 (probability > 0.5):
# woody: 0.7987
# green: 0.6662
# floral: 0.6281
# herbal: 0.5599
# fresh: 0.5183
#
# Top odors for CCCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.6024
#
# Top odors for CCCC(C)CC(CC(C)C)C(C)C (probability > 0.5):
# floral: 0.7782
# green: 0.6771
# woody: 0.6129
# fresh: 0.5173
#
# Top odors for CCC(C)C1CC1(C)CCC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.8540
#
# Top odors for CCCCCCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7659
#
# Top odors for CC(C)CC1C(C)C2CC1C1CCC(C)C21 (probability > 0.5):
# woody: 0.7507
# green: 0.6643
# herbal: 0.6270
# fresh: 0.5326
# pine: 0.5263
#
# Top odors for CCC12CCC(C1)C(C1(C)CCCCC1)C2 (probability > 0.5):
# woody: 0.8570
#
# Top odors for CC(C)C1CCCCC1C(C)C (probability > 0.5):
# green: 0.7240
# floral: 0.7059
# woody: 0.7013
# herbal: 0.6253
# fresh: 0.5633
# citrus: 0.5624
#
# Top odors for CCC1CCC(C)CC1CC (probability > 0.5):
# woody: 0.6839
# citrus: 0.5875
# green: 0.5600
# fresh: 0.5213
# floral: 0.5056
# herbal: 0.5010
#
# Top odors for CCCCC(C)CCCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6861
#
# Top odors for CCCCCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.7146
#
# Top odors for CCCCC1CCC(CC(C)C)CC1C (probability > 0.5):
# woody: 0.6281
# green: 0.5749
# floral: 0.5150
#
# Top odors for CCC(C)CC1CCCCC1C(C)CC (probability > 0.5):
# woody: 0.6531
# floral: 0.6121
# green: 0.5843
#
# Top odors for CC(C)CCCC(C)CCCC(C)C(C)C (probability > 0.5):
# floral: 0.7208
# green: 0.6243
# woody: 0.6010
#
# Top odors for CCCCCC(C)C(C)C(C)C (probability > 0.5):
# floral: 0.7439
# green: 0.6643
# woody: 0.5799
# fresh: 0.5366
# citrus: 0.5181
# herbal: 0.5059
#
# Top odors for CCCCCC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6794
#
# Top odors for CC(C)C1CCC(C(C)(C)C)CC1 (probability > 0.5):
# woody: 0.8230
# green: 0.6811
# floral: 0.6254
# herbal: 0.5757
# fresh: 0.5275
#
# Top odors for CCC1CC(C)CC(C)C1 (probability > 0.5):
# woody: 0.7409
# herbal: 0.6269
# floral: 0.5896
# green: 0.5644
# fresh: 0.5363
#
# Top odors for CCCCCC(C)CC(C)CC(C)C (probability > 0.5):
# floral: 0.6436
# green: 0.5786
# woody: 0.5446
# waxy: 0.5246
#
# Top odors for CCCCCC(CCC)CC(C)C (probability > 0.5):
# waxy: 0.6047
#
# Top odors for CCCCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6023
#
# Top odors for OOOOO (probability > 0.5):
# odorless: 0.6586
#
# Top odors for CCC(C)CCC(C)CC(C)C1CCCC(C)(C)C1 (probability > 0.5):
# woody: 0.7164
# floral: 0.6173
# green: 0.5654
# waxy: 0.5188
#
# Top odors for CC1CCC(C(C)C)C(C(C)CCCC2CCCCC2)C1 (probability > 0.5):
# woody: 0.7054
# green: 0.5471
#
# Top odors for CC1CCCC1C (probability > 0.5):
# woody: 0.7339
# amber: 0.5277
#
# Top odors for CC(C)C(C)CCC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6847
# floral: 0.6798
# green: 0.6310
#
# Top odors for CC1CCCC(C)(C)C1C (probability > 0.5):
# woody: 0.8051
# pine: 0.5381
# camphoreous: 0.5356
# cedar: 0.5119
# amber: 0.5111
#
# Top odors for CCCCCCCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.7102
#
# Top odors for CCCCC1CC2CC1C1CCCC21 (probability > 0.5):
# woody: 0.7341
#
# Top odors for CCCCCC1CCC(CC(C)C)CC1 (probability > 0.5):
# waxy: 0.5210
#
# Top odors for CC1CCC(C2CCC3CCCC3C2)C1 (probability > 0.5):
# woody: 0.7977
# amber: 0.5065
#
# Top odors for CC(C)CCCC1CCCC1C (probability > 0.5):
# woody: 0.6239
# green: 0.5401
#
# Top odors for CC(C)C(C)CCC1CCC(C)C1(C)C (probability > 0.5):
# woody: 0.8069
# green: 0.5898
# floral: 0.5748
#
# Top odors for CCCCCCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.6931
#
# Top odors for CCCCCC(CC)CC(C)C(C)CC (probability > 0.5):
# floral: 0.6263
# waxy: 0.5758
# woody: 0.5521
# green: 0.5222
#
# Top odors for CCC(C)CCC(CCC(C)CC)CC(C)CC (probability > 0.5):
# floral: 0.6461
# woody: 0.5915
# waxy: 0.5890
# green: 0.5147
#
# Top odors for CCCCC(C)C(C)CC (probability > 0.5):
# floral: 0.6795
# green: 0.5968
# citrus: 0.5334
# woody: 0.5280
# fresh: 0.5172
#
# Top odors for CC1CCC2(CC1)CCC(C)CC2 (probability > 0.5):
# woody: 0.7388
# dry: 0.5195
# amber: 0.5183
#
# Top odors for CC(C)CC1CC(C)C2CC(C(C)C)CC2C(C)C1 (probability > 0.5):
# woody: 0.7454
# green: 0.6963
# herbal: 0.6390
# floral: 0.5905
# fresh: 0.5651
# citrus: 0.5414
# pine: 0.5203
#
# Top odors for C1CCC(CCCC2CCCC2)CC1 (probability > 0.5):
# waxy: 0.5498
#
# Top odors for CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5073
#
# Top odors for CCC(C)C1CCCCC1CCCC(C)CCCC(C)(C)C (probability > 0.5):
# woody: 0.6777
# floral: 0.6272
# green: 0.5602
# waxy: 0.5423
#
# Top odors for CCCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.5887
#
# Top odors for CCCCC1CCC(CC)CC1 (probability > 0.5):
#
# Top odors for CCC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6130
#
# Top odors for CC(C)CCCCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6429
# green: 0.5340
# waxy: 0.5291
# floral: 0.5222
#
# Top odors for CCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.6565
#
# Top odors for CCCCC(C)CC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.5228
# woody: 0.5060
#
# Top odors for CC1CCCCCCCCCCCCCCCC1 (probability > 0.5):
# musk: 0.7378
# amber: 0.5948
# animal: 0.5798
# woody: 0.5793
# sweet: 0.5685
# dry: 0.5071
#
# Top odors for CC(C1CCCCC1)C1CCCC1 (probability > 0.5):
# woody: 0.7004
#
# Top odors for CCCC(C)CCC1CCCC1 (probability > 0.5):
# waxy: 0.5717
#
# Top odors for CC(C)C(C)CCC1CCCCC1 (probability > 0.5):
# woody: 0.6234
# floral: 0.5893
# green: 0.5836
#
# Top odors for CCCC(C)C1CC1C1CCCCC1 (probability > 0.5):
# woody: 0.6947
# green: 0.5494
#
# Top odors for CCCCCCCC(C)CCCCCC (probability > 0.5):
# waxy: 0.6853
#
# Top odors for CC1CC2CCCCC2C1 (probability > 0.5):
# woody: 0.7963
# amber: 0.5390
#
# Top odors for CCC1(C)CCC(C(C)(C)CC(C)C)C1 (probability > 0.5):
# woody: 0.8144
# green: 0.6123
# floral: 0.5141
#
# Top odors for CCCC1CC(C)C2CCCCC12 (probability > 0.5):
# woody: 0.7162
#
# Top odors for CC(C)C(C)CCCC1CCCC1C (probability > 0.5):
# woody: 0.6785
# floral: 0.6268
# green: 0.5936
#
# Top odors for CCCCCCC(C)C(C)C (probability > 0.5):
# floral: 0.5402
# green: 0.5368
#
# Top odors for CCCCCCCCCC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.7216
#
# Top odors for CCC(C)C(C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7521
# green: 0.7130
# woody: 0.6370
# herbal: 0.5752
# citrus: 0.5740
# fresh: 0.5710
# muguet: 0.5011
#
# Top odors for CC1CCCCCC1 (probability > 0.5):
# musk: 0.6989
# woody: 0.6364
# amber: 0.6060
# sweet: 0.5382
# animal: 0.5205
# dry: 0.5120
#
# Top odors for CCC1CC2CC1C1CCCCC21 (probability > 0.5):
# woody: 0.8051
#
# Top odors for CCC(C)C(C)CC1(C)CC2CCC1C2 (probability > 0.5):
# woody: 0.8006
# green: 0.5438
#
# Top odors for CCCC1C2(C)CCC(C2)C1(C)C (probability > 0.5):
# woody: 0.8735
# amber: 0.5348
#
# Top odors for CC1CCC2CCCC2C1 (probability > 0.5):
# woody: 0.7962
# amber: 0.5320
#
# Top odors for CCC(CC)CC(C)CCCC(C)(C)C (probability > 0.5):
# floral: 0.7167
# woody: 0.6548
# green: 0.5939
#
# Top odors for CC(C)CC(C)CCC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6380
# green: 0.5651
# floral: 0.5522
#
# Top odors for CCCC1C2CCC(C2)C1CC (probability > 0.5):
# woody: 0.7037
# green: 0.5365
#
# Top odors for CC1CCC2(C1)C(C)(C)CCCC2(C)C (probability > 0.5):
# woody: 0.8847
# amber: 0.5905
# cedar: 0.5884
# dry: 0.5719
#
# Top odors for CCCC(C)C1C(CC(C)C)C1(C)C (probability > 0.5):
# woody: 0.7664
# green: 0.6118
# floral: 0.5548
# herbal: 0.5474
#
# Top odors for CC1CCC2(C)CCCC(C)(C)C23CC13 (probability > 0.5):
# woody: 0.9168
# amber: 0.6266
# dry: 0.5800
# cedar: 0.5679
#
# Top odors for CC(C)CCC1C(C)CC(C)CC1(C)C (probability > 0.5):
# woody: 0.7947
# green: 0.6167
# floral: 0.5663
# herbal: 0.5438
# fresh: 0.5163
#
# Top odors for CCCC(C)CCCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.7085
#
# Top odors for C=C=C (probability > 0.5):
# pungent: 0.6350
# ethereal: 0.5449
# green: 0.5218
# sharp: 0.5195
#
# Top odors for CC(C)CCCCCC(C)C (probability > 0.5):
# green: 0.5385
#
# Top odors for CCC1CCC(C)C(CC(C)C)C1 (probability > 0.5):
# woody: 0.6872
# green: 0.6514
# floral: 0.6393
# herbal: 0.5756
# fresh: 0.5596
# citrus: 0.5524
#
# Top odors for CCCCCCCCCCCCCCCCCC(C)CCCCCCC (probability > 0.5):
# waxy: 0.7600
#
# Top odors for CCCC(C)C1CC1(C)C1CCC(C)CC1 (probability > 0.5):
# woody: 0.8138
# green: 0.5086
#
# Top odors for CC(C)CCC1C(C)C(C)CCC1(C)C (probability > 0.5):
# woody: 0.8047
# green: 0.6021
# floral: 0.5474
# herbal: 0.5267
#
# Top odors for CCCCCC(CCC1CCCCC1)CC(C)C (probability > 0.5):
# waxy: 0.6667
#
# Top odors for CC(C)CCCC(C)CCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5834
# woody: 0.5424
# floral: 0.5088
#
# Top odors for CC1CCCCCCCCCCCC1 (probability > 0.5):
# musk: 0.7322
# amber: 0.5991
# woody: 0.5931
# animal: 0.5691
# sweet: 0.5636
# dry: 0.5088
#
# Top odors for CCC(C)C1CC1C1CCC(C)CC1 (probability > 0.5):
# woody: 0.7517
# green: 0.5733
#
# Top odors for CC1CCCCC1C(C)CCC1CCCCC1 (probability > 0.5):
# woody: 0.6773
#
# Top odors for CC1CCCC(C)C1 (probability > 0.5):
# woody: 0.7289
# amber: 0.5920
# musk: 0.5633
#
# Top odors for CCC1CC(C)CCC1C (probability > 0.5):
# woody: 0.7431
# green: 0.5351
# herbal: 0.5348
# citrus: 0.5340
# fresh: 0.5240
# floral: 0.5141
#
# Top odors for CC(C)CCC(C)C(C)C (probability > 0.5):
# green: 0.7210
# floral: 0.7079
# woody: 0.6442
# herbal: 0.6294
# citrus: 0.5999
# fresh: 0.5632
#
# Top odors for CCCCCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6201
#
# Top odors for CCCCCCC(C)C1CCCCC1C (probability > 0.5):
# waxy: 0.5744
# woody: 0.5218
#
# Top odors for CC(C)CCCC(C)(C)C1CC1 (probability > 0.5):
# woody: 0.7675
# floral: 0.6429
# green: 0.5928
#
# Top odors for CCCCC(C)C1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7541
# floral: 0.5550
# green: 0.5507
#
# Top odors for CCCC1CCCC(CC)C1C (probability > 0.5):
# woody: 0.6216
# citrus: 0.5542
# green: 0.5468
# fresh: 0.5077
#
# Top odors for CC(C)CC(C)C1CCCCC1 (probability > 0.5):
# green: 0.6442
# woody: 0.6440
# floral: 0.6306
#
# Top odors for CCC1CCCCC1CCC(C)C (probability > 0.5):
# woody: 0.6182
# green: 0.5604
# floral: 0.5260
#
# Top odors for CCCCCCC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.5957
#
# Top odors for CCCC1CCCCC1C (probability > 0.5):
# woody: 0.5705
#
# Top odors for CC(C)C(C)CC1CC2CC1C1CCCC21 (probability > 0.5):
# woody: 0.7685
# green: 0.5975
# floral: 0.5228
# herbal: 0.5068
#
# Top odors for CCCCCCC(C)CC(C)CCC (probability > 0.5):
# waxy: 0.6168
#
# Top odors for CCCCC1CCCCC(C)C1 (probability > 0.5):
#
# Top odors for CCCCC(C(C)C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7726
# green: 0.6898
# woody: 0.6145
# fresh: 0.5437
# herbal: 0.5074
# citrus: 0.5055
#
# Top odors for CCCC1CC(CC)C(C)C(C)C1C (probability > 0.5):
# green: 0.6948
# woody: 0.6886
# herbal: 0.6454
# citrus: 0.6103
# fresh: 0.6011
# floral: 0.5733
#
# Top odors for CC(C)C(C)CC(C)C(C)C (probability > 0.5):
# green: 0.7271
# floral: 0.7057
# woody: 0.6755
# herbal: 0.6322
# citrus: 0.5811
# fresh: 0.5631
#
# Top odors for CC(CCCCC1CCCCC1)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.6326
#
# Top odors for CCC1CCC(CC(C)C)CC1C (probability > 0.5):
# woody: 0.6730
# green: 0.6435
# floral: 0.6193
# herbal: 0.5516
# fresh: 0.5510
# citrus: 0.5333
#
# Top odors for CCC(C)C(C)CCCC1CCCCC1 (probability > 0.5):
# woody: 0.5825
# waxy: 0.5514
#
# Top odors for CCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.5094
#
# Top odors for CCCC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7785
# green: 0.5172
# fresh: 0.5005
#
# Top odors for C1CCC(CCC2CCCCC2)CC1 (probability > 0.5):
# woody: 0.5279
#
# Top odors for CCC(C)(CCC1CC1(C)C)CC(C)C (probability > 0.5):
# woody: 0.8117
# floral: 0.5247
# green: 0.5031
#
# Top odors for CCCCCCCCC(CC(C)C)C(C)CC (probability > 0.5):
# waxy: 0.6057
# woody: 0.5173
#
# Top odors for CC(C)CCCC1CCCC1 (probability > 0.5):
#
# Top odors for CCC1C(C)CC2C(C1CC)C(C)(C)CCC2(C)C (probability > 0.5):
# woody: 0.8424
# green: 0.5564
# pine: 0.5509
# herbal: 0.5297
#
# Top odors for CCC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6847
#
# Top odors for CCC(C)(C)CC (probability > 0.5):
# green: 0.5625
# camphoreous: 0.5424
# fresh: 0.5126
# herbal: 0.5011
#
# Top odors for CCCCCC(C)C(C)CCCC (probability > 0.5):
# waxy: 0.5804
#
# Top odors for CCCCCC(C)CCC(CC)CCCC (probability > 0.5):
# waxy: 0.6661
#
# Top odors for CCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.6457
#
# Top odors for CCCCCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7405
#
# Top odors for CC1CCC2CCC(C)CC2C1 (probability > 0.5):
# woody: 0.8036
# amber: 0.5404
#
# Top odors for CC(C)C1CCC2(C)C3CCC(C)C3C12 (probability > 0.5):
# woody: 0.8056
# green: 0.6112
# herbal: 0.5828
# pine: 0.5155
#
# Top odors for CCCC(C)CC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6251
# green: 0.5509
# waxy: 0.5233
# floral: 0.5101
#
# Top odors for CCC(C)C1CC(C(C)C)CCC1C (probability > 0.5):
# woody: 0.7184
# green: 0.7048
# floral: 0.6412
# herbal: 0.6069
# citrus: 0.5777
# fresh: 0.5662
#
# Top odors for CCCCCCCCCC(C)CC(CCCC)CCCCC(C)C (probability > 0.5):
# waxy: 0.6918
#
# Top odors for CC(C)C(C)C (probability > 0.5):
# green: 0.6377
# mint: 0.5962
# ethereal: 0.5871
# camphoreous: 0.5728
# herbal: 0.5459
# fermented: 0.5069
#
# Top odors for CCCCCCCC(CCC(C)C)CC(C)C (probability > 0.5):
# waxy: 0.6072
#
# Top odors for CCCCCC1CC(C)CC1C (probability > 0.5):
# woody: 0.5366
#
# Top odors for CCC(C)CC(C)CC (probability > 0.5):
# floral: 0.6934
# green: 0.6144
# citrus: 0.5794
# fresh: 0.5442
# herbal: 0.5054
#
# Top odors for CC1CCC(C(C)C)C(CC(C)CC2CCCCC2)C1 (probability > 0.5):
# woody: 0.7096
# green: 0.5756
# floral: 0.5087
#
# Top odors for CCCCC(CCCC)CCCC (probability > 0.5):
# waxy: 0.6811
#
# Top odors for CCCCC(CC)CC (probability > 0.5):
# waxy: 0.5536
#
# Top odors for CC(C)C1CCC2(C)CC2C1 (probability > 0.5):
# woody: 0.8555
# green: 0.5445
# amber: 0.5143
# pine: 0.5032
#
# Top odors for CCCCCCC1CC1CCCC (probability > 0.5):
# waxy: 0.6797
#
# Top odors for CCCC1CC(C2CC(C)CC(C)(C)C2)CCC1C (probability > 0.5):
# woody: 0.7851
# green: 0.5166
#
# Top odors for CCC1CCC(C(C)CCC2CCCCC2)C(C)C1 (probability > 0.5):
# woody: 0.6813
#
# Top odors for CC1CC(C)C2(CC(C)(C)CC(C)(C)C2)C1(C)C (probability > 0.5):
# woody: 0.8775
# cedar: 0.5962
# amber: 0.5790
# dry: 0.5476
# earthy: 0.5375
#
# Top odors for CCCC(C)CC(C)(CC(C)CCC)C(C)C (probability > 0.5):
# floral: 0.6835
# woody: 0.6823
# green: 0.6144
#
# Top odors for CC(C)C1CCC(C)(C(C)C2CCCC2C)C1C (probability > 0.5):
# woody: 0.8213
# green: 0.5724
# sandalwood: 0.5021
# herbal: 0.5005
#
# Top odors for CC(C)C(C)CC1CCC2CCCCC2C1 (probability > 0.5):
# woody: 0.7048
# floral: 0.5880
# green: 0.5592
#
# Top odors for CCCCC(CC)C(C)CCC (probability > 0.5):
# floral: 0.6343
# waxy: 0.5650
# green: 0.5353
# woody: 0.5208
#
# Top odors for CC(C)CCC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.8022
# green: 0.5875
# floral: 0.5559
#
# Top odors for CCC1(C)CCC(C)C1 (probability > 0.5):
# woody: 0.6822
#
# Top odors for CC(C)CCC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6228
# green: 0.5311
#
# Top odors for CC1CCCCCCCCCCCCCC(C)C1 (probability > 0.5):
# musk: 0.7222
# woody: 0.6449
# amber: 0.6239
# animal: 0.5396
# sweet: 0.5245
# dry: 0.5218
#
# Top odors for CCCCC(C)C1CCCC(C)(C)C1 (probability > 0.5):
# woody: 0.6988
#
# Top odors for CCCCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7413
#
# Top odors for CC1CCC(CC2C3CCC(C3)C2(C)C)CC1C (probability > 0.5):
# woody: 0.8642
# amber: 0.5087
#
# Top odors for CCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.6842
#
# Top odors for CCCC(C)CCCC(C)(C)CC (probability > 0.5):
# woody: 0.6035
# floral: 0.5557
# green: 0.5550
#
# Top odors for CCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.6683
#
# Top odors for CC1CCC(C)(C(C)C)C1 (probability > 0.5):
# woody: 0.7795
# green: 0.5904
# herbal: 0.5354
# fresh: 0.5228
#
# Top odors for CCCC1CC(C(C)C)CCC1C (probability > 0.5):
# woody: 0.6869
# green: 0.6673
# floral: 0.5984
# herbal: 0.5698
# fresh: 0.5693
# citrus: 0.5565
#
# Top odors for CC1CCC2(CCCCC2C)CC1 (probability > 0.5):
# woody: 0.7442
# dry: 0.5162
# amber: 0.5052
#
# Top odors for CCCCCC(C)CC1CCCCC1 (probability > 0.5):
# waxy: 0.6006
#
# Top odors for CC(C)CCCC(C)C1CCCC1 (probability > 0.5):
# woody: 0.6314
# green: 0.5587
# floral: 0.5518
# waxy: 0.5266
#
# Top odors for CCCCC1CCCC1C (probability > 0.5):
# woody: 0.5136
#
# Top odors for CC1CCCC1 (probability > 0.5):
# woody: 0.6672
# musk: 0.6640
# amber: 0.6049
# sweet: 0.5169
# dry: 0.5091
#
# Top odors for CCCC(C)(C)CCC (probability > 0.5):
# green: 0.6314
# woody: 0.6083
# floral: 0.5058
#
# Top odors for CCC(C)CCC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6219
# waxy: 0.5318
# green: 0.5166
#
# Top odors for CCCC1CCC2CCC(C)CCC2C1 (probability > 0.5):
# woody: 0.6747
#
# Top odors for CCCCCC(C)CCCC(C)CCC (probability > 0.5):
# waxy: 0.6244
#
# Top odors for CCCC(C)CCCCC1CCCC1 (probability > 0.5):
# waxy: 0.6508
#
# Top odors for CCCCCCCCCC(C)CCC(C)C (probability > 0.5):
# waxy: 0.6600
#
# Top odors for CCCCC(C)CC(C)(C)C1CCC(C)CC1 (probability > 0.5):
# woody: 0.7342
# green: 0.5767
# floral: 0.5685
#
# Top odors for CCC1CCC(CC)C1 (probability > 0.5):
# woody: 0.6665
# floral: 0.5177
#
# Top odors for CCCCCC(C)CC(CC(C)C)(CC(C)CCCCC)C(C)CCCCC (probability > 0.5):
# woody: 0.6345
# waxy: 0.5780
#
# Top odors for CC1CCCC(C)C1C (probability > 0.5):
# woody: 0.7593
#
# Top odors for CCCCCC(C)CCCC(C)CCC(C)CC (probability > 0.5):
# waxy: 0.6221
# woody: 0.5046
#
# Top odors for CC(C)C1CCCCCCC1 (probability > 0.5):
# woody: 0.7224
#
# Top odors for CCC1CCC(CC2CC2)CC1 (probability > 0.5):
# woody: 0.6779
#
# Top odors for CCC1CC(C)CC(CC)C1C (probability > 0.5):
# green: 0.7040
# herbal: 0.6875
# woody: 0.6873
# floral: 0.6647
# citrus: 0.6262
# fresh: 0.6152
#
# Top odors for CCCCCCCCCCCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.7576
#
# Top odors for CC(C)CCC1CCC(C(C)C)CC1 (probability > 0.5):
# woody: 0.6609
# green: 0.6515
# floral: 0.6316
# fresh: 0.5086
#
# Top odors for CC1CCC(C(C)C)C(CC(C)C2CC2)C1 (probability > 0.5):
# woody: 0.7591
# green: 0.6075
# floral: 0.5205
#
# Top odors for CCCCCC(C)C(C)(C)C (probability > 0.5):
# woody: 0.6110
# green: 0.5964
# floral: 0.5918
# herbal: 0.5005
#
# Top odors for CCCCCC1CCC(CCC)CC1 (probability > 0.5):
# waxy: 0.5706
#
# Top odors for CC(C)CC(C)CC1CC(C(C)C)CCC1C (probability > 0.5):
# woody: 0.7087
# floral: 0.6871
# green: 0.6868
# herbal: 0.5268
# fresh: 0.5228
#
# Top odors for CCCC(C)C1CC1(C)C1CCCCC1 (probability > 0.5):
# woody: 0.8039
#
# Top odors for CCCC(C)C(CC)(CC)C(C)CCC (probability > 0.5):
# woody: 0.6619
# floral: 0.6486
# green: 0.5727
#
# Top odors for CCC1CCCC(CC)C1 (probability > 0.5):
# woody: 0.6653
#
# Top odors for CCCCCC(C)C1(C2CCCCC2)CC1C (probability > 0.5):
# woody: 0.7058
# waxy: 0.5673
#
# Top odors for CCCCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.6337
#
# Top odors for CCCC(C)C1CCC(C)(C)CC1C (probability > 0.5):
# woody: 0.7657
# green: 0.5837
# floral: 0.5669
#
# Top odors for CCC1CCCCC1CC (probability > 0.5):
# woody: 0.6188
# citrus: 0.5535
#
# Top odors for CCCCCCCCC(C)CCC1CCC(C)C(CC)C1 (probability > 0.5):
# waxy: 0.6602
#
# Top odors for CCC(CC(C)C)C1CCC(CC(C)C)CC1 (probability > 0.5):
# floral: 0.6965
# woody: 0.6606
# green: 0.6309
#
# Top odors for CCCC1CC(CC)CCC1CC(C)C (probability > 0.5):
# woody: 0.6362
# green: 0.6060
# floral: 0.5920
# fresh: 0.5152
#
# Top odors for CC(C)CC(C)(C)C1CCC(C)C2CCC(C)C2C1 (probability > 0.5):
# woody: 0.8277
# green: 0.6176
# floral: 0.5309
# herbal: 0.5220
#
# Top odors for CCCC(C)C1C(C)C(C)CCC1(C)C (probability > 0.5):
# woody: 0.7904
# green: 0.6027
# floral: 0.5458
# herbal: 0.5184
#
# Top odors for CCCCC1CCC(C)C(CC)C1 (probability > 0.5):
# woody: 0.5761
#
# Top odors for CCCCCC(C)CC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.5743
#
# Top odors for CCC(CCC1CCCCC1)CC(C)C (probability > 0.5):
# waxy: 0.5828
# woody: 0.5326
#
# Top odors for CCC1CC2CC(CC(C)C)C1C2 (probability > 0.5):
# woody: 0.7452
# green: 0.6454
# floral: 0.5822
# herbal: 0.5753
# fresh: 0.5210
#
# Top odors for CCC1CCCCC1C(C)CCCC1CCCCC1 (probability > 0.5):
# woody: 0.6026
# waxy: 0.5297
#
# Top odors for CCCCCCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7533
#
# Top odors for CCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.6171
#
# Top odors for CCCC(CC(C)C)CC(C)C1CCC(C)C(C)C1 (probability > 0.5):
# woody: 0.6903
# floral: 0.6423
# green: 0.5891
# waxy: 0.5124
#
# Top odors for CCCCCC1CC1C(C)C (probability > 0.5):
# woody: 0.6226
# green: 0.5919
# floral: 0.5893
#
# Top odors for CCCCCC(C)CCC(C)CCCCC (probability > 0.5):
# waxy: 0.6442
#
# Top odors for CCC1CC(C)(C)CCC1C (probability > 0.5):
# woody: 0.7766
# green: 0.5251
# fresh: 0.5181
# herbal: 0.5155
# pine: 0.5099
#
# Top odors for CC1CC2C3CC(CC3C)C2C1C (probability > 0.5):
# woody: 0.7850
# herbal: 0.6534
# green: 0.6474
# fresh: 0.5670
# pine: 0.5531
# spicy: 0.5420
#
# Top odors for CCCCCCCC1(C)CCC(C)C1 (probability > 0.5):
# waxy: 0.6660
#
# Top odors for CC1CCCC1CC1(C)CCCC1C (probability > 0.5):
# woody: 0.8355
#
# Top odors for CCCCCCCCC(CC)CC (probability > 0.5):
# waxy: 0.7044
#
# Top odors for CCC(C)C1CCC(C)CC1 (probability > 0.5):
# woody: 0.6830
# green: 0.5664
# fresh: 0.5150
# citrus: 0.5074
#
# Top odors for CC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6520
# green: 0.5863
# woody: 0.5576
#
# Top odors for CCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.6312
#
# Top odors for CCCCCCCC(CCCCC)CCCCCCC (probability > 0.5):
# waxy: 0.7458
#
# Top odors for CCC1CC(CC)CC(CC)C1 (probability > 0.5):
# woody: 0.6781
# herbal: 0.6251
# floral: 0.6231
# green: 0.6140
# fresh: 0.5545
# citrus: 0.5259
#
# Top odors for CCCCCCCCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6613
#
# Top odors for CC1CCC(C)(C)C1C (probability > 0.5):
# woody: 0.8200
# camphoreous: 0.5663
# pine: 0.5625
# herbal: 0.5257
# fresh: 0.5223
# cedar: 0.5190
#
# Top odors for CC1CCCC1CCC1CCCCC1 (probability > 0.5):
# woody: 0.6383
#
# Top odors for CC(C)C(C)CC1CCCCC1C (probability > 0.5):
# woody: 0.7013
# floral: 0.6712
# green: 0.6447
# fresh: 0.5084
#
# Top odors for CC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.6057
# green: 0.5399
# floral: 0.5040
#
# Top odors for CCCCCCCCCC(C)CC(CCCCCCCC)C(C)C (probability > 0.5):
# waxy: 0.6903
#
# Top odors for CCCCC1C(C)C(C)CCC1(C)C (probability > 0.5):
# woody: 0.7760
# green: 0.5174
#
# Top odors for CC(C)CCC1C(C)CCC(C)C1C (probability > 0.5):
# woody: 0.7353
# green: 0.6560
# herbal: 0.5677
# floral: 0.5647
# fresh: 0.5404
# citrus: 0.5188
#
# Top odors for CC(C)CCCCCCCCC(C)CCCCC(C)CCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.6886
#
# Top odors for CCCCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6261
#
# Top odors for CC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5556
#
# Top odors for CCCCC(CC)C(C)C (probability > 0.5):
# floral: 0.7110
# green: 0.6194
# fresh: 0.5277
# citrus: 0.5229
# fruity: 0.5105
# woody: 0.5092
#
# Top odors for CCCCCCCC(C)C1CCC(CC)CC1 (probability > 0.5):
# waxy: 0.6360
#
# Top odors for CC(C)CC(C)CCC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7625
# floral: 0.6265
# green: 0.5870
#
# Top odors for CCCCCC(CCC(C)C)CCC(C)C (probability > 0.5):
# waxy: 0.5714
# floral: 0.5340
# woody: 0.5331
#
# Top odors for CC1CC(C)(C)CC2(C1)C(C)CC(C)C2(C)C (probability > 0.5):
# woody: 0.8735
# cedar: 0.5890
# amber: 0.5872
# dry: 0.5403
# earthy: 0.5031
#
# Top odors for CC1CC(C)C2(CCC(C(C)C)C2)C(C)C1 (probability > 0.5):
# woody: 0.8269
# green: 0.5607
# pine: 0.5244
# herbal: 0.5134
#
# Top odors for CCC1(C)CCC(C)C(C)(C)C1 (probability > 0.5):
# woody: 0.7602
#
# Top odors for CC(C)CCCCC1CC(C)CC1C (probability > 0.5):
# woody: 0.6358
# green: 0.5460
# floral: 0.5121
#
# Top odors for CCC1(C)CCCC(CCCC(C)C)C1 (probability > 0.5):
# woody: 0.6223
#
# Top odors for CCC1CC2CCCCC2C1 (probability > 0.5):
# woody: 0.7706
# amber: 0.5087
#
# Top odors for CC(C)CCCC(C)CCCC(C)CC1CCCCC1 (probability > 0.5):
# waxy: 0.6042
# woody: 0.5664
#
# Top odors for CCC(C)(C)C (probability > 0.5):
# camphoreous: 0.6152
# fresh: 0.5788
# green: 0.5240
# ethereal: 0.5229
# mint: 0.5101
#
# Top odors for CCCCC(CC)CCC(C)C1CCCCC1 (probability > 0.5):
# waxy: 0.6426
# woody: 0.5168
# oily: 0.5007
#
# Top odors for CC(C)CC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6695
# green: 0.5502
# floral: 0.5023
#
# Top odors for CCCC(CCC)CCCCCC(C)C (probability > 0.5):
# waxy: 0.6500
#
# Top odors for CCCCCCC(CC)CC(C)C (probability > 0.5):
# waxy: 0.6197
#
# Top odors for CCCC(C)CCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.6736
#
# Top odors for CC1CCCCCCCCCCCCC1 (probability > 0.5):
# musk: 0.7340
# amber: 0.5979
# woody: 0.5891
# animal: 0.5725
# sweet: 0.5652
# dry: 0.5085
#
# Top odors for CCC(C)C(C)CCC(C)CC(C)C(C)CC (probability > 0.5):
# floral: 0.7668
# green: 0.6537
# woody: 0.6359
#
# Top odors for CCCCCCCCCCC1CCCCC1C(C)CC (probability > 0.5):
# waxy: 0.6872
#
# Top odors for CCCC(C)CCCC(C)(C)C (probability > 0.5):
# floral: 0.6404
# woody: 0.6296
# green: 0.6149
#
# Top odors for CCCC1CCCCC1C(C)C (probability > 0.5):
# woody: 0.6333
# green: 0.6191
# floral: 0.5618
# fresh: 0.5192
#
# Top odors for OOOOOOOOOOOOO (probability > 0.5):
# odorless: 0.5308
#
# Top odors for C=C=C=C=C=C (probability > 0.5):
# pungent: 0.8216
# sweet: 0.5641
#
# Top odors for CCC(C)CCC(C)C (probability > 0.5):
# floral: 0.6619
# green: 0.6526
# herbal: 0.5738
# citrus: 0.5657
# fresh: 0.5441
# woody: 0.5214
#
# Top odors for CC(C)CCC(CCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.7372
# green: 0.6401
# woody: 0.6251
#
# Top odors for CC(C)CCC1CCC2CC1C2(C)C (probability > 0.5):
# woody: 0.8249
# green: 0.5713
#
# Top odors for CC1CC(C)C2CC3CCCCC3C2C1 (probability > 0.5):
# woody: 0.8183
# amber: 0.5157
#
# Top odors for CC(C)CCC(CCC(C)C)CC1CCCCC1 (probability > 0.5):
# woody: 0.6181
# floral: 0.5800
# waxy: 0.5752
# green: 0.5246
#
# Top odors for CCCCCCC(C)C1CCCC1 (probability > 0.5):
# waxy: 0.6302
#
# Top odors for CCC1CCC(CCCC(C)C)CC1 (probability > 0.5):
# woody: 0.5325
#
# Top odors for CCCCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6548
#
# Top odors for CCC(CC)C(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.7018
# woody: 0.5932
# green: 0.5813
# waxy: 0.5473
#
# Top odors for CCCCCCC(C)C(C)(C)C (probability > 0.5):
# woody: 0.5724
# floral: 0.5429
# green: 0.5383
#
# Top odors for CCCCC(CC)CC(C)C (probability > 0.5):
# floral: 0.6099
# waxy: 0.5297
# green: 0.5220
#
# Top odors for CC1CC(C)C2(C)CC(C(C)C)CCC2C1 (probability > 0.5):
# woody: 0.8312
# green: 0.5788
# pine: 0.5464
# herbal: 0.5369
# fresh: 0.5126
#
# Top odors for CCCCCCCCCC(C)CC(C)CCCCCCCCC (probability > 0.5):
# waxy: 0.7266
#
# Top odors for CC(CCCC1CCCCC1)CCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6255
#
# Top odors for CCCCCCC(C)CC (probability > 0.5):
# waxy: 0.5710
#
# Top odors for CCC(C)(C)CC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.7647
# green: 0.6140
# floral: 0.5626
#
# Top odors for CCCC(CCC)CC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5787
# floral: 0.5711
# woody: 0.5332
# green: 0.5131
#
# Top odors for CCCCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7325
#
# Top odors for CCCC(C)C1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7842
# green: 0.5859
# floral: 0.5677
#
# Top odors for CCCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5828
# woody: 0.5176
# floral: 0.5142
#
# Top odors for CC(C)C1CCC(C)C(C)C1C (probability > 0.5):
# woody: 0.7456
# green: 0.7263
# herbal: 0.7184
# fresh: 0.6011
# citrus: 0.5925
# floral: 0.5898
# pine: 0.5275
# camphoreous: 0.5164
#
# Top odors for CCC1CC(C(C)C)CC(CC)C1C (probability > 0.5):
# green: 0.7256
# woody: 0.7041
# floral: 0.7022
# herbal: 0.6859
# citrus: 0.6366
# fresh: 0.6063
#
# Top odors for CC(C)C12CCC(C)(CC1)C2 (probability > 0.5):
# woody: 0.8603
# amber: 0.5437
#
# Top odors for CC(C)CCC1(C)CCC(C)C(C)C1C (probability > 0.5):
# woody: 0.7911
# green: 0.5681
#
# Top odors for CCCCCCCCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.7108
#
# Top odors for CCCCCC(CC)CC(C)CCC (probability > 0.5):
# waxy: 0.6374
#
# Top odors for CC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6998
# amber: 0.5660
# musk: 0.5548
#
# Top odors for CCC1(C)CCC(C(C)(C)CC)CC1 (probability > 0.5):
# woody: 0.8122
# green: 0.5667
#
# Top odors for CCC1CCC(CCC(C)C)CC1CC (probability > 0.5):
# woody: 0.6459
# green: 0.6055
# floral: 0.5786
# fresh: 0.5152
#
# Top odors for CC1CCCC(C)CCC(C)(C)CCC1 (probability > 0.5):
# woody: 0.7369
# amber: 0.5829
# musk: 0.5304
#
# Top odors for CCCCCCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.7389
#
# Top odors for CC(C)CCCC(C)C1(C)CCC(C)CC1 (probability > 0.5):
# woody: 0.7317
# green: 0.5311
#
# Top odors for CCCCC1CC1CCC (probability > 0.5):
# waxy: 0.5687
#
# Top odors for CCC(C)C(C)C1CCCCC1 (probability > 0.5):
# floral: 0.6837
# woody: 0.6353
# green: 0.6138
#
# Top odors for C1CCC(CC2CCC(CC3CCCC3)C2)C1 (probability > 0.5):
# woody: 0.6962
#
# Top odors for CC1CCC(CC(C)(C)C)CC1 (probability > 0.5):
# woody: 0.8237
# green: 0.6287
# floral: 0.5207
# herbal: 0.5014
#
# Top odors for CC1CCCCC1CC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.7485
# green: 0.5017
#
# Top odors for C=C=C=C=C=C=C=C=C (probability > 0.5):
# pungent: 0.8526
# sweet: 0.5657
#
# Top odors for CCC1(C)CC(C)(C)C2CCCCC21 (probability > 0.5):
# woody: 0.8759
# amber: 0.5631
# dry: 0.5121
#
# Top odors for CCCCCC1CCC(C(C)C)CC1 (probability > 0.5):
# woody: 0.5056
#
# Top odors for CCCC(CC)CCCC(C)C (probability > 0.5):
# waxy: 0.5657
# floral: 0.5325
#
# Top odors for CCC(CC(C)CC(C)C)C(C)CCC(C)C (probability > 0.5):
# floral: 0.7740
# green: 0.6586
# woody: 0.6327
#
# Top odors for CCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.5552
#
# Top odors for CC1CCC(C)(C2CCCCC2)C1 (probability > 0.5):
# woody: 0.8139
#
# Top odors for CCCC1CCCCC1C(C)CC (probability > 0.5):
# woody: 0.6089
# green: 0.5497
#
# Top odors for CC1CCC2C(C1)C(C(C)C)CCC2(C)C (probability > 0.5):
# woody: 0.8533
# pine: 0.6005
# green: 0.5884
# herbal: 0.5777
# camphoreous: 0.5385
# fresh: 0.5252
#
# Top odors for CC(C)C(C)C1CCCCC1 (probability > 0.5):
# floral: 0.7178
# green: 0.6645
# woody: 0.6597
# herbal: 0.5266
# fresh: 0.5113
#
# Top odors for CCCCCCCCCCCC(C)CCCCCCC (probability > 0.5):
# waxy: 0.7383
#
# Top odors for CCCC(CCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.6978
# green: 0.6035
# woody: 0.5829
#
# Top odors for CCCCCCCCCCCC(C)CCC(C)C (probability > 0.5):
# waxy: 0.6916
#
# Top odors for CCC1CCC(CC(C)C)C(CC)C1 (probability > 0.5):
# woody: 0.6568
# floral: 0.6488
# green: 0.6352
# fresh: 0.5486
# citrus: 0.5420
# herbal: 0.5248
#
# Top odors for CCCCC(C)CCC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7089
# waxy: 0.5296
#
# Top odors for CCCCCCC(C)CC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.6185
#
# Top odors for CCCC1CCC(CC)C(CC)C1 (probability > 0.5):
# woody: 0.5811
# citrus: 0.5446
# green: 0.5301
#
# Top odors for CCC1C(C(C)C)C(C)C(C(C)C)CC1C(C)(C)C (probability > 0.5):
# woody: 0.7665
# green: 0.7074
# herbal: 0.6557
# floral: 0.5614
# fresh: 0.5422
# camphoreous: 0.5356
# citrus: 0.5285
# pine: 0.5263
# terpenic: 0.5152
#
# Top odors for CCC(C)CC1C(C)CCCC1C (probability > 0.5):
# woody: 0.6974
# green: 0.5914
# floral: 0.5453
# fresh: 0.5099
#
# Top odors for CC(C)CCCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6732
# floral: 0.5954
# green: 0.5855
#
# Top odors for CC(C)C1CCC(C)(C)C(C)C1 (probability > 0.5):
# woody: 0.8226
# green: 0.6315
# herbal: 0.6295
# pine: 0.5807
# camphoreous: 0.5752
# fresh: 0.5633
# floral: 0.5288
# earthy: 0.5177
#
# Top odors for CCC(C)(C)CC1CCCCC1 (probability > 0.5):
# woody: 0.7479
# green: 0.5782
#
# Top odors for CC(C)C1CCC(C)C23CCC(C)(C)C2C13 (probability > 0.5):
# woody: 0.8455
# green: 0.5559
# herbal: 0.5355
# amber: 0.5225
# cedar: 0.5063
#
# Top odors for CCC1(CC(C)C)CCCCC1 (probability > 0.5):
# woody: 0.6483
#
# Top odors for SSSSSSSSS (probability > 0.5):
# sulfurous: 0.8036
# onion: 0.5865
# garlic: 0.5736
# savory: 0.5197
#
# Top odors for CC(C)CCCC(C)CCCC(C)C1CC1 (probability > 0.5):
# woody: 0.6461
# floral: 0.5997
# waxy: 0.5581
# green: 0.5444
#
# Top odors for CCC1CC(C)CCC1C(C)C (probability > 0.5):
# green: 0.7065
# woody: 0.7029
# floral: 0.6515
# herbal: 0.6456
# fresh: 0.5944
# citrus: 0.5941
#
# Top odors for CCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7216
#
# Top odors for CC(C)C(C)CC1CCCC1C (probability > 0.5):
# woody: 0.7180
# floral: 0.6905
# green: 0.6643
# fresh: 0.5088
#
# Top odors for CC1CC(C)C(CCC2CC(C)CC2C)C1 (probability > 0.5):
# woody: 0.7599
# green: 0.5436
#
# Top odors for CCC(CC)CC1CCCC1 (probability > 0.5):
# waxy: 0.5580
#
# Top odors for CC(C)CCC1CCCC1C (probability > 0.5):
# woody: 0.6748
# green: 0.5988
# floral: 0.5337
#
# Top odors for CC1CCC(C(C)C)C(C)C1 (probability > 0.5):
# woody: 0.7354
# green: 0.7100
# herbal: 0.7024
# floral: 0.6195
# fresh: 0.5976
# citrus: 0.5519
# pine: 0.5005
#
# Top odors for CCC(C)CC(C)C(C)C (probability > 0.5):
# floral: 0.7558
# green: 0.7115
# woody: 0.6218
# citrus: 0.6065
# herbal: 0.5819
# fresh: 0.5760
#
# Top odors for CCC(C)C(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5945
# woody: 0.5290
#
# Top odors for C1CCC(CCCCC2CCCCC2)CC1 (probability > 0.5):
# waxy: 0.5859
#
# Top odors for CC(C)C1CCC(C(C)C)CC1 (probability > 0.5):
# green: 0.7162
# woody: 0.7132
# floral: 0.6885
# herbal: 0.5990
# fresh: 0.5705
# citrus: 0.5525
#
# Top odors for CCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.6974
#
# Top odors for CC(C)CC1C(C)CCC1C (probability > 0.5):
# woody: 0.7353
# green: 0.6778
# herbal: 0.5952
# floral: 0.5922
# fresh: 0.5620
# citrus: 0.5557
#
# Top odors for CCCCC1CC(C)CC(C)C1 (probability > 0.5):
# woody: 0.5838
# green: 0.5327
# floral: 0.5300
#
# Top odors for CCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7093
#
# Top odors for CC(C)CC(C)C(C)CC(C)C (probability > 0.5):
# green: 0.7201
# floral: 0.7166
# woody: 0.6404
# herbal: 0.6042
# fresh: 0.5628
# citrus: 0.5626
#
# Top odors for CCC1CCC(CC)CC1 (probability > 0.5):
# woody: 0.6311
#
# Top odors for CCCC(C)CC1C(C)CCC1C (probability > 0.5):
# woody: 0.7000
# green: 0.5875
# floral: 0.5351
#
# Top odors for SSSSS (probability > 0.5):
# sulfurous: 0.8501
# garlic: 0.6032
# onion: 0.5982
# savory: 0.5128
#
# Top odors for CCCC1(C)CCC23CC1C(C)(C)C2CCC3C (probability > 0.5):
# woody: 0.9022
# amber: 0.5599
# dry: 0.5211
#
# Top odors for CCCCCCCCCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7594
#
# Top odors for CC(C)CCCC(C)CCCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6471
# floral: 0.5670
# waxy: 0.5575
# green: 0.5415
#
# Top odors for CCC(C)C1CC2CC1C(C)(C)C2 (probability > 0.5):
# woody: 0.8160
# green: 0.5862
# herbal: 0.5343
#
# Top odors for CCC1C(C)CC(C)C(C)C1CC (probability > 0.5):
# woody: 0.7125
# green: 0.7058
# herbal: 0.6789
# citrus: 0.6206
# fresh: 0.6067
# floral: 0.5641
#
# Top odors for CC1CCC(C)C1C (probability > 0.5):
# woody: 0.7706
# herbal: 0.5905
# green: 0.5477
# fresh: 0.5378
# citrus: 0.5083
#
# Top odors for CCCCCCCC(C)C1CCCCC1 (probability > 0.5):
# waxy: 0.6527
#
# Top odors for CCCCC(C)CCC(C)C (probability > 0.5):
# floral: 0.5789
# green: 0.5582
#
# Top odors for CCC(C)(CCCC(C)CCCC(C)C)CC(C)C (probability > 0.5):
# woody: 0.6551
# floral: 0.6247
# green: 0.5713
# waxy: 0.5110
#
# Top odors for CC(C)CCCCC(C)C (probability > 0.5):
# green: 0.6074
# floral: 0.5786
# herbal: 0.5266
#
# Top odors for CCCC(CCCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.6632
# green: 0.5679
# woody: 0.5654
# waxy: 0.5297
#
# Top odors for CC1(C)CCCC2(C)C1CCC1(C)CCCC12 (probability > 0.5):
# woody: 0.9151
# amber: 0.6196
# cedar: 0.5809
# dry: 0.5805
#
# Top odors for CCCCCCCCC(CC)CCCCCC (probability > 0.5):
# waxy: 0.7365
#
# Top odors for CC(C)CCCCCCCCCCCCCCC(C)CCC(C)CCCC(CCC(C)CCCCCCCCCCCCCCC(C)C)CC(C)CCCCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7140
#
# Top odors for CCC(CC)C(C)(C)CCC(C)C (probability > 0.5):
# floral: 0.7377
# woody: 0.6994
# green: 0.6297
#
# Top odors for CC(C)CCCC(C)CC1CCCCC1 (probability > 0.5):
# woody: 0.5565
# waxy: 0.5338
# green: 0.5058
#
# Top odors for CCC(C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7214
# green: 0.7197
# woody: 0.6330
# herbal: 0.6081
# citrus: 0.5986
# fresh: 0.5672
#
# Top odors for CCCC(C)C(C)CCC (probability > 0.5):
# floral: 0.7088
# green: 0.6277
# woody: 0.5517
# citrus: 0.5460
# fresh: 0.5225
# herbal: 0.5163
#
# Top odors for C1CC1 (probability > 0.5):
# musk: 0.7450
# animal: 0.6078
# amber: 0.5811
# sweet: 0.5811
# woody: 0.5327
# dry: 0.5011
#
# Top odors for CCCC(C)C(C)C(C)CC (probability > 0.5):
# floral: 0.7751
# green: 0.6942
# woody: 0.5949
# citrus: 0.5845
# fresh: 0.5711
# herbal: 0.5294
# muguet: 0.5027
#
# Top odors for CC(C)CC1CC(C)C2CC1C2(C)C (probability > 0.5):
# woody: 0.8189
# green: 0.6207
# herbal: 0.5741
# pine: 0.5263
#
# Top odors for CC1C2(C)CCC(C2)C1(C)C (probability > 0.5):
# woody: 0.9088
# amber: 0.6151
# cedar: 0.5963
# dry: 0.5740
#
# Top odors for CC(C)CCCC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.5801
# waxy: 0.5521
# green: 0.5277
#
# Top odors for CC1CC(C)(C)C(C)CC1(C)C (probability > 0.5):
# woody: 0.8204
# camphoreous: 0.6175
# pine: 0.5675
# earthy: 0.5432
# cedar: 0.5362
# fresh: 0.5314
# herbal: 0.5175
# dry: 0.5085
#
# Top odors for CCCCCC(C)C(C)CC(C)CCC (probability > 0.5):
# floral: 0.6461
# woody: 0.5693
# green: 0.5670
# waxy: 0.5439
#
# Top odors for CC(C)C1CC2C(CC1C)C2(C)C (probability > 0.5):
# woody: 0.8209
# green: 0.6327
# herbal: 0.6124
# pine: 0.5751
# camphoreous: 0.5674
# terpenic: 0.5118
# fresh: 0.5094
#
# Top odors for CC1CCC2(C)C(C)CCC(C(C)C)C2C1 (probability > 0.5):
# woody: 0.8352
# green: 0.5669
# pine: 0.5435
# herbal: 0.5235
# fresh: 0.5052
#
# Top odors for CCC(C)CCC(C)C(C)CC (probability > 0.5):
# floral: 0.7530
# green: 0.6387
# woody: 0.5971
# citrus: 0.5159
# fresh: 0.5149
#
# Top odors for CC(C)CCCCCCCC(C)C (probability > 0.5):
# waxy: 0.5773
#
# Top odors for CC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.7082
# green: 0.5401
#
# Top odors for CCCCCCC(C)CC(C)CCCCCC (probability > 0.5):
# waxy: 0.6689
#
# Top odors for CCC1CCC(C(C)C)CC1 (probability > 0.5):
# woody: 0.6811
# green: 0.6137
# floral: 0.6003
# herbal: 0.5298
# fresh: 0.5294
# citrus: 0.5107
#
# Top odors for OOOOOOOO (probability > 0.5):
# odorless: 0.5519
# sweet: 0.5162
#
# Top odors for CCCC(C)C(C)C(C)C (probability > 0.5):
# green: 0.7309
# floral: 0.7301
# woody: 0.6247
# herbal: 0.6117
# citrus: 0.5968
# fresh: 0.5671
#
# Top odors for CCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.6332
#
# Top odors for CC(C)CCC1CCC(CC(C)C)CC1 (probability > 0.5):
# woody: 0.6307
# green: 0.6156
# floral: 0.5939
#
# Top odors for CCC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.5054
#
# Top odors for CCCCC(C)CC1CC2CCC1(C)C2(C)C (probability > 0.5):
# woody: 0.8214
# waxy: 0.5057
#
# Top odors for CCCCCCCCCCCCCCCCCC(C)CC1CC(C)CCC1C(C)C (probability > 0.5):
# waxy: 0.7130
#
# Top odors for CC1CCCC(C(C)(C)C)C1 (probability > 0.5):
# woody: 0.8467
# green: 0.6308
# herbal: 0.5745
# pine: 0.5551
# floral: 0.5428
# fresh: 0.5400
# camphoreous: 0.5289
#
# Top odors for CCCCCC1CC(C)C(C)C1 (probability > 0.5):
# woody: 0.5167
#
# Top odors for CCCCCCCC(C)C (probability > 0.5):
# waxy: 0.5223
#
# Top odors for CC(C)CC(C)CCCC1CCCCC1 (probability > 0.5):
# woody: 0.5470
# waxy: 0.5438
#
# Top odors for CCC(C)C(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.7010
# woody: 0.6009
# green: 0.5998
# waxy: 0.5151
#
# Top odors for CCCC(C)C(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6419
# floral: 0.6347
# green: 0.6032
#
# Top odors for CCCC(C)C (probability > 0.5):
# green: 0.6614
# herbal: 0.5785
# musty: 0.5105
#
# Top odors for CC1CCC2(C)CCC1C2 (probability > 0.5):
# woody: 0.8499
# amber: 0.5531
# dry: 0.5225
#
# Top odors for CCCCC (probability > 0.5):
# sweet: 0.6926
# musty: 0.5120
#
# Top odors for CC1CCC(C(C)C)C2(C1)CC(C)C(C)C2 (probability > 0.5):
# woody: 0.8229
# green: 0.5716
# pine: 0.5269
# herbal: 0.5221
# fresh: 0.5062
#
# Top odors for CCCC1CCCC1 (probability > 0.5):
#
# Top odors for CCC1CCC2CCCCC12 (probability > 0.5):
# woody: 0.7571
#
# Top odors for CCC1CC(CC)C(C)C(C2CC(CC)CC(CC)C2C)C1 (probability > 0.5):
# woody: 0.7383
# green: 0.6443
# herbal: 0.6211
# floral: 0.5766
# fresh: 0.5630
# citrus: 0.5463
#
# Top odors for CCCC(C)CC(C)(CC(C)CCC)C(C)CCC (probability > 0.5):
# woody: 0.6799
# floral: 0.6565
# green: 0.5859
#
# Top odors for CCC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6267
#
# Top odors for CCCC(C)C1CCC(C)C(C)C1 (probability > 0.5):
# woody: 0.6919
# green: 0.6113
# floral: 0.5210
# fresh: 0.5192
# herbal: 0.5142
#
# Top odors for CC(CCC1CCCCC1)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.5779
# woody: 0.5003
#
# Top odors for CCCCCCCCC(C)C1CCCCC1 (probability > 0.5):
# waxy: 0.6787
#
# Top odors for CC1C2CCC(C2)C1(C)C (probability > 0.5):
# woody: 0.8945
# pine: 0.6010
# amber: 0.5646
# camphoreous: 0.5607
# cedar: 0.5575
# dry: 0.5252
# herbal: 0.5041
# green: 0.5020
#
# Top odors for CCCCC(CC)CCC(C)CC (probability > 0.5):
# waxy: 0.6292
#
# Top odors for CC(CC1CCCCC1)CC1CCCCC1C (probability > 0.5):
# woody: 0.6490
#
# Top odors for CCCCCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.7321
#
# Top odors for CC1CC23CCCC(C)(C)C2CC1(C)CC3 (probability > 0.5):
# woody: 0.9135
# amber: 0.6096
# dry: 0.5670
# cedar: 0.5461
#
# Top odors for CCCC1CC(C)CCC1C(C)C (probability > 0.5):
# green: 0.6826
# woody: 0.6779
# floral: 0.6059
# herbal: 0.5848
# fresh: 0.5670
# citrus: 0.5543
#
# Top odors for CC1CCC2C(C3C(C)CCC13)C2(C)C (probability > 0.5):
# woody: 0.8442
# herbal: 0.5691
# pine: 0.5651
# green: 0.5584
# fresh: 0.5156
#
# Top odors for CCC(C)CCC1C(C)CCC2C(C)(C)CCCC12C (probability > 0.5):
# woody: 0.8339
# green: 0.5036
#
# Top odors for CC(C)C1CC(C)C2(C)CC2C1 (probability > 0.5):
# woody: 0.8348
# green: 0.5870
# herbal: 0.5404
# pine: 0.5351
#
# Top odors for CCC1CC2C(C)(C)C3CCC2(C3)C(C)(C)C1 (probability > 0.5):
# woody: 0.9040
# amber: 0.6077
# cedar: 0.5587
# dry: 0.5541
# sandalwood: 0.5072
#
# Top odors for CCCCCCCCCCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.7173
#
# Top odors for CCCCCC(C(C)C)C(C)CCC (probability > 0.5):
# floral: 0.7298
# green: 0.6188
# woody: 0.5775
# waxy: 0.5054
#
# Top odors for CCCCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.7141
#
# Top odors for CC1(C)CCC2C(CCCC2(C)C)C1 (probability > 0.5):
# woody: 0.8905
# amber: 0.5835
# pine: 0.5714
# cedar: 0.5553
# dry: 0.5448
# camphoreous: 0.5281
#
# Top odors for CCC(C)(CCCC(C)C)CC(C)CC1CCCCC1 (probability > 0.5):
# woody: 0.6702
# waxy: 0.5712
# green: 0.5112
# floral: 0.5034
#
# Top odors for CCCC(CCC)C1CCC(CC)CC1 (probability > 0.5):
# waxy: 0.5719
# woody: 0.5457
#
# Top odors for CC(C)CCC1CCCC1 (probability > 0.5):
# woody: 0.5457
# green: 0.5100
#
# Top odors for CCC(C)C1CCC(C)C(CC)C1 (probability > 0.5):
# woody: 0.6930
# green: 0.6461
# floral: 0.6019
# citrus: 0.5762
# fresh: 0.5625
# herbal: 0.5569
#
# Top odors for CCCCCC(CCCC)CCCCC (probability > 0.5):
# waxy: 0.7058
#
# Top odors for CCCCCC(C)(C)C (probability > 0.5):
# green: 0.6116
# woody: 0.5417
# herbal: 0.5039
#
# Top odors for CC(C)CCCC1CCC(C)C1(C)C (probability > 0.5):
# woody: 0.7733
# green: 0.5420
# floral: 0.5117
#
# Top odors for CCCCCC(C)CC(C)CC (probability > 0.5):
# waxy: 0.5765
#
# Top odors for CCCCC1CC(C)C2CCCCC12 (probability > 0.5):
# woody: 0.6731
#
# Top odors for CC(C)CCC1CCCCC1C (probability > 0.5):
# woody: 0.6559
# green: 0.5638
#
# Top odors for CCCC(C)CCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5980
#
# Top odors for CCCCCCCCCC(C)C(C)C (probability > 0.5):
# waxy: 0.6281
#
# Top odors for CCCCCCC(CCCC(C)C)CC(C)C (probability > 0.5):
# waxy: 0.6030
#
# Top odors for CCCCCCCCCC(C)CCCCCCCCC (probability > 0.5):
# waxy: 0.7381
#
# Top odors for CC1CC(C)C(C)C1 (probability > 0.5):
# woody: 0.7556
# herbal: 0.6345
# green: 0.5546
# fresh: 0.5410
# camphoreous: 0.5318
#
# Top odors for CC(C)C(C)CC1C(C)CCCC1C (probability > 0.5):
# woody: 0.7448
# green: 0.6736
# floral: 0.6603
# herbal: 0.5474
# fresh: 0.5259
# citrus: 0.5222
#
# Top odors for CCCCC(CC)CCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6095
# waxy: 0.6067
#
# Top odors for CCC1CCCC1 (probability > 0.5):
# woody: 0.6407
#
# Top odors for CCCCCCCC(CCC)CCCCC (probability > 0.5):
# waxy: 0.7181
#
# Top odors for CC(C)C1CCC(C)(C)C1C (probability > 0.5):
# woody: 0.8290
# green: 0.6331
# herbal: 0.6133
# camphoreous: 0.5768
# pine: 0.5673
# fresh: 0.5486
# earthy: 0.5145
#
# Top odors for CCC(C)CCC1CC1(C)C (probability > 0.5):
# woody: 0.7770
# floral: 0.5237
# green: 0.5094
# waxy: 0.5055
#
# Top odors for CCC(C)C1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.8115
# green: 0.5977
# floral: 0.5505
# herbal: 0.5303
# fresh: 0.5028
#
# Top odors for CC1CC(CC2CCCCC2)CC1C (probability > 0.5):
# woody: 0.7410
#
# Top odors for CC(C)CCC(C)C(C)(C)C (probability > 0.5):
# woody: 0.7201
# floral: 0.6741
# green: 0.6687
# herbal: 0.6011
# fresh: 0.5391
# citrus: 0.5257
#
# Top odors for CCCCCCCCCCCC1CCCCC1C(C)CC (probability > 0.5):
# waxy: 0.7007
#
# Top odors for CC(C)CCC(CC(C)C(C)C)C(C)C (probability > 0.5):
# floral: 0.7611
# green: 0.6943
# woody: 0.6574
# herbal: 0.5430
# fresh: 0.5386
# citrus: 0.5052
#
# Top odors for CCCC(C)CC1CCC(C)CC1 (probability > 0.5):
# woody: 0.5526
#
# Top odors for CCCCCCCCC1CCCC1C (probability > 0.5):
# waxy: 0.6816
#
# Top odors for CCCCCCCCC(C)C(C)CCC (probability > 0.5):
# waxy: 0.6352
#
# Top odors for CC1CCC(C(C)CC2CCCC2C)CC1 (probability > 0.5):
# woody: 0.7559
# green: 0.5057
#
# Top odors for CCCC1CC(CC)C(C)C(CC)C1 (probability > 0.5):
# green: 0.6455
# woody: 0.6384
# floral: 0.6257
# citrus: 0.6035
# fresh: 0.5890
# herbal: 0.5887
#
# Top odors for CCC(C)C(C)CCC1CCCC1 (probability > 0.5):
# woody: 0.6381
# floral: 0.5861
# green: 0.5538
# waxy: 0.5319
#
# Top odors for CC(C)CCCC(C)CCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.5933
# woody: 0.5848
# waxy: 0.5671
# green: 0.5356
#
# Top odors for CCCCCC(C)CC(C)C1CCCCC1 (probability > 0.5):
# waxy: 0.5940
# woody: 0.5468
#
# Top odors for CC(C)C1CC2C(C(C(C)C)C1C)C(C)(C)CC2(C)C (probability > 0.5):
# woody: 0.8084
# green: 0.6498
# herbal: 0.6409
# camphoreous: 0.6265
# pine: 0.6062
# terpenic: 0.5226
# fresh: 0.5225
# earthy: 0.5127
#
# Top odors for CCCCCCCCC(CC(C)C)C(C)CCC (probability > 0.5):
# waxy: 0.6135
# woody: 0.5116
#
# Top odors for CC(C)C1CCCC1C (probability > 0.5):
# woody: 0.7274
# green: 0.6890
# floral: 0.6424
# herbal: 0.6384
# fresh: 0.5721
# citrus: 0.5430
#
# ...
#
# Top odors for CC1CCCCCCCCCCCCCCC1C (probability > 0.5):
# musk: 0.6992
# woody: 0.6238
# amber: 0.5972
# animal: 0.5337
# sweet: 0.5260
# dry: 0.5201
#
# Top odors for CC1CCC(CC(C)C(C)C)CC1 (probability > 0.5):
# woody: 0.6877
# floral: 0.6527
# green: 0.6284
# fresh: 0.5017
#
# Top odors for CCCCCCCCCC(C)C1CCCC1 (probability > 0.5):
# waxy: 0.7012
#
# Top odors for CCCCCCCCCCCCCCCC(C)CCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6964
#
# Top odors for CCCCCC(C)C1CCCC1 (probability > 0.5):
# waxy: 0.5833
#
# Top odors for CCC1CCCC1C(C)C (probability > 0.5):
# green: 0.6816
# woody: 0.6792
# floral: 0.6680
# citrus: 0.5770
# herbal: 0.5753
# fresh: 0.5694
#
# Top odors for CCCCCCCC1CC1C(C)C (probability > 0.5):
# waxy: 0.5888
# woody: 0.5256
# oily: 0.5011
#
# Top odors for CC (probability > 0.5):
# ethereal: 0.6569
# sweet: 0.5423
#
# Top odors for CCC1CCCCC1C(C)C (probability > 0.5):
# woody: 0.6674
# green: 0.6466
# floral: 0.6330
# herbal: 0.5530
# citrus: 0.5505
# fresh: 0.5466
#
# Top odors for CC(C)CCC1(C)CC(C)CC(C)C1C (probability > 0.5):
# woody: 0.7778
# green: 0.5848
# herbal: 0.5013
#
# Top odors for CCCC1CCC(CC(C)C2CCCCC2)C(CC)C1 (probability > 0.5):
# woody: 0.6542
#
# Top odors for C=C=C=C (probability > 0.5):
# pungent: 0.7194
# ethereal: 0.6051
# sweet: 0.5555
# sharp: 0.5176
#
# Top odors for CCCC(C)C(CC)CCC (probability > 0.5):
# floral: 0.6943
# green: 0.5747
# waxy: 0.5436
# woody: 0.5401
#
# Top odors for CCCCCC(CC)CC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.6505
#
# Top odors for CCC(C)CC1CCC(CC)CC1 (probability > 0.5):
# woody: 0.5522
#
# Top odors for CCC1CCCC(C)C1 (probability > 0.5):
# woody: 0.7018
# amber: 0.5133
#
# Top odors for CCC1CCC(C(C)CCC(C)C)CC1 (probability > 0.5):
# woody: 0.6689
# floral: 0.6212
# green: 0.6040
#
# Top odors for CCC(C)C1CC1(C)C1CC2CCC1C2 (probability > 0.5):
# woody: 0.8338
# green: 0.5149
# sandalwood: 0.5136
#
# Top odors for CC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.7269
# green: 0.6361
# floral: 0.5953
# herbal: 0.5884
# fresh: 0.5400
#
# Top odors for OOOOOO (probability > 0.5):
# odorless: 0.6125
#
# Top odors for CC1CCC(C(C)(C)CC(C)CCC2CCCCC2)CC1 (probability > 0.5):
# woody: 0.7719
# green: 0.5229
# waxy: 0.5114
#
# Top odors for CCC1(C)CCC(CCC(C)C)C(C)(C)C1C(C)C (probability > 0.5):
# woody: 0.8149
# green: 0.5902
# floral: 0.5402
#
# Top odors for CCC(C)(C)C1CCC(C)CC1 (probability > 0.5):
# woody: 0.8178
# green: 0.5956
#
# Top odors for CC(C)C1CC2C(C)CC1CC2C1CCCC1 (probability > 0.5):
# woody: 0.7663
# green: 0.5908
# herbal: 0.5490
#
# Top odors for CCC(C)CCC1CCC(C)C1(C)C (probability > 0.5):
# woody: 0.7749
# green: 0.5218
# floral: 0.5039
#
# Top odors for CCCC1CC(C)C2CC(C(C)C)CC2C(C)C1 (probability > 0.5):
# woody: 0.7295
# green: 0.6865
# herbal: 0.6260
# floral: 0.5765
# fresh: 0.5760
# citrus: 0.5493
#
# Top odors for CCCC(C)C(C)CC(C)CC (probability > 0.5):
# floral: 0.7656
# green: 0.6544
# woody: 0.5916
# citrus: 0.5223
# fresh: 0.5222
#
# Top odors for CCC(C)C1CCC(C(C)C)CC1 (probability > 0.5):
# woody: 0.6971
# green: 0.6691
# floral: 0.6378
# fresh: 0.5415
# herbal: 0.5341
# citrus: 0.5296
#
# Top odors for CC(C)CC(C)CC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6493
# green: 0.6083
# floral: 0.6064
#
# Top odors for CCCCCC1CCCC(CCC)C1 (probability > 0.5):
# waxy: 0.5631
#
# Top odors for CCCCCC(CCC)CCCC (probability > 0.5):
# waxy: 0.6782
#
# Top odors for CC1C2CCC(C3(C)CCCCC3)(C2)C1(C)C (probability > 0.5):
# woody: 0.9113
# amber: 0.5828
# dry: 0.5414
#
# Top odors for CCCC(C)CCC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6109
# waxy: 0.5610
# green: 0.5061
#
# Top odors for CC1CCCC(C)C12CCC(C(C)(C)C)C2 (probability > 0.5):
# woody: 0.8859
# amber: 0.5529
# green: 0.5174
# pine: 0.5087
# dry: 0.5028
#
# Top odors for CCC1(C)CC(C)C(C)C(C)C1C (probability > 0.5):
# woody: 0.7721
# herbal: 0.6244
# green: 0.6193
# fresh: 0.5845
# camphoreous: 0.5563
# pine: 0.5364
# spicy: 0.5087
#
# Top odors for CCC(C)CC(C)C (probability > 0.5):
# green: 0.7226
# herbal: 0.6439
# floral: 0.6187
# citrus: 0.5586
# fresh: 0.5371
# woody: 0.5309
#
# Top odors for CC1CCC2C(C)CC(C)C2C1 (probability > 0.5):
# woody: 0.8099
# green: 0.5582
# herbal: 0.5529
# fresh: 0.5320
# citrus: 0.5004
#
# Top odors for CC1CCCCC1C(C)CC1CCC2CCCCC2C1 (probability > 0.5):
# woody: 0.7475
#
# Top odors for CC(C)C1CCCC(C2CCCCC2)C1 (probability > 0.5):
# woody: 0.7466
#
# Top odors for CC1CCC2(C1)C(C)CCC(C)C2(C)C (probability > 0.5):
# woody: 0.8754
# amber: 0.5905
# dry: 0.5489
# cedar: 0.5484
#
# Top odors for CC(C)CCCC(C)CCCC(C)CCCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5871
# woody: 0.5815
# floral: 0.5373
# green: 0.5031
#
# Top odors for CCC(C)C1CCCCC1CC(C)C (probability > 0.5):
# woody: 0.6655
# floral: 0.6514
# green: 0.6413
# fresh: 0.5108
#
# Top odors for CC1CCCC(C)CCC2CC2(C)CCC1 (probability > 0.5):
# woody: 0.7841
# amber: 0.5505
# dry: 0.5192
#
# Top odors for CC1CCCCCCCCCCC(C)CCCC1 (probability > 0.5):
# musk: 0.7091
# woody: 0.6262
# amber: 0.6061
# sweet: 0.5461
# animal: 0.5344
# dry: 0.5113
#
# Top odors for CCCCCC1CC(C)CC(C)C1C(C)CCC (probability > 0.5):
# woody: 0.6270
# green: 0.5832
# floral: 0.5684
#
# Top odors for CC1CC(C)C2(CCCCCC2)C1(C)C (probability > 0.5):
# woody: 0.8550
# amber: 0.5879
# dry: 0.5517
# cedar: 0.5095
#
# Top odors for CCC(C)(CCCC(C)C)CC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.7279
# floral: 0.5837
# green: 0.5553
# waxy: 0.5167
#
# Top odors for CCCC1CCC(CC(C)C)C(CC)C1 (probability > 0.5):
# woody: 0.6316
# green: 0.6127
# floral: 0.5804
# fresh: 0.5242
#
# Top odors for CC(C)CC1CCCCC1 (probability > 0.5):
# woody: 0.6170
#
# Top odors for CCCC1CC2CCC1(C)C2(C)C (probability > 0.5):
# woody: 0.8711
# amber: 0.5264
#
# Top odors for CCCC(C)CC(C)CCC (probability > 0.5):
# floral: 0.6130
# green: 0.5681
# waxy: 0.5109
# woody: 0.5067
#
# Top odors for CCCCCCCC1CCCC1 (probability > 0.5):
# waxy: 0.6647
#
# Top odors for CC(C)CC(C)C(C)CC1C(C)CCCC1(C)C (probability > 0.5):
# woody: 0.7883
# floral: 0.6439
# green: 0.6261
#
# Top odors for CC1C2CC3CC1C(C)C(C2)C3C (probability > 0.5):
# woody: 0.8047
# herbal: 0.6434
# green: 0.6409
# pine: 0.5788
# fresh: 0.5578
# spicy: 0.5264
#
# Top odors for CCCC(C)CCC(C)C (probability > 0.5):
# floral: 0.6501
# green: 0.6126
# woody: 0.5179
# herbal: 0.5133
# citrus: 0.5032
#
# Top odors for CCCCCCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.7249
#
# Top odors for CCC(CCC(C)C)C(C)C (probability > 0.5):
# floral: 0.7689
# green: 0.6998
# woody: 0.6005
# citrus: 0.5670
# fresh: 0.5655
# herbal: 0.5352
#
# Top odors for CCCCC(C)C(C)(C)C (probability > 0.5):
# woody: 0.6533
# green: 0.6355
# floral: 0.6078
# herbal: 0.5606
# fresh: 0.5158
# citrus: 0.5114
#
# Top odors for CCCCC1CC1CCCC (probability > 0.5):
# waxy: 0.6177
#
# Top odors for CCCC(C)CCC(CC)CC (probability > 0.5):
# waxy: 0.5897
# floral: 0.5532
#
# Top odors for CC(C)CC1CCC2C3CCC(C3)C12 (probability > 0.5):
# woody: 0.7643
# green: 0.5700
# herbal: 0.5215
#
# Top odors for CCCCCC(C)CC(C)C (probability > 0.5):
# green: 0.5445
# floral: 0.5392
#
# Top odors for CCCC(C)CC(C)CC(C)(C)C (probability > 0.5):
# floral: 0.7261
# woody: 0.6797
# green: 0.6729
# herbal: 0.5251
#
# Top odors for CC(C)CCCCC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.5263
#
# Top odors for CC1CCCC2(CCCCC2)C1 (probability > 0.5):
# woody: 0.7065
# amber: 0.5396
# dry: 0.5238
#
# Top odors for CC(C)CC1CCC(C)C(C)C1 (probability > 0.5):
# woody: 0.7054
# green: 0.6454
# herbal: 0.5911
# floral: 0.5764
# fresh: 0.5531
# citrus: 0.5137
#
# Top odors for CCCCC(C)CC (probability > 0.5):
# green: 0.5101
# sweet: 0.5094
#
# Top odors for CCCCC(C)CC(C)CCCC (probability > 0.5):
# waxy: 0.5913
#
# Top odors for CCC(C)CC1CCCCCCC1 (probability > 0.5):
# woody: 0.5149
#
# Top odors for CC(C)C(C)CC1CC2CCC1(C)C2(C)C (probability > 0.5):
# woody: 0.8622
# amber: 0.5478
# sandalwood: 0.5384
# green: 0.5189
#
# Top odors for CCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6842
# green: 0.5888
# floral: 0.5303
# citrus: 0.5220
# fresh: 0.5206
#
# Top odors for C1CCC2C(C1)CC1CCCCC12 (probability > 0.5):
# woody: 0.8071
# amber: 0.5234
#
# Top odors for CC(C)C(C)C1CCCC1 (probability > 0.5):
# floral: 0.7444
# green: 0.6987
# woody: 0.6632
# herbal: 0.5429
# fresh: 0.5313
# citrus: 0.5039
#
# Top odors for CCCC1(C(C)(C)C)CCC(C)C1 (probability > 0.5):
# woody: 0.8061
# green: 0.5448
#
# Top odors for CC(C)CCCC(C)C(C)C1CCCCC1 (probability > 0.5):
# floral: 0.6695
# woody: 0.6580
# green: 0.6142
# waxy: 0.5153
#
# Top odors for CCC(C)CCC(C)CC(C)C(C)CCC(C)CC (probability > 0.5):
# floral: 0.7403
# woody: 0.6325
# green: 0.6197
# waxy: 0.5100
#
# Top odors for CCCC(C)CC1CCCC1C1CCCC1 (probability > 0.5):
# woody: 0.6485
# waxy: 0.5128
#
# Top odors for CCCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7327
#
# Top odors for CC(C)CCCC(CCCC(C)C)C1CCCCC1 (probability > 0.5):
# woody: 0.5953
# waxy: 0.5911
# floral: 0.5321
#
# Top odors for CC(C)CCC(C)C(CC(C)CCC(C)C(C)C)C(C)C (probability > 0.5):
# floral: 0.7635
# green: 0.6704
# woody: 0.6558
# herbal: 0.5142
#
# Top odors for CCCCCCC(C)CCCCCC (probability > 0.5):
# waxy: 0.6684
#
# Top odors for CCCCCC(CC)C1CCC(C)CC1 (probability > 0.5):
# waxy: 0.6006
#
# Top odors for CCCCCC1CC2CC1C1CCCC21 (probability > 0.5):
# woody: 0.6728
#
# Top odors for CCCCCCCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.7443
#
# Top odors for CCCC1CCC(C)C(C2CC(CCC)CCC2C)C1 (probability > 0.5):
# woody: 0.6819
# green: 0.5143
#
# Top odors for CCCC(C)CC(C)CC (probability > 0.5):
# floral: 0.6582
# green: 0.5848
# citrus: 0.5056
# fresh: 0.5042
#
# Top odors for CC1CCC2CC2(C)CCC2C1CC2(C)C (probability > 0.5):
# woody: 0.9070
# amber: 0.5741
# cedar: 0.5479
# dry: 0.5334
# pine: 0.5160
#
# Top odors for CCCCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.6239
#
# Top odors for CC(C)CC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.7001
# green: 0.6675
# floral: 0.6546
# herbal: 0.5110
# fresh: 0.5018
#
# Top odors for CC1CCC(C2CCCCC2)C1 (probability > 0.5):
# woody: 0.7486
#
# Top odors for CCC(C)CCCC(C)(CC)CC (probability > 0.5):
# woody: 0.5723
# waxy: 0.5543
#
# Top odors for CCC1CC2C3CCC(C3)C2C1 (probability > 0.5):
# woody: 0.8139
# amber: 0.5046
#
# Top odors for CCC1CCC(CC(C)CCCC(C)C)C1 (probability > 0.5):
# woody: 0.6197
# floral: 0.5890
# green: 0.5665
# waxy: 0.5373
#
# Top odors for CC(C)(C)CCC1CCCCC1 (probability > 0.5):
# woody: 0.7603
# green: 0.5775
#
# Top odors for CC1CCC(C(C)(C)C)C(C)C1 (probability > 0.5):
# woody: 0.8543
# green: 0.6487
# herbal: 0.6174
# floral: 0.5686
# pine: 0.5638
# fresh: 0.5563
# camphoreous: 0.5537
#
# Top odors for CCC(C)(CCCC(C)C)CC(C)C(C)C (probability > 0.5):
# woody: 0.6897
# floral: 0.6805
# green: 0.6148
#
# Top odors for CCCCCCCCCCCC(C)CC(C)CCC (probability > 0.5):
# waxy: 0.7036
#
# Top odors for CCC(C)CCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6512
# green: 0.5691
# woody: 0.5645
# waxy: 0.5262
#
# Top odors for CC(C)CC1CCCCC1C (probability > 0.5):
# woody: 0.6844
# green: 0.5862
# floral: 0.5436
# fresh: 0.5066
#
# Top odors for CC1CCC2C(C1)C2(C)C (probability > 0.5):
# woody: 0.8850
# pine: 0.5868
# amber: 0.5511
# cedar: 0.5329
# camphoreous: 0.5233
# green: 0.5074
# herbal: 0.5052
# dry: 0.5047
#
# Top odors for CCCC1CCC(CC)C(C)C1 (probability > 0.5):
# woody: 0.6126
# citrus: 0.5324
# green: 0.5206
#
# Top odors for CCC(C)CCC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6824
# floral: 0.5777
# green: 0.5644
# waxy: 0.5072
#
# Top odors for NNNNN(N)n1[nH][nH][nH][nH]1 (probability > 0.5):
# odorless: 0.8034
#
# Top odors for CCC(C)C(C)CCC1CCCCC1 (probability > 0.5):
# woody: 0.6163
# floral: 0.5447
# green: 0.5332
# waxy: 0.5119
#
# Top odors for CC1CCCCC1CCC1CCCC1 (probability > 0.5):
# woody: 0.6337
#
# Top odors for CC(CCCCC1CCCCC1)C1CCCCC1 (probability > 0.5):
# waxy: 0.5878
#
# Top odors for CC1CC(C)C23CC1C(C)(C)C2CCC3C (probability > 0.5):
# woody: 0.8878
# amber: 0.5731
# cedar: 0.5620
# dry: 0.5164
# pine: 0.5123
#
# Top odors for CCC1C2(C)CCCC1(C)CC2 (probability > 0.5):
# woody: 0.8683
# amber: 0.5547
# dry: 0.5245
#
# Top odors for CC1CC(C)CC(C)(C2CCCCC2)C1 (probability > 0.5):
# woody: 0.8214
# amber: 0.5314
#
# Top odors for CCCCCC(C)C1CCCCC1 (probability > 0.5):
# waxy: 0.5671
#
# Top odors for CCCCCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6489
#
# Top odors for CCCCCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6784
#
# Top odors for CCCC(CC)CC (probability > 0.5):
# sweet: 0.5214
# citrus: 0.5181
# fruity: 0.5148
# green: 0.5030
#
# Top odors for CCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.5902
#
# Top odors for CCCC(C)C(CC)CC (probability > 0.5):
# floral: 0.7467
# green: 0.6138
# citrus: 0.5560
# fresh: 0.5334
# woody: 0.5328
# waxy: 0.5020
#
# Top odors for CCCCCC(CCC)CCCC(C)CCC (probability > 0.5):
# waxy: 0.6707
#
# Top odors for CCC(C)(C)CCCC(C)C (probability > 0.5):
# woody: 0.6335
# green: 0.6214
# floral: 0.5611
# herbal: 0.5261
#
# Top odors for CCCC1CCC(C)C1(C)C (probability > 0.5):
# woody: 0.7848
# green: 0.5048
#
# Top odors for CCCC1CCC(C)C(CCC)C1 (probability > 0.5):
# woody: 0.5645
# green: 0.5071
#
# Top odors for CC1CCCC(CC2CCCCC2)C1 (probability > 0.5):
# woody: 0.6986
#
# Top odors for CC1C2CCCCC2C(C)(C)C1C (probability > 0.5):
# woody: 0.8747
# pine: 0.5777
# camphoreous: 0.5217
# amber: 0.5215
# herbal: 0.5180
# green: 0.5139
# fresh: 0.5131
# cedar: 0.5032
#
# Top odors for CCCC(C)C(C)C(CC)C(C)C (probability > 0.5):
# floral: 0.7975
# green: 0.6966
# woody: 0.6139
# fresh: 0.5610
# citrus: 0.5426
# herbal: 0.5104
# muguet: 0.5044
#
# Top odors for CCCCCCCCCCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.7248
#
# Top odors for CC(C)C1CC2CC(C(C)C)C1CC2C (probability > 0.5):
# woody: 0.7516
# green: 0.7179
# herbal: 0.6636
# fresh: 0.5573
# pine: 0.5481
# floral: 0.5268
# citrus: 0.5240
# camphoreous: 0.5141
#
# Top odors for C=C=C=C=C=C=C (probability > 0.5):
# pungent: 0.8359
# sweet: 0.5687
#
# Top odors for CCCCCC(C)C(C)CCC (probability > 0.5):
# floral: 0.5697
# waxy: 0.5417
# green: 0.5254
# woody: 0.5067
#
# Top odors for CC(C)C1(C)CCC2CCCC(C)(C)C2C1C (probability > 0.5):
# woody: 0.8711
# amber: 0.5454
# pine: 0.5416
# green: 0.5245
# camphoreous: 0.5110
# cedar: 0.5098
# dry: 0.5071
#
# Top odors for CC1CCCCC1C (probability > 0.5):
# woody: 0.7167
# amber: 0.5543
# musk: 0.5162
#
# Top odors for CC1CCCCCCCCCCCCCC1C (probability > 0.5):
# musk: 0.6937
# woody: 0.6289
# amber: 0.5973
# animal: 0.5270
# sweet: 0.5215
# dry: 0.5206
#
# Top odors for CCCC(C)C(CC)C(C)C (probability > 0.5):
# floral: 0.7859
# green: 0.7079
# woody: 0.5834
# fresh: 0.5737
# citrus: 0.5656
# herbal: 0.5201
# muguet: 0.5118
#
# Top odors for CCC1CC(C)CC1CC (probability > 0.5):
# woody: 0.6690
# green: 0.6550
# citrus: 0.6138
# herbal: 0.6008
# floral: 0.5961
# fresh: 0.5805
#
# Top odors for CC(C)CCC1(C)C(C)CC(C)CC1(C)C (probability > 0.5):
# woody: 0.8047
# green: 0.5155
#
# Top odors for CCCC1CCC2CCCCC2C1 (probability > 0.5):
# woody: 0.6366
#
# Top odors for CCC1CC2C3CC(CC)C(C3)C2C1 (probability > 0.5):
# woody: 0.7863
# herbal: 0.5594
# green: 0.5481
# pine: 0.5171
# fresh: 0.5037
#
# Top odors for CCCCCC(C)C (probability > 0.5):
# green: 0.5481
#
# Top odors for CCCCCCC(CC(C)C)C(C)CCC (probability > 0.5):
# floral: 0.5912
# waxy: 0.5706
# woody: 0.5542
# green: 0.5193
#
# Top odors for CCCCCC(C)CC(C)C1CCCCC1C (probability > 0.5):
# woody: 0.6217
# waxy: 0.5638
# green: 0.5139
#
# Top odors for CCCCCC(C)C1CCC(C)C(CC)C1 (probability > 0.5):
# woody: 0.6121
# waxy: 0.5157
# green: 0.5104
#
# Top odors for CCCCCCCCCC(C)CC(C)CCC (probability > 0.5):
# waxy: 0.6778
#
# Top odors for CCC1C(C)CC(C)C1C (probability > 0.5):
# woody: 0.7346
# herbal: 0.7293
# green: 0.7207
# fresh: 0.6174
# citrus: 0.6127
# floral: 0.5652
# spicy: 0.5026
#
# Top odors for CC(C)CC(C)C(C)C(C)C (probability > 0.5):
# green: 0.7293
# floral: 0.6786
# woody: 0.6621
# herbal: 0.6301
# citrus: 0.5645
# fresh: 0.5476
#
# Top odors for CC(CCCC1CCCCC1)C1CCCC1 (probability > 0.5):
# woody: 0.5574
# waxy: 0.5568
#
# Top odors for CCCCCCCCC(C)CCC(C)C (probability > 0.5):
# waxy: 0.6379
#
# Top odors for CCC(C)CCC(C)C(C)C (probability > 0.5):
# floral: 0.7474
# green: 0.6775
# woody: 0.6084
# citrus: 0.5666
# fresh: 0.5546
# herbal: 0.5395
#
# Top odors for CC1CCCC(CC(C)CC2CCCCC2)C1 (probability > 0.5):
# woody: 0.6221
#
# Top odors for CCC1CCC2CCCC2C1 (probability > 0.5):
# woody: 0.7596
#
# Top odors for CC1CCC2C1C1C(CCC2(C)C)C1(C)C (probability > 0.5):
# woody: 0.8844
# pine: 0.5825
# cedar: 0.5502
# camphoreous: 0.5500
# amber: 0.5353
# green: 0.5325
# herbal: 0.5299
# dry: 0.5011
#
# Top odors for CCCC(C)CC (probability > 0.5):
# green: 0.6141
# herbal: 0.5269
# sweet: 0.5156
#
# Top odors for CCC(C)CCCC(C)CCCC(C)CC (probability > 0.5):
# waxy: 0.5954
# floral: 0.5452
# woody: 0.5214
#
# Top odors for CCC1CCC(CC(C)C)CC1 (probability > 0.5):
# woody: 0.6173
# green: 0.5550
# floral: 0.5525
#
# Top odors for CCCC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6400
#
# Top odors for CC(C)CCCCCCCCCCCC(CCCCCCCCCCCC(C)C)CC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6986
#
# Top odors for CCCCCCCCC(C)CC1CCCCC1 (probability > 0.5):
# waxy: 0.6905
#
# Top odors for CCCCCCCC(CCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.7082
#
# Top odors for CC1CC(C)C(C)C(C)C1 (probability > 0.5):
# woody: 0.7549
# herbal: 0.7230
# green: 0.6497
# fresh: 0.5874
# camphoreous: 0.5476
# citrus: 0.5232
# floral: 0.5211
# mint: 0.5137

# %%
import os 
#Count occurrences of each odor in the top 10 lists
odor_counts = Counter(all_top_odors)


plt.figure(figsize=(12, 6))
odors, counts = zip(*odor_counts.most_common(20))  
plt.bar(odors, counts)
plt.title("Top Predicted Odors Across All Molecules")
plt.xlabel("Odor Labels")
plt.ylabel("Count in Top 10 Predictions")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_folder = '../../figures/ARGA/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300, 600, 1200]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_ten_{dpi}dpi.png", dpi=dpi, bbox_inches='tight')
plt.show()


print("\nCounts of odors in top 10 predictions across all molecules:")
for odor, count in odor_counts.most_common():
    print(f"{odor}: {count}")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Counts of odors in top 10 predictions across all molecules:
# woody: 1145
# green: 797
# waxy: 597
# floral: 585
# herbal: 359
# fresh: 341
# citrus: 213
# amber: 161
# pine: 110
# dry: 100
# camphoreous: 77
# cedar: 55
# sweet: 50
# musk: 28
# odorless: 23
# animal: 19
# earthy: 19
# sandalwood: 17
# mint: 13
# terpenic: 11
# spicy: 10
# ethereal: 9
# pungent: 8
# muguet: 7
# oily: 6
# sulfurous: 6
# onion: 6
# garlic: 6
# savory: 6
# musty: 6
# fruity: 4
# fermented: 3
# fatty: 3
# sharp: 2
# rose: 2
# balsamic: 2
# alcoholic: 1
# solvent: 1
#
# Problematic SMILES that caused errors:

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt


odor_counts = Counter(all_top_odors)
total_predictions = sum(odor_counts.values())  


percentages = [(count / total_predictions) * 100 for count in odor_counts.values()]


sorted_odors_percentages = sorted(zip(odor_counts.keys(), percentages), key=lambda x: x[1], reverse=True)


sorted_odors_percentages = [(odor, pct) for odor, pct in sorted_odors_percentages if odor != 'odorless']


top_20_odors_percentages = sorted_odors_percentages[:20]
top_20_odors, top_20_percentages = zip(*top_20_odors_percentages)


plt.figure(figsize=(15, 8))  


bars = plt.bar(top_20_odors, top_20_percentages, edgecolor='black')
ax = plt.gca()  
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(2)  


plt.title("Most Common Odor Predictions (ARGVA)", fontsize=33, fontweight='bold', pad=20)
plt.xlabel("Odor Labels", fontsize=33, fontweight='bold', labelpad=15)
plt.ylabel("(%) of Predictions", fontsize=29, fontweight='bold', labelpad=15)


plt.xticks(rotation=45, ha='right', fontsize=28, fontweight='bold')
plt.yticks(fontsize=26, fontweight='bold')


plt.tight_layout()


output_folder = '../../figures/ARGVA/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_odor_per.png", dpi=dpi, bbox_inches='tight')


plt.show()


print("\nPercentages of top 20 odors in top 10 predictions across all molecules:")
for odor, percentage in zip(top_20_odors, top_20_percentages):
    print(f"{odor}: {percentage:.2f}%")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Percentages of top 20 odors in top 10 predictions across all molecules:
# woody: 23.81%
# green: 16.58%
# waxy: 12.42%
# floral: 12.17%
# herbal: 7.47%
# fresh: 7.09%
# citrus: 4.43%
# amber: 3.35%
# pine: 2.29%
# dry: 2.08%
# camphoreous: 1.60%
# cedar: 1.14%
# sweet: 1.04%
# musk: 0.58%
# animal: 0.40%
# earthy: 0.40%
# sandalwood: 0.35%
# mint: 0.27%
# terpenic: 0.23%
# spicy: 0.21%
#
# Problematic SMILES that caused errors:
