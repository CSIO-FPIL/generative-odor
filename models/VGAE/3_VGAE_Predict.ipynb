# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
from openpom.feat.graph_featurizer import GraphFeaturizer, GraphConvConstants
from openpom.utils.data_utils import get_class_imbalance_ratio, IterativeStratifiedSplitter
from openpom.models.mpnn_pom import MPNNPOMModel
from datetime import datetime
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import gaussian_kde
from collections import Counter
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# WARNING:tensorflow:From c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\sarab\miniconda3\envs\ENV4\lib\site-packages\deepchem\models\torch_models\__init__.py)

# %%
# Odor Labels
TASKS = [
    'alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
    'anisic', 'apple', 'apricot', 'aromatic', 'balsamic', 'banana', 'beefy',
    'bergamot', 'berry', 'bitter', 'black currant', 'brandy', 'burnt',
    'buttery', 'cabbage', 'camphoreous', 'caramellic', 'cedar', 'celery',
    'chamomile', 'cheesy', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clean',
    'clove', 'cocoa', 'coconut', 'coffee', 'cognac', 'cooked', 'cooling',
    'cortex', 'coumarinic', 'creamy', 'cucumber', 'dairy', 'dry', 'earthy',
    'ethereal', 'fatty', 'fermented', 'fishy', 'floral', 'fresh', 'fruit skin',
    'fruity', 'garlic', 'gassy', 'geranium', 'grape', 'grapefruit', 'grassy',
    'green', 'hawthorn', 'hay', 'hazelnut', 'herbal', 'honey', 'hyacinth',
    'jasmin', 'juicy', 'ketonic', 'lactonic', 'lavender', 'leafy', 'leathery',
    'lemon', 'lily', 'malty', 'meaty', 'medicinal', 'melon', 'metallic',
    'milky', 'mint', 'muguet', 'mushroom', 'musk', 'musty', 'natural', 'nutty',
    'odorless', 'oily', 'onion', 'orange', 'orangeflower', 'orris', 'ozone',
    'peach', 'pear', 'phenolic', 'pine', 'pineapple', 'plum', 'popcorn',
    'potato', 'powdery', 'pungent', 'radish', 'raspberry', 'ripe', 'roasted',
    'rose', 'rummy', 'sandalwood', 'savory', 'sharp', 'smoky', 'soapy',
    'solvent', 'sour', 'spicy', 'strawberry', 'sulfurous', 'sweaty', 'sweet',
    'tea', 'terpenic', 'tobacco', 'tomato', 'tropical', 'vanilla', 'vegetable',
    'vetiver', 'violet', 'warm', 'waxy', 'weedy', 'winey', 'woody'
]
len(TASKS)
# Out:
# 138

# %%
input_file = '../../data/curated dataset/curated_GS_LF_merged_4983.csv'
featurizer = GraphFeaturizer()
smiles_field = 'nonStereoSMILES' # column that contains SMILES

# %%
loader = dc.data.CSVLoader(tasks=TASKS,
feature_field=smiles_field,
featurizer=featurizer)

# %%
dataset = loader.create_dataset(inputs=[input_file])
n_tasks = len(dataset.tasks)
randomstratifiedsplitter = dc.splits.RandomStratifiedSplitter()
train_dataset, test_dataset, valid_dataset = randomstratifiedsplitter.train_valid_test_split(dataset, frac_train = 0.8, frac_valid = 0.1, frac_test = 0.1, seed = 1)
train_ratios = get_class_imbalance_ratio(train_dataset)

# %%
assert len(train_ratios) == n_tasks

# %%
learning_rate = dc.models.optimizers.ExponentialDecay(initial_rate=0.001, decay_rate=0.5, decay_steps=32*20, staircase=True)

# %%
model = MPNNPOMModel(n_tasks = n_tasks,
                     batch_size = 128,
                     learning_rate = learning_rate,
                     class_imbalance_ratio = train_ratios,
                     loss_aggr_type = 'sum',
                     node_out_feats = 100,
                     edge_hidden_feats = 75,
                     edge_out_feats = 100,
                     num_step_message_passing = 5,
                     mpnn_residual = True,
                     message_aggregator_type = 'sum',
                     mode = 'classification',
                     number_atom_features = GraphConvConstants.ATOM_FDIM,
                     number_bond_features = GraphConvConstants.BOND_FDIM,
                     n_classes = 1,
                     readout_type = 'set2set',
                     num_step_set2set = 3,
                     num_layer_set2set = 2,
                     ffn_hidden_list = [392, 392],
                     ffn_embeddings = 256,
                     ffn_activation = 'relu',
                     ffn_dropout_p = 0.12,
                     ffn_dropout_at_input_no_act = False,
                     weight_decay = 1e-5,
                     self_loop = False,
                     optimizer_name = 'adam',
                     log_frequency = 32,
                     model_dir = './experiments',
                     device_name ='cpu')

# %%
import torch
checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
if 'model_state_dict' in checkpoint:
    model.model.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    model.model.load_state_dict(checkpoint, strict=False)
model.model.eval()
# Out:
# C:\Users\sarab\AppData\Local\Temp\ipykernel_10448\2995347586.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pt', map_location=torch.device('cpu'))
# MPNNPOM(
#   (mpnn): CustomMPNNGNN(
#     (project_node_feats): Sequential(
#       (0): Linear(in_features=134, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (gnn_layer): NNConv(
#       (edge_func): Sequential(
#         (0): Linear(in_features=6, out_features=75, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=75, out_features=10000, bias=True)
#       )
#       (res_fc): Identity()
#     )
#     (gru): GRU(100, 100)
#   )
#   (project_edge_feats): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): ReLU()
#   )
#   (readout_set2set): Set2Set(
#     n_iters=3
#     (lstm): LSTM(400, 200, num_layers=2)
#   )
#   (ffn): CustomPositionwiseFeedForward(
#     (activation): ReLU()
#     (linears): ModuleList(
#       (0): Linear(in_features=400, out_features=392, bias=True)
#       (1): Linear(in_features=392, out_features=392, bias=True)
#       (2): Linear(in_features=392, out_features=256, bias=True)
#       (3): Linear(in_features=256, out_features=138, bias=True)
#     )
#     (dropout_p): ModuleList(
#       (0-3): 4 x Dropout(p=0.12, inplace=False)
#     )
#     (batchnorms): ModuleList(
#       (0-1): 2 x BatchNorm1d(392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
csv_file_path = '../../data/VGAE/logistic equation/novel_odorrous_set_log_eq.csv'
df = pd.read_csv(csv_file_path)

# %%
smiles_list = df['SMILE'].tolist()
print(smiles_list)


featurizer = GraphFeaturizer()
featurized_data = featurizer.featurize(smiles_list)


all_top_odors = []
problematic_smiles = []

for i, featurized_mol in enumerate(featurized_data):
    try:

        single_mol_dataset = dc.data.NumpyDataset([featurized_mol])

        
        prediction = model.predict(single_mol_dataset)

        
        odor_probs = prediction.squeeze()
        high_prob_indices = np.where(odor_probs > 0.5)[0]
        
        
        sorted_indices = high_prob_indices[np.argsort(odor_probs[high_prob_indices])[::-1]]
        
        
        top_odors = [TASKS[i] for i in sorted_indices]
        all_top_odors.extend(top_odors)

        # Printing top odors for each molecule
        print(f"\nTop odors for {smiles_list[i]} (probability > 0.5):")
        for odor, score in zip(top_odors, odor_probs[sorted_indices]):
            print(f"{odor}: {score:.4f}")

    except KeyError as e:
        print(f"\nError processing SMILES: {smiles_list[i]}")
        print(f"Error message: {str(e)}")
        problematic_smiles.append(smiles_list[i])
        continue
# Out:
# ['C=CC(CC)CCCCCCCCCC', 'CCCC(CC)CCC', 'C=C(C)CC(CCCCCCCCCC)C(C)CC', 'C=C(C)CCCC', 'CC(C)CCC(C)C(C)C', 'CC1C=CCC(C)C1', 'CCCCCCCCCCCCCCCCCCC', 'CCCCCC(C)CCC(C)C', 'C1=CCC(CCC2CCCCC2)CC1', 'C=C(C)CCCC(C)(C)CC', 'C=CCC(=C)CCC', 'CCC(C)C(CC)CC', 'C=C(C)CCCCCCCC', 'C=C(CCCCCCC)CCC1C=CC=C1', 'CCC1C=CC=CCCCCCCC1', 'CC1CCCC=CCCCCCCCC1', 'CCCCCCC=CC=N', 'C=CC(CC)CCCCC', 'CC=CCCCCCC(CC)CC', 'CCCCCCCCCC(C)C(CC)CC', 'C=C(C)C(CC)CCCC', 'CC1C=CCC1', 'CCC(C)C(C)CC=N', 'CCCCCCCC1C=CC(C)C1', 'C=C(C)CCC(CC)CC', 'C=C(CCCCC(C)CC(C)C)CC(C)C', 'CCCC(C)CC(C)C(C)CCC', 'C1=CCCC1', 'CCCCCCCCCCCCCCCC(C)C=N', 'C=C=CC(C)CC', 'C=CC(CCC)CCCCCCC', 'CC(C)CC1=CCCC(C)C1', 'C=CC(C)C(C)C', 'CCCC=CCCCCCCC', 'CCCCCCCC(C)CC1CCCC1', 'CC(C)CCC=N', 'C=CCC(=C)C(C)CC(C)C', 'CC1CC=CCCCC=CCCCCCCC1', 'CCCCCC(CCC)CCCC(C)C', 'CCCCCC(CCCC)CCCCC', 'C=C(CCC(C)CC)C(C)C', 'CCCCCCCCCCN', 'C=CCCCC(C)C', 'NCCCC1CCCCCCCCCCC1', 'C=C1C=CCC(CCCCC)=C1', 'C=CCC(C)C', 'CCCCCC=CCCC(CCC)CCC', 'C=C1C=CC=C1CCCCCC', 'CCCC=CC1C=CC(C)CC1', 'CC(C)CC1CCCC1', 'CCC(C)C1CC(C)C(CC)C1', 'CCCCC(C)N', 'CC1CCC=CCCCCC=CCCCCC1', 'CCC(C)CCCC(C)(C)C', 'C=CC(=C)CCC', 'C=C(CCC)C(CC)CCC(C)C', 'C=C1CCC(=N)C(=C)C1', 'CC(C)C(C)CC(C)C(C)C', 'CCCCC(CCCC)CC(C)C', 'CCC(C)C', 'C=C(C)CCCC(C)CCCC(C)C', 'C=CC(C)(C)CCC', 'C=C(CCCCCCC)CC(C)C', 'C=C=C(CC)CCC', 'CCCCCCC(C)CCCC', 'CC(C)CC1CC(C)C(C)C1', 'C=C(CCCC(C)C)C(C)CCC', 'C=C1C=CC(CCCC)C1', 'C=CCCCCCC(=C)CCC', 'CCCCCCCC(C)CC(C)C', 'C=CCCCCC(C)C', 'CCCCCCCCC=CCCCCCCCC(C)CC=N', 'CCCCCCCCCCCC=N', 'CCCCCC(C)CCC(C)CCCCC', 'C=CC(CC)CCCCC=CCC', 'NC1CCCC1', 'C=C1CC(C)C(C)C1=N', 'C=CCCCCCCCC', 'CCCCCCCCCC1C=C(C)CCC1', 'C=CC(CC)CCCCCCC', 'CCC(C)CCCC(C)CC=N', 'C=C1C=C(C(C)C)CCC1C', 'C=CCC(C)(CC)CCCC', 'CCCCCC(CCCCC)CC(C)C', 'CCCCCCCC(C=N)CC', 'CCC(C)C(C)CC(C)C', 'CCCCCCCCCCC(C)CCCCCC', 'CCCCCCCC(C)CC', 'C=CCC=CC', 'C=CCCCCC(C)CCC', 'CC1=CCCC1C', 'C=C(C)CCCC(C)CCCC(C)CC(=C)C', 'CCCCCCCCC(C)C(C)C', 'CC1CCCCC=CCCCCCCCCC1', 'CCCCCC(C=N)CC', 'C=C(C)CC(C)CC', 'CC(C)CC1CCC(C)C1', 'C=C1CCC(CCC)C1', 'C=CCCCC(C)CCCC', 'CCC(C)(C)C(C)CC(C)C', 'CCCCCC1=CC=C=C=C1', 'CCCCC(=N)C(C)CC', 'C=CCCC(C)(C)C', 'CCCCCC(C)CCC(C)CC', 'CCCC(C)(C)CCC(C)(C)CCC', 'CCCCCC1C=CCC(CCCCC)C1', 'C=CCCC(=N)CC(C)(CC)CCCC(C)C', 'C=CCC(CCC)CCCCCCCCCCC', 'CC(C)C1CCC(C)C(C)C1', 'C=C=CCCC(C)C', 'C=C=CC=CCC', 'CC1C=CC=C1', 'C=C=CCCCCCCC', 'CCCCCCCCCCC(CC)CC', 'CCCCCCCC1CCCC1C', 'C=CC1=CC(=C)CC1', 'C=CC(C)(CCC)CCCC(C)C', 'CCC(C)CCC(C)CC', 'C=C(CCCCCC)CCC(C)C', 'C=CCCC=N', 'CC(C)CCCC(CCC(C)C)CC(C)C', 'CC(C)CCCC(CCCC(C)C)C(C)C', 'C=C(CCCC)CCCCCCCCC', 'C=C(CCC)CC(C)C(C)C', 'CCCCC=CCCCCCCC', 'C=C(CCC)CCC', 'CCCCC1=CCC(CN)CC1', 'CCCC(C)C(C)C(C)C', 'CCCCCC1=CCCC1', 'C=CC(C)C(C)CCCC', 'CCCC(CC)CCC=N', 'CCC(C)C(C)C(C)CC(C)C', 'CCCC(CCCC(C)C)C(C)C', 'CC1CC(N)CC(C(C)C)C1', 'C=CC(CCC)CC(C)C', 'C=CCCC(CC=C)CCCCC', 'C=C(C)CCCC(C)CC(C)(C)C', 'CCCC=N', 'CCCC(CC)CC(C)CC', 'CCCC(C)C(C)(C)CC', 'CCCC(CCC(C)C)C(C)C', 'C=CC(CC)CCCCCC', 'CCCCC(CC)CCC', 'CCCCCCCCCC(C)C(C)CC', 'C=C(CCCCC)CC(C)CCC(C)CCCCC', 'CCCCCCCCC(C)CCCCCCCC', 'C=C(C)CC(C)(CC)CCCC(C)C', 'C=CCC(CC)C(C)C=C', 'C=C(C=CCCCCC)CCCCC', 'CC=CCCCC', 'CCCCCCCCC(C=N)CC', 'C=C=CCCCCCCCCCC', 'C=C(C=N)C(C)C', 'CCCCCCCCC(C)CC(C)C', 'CCCCC(C)C(C)CC(C)(C)CC', 'CCC(C)C1CC(C(C)C)CCC1C', 'C=C(C=N)CC=CCCCCCC', 'CC1CCCCC1C', 'C=C(C)CCCC(C)CCCCN', 'CC(C)C1CC2CCC1C2', 'CCC=CC(C)C(CC)CC', 'CCCCC1CCCC1', 'CC(C)CCC(C(C)C)C(C)CC(C)C', 'C=CCCCC(=C)CCCCCCCCC', 'C=CCC(C=C)CCC', 'C=CCC(CC)CCCC', 'C=C(CCCC)CCCCCCC', 'CCCCC(CCC(C)C)CCC(C)C', 'CC(C)C(C)(C)C', 'CC1CCC(C(C)C)C(C)C1', 'CCCCCCCC(C)C1C=C1', 'CCCCCCCCCCC(C)C(C)C', 'C=CCCCCCCCC(=C)C', 'C=CCCCCCCCCCCC(C)C', 'CCCCCCC(C)CCCCCCCCCCC(C)CCC', 'C=C=CCCC(C)CC(C)(C)C', 'C=C(C)CC1CCCC1', 'CC1CC=CCCCCCCCCCC=CCC1', 'C=CCCC(CC)CCCC', 'C=CCC(=C)CCCCC', 'C=CCCCC(C)CCCC(C)CCC', 'C=CCCCCC(C)CCCC(C)C', 'CCC(CC=N)CCCC(C)C', 'CCCCCCCC(C)CCC', 'C=CC(C)(C)CCCC(C)CCCC(C)CCCC(C)C', 'C=CCCCCCCCC(C)CCCCCCCCC', 'C=CCC(=C)CCCCCCCCCCCCCCCC', 'CC1C=C(CC(C)CCCC(C)(C)C)CC1', 'CC(C)C1C=CC(C)C(C)C1', 'CCCCCC1CCC(C)CC1', 'CCC(C)CC1CCCC1', 'CCCCC(CC)C(C)C', 'CCCC(CCC)CCCCCC(C)C', 'CC(C)CCCCCCCCCC ...
#
# Top odors for C=CC(CC)CCCCCCCCCC (probability > 0.5):
# waxy: 0.6706
#
# Top odors for CCCC(CC)CCC (probability > 0.5):
# waxy: 0.5629
#
# Top odors for C=C(C)CC(CCCCCCCCCC)C(C)CC (probability > 0.5):
# waxy: 0.6254
# woody: 0.5702
#
# Top odors for C=C(C)CCCC (probability > 0.5):
# citrus: 0.5983
# gassy: 0.5263
# herbal: 0.5179
# fruity: 0.5126
# sweet: 0.5084
#
# Top odors for CC(C)CCC(C)C(C)C (probability > 0.5):
# green: 0.7210
# floral: 0.7079
# woody: 0.6442
# herbal: 0.6294
# citrus: 0.5999
# fresh: 0.5632
#
# Top odors for CC1C=CCC(C)C1 (probability > 0.5):
# woody: 0.6050
# citrus: 0.5928
# herbal: 0.5022
#
# Top odors for CCCCCCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7659
#
# Top odors for CCCCCC(C)CCC(C)C (probability > 0.5):
# waxy: 0.5328
# green: 0.5019
#
# Top odors for C1=CCC(CCC2CCCCC2)CC1 (probability > 0.5):
# woody: 0.5279
#
# Top odors for C=C(C)CCCC(C)(C)CC (probability > 0.5):
# floral: 0.6766
# woody: 0.6729
# herbal: 0.5445
# sweet: 0.5370
# citrus: 0.5144
#
# Top odors for C=CCC(=C)CCC (probability > 0.5):
# citrus: 0.5661
# fruity: 0.5561
#
# Top odors for CCC(C)C(CC)CC (probability > 0.5):
# floral: 0.7613
# green: 0.6459
# citrus: 0.6121
# fresh: 0.5691
# woody: 0.5408
# rose: 0.5291
# herbal: 0.5198
#
# Top odors for C=C(C)CCCCCCCC (probability > 0.5):
# waxy: 0.5950
#
# Top odors for C=C(CCCCCCC)CCC1C=CC=C1 (probability > 0.5):
# waxy: 0.5445
# woody: 0.5414
#
# Top odors for CCC1C=CC=CCCCCCCC1 (probability > 0.5):
# musk: 0.5229
#
# Top odors for CC1CCCC=CCCCCCCCC1 (probability > 0.5):
# musk: 0.7299
# animal: 0.5667
# amber: 0.5401
# dry: 0.5165
#
# Top odors for CCCCCCC=CC=N (probability > 0.5):
# green: 0.7941
# fatty: 0.6935
#
# Top odors for C=CC(CC)CCCCC (probability > 0.5):
# waxy: 0.5541
#
# Top odors for CC=CCCCCCC(CC)CC (probability > 0.5):
# waxy: 0.5975
#
# Top odors for CCCCCCCCCC(C)C(CC)CC (probability > 0.5):
# waxy: 0.6750
#
# Top odors for C=C(C)C(CC)CCCC (probability > 0.5):
# floral: 0.7730
# citrus: 0.6011
# woody: 0.5964
# sweet: 0.5941
# fruity: 0.5620
# waxy: 0.5556
# rose: 0.5323
#
# Top odors for CC1C=CCC1 (probability > 0.5):
# citrus: 0.6059
#
# Top odors for CCC(C)C(C)CC=N (probability > 0.5):
# green: 0.7936
# citrus: 0.5274
#
# Top odors for CCCCCCCC1C=CC(C)C1 (probability > 0.5):
# waxy: 0.5562
#
# Top odors for C=C(C)CCC(CC)CC (probability > 0.5):
# floral: 0.7549
# citrus: 0.5990
# sweet: 0.5877
# woody: 0.5693
# waxy: 0.5562
# fruity: 0.5363
# rose: 0.5247
#
# Top odors for C=C(CCCCC(C)CC(C)C)CC(C)C (probability > 0.5):
# floral: 0.6877
# woody: 0.6537
# waxy: 0.5091
#
# Top odors for CCCC(C)CC(C)C(C)CCC (probability > 0.5):
# floral: 0.7338
# green: 0.6356
# woody: 0.5888
#
# Top odors for C1=CCCC1 (probability > 0.5):
# musk: 0.5594
#
# Top odors for CCCCCCCCCCCCCCCC(C)C=N (probability > 0.5):
# waxy: 0.6465
# fatty: 0.5964
#
# Top odors for C=C=CC(C)CC (probability > 0.5):
# green: 0.7918
# sweet: 0.5367
#
# Top odors for C=CC(CCC)CCCCCCC (probability > 0.5):
# waxy: 0.6259
#
# Top odors for CC(C)CC1=CCCC(C)C1 (probability > 0.5):
# woody: 0.7378
# citrus: 0.5708
# herbal: 0.5596
# fresh: 0.5596
# green: 0.5543
# floral: 0.5392
#
# Top odors for C=CC(C)C(C)C (probability > 0.5):
# green: 0.6874
# herbal: 0.6507
# citrus: 0.6210
# fresh: 0.5963
# floral: 0.5574
# fruity: 0.5474
#
# Top odors for CCCC=CCCCCCCC (probability > 0.5):
# waxy: 0.5388
#
# Top odors for CCCCCCCC(C)CC1CCCC1 (probability > 0.5):
# waxy: 0.6790
#
# Top odors for CC(C)CCC=N (probability > 0.5):
# green: 0.8778
# vegetable: 0.5141
# fruity: 0.5137
#
# Top odors for C=CCC(=C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7216
# woody: 0.6532
# citrus: 0.5670
# fruity: 0.5660
# herbal: 0.5379
# sweet: 0.5338
#
# Top odors for CC1CC=CCCCC=CCCCCCCC1 (probability > 0.5):
# musk: 0.6930
# animal: 0.5361
# dry: 0.5124
#
# Top odors for CCCCCC(CCC)CCCC(C)C (probability > 0.5):
# waxy: 0.6388
#
# Top odors for CCCCCC(CCCC)CCCCC (probability > 0.5):
# waxy: 0.7058
#
# Top odors for C=C(CCC(C)CC)C(C)C (probability > 0.5):
# floral: 0.7173
# woody: 0.6626
# citrus: 0.5635
# herbal: 0.5597
# sweet: 0.5166
#
# Top odors for CCCCCCCCCCN (probability > 0.5):
# fatty: 0.6091
#
# Top odors for C=CCCCC(C)C (probability > 0.5):
# citrus: 0.5857
# fruity: 0.5419
# green: 0.5065
# herbal: 0.5033
#
# Top odors for NCCCC1CCCCCCCCCCC1 (probability > 0.5):
#
# Top odors for C=C1C=CCC(CCCCC)=C1 (probability > 0.5):
# woody: 0.6355
#
# Top odors for C=CCC(C)C (probability > 0.5):
# green: 0.7279
# fruity: 0.6389
# fresh: 0.5426
#
# Top odors for CCCCCC=CCCC(CCC)CCC (probability > 0.5):
# waxy: 0.6164
#
# Top odors for C=C1C=CC=C1CCCCCC (probability > 0.5):
# woody: 0.6632
#
# Top odors for CCCC=CC1C=CC(C)CC1 (probability > 0.5):
# citrus: 0.5652
# herbal: 0.5219
#
# Top odors for CC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.6057
# green: 0.5399
# floral: 0.5040
#
# Top odors for CCC(C)C1CC(C)C(CC)C1 (probability > 0.5):
# woody: 0.7007
# green: 0.6812
# floral: 0.6124
# herbal: 0.5893
# citrus: 0.5857
# fresh: 0.5700
#
# Top odors for CCCCC(C)N (probability > 0.5):
# cheesy: 0.6892
# fishy: 0.6821
#
# Top odors for CC1CCC=CCCCCC=CCCCCC1 (probability > 0.5):
# musk: 0.6817
# animal: 0.5227
# dry: 0.5110
#
# Top odors for CCC(C)CCCC(C)(C)C (probability > 0.5):
# woody: 0.6497
# floral: 0.6456
# green: 0.6300
# herbal: 0.5204
#
# Top odors for C=CC(=C)CCC (probability > 0.5):
# herbal: 0.6188
# fruity: 0.6158
# citrus: 0.5970
# woody: 0.5674
# floral: 0.5448
# sweet: 0.5053
# green: 0.5031
#
# Top odors for C=C(CCC)C(CC)CCC(C)C (probability > 0.5):
# floral: 0.7271
# woody: 0.6744
# waxy: 0.5040
#
# Top odors for C=C1CCC(=N)C(=C)C1 (probability > 0.5):
#
# Top odors for CC(C)C(C)CC(C)C(C)C (probability > 0.5):
# green: 0.7271
# floral: 0.7057
# woody: 0.6755
# herbal: 0.6322
# citrus: 0.5811
# fresh: 0.5631
#
# Top odors for CCCCC(CCCC)CC(C)C (probability > 0.5):
# waxy: 0.5978
#
# Top odors for CCC(C)C (probability > 0.5):
# ethereal: 0.6290
# musty: 0.5625
# fermented: 0.5411
#
# Top odors for C=C(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.7081
# woody: 0.6143
# waxy: 0.5300
#
# Top odors for C=CC(C)(C)CCC (probability > 0.5):
# floral: 0.7404
# citrus: 0.6453
# green: 0.6412
# herbal: 0.6117
# woody: 0.5809
# fresh: 0.5487
#
# Top odors for C=C(CCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.6196
# woody: 0.5180
#
# Top odors for C=C=C(CC)CCC (probability > 0.5):
# citrus: 0.6062
# green: 0.5831
# herbal: 0.5825
# floral: 0.5383
# sweet: 0.5361
# fruity: 0.5278
# fresh: 0.5028
#
# Top odors for CCCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6281
#
# Top odors for CC(C)CC1CC(C)C(C)C1 (probability > 0.5):
# green: 0.7067
# woody: 0.7005
# herbal: 0.6648
# floral: 0.6188
# fresh: 0.5806
# citrus: 0.5465
#
# Top odors for C=C(CCCC(C)C)C(C)CCC (probability > 0.5):
# floral: 0.6949
# woody: 0.6689
# waxy: 0.5026
#
# Top odors for C=C1C=CC(CCCC)C1 (probability > 0.5):
# woody: 0.5988
# citrus: 0.5514
#
# Top odors for C=CCCCCCC(=C)CCC (probability > 0.5):
# waxy: 0.5994
#
# Top odors for CCCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.5887
#
# Top odors for C=CCCCCC(C)C (probability > 0.5):
# citrus: 0.5536
#
# Top odors for CCCCCCCCC=CCCCCCCCC(C)CC=N (probability > 0.5):
# waxy: 0.6136
# fatty: 0.5461
#
# Top odors for CCCCCCCCCCCC=N (probability > 0.5):
# citrus: 0.6977
# fatty: 0.6446
# waxy: 0.6345
#
# Top odors for CCCCCC(C)CCC(C)CCCCC (probability > 0.5):
# waxy: 0.6442
#
# Top odors for C=CC(CC)CCCCC=CCC (probability > 0.5):
# waxy: 0.5106
#
# Top odors for NC1CCCC1 (probability > 0.5):
# fishy: 0.7467
#
# Top odors for C=C1CC(C)C(C)C1=N (probability > 0.5):
# woody: 0.5983
# mint: 0.5908
# herbal: 0.5465
# spicy: 0.5027
#
# Top odors for C=CCCCCCCCC (probability > 0.5):
# waxy: 0.5692
#
# Top odors for CCCCCCCCCC1C=C(C)CCC1 (probability > 0.5):
# waxy: 0.6505
#
# Top odors for C=CC(CC)CCCCCCC (probability > 0.5):
# waxy: 0.6133
#
# Top odors for CCC(C)CCCC(C)CC=N (probability > 0.5):
# citrus: 0.6616
# green: 0.6221
# floral: 0.6135
# waxy: 0.5236
# fresh: 0.5157
#
# Top odors for C=C1C=C(C(C)C)CCC1C (probability > 0.5):
# woody: 0.7980
# sweet: 0.5629
# herbal: 0.5567
# citrus: 0.5322
# fresh: 0.5215
#
# Top odors for C=CCC(C)(CC)CCCC (probability > 0.5):
# waxy: 0.5533
# woody: 0.5379
#
# Top odors for CCCCCC(CCCCC)CC(C)C (probability > 0.5):
# waxy: 0.6477
#
# Top odors for CCCCCCCC(C=N)CC (probability > 0.5):
# citrus: 0.6824
# waxy: 0.5897
# fatty: 0.5759
# green: 0.5429
# floral: 0.5237
# fruity: 0.5180
#
# Top odors for CCC(C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7214
# green: 0.7197
# woody: 0.6330
# herbal: 0.6081
# citrus: 0.5986
# fresh: 0.5672
#
# Top odors for CCCCCCCCCCC(C)CCCCCC (probability > 0.5):
# waxy: 0.7237
#
# Top odors for CCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.6171
#
# Top odors for C=CCC=CC (probability > 0.5):
# green: 0.6976
# gassy: 0.5216
#
# Top odors for C=CCCCCC(C)CCC (probability > 0.5):
# waxy: 0.5551
#
# Top odors for CC1=CCCC1C (probability > 0.5):
# woody: 0.7745
# citrus: 0.6039
# herbal: 0.5233
#
# Top odors for C=C(C)CCCC(C)CCCC(C)CC(=C)C (probability > 0.5):
# floral: 0.7260
# woody: 0.6723
# waxy: 0.5197
# balsamic: 0.5112
# sweet: 0.5078
#
# Top odors for CCCCCCCCC(C)C(C)C (probability > 0.5):
# waxy: 0.5925
#
# Top odors for CC1CCCCC=CCCCCCCCCC1 (probability > 0.5):
# musk: 0.7379
# animal: 0.5761
# amber: 0.5503
# dry: 0.5181
# sweet: 0.5090
#
# Top odors for CCCCCC(C=N)CC (probability > 0.5):
# green: 0.6560
# citrus: 0.6344
# fatty: 0.5787
# floral: 0.5322
# waxy: 0.5092
#
# Top odors for C=C(C)CC(C)CC (probability > 0.5):
# floral: 0.6917
# citrus: 0.6541
# herbal: 0.5878
# sweet: 0.5674
# fruity: 0.5521
# woody: 0.5498
# fresh: 0.5431
# rose: 0.5034
#
# Top odors for CC(C)CC1CCC(C)C1 (probability > 0.5):
# woody: 0.6653
# green: 0.6482
# floral: 0.6173
# herbal: 0.5629
# fresh: 0.5343
#
# Top odors for C=C1CCC(CCC)C1 (probability > 0.5):
# woody: 0.5706
# citrus: 0.5195
#
# Top odors for C=CCCCC(C)CCCC (probability > 0.5):
# waxy: 0.5493
#
# Top odors for CCC(C)(C)C(C)CC(C)C (probability > 0.5):
# woody: 0.7192
# green: 0.6483
# floral: 0.6203
# herbal: 0.5876
# fresh: 0.5247
#
# Top odors for CCCCCC1=CC=C=C=C1 (probability > 0.5):
# green: 0.6359
# citrus: 0.5778
# herbal: 0.5262
#
# Top odors for CCCCC(=N)C(C)CC (probability > 0.5):
# citrus: 0.6196
# green: 0.5967
# floral: 0.5665
# fresh: 0.5225
#
# Top odors for C=CCCC(C)(C)C (probability > 0.5):
# citrus: 0.6614
# floral: 0.6359
# green: 0.6087
# herbal: 0.6075
# fruity: 0.5784
# fresh: 0.5603
# sweet: 0.5154
#
# Top odors for CCCCCC(C)CCC(C)CC (probability > 0.5):
# waxy: 0.6014
#
# Top odors for CCCC(C)(C)CCC(C)(C)CCC (probability > 0.5):
# woody: 0.7209
# green: 0.5960
# floral: 0.5558
#
# Top odors for CCCCCC1C=CCC(CCCCC)C1 (probability > 0.5):
# waxy: 0.5699
#
# Top odors for C=CCCC(=N)CC(C)(CC)CCCC(C)C (probability > 0.5):
# floral: 0.6891
# woody: 0.5209
# green: 0.5067
#
# Top odors for C=CCC(CCC)CCCCCCCCCCC (probability > 0.5):
# waxy: 0.7072
# fatty: 0.5226
#
# Top odors for CC(C)C1CCC(C)C(C)C1 (probability > 0.5):
# woody: 0.7442
# green: 0.6987
# herbal: 0.6759
# fresh: 0.5956
# floral: 0.5956
# citrus: 0.5493
#
# Top odors for C=C=CCCC(C)C (probability > 0.5):
# green: 0.7525
# fruity: 0.5202
# sweet: 0.5196
# fresh: 0.5033
#
# Top odors for C=C=CC=CCC (probability > 0.5):
# green: 0.7853
# sweet: 0.5090
#
# Top odors for CC1C=CC=C1 (probability > 0.5):
#
# Top odors for C=C=CCCCCCCC (probability > 0.5):
# green: 0.6112
# citrus: 0.5527
#
# Top odors for CCCCCCCCCCC(CC)CC (probability > 0.5):
# waxy: 0.7370
#
# Top odors for CCCCCCCC1CCCC1C (probability > 0.5):
# waxy: 0.6481
#
# Top odors for C=CC1=CC(=C)CC1 (probability > 0.5):
# woody: 0.7519
# fruity: 0.5747
# citrus: 0.5629
# sweet: 0.5434
#
# Top odors for C=CC(C)(CCC)CCCC(C)C (probability > 0.5):
# floral: 0.7299
# woody: 0.6438
# green: 0.5321
# waxy: 0.5104
#
# Top odors for CCC(C)CCC(C)CC (probability > 0.5):
# floral: 0.6337
# green: 0.5534
# citrus: 0.5048
# woody: 0.5029
#
# Top odors for C=C(CCCCCC)CCC(C)C (probability > 0.5):
# waxy: 0.6349
# woody: 0.5084
#
# Top odors for C=CCCC=N (probability > 0.5):
# green: 0.8503
# pungent: 0.6315
# fatty: 0.5687
# vegetable: 0.5367
# radish: 0.5201
#
# Top odors for CC(C)CCCC(CCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.7185
# woody: 0.6129
# green: 0.6122
#
# Top odors for CC(C)CCCC(CCCC(C)C)C(C)C (probability > 0.5):
# floral: 0.7377
# green: 0.6335
# woody: 0.6138
#
# Top odors for C=C(CCCC)CCCCCCCCC (probability > 0.5):
# waxy: 0.7162
#
# Top odors for C=C(CCC)CC(C)C(C)C (probability > 0.5):
# floral: 0.7521
# woody: 0.6559
# citrus: 0.5157
# herbal: 0.5131
# sweet: 0.5110
# fruity: 0.5006
#
# Top odors for CCCCC=CCCCCCCC (probability > 0.5):
# waxy: 0.5739
#
# Top odors for C=C(CCC)CCC (probability > 0.5):
# waxy: 0.5398
#
# Top odors for CCCCC1=CCC(CN)CC1 (probability > 0.5):
# floral: 0.5120
#
# Top odors for CCCC(C)C(C)C(C)C (probability > 0.5):
# green: 0.7309
# floral: 0.7301
# woody: 0.6247
# herbal: 0.6117
# citrus: 0.5968
# fresh: 0.5671
#
# Top odors for CCCCCC1=CCCC1 (probability > 0.5):
# waxy: 0.5632
#
# Top odors for C=CC(C)C(C)CCCC (probability > 0.5):
# floral: 0.7466
# citrus: 0.5991
# fruity: 0.5407
# woody: 0.5293
# fresh: 0.5237
# green: 0.5148
# waxy: 0.5110
# herbal: 0.5086
# sweet: 0.5062
#
# Top odors for CCCC(CC)CCC=N (probability > 0.5):
# citrus: 0.6886
# green: 0.6770
# fatty: 0.6067
# waxy: 0.5443
# fresh: 0.5149
# floral: 0.5112
#
# Top odors for CCC(C)C(C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7521
# green: 0.7130
# woody: 0.6370
# herbal: 0.5752
# citrus: 0.5740
# fresh: 0.5710
# muguet: 0.5011
#
# Top odors for CCCC(CCCC(C)C)C(C)C (probability > 0.5):
# floral: 0.7337
# green: 0.6294
# woody: 0.5901
#
# Top odors for CC1CC(N)CC(C(C)C)C1 (probability > 0.5):
# mint: 0.6146
# cooling: 0.5055
#
# Top odors for C=CC(CCC)CC(C)C (probability > 0.5):
# floral: 0.7329
# citrus: 0.5648
# woody: 0.5522
# fruity: 0.5494
# waxy: 0.5149
#
# Top odors for C=CCCC(CC=C)CCCCC (probability > 0.5):
# waxy: 0.5777
# fatty: 0.5375
#
# Top odors for C=C(C)CCCC(C)CC(C)(C)C (probability > 0.5):
# floral: 0.7635
# woody: 0.6917
# green: 0.5548
# herbal: 0.5489
# sweet: 0.5019
#
# Top odors for CCCC=N (probability > 0.5):
# green: 0.8600
# pungent: 0.6300
# vegetable: 0.5798
# radish: 0.5124
# fruity: 0.5009
#
# Top odors for CCCC(CC)CC(C)CC (probability > 0.5):
# floral: 0.5998
# waxy: 0.5776
# green: 0.5004
#
# Top odors for CCCC(C)C(C)(C)CC (probability > 0.5):
# woody: 0.6754
# green: 0.6238
# floral: 0.5804
# herbal: 0.5581
# fresh: 0.5142
#
# Top odors for CCCC(CCC(C)C)C(C)C (probability > 0.5):
# floral: 0.7593
# green: 0.6695
# woody: 0.5960
# fresh: 0.5294
# citrus: 0.5195
# herbal: 0.5027
#
# Top odors for C=CC(CC)CCCCCC (probability > 0.5):
# waxy: 0.5851
#
# Top odors for CCCCC(CC)CCC (probability > 0.5):
# waxy: 0.6056
#
# Top odors for CCCCCCCCCC(C)C(C)CC (probability > 0.5):
# waxy: 0.6555
#
# Top odors for C=C(CCCCC)CC(C)CCC(C)CCCCC (probability > 0.5):
# waxy: 0.6335
# woody: 0.5673
#
# Top odors for CCCCCCCCC(C)CCCCCCCC (probability > 0.5):
# waxy: 0.7223
#
# Top odors for C=C(C)CC(C)(CC)CCCC(C)C (probability > 0.5):
# floral: 0.7458
# woody: 0.7066
# green: 0.5212
# sweet: 0.5010
# herbal: 0.5007
#
# Top odors for C=CCC(CC)C(C)C=C (probability > 0.5):
# floral: 0.7303
# citrus: 0.6338
# fruity: 0.5548
# waxy: 0.5354
# sweet: 0.5264
# fresh: 0.5189
# woody: 0.5153
#
# Top odors for C=C(C=CCCCCC)CCCCC (probability > 0.5):
# waxy: 0.5428
#
# Top odors for CC=CCCCC (probability > 0.5):
# green: 0.5823
# gassy: 0.5606
#
# Top odors for CCCCCCCCC(C=N)CC (probability > 0.5):
# citrus: 0.6763
# waxy: 0.5994
# fatty: 0.5813
# fruity: 0.5118
# green: 0.5082
#
# Top odors for C=C=CCCCCCCCCCC (probability > 0.5):
# citrus: 0.5677
#
# Top odors for C=C(C=N)C(C)C (probability > 0.5):
# green: 0.6277
# spicy: 0.5175
# pungent: 0.5152
#
# Top odors for CCCCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.6239
#
# Top odors for CCCCC(C)C(C)CC(C)(C)CC (probability > 0.5):
# floral: 0.6896
# woody: 0.6819
# green: 0.6367
# herbal: 0.5165
#
# Top odors for CCC(C)C1CC(C(C)C)CCC1C (probability > 0.5):
# woody: 0.7184
# green: 0.7048
# floral: 0.6412
# herbal: 0.6069
# citrus: 0.5777
# fresh: 0.5662
#
# Top odors for C=C(C=N)CC=CCCCCCC (probability > 0.5):
# citrus: 0.6550
# fatty: 0.5783
# green: 0.5212
#
# Top odors for CC1CCCCC1C (probability > 0.5):
# woody: 0.7167
# amber: 0.5543
# musk: 0.5162
#
# Top odors for C=C(C)CCCC(C)CCCCN (probability > 0.5):
# floral: 0.5222
#
# Top odors for CC(C)C1CC2CCC1C2 (probability > 0.5):
# woody: 0.7645
# green: 0.6425
# herbal: 0.5975
# floral: 0.5743
# pine: 0.5249
# fresh: 0.5224
#
# Top odors for CCC=CC(C)C(CC)CC (probability > 0.5):
# floral: 0.7993
# citrus: 0.6008
# fresh: 0.5548
# fruity: 0.5543
# waxy: 0.5480
# rose: 0.5456
# green: 0.5425
# sweet: 0.5198
#
# Top odors for CCCCC1CCCC1 (probability > 0.5):
# waxy: 0.5167
#
# Top odors for CC(C)CCC(C(C)C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7329
# green: 0.6980
# woody: 0.6531
# herbal: 0.5628
# fresh: 0.5341
# citrus: 0.5037
#
# Top odors for C=CCCCC(=C)CCCCCCCCC (probability > 0.5):
# waxy: 0.6670
# fatty: 0.5129
#
# Top odors for C=CCC(C=C)CCC (probability > 0.5):
# citrus: 0.5865
#
# Top odors for C=CCC(CC)CCCC (probability > 0.5):
# waxy: 0.6149
# citrus: 0.5728
# fatty: 0.5216
# fruity: 0.5148
#
# Top odors for C=C(CCCC)CCCCCCC (probability > 0.5):
# waxy: 0.6961
#
# Top odors for CCCCC(CCC(C)C)CCC(C)C (probability > 0.5):
# floral: 0.6097
# woody: 0.5594
# waxy: 0.5450
# green: 0.5332
#
# Top odors for CC(C)C(C)(C)C (probability > 0.5):
# camphoreous: 0.6528
# fresh: 0.5782
# green: 0.5699
# mint: 0.5540
# woody: 0.5403
# herbal: 0.5314
# earthy: 0.5146
#
# Top odors for CC1CCC(C(C)C)C(C)C1 (probability > 0.5):
# woody: 0.7354
# green: 0.7100
# herbal: 0.7024
# floral: 0.6195
# fresh: 0.5976
# citrus: 0.5519
# pine: 0.5005
#
# Top odors for CCCCCCCC(C)C1C=C1 (probability > 0.5):
# woody: 0.5482
# waxy: 0.5372
# oily: 0.5064
#
# Top odors for CCCCCCCCCCC(C)C(C)C (probability > 0.5):
# waxy: 0.6531
#
# Top odors for C=CCCCCCCCC(=C)C (probability > 0.5):
# waxy: 0.5482
#
# Top odors for C=CCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.6703
#
# Top odors for CCCCCCC(C)CCCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.7238
#
# Top odors for C=C=CCCC(C)CC(C)(C)C (probability > 0.5):
# floral: 0.7547
# citrus: 0.6549
# herbal: 0.5816
# sweet: 0.5777
# green: 0.5772
# fresh: 0.5531
# woody: 0.5170
#
# Top odors for C=C(C)CC1CCCC1 (probability > 0.5):
# woody: 0.7298
# citrus: 0.5656
# sweet: 0.5251
#
# Top odors for CC1CC=CCCCCCCCCCC=CCC1 (probability > 0.5):
# musk: 0.6988
# animal: 0.5422
# dry: 0.5146
#
# Top odors for C=CCCC(CC)CCCC (probability > 0.5):
# waxy: 0.6062
#
# Top odors for C=CCC(=C)CCCCC (probability > 0.5):
# waxy: 0.5526
# fatty: 0.5132
#
# Top odors for C=CCCCC(C)CCCC(C)CCC (probability > 0.5):
# waxy: 0.5973
#
# Top odors for C=CCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5836
#
# Top odors for CCC(CC=N)CCCC(C)C (probability > 0.5):
# citrus: 0.6868
# green: 0.6343
# floral: 0.6270
# fresh: 0.5506
# waxy: 0.5324
#
# Top odors for CCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.6332
#
# Top odors for C=CC(C)(C)CCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.7242
# woody: 0.6345
# green: 0.5740
# waxy: 0.5190
#
# Top odors for C=CCCCCCCCC(C)CCCCCCCCC (probability > 0.5):
# waxy: 0.7043
#
# Top odors for C=CCC(=C)CCCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7028
# fatty: 0.5246
#
# Top odors for CC1C=C(CC(C)CCCC(C)(C)C)CC1 (probability > 0.5):
# woody: 0.7575
# floral: 0.6533
# green: 0.5484
#
# Top odors for CC(C)C1C=CC(C)C(C)C1 (probability > 0.5):
# green: 0.7695
# herbal: 0.7662
# woody: 0.6861
# fresh: 0.6415
# citrus: 0.6205
# floral: 0.5901
# mint: 0.5043
#
# Top odors for CCCCCC1CCC(C)CC1 (probability > 0.5):
# waxy: 0.5345
#
# Top odors for CCC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.5054
#
# Top odors for CCCCC(CC)C(C)C (probability > 0.5):
# floral: 0.7110
# green: 0.6194
# fresh: 0.5277
# citrus: 0.5229
# fruity: 0.5105
# woody: 0.5092
#
# Top odors for CCCC(CCC)CCCCCC(C)C (probability > 0.5):
# waxy: 0.6500
#
# Top odors for CC(C)CCCCCCCCCCCC(CCCCCCCCCCCC(C)C)CC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6986
#
# Top odors for C=CCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.6619
#
# Top odors for CCCCCCCC(CCC)CCCCC (probability > 0.5):
# waxy: 0.7181
#
# Top odors for CCCCC1CCC(C)C1 (probability > 0.5):
#
# Top odors for C=C(C)C(C)CC(C)C (probability > 0.5):
# herbal: 0.6591
# citrus: 0.6565
# floral: 0.6465
# woody: 0.6283
# fresh: 0.5741
# green: 0.5305
# sweet: 0.5106
#
# Top odors for C=C=CCCCCCCC=CC (probability > 0.5):
# green: 0.5621
# citrus: 0.5564
#
# Top odors for CC(C)CCCC(C)(C)C (probability > 0.5):
# green: 0.6718
# woody: 0.6675
# floral: 0.5980
# herbal: 0.5872
# fresh: 0.5275
#
# Top odors for CC(C)CCCC(C)CC(C)CC(C)C (probability > 0.5):
# floral: 0.7418
# green: 0.6531
# woody: 0.6004
#
# Top odors for CC(C)C1CCCC1 (probability > 0.5):
# woody: 0.6903
# green: 0.6132
# floral: 0.5685
# herbal: 0.5080
#
# Top odors for C=C(CCC)CCCCCCCCCCC (probability > 0.5):
# waxy: 0.7203
#
# Top odors for CCCC(CCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.6978
# green: 0.6035
# woody: 0.5829
#
# Top odors for CCCCCCCCN (probability > 0.5):
# fishy: 0.5899
# cheesy: 0.5785
# fatty: 0.5519
#
# Top odors for CCC(CCC(C)C)CCC(C)C (probability > 0.5):
# floral: 0.7123
# green: 0.6106
# woody: 0.5878
#
# Top odors for CCC1CCC(CC)C1 (probability > 0.5):
# woody: 0.6665
# floral: 0.5177
#
# Top odors for CCCCCC(=N)CCC (probability > 0.5):
# citrus: 0.6484
# fatty: 0.5556
#
# Top odors for CCC(=N)CCC1CCCC1 (probability > 0.5):
# citrus: 0.5903
# green: 0.5151
#
# Top odors for C=CC=CCC(C)(C)C (probability > 0.5):
# floral: 0.6150
# herbal: 0.6086
# citrus: 0.6058
# fruity: 0.6022
# green: 0.5779
# sweet: 0.5674
# fresh: 0.5425
#
# Top odors for CCC(C)CC(C)CC (probability > 0.5):
# floral: 0.6934
# green: 0.6144
# citrus: 0.5794
# fresh: 0.5442
# herbal: 0.5054
#
# Top odors for CC(C)(C)CCCN (probability > 0.5):
#
# Top odors for CCC(C)CC(C)C=N (probability > 0.5):
# green: 0.7630
# floral: 0.5386
# citrus: 0.5062
# sweet: 0.5005
#
# Top odors for CCCC (probability > 0.5):
# sweet: 0.6530
# ethereal: 0.5686
# musty: 0.5133
#
# Top odors for CC(C)CCCC=N (probability > 0.5):
# green: 0.8512
# fatty: 0.5859
# fruity: 0.5102
#
# Top odors for CCCC(CCC)C(C)C (probability > 0.5):
# floral: 0.7146
# green: 0.6151
# woody: 0.5392
# citrus: 0.5317
# fresh: 0.5146
#
# Top odors for CCCC(CCC)CCCCC(C)C (probability > 0.5):
# waxy: 0.6284
#
# Top odors for C=C(CCCC)CCCC(C)CC (probability > 0.5):
# waxy: 0.6548
# woody: 0.5137
#
# Top odors for C=CC(C)C (probability > 0.5):
# green: 0.8070
# fruity: 0.6385
# fresh: 0.5259
#
# Top odors for C=CC(C)CCCCCCCCCCCC (probability > 0.5):
# waxy: 0.6719
#
# Top odors for C=C=C=C=CC (probability > 0.5):
# pungent: 0.7189
# sweet: 0.5722
# ethereal: 0.5207
#
# Top odors for C=C(C)CC1CC=CCCCCCCCC1 (probability > 0.5):
# citrus: 0.6108
# woody: 0.5261
#
# Top odors for C=C(CCC)CC(C)CCCCC (probability > 0.5):
# waxy: 0.6061
# woody: 0.5592
#
# Top odors for C=C(C)CCCCCCCC=CCCCCCCCC (probability > 0.5):
# waxy: 0.6434
#
# Top odors for CC(N)CCCC=N (probability > 0.5):
# fishy: 0.5352
#
# Top odors for C=CC1C2C=CC(=C2)C1CCC (probability > 0.5):
# fruity: 0.7260
# woody: 0.5918
# herbal: 0.5790
# green: 0.5361
#
# Top odors for CCCCCCC=N (probability > 0.5):
# green: 0.7905
# fatty: 0.6797
# citrus: 0.5539
#
# Top odors for C=CCC(CCC)CCCCCCCC (probability > 0.5):
# waxy: 0.6763
# fatty: 0.5209
#
# Top odors for C=C(C)CC(CC)CCC (probability > 0.5):
# floral: 0.7212
# woody: 0.6020
# citrus: 0.5539
# waxy: 0.5479
# sweet: 0.5449
#
# Top odors for C=C(C=CC)CCCCC (probability > 0.5):
# woody: 0.5991
# citrus: 0.5372
# herbal: 0.5227
# floral: 0.5069
#
# Top odors for C=C(C)C(C)CC (probability > 0.5):
# citrus: 0.6715
# herbal: 0.6646
# fresh: 0.5916
# floral: 0.5869
# woody: 0.5554
# fruity: 0.5470
# sweet: 0.5355
# green: 0.5322
# lemon: 0.5115
#
# Top odors for CCCCCCC=CCN (probability > 0.5):
# fatty: 0.6356
# citrus: 0.5579
#
# Top odors for CC(CCN)CCCC(C)(C)C (probability > 0.5):
# woody: 0.5898
# floral: 0.5380
#
# Top odors for CCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.6344
#
# Top odors for C=C1CCCC(C)C1=C (probability > 0.5):
# woody: 0.8248
# sweet: 0.5577
#
# Top odors for C=C=CCCCCCCCCC(C)CC (probability > 0.5):
# citrus: 0.5708
#
# Top odors for CCCCC=CC(C)CCCCC (probability > 0.5):
# waxy: 0.5358
#
# Top odors for CCCCCC(C)CC(C)CC (probability > 0.5):
# waxy: 0.5765
#
# Top odors for CC(=N)CCCCCCC(C)C (probability > 0.5):
# citrus: 0.6674
# floral: 0.6453
# waxy: 0.5654
# fruity: 0.5332
# fresh: 0.5194
# green: 0.5156
#
# Top odors for C=CCCCCCCCCCCC(=C)C (probability > 0.5):
# waxy: 0.6212
#
# Top odors for CCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6021
# waxy: 0.5522
# green: 0.5408
# woody: 0.5373
#
# Top odors for CCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7216
#
# Top odors for C=CC(C)(C)C(=C)CCC (probability > 0.5):
# floral: 0.7353
# woody: 0.7156
# herbal: 0.6117
# sweet: 0.5602
# citrus: 0.5489
#
# Top odors for C=CCC(C)(C)C=C (probability > 0.5):
# floral: 0.7288
# citrus: 0.6134
# herbal: 0.6077
# sweet: 0.5773
# woody: 0.5697
# green: 0.5234
# fresh: 0.5115
#
# Top odors for CCC1(C)CCC(CCCC(C)C)CC1 (probability > 0.5):
# woody: 0.6263
#
# Top odors for CCCCCCCCC=CCCCCCCCCC (probability > 0.5):
# waxy: 0.6877
#
# Top odors for C=C(CCC)CCC1C=CCCC1 (probability > 0.5):
# woody: 0.6023
# waxy: 0.5717
#
# Top odors for C=C1CCCC(CC)C1 (probability > 0.5):
# woody: 0.6043
# citrus: 0.5401
#
# Top odors for CCCCCCCC(=N)C(C)(C)C (probability > 0.5):
# green: 0.5827
# floral: 0.5556
#
# Top odors for CC1=CC(C(C)C)C=C1 (probability > 0.5):
# herbal: 0.7539
# green: 0.6897
# woody: 0.6545
# fresh: 0.6461
# citrus: 0.6418
# mint: 0.5346
# spicy: 0.5045
#
# Top odors for CC1C=CCCCCCCCCCCCCC1 (probability > 0.5):
# musk: 0.7129
# animal: 0.5645
# amber: 0.5313
# dry: 0.5176
#
# Top odors for CCCCCCCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.7344
#
# Top odors for CCCCC(C)(C)CC (probability > 0.5):
# green: 0.5725
# woody: 0.5240
#
# Top odors for C=C1CC(C)C(C)C1=C (probability > 0.5):
# woody: 0.8050
# sweet: 0.5466
# fruity: 0.5109
#
# Top odors for C=CCCCCCC(=C)C(C)C (probability > 0.5):
# woody: 0.5837
# waxy: 0.5327
# floral: 0.5305
#
# Top odors for CCC(C)(C)C (probability > 0.5):
# camphoreous: 0.6152
# fresh: 0.5788
# green: 0.5240
# ethereal: 0.5229
# mint: 0.5101
#
# Top odors for C=C(CCCCC)CCCCCCC (probability > 0.5):
# waxy: 0.7047
#
# Top odors for CCCCCC(CC)CC(C)C (probability > 0.5):
# waxy: 0.5786
#
# Top odors for CCCCCCCCCCC(C)CCCCCCC (probability > 0.5):
# waxy: 0.7313
#
# Top odors for CCC=CCC(CCC)CCC (probability > 0.5):
# waxy: 0.5504
#
# Top odors for CCCCCC(C)C(C)C(C)C (probability > 0.5):
# floral: 0.7439
# green: 0.6643
# woody: 0.5799
# fresh: 0.5366
# citrus: 0.5181
# herbal: 0.5059
#
# Top odors for CCCCCCCCCC(C)CCCCCCCC (probability > 0.5):
# waxy: 0.7312
#
# Top odors for C=C(C)C=CC(C)CC (probability > 0.5):
# floral: 0.6990
# citrus: 0.6540
# herbal: 0.6253
# sweet: 0.6037
# woody: 0.5597
# fresh: 0.5552
# lemon: 0.5022
#
# Top odors for C=CCC(C)C(C)(C)CC (probability > 0.5):
# floral: 0.7276
# citrus: 0.6360
# woody: 0.6120
# herbal: 0.5882
# green: 0.5575
# fresh: 0.5441
# sweet: 0.5233
#
# Top odors for CCCC=CCCCCCN (probability > 0.5):
# fatty: 0.6835
# citrus: 0.5573
# meaty: 0.5502
#
# Top odors for C=C1CCCCCCCCCCC(C)CCCC1 (probability > 0.5):
# musk: 0.7437
# animal: 0.5652
# amber: 0.5415
# dry: 0.5297
# sweet: 0.5019
# woody: 0.5011
#
# Top odors for CCCC(CC)CN (probability > 0.5):
# cheesy: 0.5948
# fishy: 0.5932
#
# Top odors for CCCCCC(=N)CC(C)C (probability > 0.5):
# citrus: 0.6199
# floral: 0.5420
# green: 0.5414
# fresh: 0.5110
#
# Top odors for C=CC(C)CCCC(C)(C)CC (probability > 0.5):
# floral: 0.7150
# woody: 0.6262
# herbal: 0.5406
# green: 0.5256
#
# Top odors for CCCCCCCCCCC(C=N)CC (probability > 0.5):
# citrus: 0.6283
# waxy: 0.6119
# fatty: 0.5973
#
# Top odors for C=C(CCCC1CCCCC1)C(C)C (probability > 0.5):
# woody: 0.7011
# waxy: 0.5572
# floral: 0.5408
#
# Top odors for CCC(C)(CC)C(C)C (probability > 0.5):
# woody: 0.6549
# green: 0.6283
# herbal: 0.5968
# fresh: 0.5322
# camphoreous: 0.5315
# floral: 0.5265
#
# Top odors for CCCC(C)CCCC(C)CCC (probability > 0.5):
# waxy: 0.5805
#
# Top odors for CC1CCCCCC=CC=CCCCCCC1 (probability > 0.5):
# musk: 0.7103
# animal: 0.5471
# dry: 0.5147
#
# Top odors for CC(C)C=N (probability > 0.5):
# green: 0.8460
# ethereal: 0.6399
# pungent: 0.6258
# fruity: 0.5253
#
# Top odors for C=C(CCC)C(CCCCCCCCCC)C(C)C (probability > 0.5):
# waxy: 0.6083
# woody: 0.5886
#
# Top odors for CCCCCCCCCC(C)C(C)C (probability > 0.5):
# waxy: 0.6281
#
# Top odors for CC(C)C(C)CCCC1CCCCC1 (probability > 0.5):
# woody: 0.5802
# green: 0.5329
# floral: 0.5309
#
# Top odors for C=C(CCCCCCCCC)CCC(C)C (probability > 0.5):
# waxy: 0.6850
#
# Top odors for CCCCCC (probability > 0.5):
# sweet: 0.6706
#
# Top odors for CC1CCCCCC1 (probability > 0.5):
# musk: 0.6989
# woody: 0.6364
# amber: 0.6060
# sweet: 0.5382
# animal: 0.5205
# dry: 0.5120
#
# Top odors for C=C(CCCC)CCCCCC (probability > 0.5):
# waxy: 0.6821
#
# Top odors for C=C(C)CCCC(CCC)CC(C)C (probability > 0.5):
# floral: 0.7196
# woody: 0.6210
# waxy: 0.5579
#
# Top odors for CCCCCCCC(CCCC)CCCCCCC (probability > 0.5):
# waxy: 0.7442
#
# Top odors for C=CCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.6836
#
# Top odors for CCCCC(CC)C(C)CCC (probability > 0.5):
# floral: 0.6343
# waxy: 0.5650
# green: 0.5353
# woody: 0.5208
#
# Top odors for CCCCC(CC)C1C=CCC1 (probability > 0.5):
# waxy: 0.5592
# woody: 0.5485
#
# Top odors for CCCCC1=CCCCC(C)=C1 (probability > 0.5):
# woody: 0.6853
# citrus: 0.5430
#
# Top odors for CCCC1C=CCC1 (probability > 0.5):
# citrus: 0.6228
#
# Top odors for C=CCC(C)C(C)C(=C)C (probability > 0.5):
# floral: 0.6970
# citrus: 0.6495
# woody: 0.6097
# herbal: 0.5866
# sweet: 0.5738
# fresh: 0.5551
# fruity: 0.5451
#
# Top odors for CC1CCCC(CC=N)C1 (probability > 0.5):
# green: 0.7733
# citrus: 0.5062
#
# Top odors for NCCCCCC1CCCC1 (probability > 0.5):
# meaty: 0.5116
#
# Top odors for C=CCC=C (probability > 0.5):
# green: 0.6803
# gassy: 0.5165
#
# Top odors for CCC1CCCC1 (probability > 0.5):
# woody: 0.6407
#
# Top odors for C=C(CCC)CC(C)C(=C)CCCCC (probability > 0.5):
# woody: 0.7050
# floral: 0.5935
# waxy: 0.5520
#
# Top odors for C=C=CCCC (probability > 0.5):
# green: 0.7979
#
# Top odors for C=C(CCCC)CCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6793
# fatty: 0.5140
#
# Top odors for C=CCCC(C)CCCC (probability > 0.5):
# citrus: 0.5176
# waxy: 0.5142
#
# Top odors for CCCCCCCCCCCCCCCCN (probability > 0.5):
# fatty: 0.6509
# waxy: 0.6173
#
# Top odors for C=C(C)C(=C)CCCCC (probability > 0.5):
# woody: 0.6930
# floral: 0.6860
# fruity: 0.5831
# sweet: 0.5380
#
# Top odors for C=CC(C)CCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7032
#
# Top odors for C=CCCCCCC1CCCC(=C)C1 (probability > 0.5):
# waxy: 0.5842
#
# Top odors for C=C(CCCCC)C(C)C (probability > 0.5):
# floral: 0.6509
# woody: 0.6035
# fruity: 0.5357
# herbal: 0.5237
# sweet: 0.5217
# citrus: 0.5213
#
# Top odors for C=C(CCC)CCCCCC (probability > 0.5):
# waxy: 0.6565
#
# Top odors for C=C1C=CCC(C)C1=C (probability > 0.5):
# woody: 0.7717
# fruity: 0.5280
# citrus: 0.5275
# sweet: 0.5164
#
# Top odors for CCCCC1=CCC(C(C)C)CC1 (probability > 0.5):
# woody: 0.6482
# floral: 0.5072
# green: 0.5042
#
# Top odors for CCC(C)CCCC(C)(C)CC (probability > 0.5):
# woody: 0.6237
# floral: 0.5725
# green: 0.5724
#
# Top odors for CCCCCCCCC(C)C(C)CC (probability > 0.5):
# waxy: 0.6303
#
# Top odors for CCCCC(C)CC (probability > 0.5):
# green: 0.5101
# sweet: 0.5094
#
# Top odors for C=C1CCCC(C)C1 (probability > 0.5):
# woody: 0.6048
# musk: 0.5173
#
# Top odors for C=CCC(C)C(C)C(C)C (probability > 0.5):
# floral: 0.7484
# citrus: 0.6723
# fresh: 0.6204
# green: 0.6102
# herbal: 0.5616
# fruity: 0.5248
# rose: 0.5201
# woody: 0.5074
#
# Top odors for C=C(CCCCCC)CCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7486
#
# Top odors for C=CC1CCC(CC)C1 (probability > 0.5):
# citrus: 0.6534
# green: 0.5017
#
# Top odors for CCCC(C)CCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5803
# woody: 0.5595
# floral: 0.5564
# green: 0.5148
#
# Top odors for C=C(CC)CC(C)C (probability > 0.5):
# floral: 0.6451
# citrus: 0.6320
# herbal: 0.6161
# fruity: 0.5950
# fresh: 0.5447
# sweet: 0.5411
# woody: 0.5281
#
# Top odors for C=CCC(=C)CCCC (probability > 0.5):
# waxy: 0.5242
# fruity: 0.5075
#
# Top odors for C=C1C=C(CC)C(=C)C1=C (probability > 0.5):
# woody: 0.6889
# fruity: 0.6432
#
# Top odors for C=C(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5838
# woody: 0.5141
#
# Top odors for CCCCCCC1CCC(C)C1 (probability > 0.5):
# waxy: 0.6109
#
# Top odors for CCCCCCCCCCCC(C)CCCCCC (probability > 0.5):
# waxy: 0.7325
#
# Top odors for CC1CC(C)CC(C)C1 (probability > 0.5):
# woody: 0.7522
# herbal: 0.5749
# camphoreous: 0.5166
# floral: 0.5053
#
# Top odors for CCCCC(CC)CCC(C)CC (probability > 0.5):
# waxy: 0.6292
#
# Top odors for C=C(CCC=N)C(C)C (probability > 0.5):
# green: 0.6682
# citrus: 0.6113
# fresh: 0.5204
# floral: 0.5131
#
# Top odors for CCCCC=CCC(=N)C(C)C (probability > 0.5):
# citrus: 0.6244
# floral: 0.5963
# green: 0.5724
# fruity: 0.5449
# fresh: 0.5081
#
# Top odors for C=C(CCCCCCCCCCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.7165
#
# Top odors for C=CCC(C)C(C)C (probability > 0.5):
# floral: 0.6568
# citrus: 0.6411
# green: 0.6133
# fruity: 0.6077
# fresh: 0.6044
# herbal: 0.5831
# sweet: 0.5022
#
# Top odors for C=C(CCC)C1=CCCCC1 (probability > 0.5):
# woody: 0.7751
# waxy: 0.5041
# sweet: 0.5010
#
# Top odors for C=C1CC(C(C)CC)CC1C (probability > 0.5):
# woody: 0.7581
# herbal: 0.5514
# citrus: 0.5430
# green: 0.5388
# fresh: 0.5247
#
# Top odors for CCCCCCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.6931
#
# Top odors for C=CC(C)CCCCCC (probability > 0.5):
# waxy: 0.5127
#
# Top odors for CCCC=CCCCCCCCCC (probability > 0.5):
# waxy: 0.6052
#
# Top odors for CCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5257
# green: 0.5113
# floral: 0.5049
#
# Top odors for C=C(C)CCC(CCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.6076
# woody: 0.5722
# floral: 0.5515
#
# Top odors for CCCC=CCCC(C)C(CC)CC (probability > 0.5):
# floral: 0.6675
# waxy: 0.5617
# woody: 0.5223
#
# Top odors for CC1CCCCC1 (probability > 0.5):
# musk: 0.6843
# woody: 0.6497
# amber: 0.6054
# sweet: 0.5288
# dry: 0.5106
# animal: 0.5003
#
# Top odors for C=C(CC(C)C)CC(C)C (probability > 0.5):
# floral: 0.7247
# woody: 0.6421
# citrus: 0.6042
# herbal: 0.5864
# fruity: 0.5255
# fresh: 0.5240
# green: 0.5198
# sweet: 0.5054
#
# Top odors for CCC=CCCCCCCCC (probability > 0.5):
# waxy: 0.5481
#
# Top odors for C=C(CCCCC)CCCCCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7510
#
# Top odors for CCCCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6261
#
# Top odors for C=C1CCC=CCCCCCCC(C)CCCC1 (probability > 0.5):
# musk: 0.6937
# dry: 0.5246
# animal: 0.5167
#
# Top odors for C=C(CCC)CC(C)C(=C)C (probability > 0.5):
# woody: 0.7254
# floral: 0.7080
# sweet: 0.5594
# herbal: 0.5262
#
# Top odors for CCCC1CCCCCCCCCCC1 (probability > 0.5):
# sweet: 0.5118
# woody: 0.5109
#
# Top odors for CCCC(C)CCC(CC)CC (probability > 0.5):
# waxy: 0.5897
# floral: 0.5532
#
# Top odors for C=C(C(C)C)C(C)(C)CCC(C)C (probability > 0.5):
# woody: 0.7419
# floral: 0.6081
# herbal: 0.6063
# green: 0.5390
#
# Top odors for C=C=CCCCCCC=C (probability > 0.5):
# green: 0.6066
# citrus: 0.5445
# gassy: 0.5030
#
# Top odors for CCCCCCC(CCCCC)CCCCCC (probability > 0.5):
# waxy: 0.7341
#
# Top odors for CCCCCCC(C)C (probability > 0.5):
#
# Top odors for CCCCCCCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6962
#
# Top odors for C=C(CCCCC)CCC(C)CC(=C)CCCCC (probability > 0.5):
# waxy: 0.6308
# woody: 0.6111
#
# Top odors for CCCC(C)CC(C)C (probability > 0.5):
# floral: 0.6713
# green: 0.6692
# herbal: 0.5754
# citrus: 0.5473
# fresh: 0.5384
# woody: 0.5184
#
# Top odors for CCCC(C)(C)CCC (probability > 0.5):
# green: 0.6314
# woody: 0.6083
# floral: 0.5058
#
# Top odors for CCCCCCCCCC(C)CCCCCCC (probability > 0.5):
# waxy: 0.7224
#
# Top odors for C=C=CCC=N (probability > 0.5):
# pungent: 0.7888
# green: 0.7254
# radish: 0.6532
#
# Top odors for CC1CCC(C(C)C)C1 (probability > 0.5):
# woody: 0.7125
# green: 0.7102
# herbal: 0.6624
# floral: 0.6425
# fresh: 0.5878
# citrus: 0.5293
#
# Top odors for CCC(C)CC(C)C(C)CC (probability > 0.5):
# floral: 0.7665
# green: 0.6781
# woody: 0.6020
# citrus: 0.5694
# fresh: 0.5558
# herbal: 0.5177
#
# Top odors for C=CC(C)CCCCCCCCCC (probability > 0.5):
# waxy: 0.6377
#
# Top odors for CCC1CCCCCCCCCCC1 (probability > 0.5):
# musk: 0.6443
# woody: 0.6119
# amber: 0.5664
# sweet: 0.5315
#
# Top odors for C=C(C)CCCCCCCCCCC (probability > 0.5):
# waxy: 0.6719
#
# Top odors for C=C(CCC(C)C)C(C)CC (probability > 0.5):
# floral: 0.7271
# woody: 0.6850
# herbal: 0.5439
# citrus: 0.5246
# sweet: 0.5139
#
# Top odors for C=C(C)CC(CC)C(C)CCC (probability > 0.5):
# floral: 0.7834
# woody: 0.6302
# sweet: 0.5244
# green: 0.5244
# citrus: 0.5133
# waxy: 0.5063
#
# Top odors for C=CCC(=C)C(C)CC(C)CC (probability > 0.5):
# floral: 0.7333
# woody: 0.6643
# sweet: 0.5307
# waxy: 0.5113
# citrus: 0.5049
# fruity: 0.5001
#
# Top odors for C=C1CCCC(CCCCCCCC)C1 (probability > 0.5):
# waxy: 0.6715
#
# Top odors for CCCCCCCCCC (probability > 0.5):
# waxy: 0.6225
#
# Top odors for CCCCCC(C)CC1CCCCC1 (probability > 0.5):
# waxy: 0.6006
#
# Top odors for CCC(C)CCC(C)(C)CC (probability > 0.5):
# woody: 0.6580
# green: 0.6009
# floral: 0.5927
# herbal: 0.5037
#
# Top odors for CCCCCCCC (probability > 0.5):
# sweet: 0.5632
# waxy: 0.5006
#
# Top odors for CC(C)CC1CC=CC(C)C1 (probability > 0.5):
# green: 0.7055
# herbal: 0.6894
# floral: 0.6474
# citrus: 0.6307
# woody: 0.6228
# fresh: 0.6141
#
# Top odors for C=C(CCCCCCCC)C(C)C (probability > 0.5):
# waxy: 0.6019
# woody: 0.5205
#
# Top odors for C=C=CCC(C)CCCC(C)(C)CC (probability > 0.5):
# floral: 0.7425
# citrus: 0.6115
# herbal: 0.5529
# woody: 0.5515
# sweet: 0.5407
# green: 0.5342
#
# Top odors for C=C(CCC)C(CC)CC(C(=C)CC(C)C)C(C)C (probability > 0.5):
# woody: 0.7323
# floral: 0.6857
#
# Top odors for CC1C=CCCCCCCCC=CC=CCCC1 (probability > 0.5):
# musk: 0.5903
#
# Top odors for CCCCC(CCC)C(C)N (probability > 0.5):
# grapefruit: 0.5133
#
# Top odors for C=CC(C)CC(C)C (probability > 0.5):
# floral: 0.6797
# citrus: 0.6618
# fresh: 0.5985
# herbal: 0.5889
# green: 0.5868
# fruity: 0.5325
# lemon: 0.5120
#
# Top odors for C=C(CCCCCC)CC1CCCCC1 (probability > 0.5):
# waxy: 0.6737
# fatty: 0.5202
#
# Top odors for CCCC(C)CC1CCCC1 (probability > 0.5):
# waxy: 0.5063
#
# Top odors for C=C1CC(C)CC(CC)C1 (probability > 0.5):
# woody: 0.6844
# citrus: 0.5813
# herbal: 0.5680
# floral: 0.5235
# green: 0.5074
# fresh: 0.5064
#
# Top odors for C=CCC(CC=C)CCC (probability > 0.5):
# citrus: 0.6226
# fatty: 0.5980
# waxy: 0.5599
# fruity: 0.5073
#
# Top odors for C=C(CCCCC)CCCCCCCC (probability > 0.5):
# waxy: 0.7139
#
# Top odors for CCCCCC1=CC=CC1 (probability > 0.5):
# waxy: 0.5079
#
# Top odors for Cc1ccc(CC(C)(C)C)cc1 (probability > 0.5):
# floral: 0.8087
# green: 0.7328
# fresh: 0.5971
# woody: 0.5890
# herbal: 0.5569
#
# Top odors for C=C(CCCC)CCCC1CC=CCC1 (probability > 0.5):
# waxy: 0.6318
#
# Top odors for CCCCCC(C)CC(C)C (probability > 0.5):
# green: 0.5445
# floral: 0.5392
#
# Top odors for C=C(C)C(CCC(C)C)CCC(C)C (probability > 0.5):
# floral: 0.7729
# woody: 0.6719
# green: 0.5492
# citrus: 0.5033
# herbal: 0.5025
#
# Top odors for CC(C)CC(C)CCCC(C)(C)C (probability > 0.5):
# floral: 0.7196
# woody: 0.6785
# green: 0.6652
# herbal: 0.5292
# fresh: 0.5019
#
# Top odors for CCCCCCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.7249
#
# Top odors for C=CC(C)C(C)C(C)CC (probability > 0.5):
# floral: 0.7613
# citrus: 0.6655
# fresh: 0.6068
# green: 0.5962
# herbal: 0.5593
# woody: 0.5413
# fruity: 0.5053
# sweet: 0.5018
#
# Top odors for CCCCC1CC1CC (probability > 0.5):
# woody: 0.5513
# waxy: 0.5129
#
# Top odors for CCCC(C=N)CCCC(C)C (probability > 0.5):
# floral: 0.6566
# citrus: 0.6311
# green: 0.6286
# fresh: 0.5448
#
# Top odors for C=CC(C)CCCCCCCCCCC (probability > 0.5):
# waxy: 0.6571
#
# Top odors for C=C(CCC)CCC(CC)CCCC (probability > 0.5):
# waxy: 0.6565
# woody: 0.5156
#
# Top odors for CCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.5969
#
# Top odors for C=CC(C)CC(C)C=C (probability > 0.5):
# floral: 0.6923
# citrus: 0.6269
# herbal: 0.5736
# woody: 0.5571
# sweet: 0.5392
# fresh: 0.5107
#
# Top odors for CCCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.6024
#
# Top odors for CCCCCCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.7389
#
# Top odors for CCCCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.6348
#
# Top odors for CCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.5200
#
# Top odors for C=C(CCC)C(C)CC (probability > 0.5):
# floral: 0.7131
# woody: 0.6497
# sweet: 0.5599
# citrus: 0.5577
# herbal: 0.5332
#
# Top odors for C=CC=CCC(=C)C (probability > 0.5):
# herbal: 0.6232
# citrus: 0.5765
# green: 0.5606
# woody: 0.5204
# sweet: 0.5153
#
# Top odors for CCC(=N)CC(C)C (probability > 0.5):
# green: 0.7367
# citrus: 0.5153
#
# Top odors for C=C(CCCC(C)C)C(C)CC(C)CCCC(C)C (probability > 0.5):
# floral: 0.7182
# woody: 0.6649
# green: 0.5394
#
# Top odors for C=CC(C)CC(CCCCC)CC(C)C (probability > 0.5):
# floral: 0.6946
# woody: 0.5749
# waxy: 0.5580
#
# Top odors for CCCCCCCCCCCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.7524
#
# Top odors for CCCCC(C)CCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6492
#
# Top odors for CCCCCCCCCCCCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.7565
#
# Top odors for CCC1C=CCC(CC)C1 (probability > 0.5):
# citrus: 0.6624
# herbal: 0.6272
# woody: 0.6248
# green: 0.6157
# floral: 0.5636
# fresh: 0.5471
#
# Top odors for C=C(C)CCCCCCC(C)CC (probability > 0.5):
# waxy: 0.5997
# woody: 0.5220
#
# Top odors for C=C(C)CC(C)CC(C)(C)C (probability > 0.5):
# floral: 0.7332
# woody: 0.6956
# herbal: 0.6147
# citrus: 0.5909
# green: 0.5705
# fresh: 0.5024
#
# Top odors for CCCCCC1CCCC(CCC)C1 (probability > 0.5):
# waxy: 0.5631
#
# Top odors for CCCCCCCCCCCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.7281
#
# Top odors for C=CCC(C)C1CCC(=C)CC1 (probability > 0.5):
# woody: 0.6500
# citrus: 0.5447
#
# Top odors for CCCC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.5694
# waxy: 0.5623
# woody: 0.5354
# green: 0.5298
#
# Top odors for CCCCCCCCCCCC(C)CC(C)CCC (probability > 0.5):
# waxy: 0.7036
#
# Top odors for CCC(C)CC(C)(C)C (probability > 0.5):
# woody: 0.6937
# green: 0.6827
# herbal: 0.6029
# floral: 0.5925
# fresh: 0.5446
#
# Top odors for CC(C)CCCCC(C)CC(C)C (probability > 0.5):
# floral: 0.6623
# green: 0.6045
# woody: 0.5624
#
# Top odors for CCC(C)CCN (probability > 0.5):
# cheesy: 0.6826
# fishy: 0.5646
#
# Top odors for C=CC(C)CCC(C)C (probability > 0.5):
# floral: 0.7381
# citrus: 0.6315
# herbal: 0.5571
# fresh: 0.5522
# fruity: 0.5389
# green: 0.5338
# woody: 0.5179
# sweet: 0.5089
#
# Top odors for C=CCC(CCC)CC(C)C (probability > 0.5):
# floral: 0.6906
# waxy: 0.5826
# citrus: 0.5743
# fruity: 0.5638
#
# Top odors for C=CC(C)(C)CC(=C)C (probability > 0.5):
# floral: 0.7423
# woody: 0.6611
# herbal: 0.6412
# citrus: 0.6244
# sweet: 0.5788
# green: 0.5322
# fresh: 0.5107
#
# Top odors for CCCCCCCC(CCCCC)CCCCC (probability > 0.5):
# waxy: 0.7327
#
# Top odors for CC(C)CC1CCC(CC(C)C)C1 (probability > 0.5):
# floral: 0.6839
# green: 0.6759
# woody: 0.6577
# fresh: 0.5265
# herbal: 0.5156
#
# Top odors for CC(C)CCC(CCC(C)C)CC(C)C (probability > 0.5):
# floral: 0.7372
# green: 0.6401
# woody: 0.6251
#
# Top odors for CCC1CC(CC)CC(CC)C1 (probability > 0.5):
# woody: 0.6781
# herbal: 0.6251
# floral: 0.6231
# green: 0.6140
# fresh: 0.5545
# citrus: 0.5259
#
# Top odors for CCCCC(C)C (probability > 0.5):
# green: 0.6399
# herbal: 0.5495
#
# Top odors for C=CC(=C)CCCCCCC (probability > 0.5):
# woody: 0.5345
# waxy: 0.5271
#
# Top odors for CCCCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5995
#
# Top odors for CCCC(C)CC(C)CC (probability > 0.5):
# floral: 0.6582
# green: 0.5848
# citrus: 0.5056
# fresh: 0.5042
#
# Top odors for CCC(C)C=CCCCC=N (probability > 0.5):
# green: 0.6845
# citrus: 0.6168
# fatty: 0.5711
# floral: 0.5233
#
# Top odors for CCC(C)CC(C)CC(C)C (probability > 0.5):
# floral: 0.7548
# green: 0.6775
# woody: 0.5900
# fresh: 0.5569
# citrus: 0.5530
# herbal: 0.5126
#
# Top odors for C=C(C)CC(CCC)CCC (probability > 0.5):
# floral: 0.6741
# woody: 0.6154
# waxy: 0.5531
# sweet: 0.5003
#
# Top odors for C=C1C=CC(CCCCC)=C1 (probability > 0.5):
# woody: 0.6830
# fruity: 0.5088
#
# Top odors for C=CC(C)CC(CC)CCCCC (probability > 0.5):
# waxy: 0.5907
# floral: 0.5897
# woody: 0.5112
#
# Top odors for CCCCCCCCCCCCCC=N (probability > 0.5):
# waxy: 0.6498
# citrus: 0.6397
# fatty: 0.6253
#
# Top odors for C=C(CCC)C(C)C(C)C (probability > 0.5):
# floral: 0.6980
# woody: 0.6691
# herbal: 0.6058
# citrus: 0.6034
# green: 0.5117
# fruity: 0.5110
# fresh: 0.5110
# sweet: 0.5072
#
# Top odors for C=CCC(CCC)CCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7148
# fatty: 0.5227
#
# Top odors for CC(=N)CC(C)C (probability > 0.5):
# green: 0.8034
#
# Top odors for CCCCCC1C=C1CC (probability > 0.5):
# woody: 0.6326
# waxy: 0.5748
#
# Top odors for C=CCCC(=C)C (probability > 0.5):
# citrus: 0.5979
# herbal: 0.5770
# fruity: 0.5431
# gassy: 0.5206
# green: 0.5089
#
# Top odors for CCCCCCCCCC(=N)CCC (probability > 0.5):
# fatty: 0.5964
# citrus: 0.5560
# waxy: 0.5470
#
# Top odors for CCCCC(C)(CC)CCC (probability > 0.5):
# waxy: 0.5807
#
# Top odors for C=C(CCC)C(C)(C)CC (probability > 0.5):
# woody: 0.7151
# floral: 0.6023
# herbal: 0.5470
# sweet: 0.5248
#
# Top odors for CCC(C)C(C)CC(C)(C)C (probability > 0.5):
# woody: 0.7278
# floral: 0.6951
# green: 0.6853
# herbal: 0.5912
# fresh: 0.5291
#
# Top odors for CCC1=CC=CC1 (probability > 0.5):
# citrus: 0.6220
# woody: 0.5356
#
# Top odors for CCCCCCCCCCCCCC(C)CC(C)CCC(C)CC (probability > 0.5):
# waxy: 0.7044
#
# Top odors for C=C(CCCCC)CC(CCCC)C(C)CCC (probability > 0.5):
# woody: 0.6097
# waxy: 0.5992
# floral: 0.5111
#
# Top odors for C=C(CCCCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.6592
#
# Top odors for C=C(CCCCCCCCCCCCCCCCC)C(C)C (probability > 0.5):
# waxy: 0.7234
#
# Top odors for CC(C)C1CCC(C(C)C)C1 (probability > 0.5):
# green: 0.7394
# woody: 0.7305
# floral: 0.6994
# herbal: 0.6506
# citrus: 0.5823
# fresh: 0.5821
#
# Top odors for C=C(CCCCC)CCCCC (probability > 0.5):
# waxy: 0.6787
#
# Top odors for C=CC(C)CCCC(=C)CCCC (probability > 0.5):
# woody: 0.6223
# waxy: 0.5743
#
# Top odors for C=C(C)CCCCCCCCCCCC (probability > 0.5):
# waxy: 0.6862
#
# Top odors for C=CCC(=C)CC (probability > 0.5):
# fruity: 0.6295
# citrus: 0.5914
# herbal: 0.5701
# green: 0.5200
#
# Top odors for CC(C)CCCCC(C)C (probability > 0.5):
# green: 0.6074
# floral: 0.5786
# herbal: 0.5266
#
# Top odors for C=C(C)CC(CC)CCCC (probability > 0.5):
# floral: 0.6907
# woody: 0.6001
# waxy: 0.5652
# sweet: 0.5308
# citrus: 0.5085
#
# Top odors for C=C(CC)CCCC(C)(C)C (probability > 0.5):
# woody: 0.6878
# floral: 0.6632
# sweet: 0.5269
# herbal: 0.5134
#
# Top odors for C=C(CCC)CCCCCCCCCCCCCC (probability > 0.5):
# waxy: 0.7366
#
# Top odors for CCCCCC1=CC(=N)C=C1 (probability > 0.5):
# fruity: 0.6350
# citrus: 0.5207
# floral: 0.5203
# green: 0.5137
#
# Top odors for C=CC(CC)C(C)CCCC (probability > 0.5):
# floral: 0.7311
# woody: 0.5609
# waxy: 0.5512
# citrus: 0.5444
# fruity: 0.5296
#
# Top odors for C=CCCCCCCC=CCCCCC (probability > 0.5):
# waxy: 0.5627
#
# Top odors for C=C(CCCC)C(C)CCC (probability > 0.5):
# woody: 0.6452
# floral: 0.6137
# waxy: 0.5484
#
# Top odors for C=C(C)CCC(C)C(C)CC (probability > 0.5):
# floral: 0.7699
# woody: 0.6353
# citrus: 0.5808
# ...
# waxy: 0.5437
#
# Top odors for CCCC(C)C(C)CC (probability > 0.5):
# floral: 0.7149
# green: 0.6620
# citrus: 0.5937
# herbal: 0.5693
# fresh: 0.5592
# woody: 0.5550
#
# Top odors for CCCC=CCCCCCC (probability > 0.5):
# gassy: 0.5054
# waxy: 0.5002
#
# Top odors for CC(C)CCCC1=CC=CC1 (probability > 0.5):
# woody: 0.6326
# floral: 0.5273
#
# Top odors for CC(C)(C)CC(C)(C)CC(C)(C)C (probability > 0.5):
# woody: 0.7475
# green: 0.6334
# herbal: 0.5506
# camphoreous: 0.5128
#
# Top odors for C=CCCCCCC(C)C(CC)CC (probability > 0.5):
# waxy: 0.6249
#
# Top odors for CCCC(C)CC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6686
# green: 0.5921
# woody: 0.5619
# waxy: 0.5148
#
# Top odors for C=C(C)C1=CNN=C=C1 (probability > 0.5):
# nutty: 0.6169
# roasted: 0.5624
#
# Top odors for CCCCCCCCCC(C)CCCCCC (probability > 0.5):
# waxy: 0.7132
#
# Top odors for CC(C)CC(C)CC(C)C (probability > 0.5):
# green: 0.7167
# floral: 0.7141
# woody: 0.6280
# herbal: 0.6019
# citrus: 0.5826
# fresh: 0.5588
#
# Top odors for C=CCCC(C)C (probability > 0.5):
# green: 0.6162
# fruity: 0.5931
# citrus: 0.5598
# herbal: 0.5237
# fresh: 0.5209
#
# Top odors for CCCCCC(CC)C(C)C (probability > 0.5):
# floral: 0.6201
# green: 0.5535
# waxy: 0.5134
#
# Top odors for CCCCCCCCCCCCCCCCCC(C)CCC(C)CC (probability > 0.5):
# waxy: 0.7454
#
# Top odors for CCCCCCC1CCCC(C)C1 (probability > 0.5):
# waxy: 0.5889
#
# Top odors for CCCCCCCCCC(C)CCC(C)C (probability > 0.5):
# waxy: 0.6600
#
# Top odors for CCCCCCCCCCC(=N)CC(C)C (probability > 0.5):
# waxy: 0.5153
#
# Top odors for C=CCC(C)C(CC)CCC (probability > 0.5):
# floral: 0.7174
# waxy: 0.5688
# citrus: 0.5645
# woody: 0.5257
# fruity: 0.5231
#
# Top odors for C=C(CCCC(C)C)CC(C)(C)C (probability > 0.5):
# woody: 0.7349
# floral: 0.7318
# green: 0.5142
# herbal: 0.5085
#
# Top odors for CCCCCCCCCC(C)C(CCC)CCC (probability > 0.5):
# waxy: 0.6780
#
# Top odors for C=C(CCCCCCC)C(C)C (probability > 0.5):
# waxy: 0.5729
# woody: 0.5592
# floral: 0.5054
#
# Top odors for CCCCCCC1C=C(C)CCC1 (probability > 0.5):
# waxy: 0.5303
#
# Top odors for C=C(CCC)CCCC (probability > 0.5):
# waxy: 0.5944
#
# Top odors for C=CCCC(C)CCCCCCCC (probability > 0.5):
# waxy: 0.6270
#
# Top odors for CCCC=CC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6653
# woody: 0.5198
# citrus: 0.5067
# herbal: 0.5046
# waxy: 0.5029
#
# Top odors for CC(C)CC(C)C(C)C (probability > 0.5):
# green: 0.7533
# herbal: 0.6708
# woody: 0.6548
# floral: 0.6511
# citrus: 0.5749
# fresh: 0.5484
#
# Top odors for CCCCCCC1=CCC=C1 (probability > 0.5):
# waxy: 0.5368
#
# Top odors for CCCCCCCC(C)C (probability > 0.5):
# waxy: 0.5223
#
# Top odors for CC(C)CC1CCC(C)CC1 (probability > 0.5):
# woody: 0.6695
# green: 0.5502
# floral: 0.5023
#
# Top odors for CCC1C=CC(C)C1 (probability > 0.5):
# green: 0.6852
# herbal: 0.6742
# citrus: 0.6654
# woody: 0.6280
# fresh: 0.5410
# floral: 0.5161
#
# Top odors for CCCCCCCCCCC(C)=N (probability > 0.5):
# citrus: 0.6740
# waxy: 0.6157
# fatty: 0.6009
# fruity: 0.5237
#
# Top odors for CCc1ccc(C(C)C)cc1 (probability > 0.5):
# green: 0.6993
# herbal: 0.6004
# floral: 0.5711
# fresh: 0.5651
# woody: 0.5146
#
# Top odors for C=C(CC(C)C)C(C)C (probability > 0.5):
# herbal: 0.6910
# citrus: 0.6419
# woody: 0.6188
# floral: 0.6030
# fresh: 0.5599
# green: 0.5436
# lavender: 0.5092
#
# Top odors for C=CCCCC=C (probability > 0.5):
# citrus: 0.5664
# gassy: 0.5543
# green: 0.5113
#
# Top odors for C=C(C)CCCCCCCCC(C)C (probability > 0.5):
# waxy: 0.6128
#
# Top odors for CCCCC1CC=CC(C)C1 (probability > 0.5):
# citrus: 0.6126
# green: 0.5005
#
# Top odors for CCCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.5679
#
# Top odors for CCCCCCC=C=CCCC(C)C (probability > 0.5):
# citrus: 0.5880
# green: 0.5828
# floral: 0.5363
#
# Top odors for CCCCCC(C)C (probability > 0.5):
# green: 0.5481
#
# Top odors for CCCCC(C)CCCCC1CCCCC1 (probability > 0.5):
# waxy: 0.6649
#
# Top odors for CCCCCCCC1C=CCC1 (probability > 0.5):
# waxy: 0.5882
#
# Top odors for C=C1C(=N)C(C)C(C)C1C (probability > 0.5):
# mint: 0.6413
# woody: 0.6319
# herbal: 0.6015
# spicy: 0.5898
#
# Top odors for CCC(C)C(C)C(C)C=N (probability > 0.5):
# green: 0.7149
# floral: 0.6175
# citrus: 0.5459
# sweet: 0.5332
#
# Top odors for C=CC(C)C(CC)CCC(C)C (probability > 0.5):
# floral: 0.7993
# green: 0.5739
# woody: 0.5642
# citrus: 0.5633
# fresh: 0.5296
# fruity: 0.5142
# sweet: 0.5054
#
# Top odors for CC(C)CCCCCCCCCC=N (probability > 0.5):
# citrus: 0.6812
# waxy: 0.6244
# fatty: 0.6144
#
# Top odors for C1CCCCCC1 (probability > 0.5):
# musk: 0.7450
# animal: 0.6078
# amber: 0.5811
# sweet: 0.5811
# woody: 0.5327
# dry: 0.5011
#
# Top odors for C=C(CCC)C1CCC(C(=C)CCC)CC1 (probability > 0.5):
# woody: 0.7659
# waxy: 0.5337
# floral: 0.5198
#
# Top odors for C=C(C)CC(CC)CC (probability > 0.5):
# floral: 0.7586
# citrus: 0.6350
# sweet: 0.5942
# fruity: 0.5701
# woody: 0.5635
# rose: 0.5545
# waxy: 0.5259
# fresh: 0.5120
# herbal: 0.5078
#
# Top odors for CC1=CCCC=C1 (probability > 0.5):
# citrus: 0.6423
# woody: 0.5390
#
# Top odors for C=C1C=CC(C)=C1 (probability > 0.5):
# woody: 0.6947
# herbal: 0.5912
# citrus: 0.5757
# sweet: 0.5188
# fruity: 0.5067
#
# Top odors for C=C(CCCCC)C1CCCCC1 (probability > 0.5):
# waxy: 0.6232
# woody: 0.5135
#
# Top odors for C=C(CCCCCC(C)C)C(C)C (probability > 0.5):
# floral: 0.6593
# woody: 0.6530
#
# Top odors for CC1CCC=CCC=CC=CCCCCCCC1 (probability > 0.5):
# musk: 0.6404
#
# Top odors for CCCCCC(CCCC(C)C)CCCC(C)C (probability > 0.5):
# waxy: 0.6089
#
# Top odors for C=CCC=N (probability > 0.5):
# pungent: 0.7975
# green: 0.7658
# radish: 0.6270
#
# Top odors for CC1=CC(CC(C)C)CC1 (probability > 0.5):
# woody: 0.7304
# citrus: 0.6217
# herbal: 0.5928
# green: 0.5914
# fresh: 0.5788
# floral: 0.5608
#
# Top odors for CC1CC(C)C(C)C1 (probability > 0.5):
# woody: 0.7556
# herbal: 0.6345
# green: 0.5546
# fresh: 0.5410
# camphoreous: 0.5318
#
# Top odors for C=C(CC)CCC (probability > 0.5):
# citrus: 0.5592
# fruity: 0.5132
# sweet: 0.5115
# gassy: 0.5096
#
# Top odors for CC(C)CCCC(C)CC1CCCC1 (probability > 0.5):
# woody: 0.5801
# waxy: 0.5521
# green: 0.5277
#
# Top odors for C=CC(CCCCCC)CCCCCCCC (probability > 0.5):
# waxy: 0.6822
#
# Top odors for C=C=CCCCCCCCCC(C)C (probability > 0.5):
# citrus: 0.6013
#
# Top odors for C=CC1CC1CCCCCCC (probability > 0.5):
# waxy: 0.6153
#
# Top odors for C=C1CCCCCCCCCCCCC(C)C1 (probability > 0.5):
# musk: 0.7543
# animal: 0.5705
# amber: 0.5523
# dry: 0.5368
# woody: 0.5170
#
# Top odors for C=CC(CC)C(=C)CCCC (probability > 0.5):
# woody: 0.6984
# floral: 0.6455
# waxy: 0.5135
# fruity: 0.5086
#
# Top odors for C=C(CCCCCCCCCCC)CCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.6903
#
# Top odors for C=CC(CC)CC (probability > 0.5):
# citrus: 0.6444
# floral: 0.6063
# fruity: 0.5852
# herbal: 0.5396
# green: 0.5378
# fresh: 0.5292
#
# Top odors for C=CCCCC(C)CC(C)(C)C (probability > 0.5):
# floral: 0.7362
# woody: 0.5857
# green: 0.5390
# herbal: 0.5239
# citrus: 0.5053
#
# Top odors for C=C(C)CC(C)CCCC (probability > 0.5):
# floral: 0.7015
# woody: 0.5952
# citrus: 0.5612
# herbal: 0.5370
# sweet: 0.5274
#
# Top odors for CCC(C)(C)CCCC(C)C(C)C (probability > 0.5):
# woody: 0.6854
# floral: 0.6738
# green: 0.6464
# herbal: 0.5331
#
# Top odors for CCC1C=CCCCCCC=CCC1 (probability > 0.5):
# citrus: 0.5307
#
# Top odors for CCC(C)(CC)CCC(C)C (probability > 0.5):
# woody: 0.6370
# green: 0.5651
# floral: 0.5556
#
# Top odors for CC1=CCCC1 (probability > 0.5):
# woody: 0.6736
# citrus: 0.5958
#
# Top odors for C=C(CCCC(C)C)CCC(C)CCCC(C)C (probability > 0.5):
# woody: 0.6472
# floral: 0.6232
# waxy: 0.5447
#
# Top odors for C=C (probability > 0.5):
# ethereal: 0.5364
#
# Top odors for CCCCCC(C)CC(C)CCCCC (probability > 0.5):
# waxy: 0.6316
#
# Top odors for C=C(CCCCCCCCCCCCC)CC(C)C (probability > 0.5):
# waxy: 0.7043
#
# Top odors for CCCCCCCCC (probability > 0.5):
# waxy: 0.5696
# sweet: 0.5067
#
# Top odors for C=C(C)C(C)CCCCC (probability > 0.5):
# floral: 0.6569
# woody: 0.6086
# citrus: 0.5578
# sweet: 0.5409
# herbal: 0.5249
#
# Top odors for CCCCCC(=N)CC(C)CCCCC (probability > 0.5):
# waxy: 0.5226
#
# Top odors for C=C(CCCC)CCCCCCCC (probability > 0.5):
# waxy: 0.7072
#
# Top odors for CCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.6683
#
# Top odors for CCCC(C)CC1=CCCCC1 (probability > 0.5):
# woody: 0.6202
#
# Top odors for CC1C=CC=CCCCCCCCCCC=CC1 (probability > 0.5):
# musk: 0.6018
#
# Top odors for CC1CCCC(C)C1 (probability > 0.5):
# woody: 0.7289
# amber: 0.5920
# musk: 0.5633
#
# Top odors for C=CC(CC)CCC (probability > 0.5):
# citrus: 0.5965
# floral: 0.5606
# fruity: 0.5157
# herbal: 0.5095
# waxy: 0.5012
#
# Top odors for C=CCC(C)CC(C)C (probability > 0.5):
# floral: 0.7029
# citrus: 0.6399
# fresh: 0.5733
# fruity: 0.5710
# green: 0.5428
# herbal: 0.5322
# rose: 0.5101
# sweet: 0.5095
#
# Top odors for C=C(C)CCCCCCCCC (probability > 0.5):
# waxy: 0.6279
#
# Top odors for CCCCCCCCCC(C)C(C)(C)C (probability > 0.5):
# waxy: 0.6156
#
# Top odors for CC(C)CCCC(C)(C)CN (probability > 0.5):
# woody: 0.6110
#
# Top odors for CCCC(C)C=N (probability > 0.5):
# green: 0.8520
#
# Top odors for CCCC(C)C1=CC=C(C)C1 (probability > 0.5):
# woody: 0.7614
# floral: 0.5279
# sweet: 0.5150
#
# Top odors for CCCCC=CCCCCC (probability > 0.5):
# gassy: 0.5059
# waxy: 0.5026
#
# Top odors for CCCCCCCCCCC1CCC(C)C1 (probability > 0.5):
# waxy: 0.7211
#
# Top odors for CC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6520
# green: 0.5863
# woody: 0.5576
#
# Top odors for CCCC(C=N)CCC (probability > 0.5):
# green: 0.7142
# citrus: 0.5741
# fatty: 0.5120
# floral: 0.5102
#
# Top odors for CCC1CCCC(C)C1 (probability > 0.5):
# woody: 0.7018
# amber: 0.5133
#
# Top odors for CCCCC1=CC=C(CC)C1 (probability > 0.5):
# woody: 0.6500
# waxy: 0.5347
#
# Top odors for CCCCCC1CC1CC (probability > 0.5):
# waxy: 0.5855
#
# Top odors for C=C(CCCCC)CCCCCC (probability > 0.5):
# waxy: 0.6938
#
# Top odors for C=CC(CC)C(C)CCC (probability > 0.5):
# floral: 0.7642
# citrus: 0.5834
# fruity: 0.5523
# woody: 0.5474
# waxy: 0.5329
# sweet: 0.5119
# fresh: 0.5093
# green: 0.5069
#
# Top odors for C=C(CC)CC1CCCCCCCCCCC1 (probability > 0.5):
#
# Top odors for CCCCC(C)C(CC)CC (probability > 0.5):
# floral: 0.6790
# green: 0.5541
# waxy: 0.5541
# woody: 0.5211
#
# Top odors for C=CCCCCCC=CC (probability > 0.5):
# citrus: 0.5355
# gassy: 0.5272
#
# Top odors for C=C1CCCC(CCCCCCCCCCCCC)C1 (probability > 0.5):
# waxy: 0.7222
#
# Top odors for CCCCC1CCCCCCCCCCC1 (probability > 0.5):
# sweet: 0.5120
#
# Top odors for C=C(CCC)CCCCCCCCC(C)CCC (probability > 0.5):
# waxy: 0.6941
#
# Top odors for CCCCCCCCCCC(CCC)CCC (probability > 0.5):
# waxy: 0.7321
#
# Top odors for CCC1CC=CC1 (probability > 0.5):
# citrus: 0.5935
# woody: 0.5140
#
# Top odors for C=CC(C)(C)C (probability > 0.5):
# green: 0.7040
# citrus: 0.6428
# fresh: 0.6122
# herbal: 0.5890
# floral: 0.5139
#
# Top odors for CC(C)C1=CCC=C1 (probability > 0.5):
# herbal: 0.7311
# woody: 0.6530
# citrus: 0.6310
# green: 0.6251
# fresh: 0.5975
# spicy: 0.5247
# terpenic: 0.5057
#
# Top odors for C=CCCC(C)(C)CC (probability > 0.5):
# floral: 0.5885
# citrus: 0.5710
# herbal: 0.5444
# sweet: 0.5153
# green: 0.5059
#
# Top odors for CCCCCCC(C)CC(C)C (probability > 0.5):
# waxy: 0.5422
#
# Top odors for C=C(CCCC)CCC(C)C (probability > 0.5):
# woody: 0.5918
# waxy: 0.5819
# floral: 0.5581
#
# Top odors for CCCCC1CC1CCC (probability > 0.5):
# waxy: 0.5687
#
# Top odors for C=CCCCC(C)CCCC(C)C (probability > 0.5):
# waxy: 0.5590
# floral: 0.5335
#
# Top odors for C=CC1C(C)CCC1C(C)C (probability > 0.5):
# herbal: 0.6608
# citrus: 0.6540
# green: 0.6389
# woody: 0.6371
# fresh: 0.6184
# floral: 0.5446
#
# Top odors for C1=CC1 (probability > 0.5):
#
# Top odors for C=CCCC(C)CCCC(C)CC (probability > 0.5):
# waxy: 0.5738
# floral: 0.5201
#
# Top odors for CCC(CC)CC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6925
# green: 0.5642
# waxy: 0.5543
# woody: 0.5496
#
# Top odors for C=CCC(CC)CCCCC (probability > 0.5):
# waxy: 0.6228
# fatty: 0.5216
#
# Top odors for CCCCCCCC(C)CCC1=CC=CC1 (probability > 0.5):
# waxy: 0.6054
#
# Top odors for C=C(C)CCCC=C=CCCCCCC (probability > 0.5):
# citrus: 0.5913
# floral: 0.5140
# herbal: 0.5096
# green: 0.5048
#
# Top odors for CCC(C)C1CCCCC1 (probability > 0.5):
# woody: 0.6130
#
# Top odors for C=CC(C)CC (probability > 0.5):
# green: 0.6759
# fruity: 0.5774
# fresh: 0.5510
# herbal: 0.5434
# citrus: 0.5401
#
# Top odors for C=CC(C)CCCC(C)CCCC(C)C (probability > 0.5):
# floral: 0.6879
# woody: 0.5865
# waxy: 0.5339
# green: 0.5058
#
# Top odors for C=C(CCCC)CCCCC(C)CCCC (probability > 0.5):
# waxy: 0.6799
#
# Top odors for CC(C)CCC1CCCCC1 (probability > 0.5):
# woody: 0.5323
#
# Top odors for C=C(C=N)CCCC (probability > 0.5):
# green: 0.6858
# fatty: 0.5379
#
# Top odors for C=C(C)C1CCC(C)C(C)C1 (probability > 0.5):
# woody: 0.7938
# citrus: 0.6499
# herbal: 0.6241
# fresh: 0.5765
# sweet: 0.5685
# terpenic: 0.5565
# pine: 0.5069
# spicy: 0.5044
#
# Top odors for CCCCC(C)(C)C (probability > 0.5):
# green: 0.6458
# woody: 0.5872
# herbal: 0.5622
# fresh: 0.5148
# camphoreous: 0.5001
#
# Top odors for CCC(C)CCC(C)CC(C)CC (probability > 0.5):
# floral: 0.7056
# green: 0.5881
# woody: 0.5694
# waxy: 0.5345
#
# Top odors for C=C(C)C1CC1CCCCCCC (probability > 0.5):
# woody: 0.6640
# waxy: 0.5800
# floral: 0.5473
#
# Top odors for CCC(C)CC1=C=C=C(C(C)(C)C)C=C1 (probability > 0.5):
# woody: 0.6756
# herbal: 0.6418
# citrus: 0.6214
# fresh: 0.6052
# green: 0.5459
# floral: 0.5328
# sweet: 0.5116
# terpenic: 0.5017
#
# Top odors for C=C=C=CCCCCCCCCCC (probability > 0.5):
# green: 0.7512
# citrus: 0.5125
#
# Top odors for C=C(CCCCCCC)C(C)CC (probability > 0.5):
# waxy: 0.6263
# woody: 0.5566
#
# Top odors for CCCCCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7479
#
# Top odors for C=C(C)CC(C)(CC)CCC(C)CC (probability > 0.5):
# floral: 0.7518
# woody: 0.7111
# green: 0.5136
# sweet: 0.5125
#
# Top odors for CCCC1C=CCC(C)C1 (probability > 0.5):
# citrus: 0.6310
# green: 0.5747
# woody: 0.5363
# herbal: 0.5182
#
# Top odors for C=C(C(C)C)C(C)C (probability > 0.5):
# herbal: 0.7577
# mint: 0.6430
# citrus: 0.6119
# green: 0.6007
# camphoreous: 0.5925
# fresh: 0.5627
# woody: 0.5523
# spicy: 0.5385
# fruity: 0.5155
#
# Top odors for CCCCCCCC1CC1C(C)C (probability > 0.5):
# waxy: 0.5888
# woody: 0.5256
# oily: 0.5011
#
# Top odors for CCC1=CC(=N)C=C1CC (probability > 0.5):
# fruity: 0.6536
# woody: 0.5583
#
# Top odors for CC(C)CC1CCCC1C (probability > 0.5):
# woody: 0.6874
# green: 0.6309
# floral: 0.5898
# fresh: 0.5317
# herbal: 0.5243
#
# Top odors for CCCCCCCCCC(C)CCCCC (probability > 0.5):
# waxy: 0.7024
#
# Top odors for CC(C)CCC(C)C(C)(C)C (probability > 0.5):
# woody: 0.7201
# floral: 0.6741
# green: 0.6687
# herbal: 0.6011
# fresh: 0.5391
# citrus: 0.5257
#
# Top odors for CCC=CCCCC(C)C (probability > 0.5):
# citrus: 0.5507
# herbal: 0.5030
#
# Top odors for C=C(C)CC(C)CCC (probability > 0.5):
# floral: 0.7299
# citrus: 0.6073
# woody: 0.5914
# herbal: 0.5643
# sweet: 0.5400
#
# Top odors for C=C1CCC(CC)C1 (probability > 0.5):
# woody: 0.6482
# citrus: 0.5562
#
# Top odors for C=C(CCC)C(=C)C(C)CC (probability > 0.5):
# woody: 0.7723
# floral: 0.6692
# sweet: 0.5031
#
# Top odors for CCCCC(C(C)C)C(C)CC(C)C (probability > 0.5):
# floral: 0.7726
# green: 0.6898
# woody: 0.6145
# fresh: 0.5437
# herbal: 0.5074
# citrus: 0.5055
#
# Top odors for C=C(C)C(=C)CCC (probability > 0.5):
# woody: 0.6906
# floral: 0.6481
# fruity: 0.6019
# sweet: 0.5750
# herbal: 0.5544
# citrus: 0.5404
#
# Top odors for C=C(CCC(C)CC)CC(C)CCC (probability > 0.5):
# floral: 0.6656
# woody: 0.6476
# waxy: 0.5586
#
# Top odors for CCCCCC(CC)C1CCC(C)CC1 (probability > 0.5):
# waxy: 0.6006
#
# Top odors for C=CCC(C)CCCC(C)(C)C (probability > 0.5):
# floral: 0.7420
# woody: 0.5873
# green: 0.5332
# herbal: 0.5177
# citrus: 0.5131
#
# Top odors for C=C=C=C (probability > 0.5):
# pungent: 0.7194
# ethereal: 0.6051
# sweet: 0.5555
# sharp: 0.5176
#
# Top odors for CCCCCCCC(C)C(CC)CC (probability > 0.5):
# waxy: 0.6384
#
# Top odors for C=C(CC)CCCC (probability > 0.5):
# waxy: 0.5184
#
# Top odors for CCC(C)(C)CC(C)C (probability > 0.5):
# woody: 0.6793
# green: 0.6722
# herbal: 0.6103
# camphoreous: 0.5532
# fresh: 0.5473
# floral: 0.5169
#
# Top odors for C=CCCC(C)C(C)C (probability > 0.5):
# floral: 0.7166
# citrus: 0.6508
# fruity: 0.6022
# fresh: 0.5784
# herbal: 0.5582
# green: 0.5480
# rose: 0.5248
# sweet: 0.5084
#
# Top odors for CC=C=CCCCC(C)CCCCCCC (probability > 0.5):
# citrus: 0.5837
# floral: 0.5304
#
# Top odors for CC1=CCC=C1 (probability > 0.5):
# citrus: 0.6384
# woody: 0.5559
# herbal: 0.5126
#
# Top odors for CCCCCC(C)CC=N (probability > 0.5):
# green: 0.6862
# citrus: 0.6495
# fatty: 0.5625
#
# Top odors for C=C(CC1=CCCCC1)CC(C)C (probability > 0.5):
# woody: 0.7964
# floral: 0.6868
# sweet: 0.5170
#
# Top odors for C=CCCCC(CC)CC (probability > 0.5):
# waxy: 0.6058
# citrus: 0.5691
#
# Top odors for CCCCCCC(CC)CC (probability > 0.5):
# waxy: 0.6495
#
# Top odors for CCCC(C)CCC1CCCCC1 (probability > 0.5):
# waxy: 0.5552
#
# Top odors for C=CCCCCCCCCCCCCC(C)CC (probability > 0.5):
# waxy: 0.7099
#
# Top odors for C=CCCCCC (probability > 0.5):
# gassy: 0.5716
# citrus: 0.5117
#
# Top odors for CCCCCC(C=N)C=N (probability > 0.5):
# green: 0.7357
#
# Top odors for C=CC(CC)C(C)CCCCCCCCC (probability > 0.5):
# waxy: 0.6256

# %%
import os 

odor_counts = Counter(all_top_odors)

plt.figure(figsize=(12, 6))
odors, counts = zip(*odor_counts.most_common(20))  
plt.bar(odors, counts)
plt.title("Top Predicted Odors Across All Molecules")
plt.xlabel("Odor Labels")
plt.ylabel("Count in Top 10 Predictions")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_folder = '../../figures/VGAE/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300, 600, 1200]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_ten_{dpi}dpi.png", dpi=dpi, bbox_inches='tight')
plt.show()


print("\nCounts of odors in top 10 predictions across all molecules:")
for odor, count in odor_counts.most_common():
    print(f"{odor}: {count}")

# Printing the list of problematic SMILES
print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Counts of odors in top 10 predictions across all molecules:
# waxy: 743
# woody: 659
# floral: 530
# green: 519
# citrus: 491
# herbal: 342
# fresh: 246
# sweet: 212
# fruity: 168
# fatty: 98
# musk: 51
# gassy: 36
# dry: 33
# amber: 32
# animal: 31
# spicy: 22
# camphoreous: 21
# mint: 19
# pungent: 19
# rose: 16
# fishy: 15
# terpenic: 14
# ethereal: 13
# cheesy: 9
# meaty: 8
# musty: 7
# radish: 7
# vegetable: 6
# lemon: 6
# fermented: 4
# pine: 4
# lavender: 4
# balsamic: 3
# muguet: 3
# earthy: 3
# odorless: 3
# aldehydic: 3
# cooling: 2
# oily: 2
# sharp: 2
# nutty: 2
# roasted: 2
# grapefruit: 1
# tropical: 1
# cedar: 1
# alcoholic: 1
# solvent: 1
# popcorn: 1
# cocoa: 1
#
# Problematic SMILES that caused errors:

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt

odor_counts = Counter(all_top_odors)
total_predictions = sum(odor_counts.values())  


percentages = [(count / total_predictions) * 100 for count in odor_counts.values()]


sorted_odors_percentages = sorted(zip(odor_counts.keys(), percentages), key=lambda x: x[1], reverse=True)


top_20_odors_percentages = sorted_odors_percentages[:20]
top_20_odors, top_20_percentages = zip(*top_20_odors_percentages)


plt.figure(figsize=(15, 8))  


bars = plt.bar(top_20_odors, top_20_percentages, edgecolor='black')
ax = plt.gca()  
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)  

plt.title("Most Common Odor Predictions (VGAE)", fontsize=33, fontweight='bold', pad=20)
plt.xlabel("Odor Labels", fontsize=33, fontweight='bold', labelpad=15)
plt.ylabel("(%) of Predictions", fontsize=29, fontweight='bold', labelpad=10)

plt.xticks(rotation=45, ha='right', fontsize=28, fontweight='bold')
plt.yticks(fontsize=26, fontweight='bold')


plt.tight_layout()


output_folder = '../../figures/VGAE/Top ten odor/'  
os.makedirs(output_folder, exist_ok=True)  
dpi_values = [300]  
for dpi in dpi_values:
    plt.savefig(f"{output_folder}top_odor_per.png", dpi=dpi, bbox_inches='tight')


plt.show()


print("\nPercentages of top 20 odors in top 10 predictions across all molecules:")
for odor, percentage in zip(top_20_odors, top_20_percentages):
    print(f"{odor}: {percentage:.2f}%")


print("\nProblematic SMILES that caused errors:")
for smiles in problematic_smiles:
    print(smiles)
# Out:
# Percentages of top 20 odors in top 10 predictions across all molecules:
# waxy: 16.82%
# woody: 14.92%
# floral: 12.00%
# green: 11.75%
# citrus: 11.12%
# herbal: 7.74%
# fresh: 5.57%
# sweet: 4.80%
# fruity: 3.80%
# fatty: 2.22%
# musk: 1.15%
# gassy: 0.82%
# dry: 0.75%
# amber: 0.72%
# animal: 0.70%
# spicy: 0.50%
# camphoreous: 0.48%
# mint: 0.43%
# pungent: 0.43%
# rose: 0.36%
#
# Problematic SMILES that caused errors:
